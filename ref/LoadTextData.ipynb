# %%
import os
import io
import struct
from typing import List, Tuple, Optional
from enum import Enum
import pandas as pd

from blowfish import Blowfish

# %%
class PackEntryType(Enum):
  Nop = 0
  Folder = 1
  File = 2

# %%
def generate_final_blowfish_key(password: str, salt: bytes) -> bytes:
    """
    Reproduces the 'GenerateFinalBlowfishKey' logic in C#.
    """
    # 1) Limit key length to max of 56
    plain_key_length = min(len(password), 56)

    # 2) Convert password to ASCII bytes
    a_key = password.encode("ascii")

    # 3) Create a 56-byte base key buffer
    b_key = bytearray(56)
    
    # Copy salt into b_key
    # Equivalent to `Array.ConstrainedCopy(salt, 0, bKey, 0, salt.Length)`
    b_key[:len(salt)] = salt

    # 4) Generate the final blowfish key by XOR-ing
    #    the ASCII password bytes with the corresponding part of b_key.
    bf_key = bytearray(plain_key_length)
    for x in range(plain_key_length):
        bf_key[x] = a_key[x] ^ b_key[x]

    return bytes(bf_key)

# %%
def read_string_with_length(stream, byte_count: int) -> str:
    """
    Read 'byte_count' bytes, then decode using self._encoding,
    stopping at the first 0 (null terminator) if present.
    """
    buffer = stream.read(byte_count)

    # Find null terminator offset (if any)
    terminator_offset = byte_count
    for i in range(byte_count):
        if buffer[i] == 0:
            terminator_offset = i
            break

    return buffer[:terminator_offset].decode('ascii', errors='replace')

# %%
data_pk2_path = os.path.join(os.getcwd(), 'data', 'Data.pk2')
media_pk2_path = os.path.join(os.getcwd(), 'data', 'Media.pk2')
print(data_pk2_path)
print(media_pk2_path)
# Out:
# c:\Users\htdun\Desktop\workspace\pk2-extractor\data\Data.pk2
# c:\Users\htdun\Desktop\workspace\pk2-extractor\data\Media.pk2

# %%
pk2key = '169841'
salt = [0x03, 0xF8, 0xE4, 0x44, 0x88, 0x99, 0x3F, 0x64, 0xFE, 0x35]

# %%
key = generate_final_blowfish_key(pk2key, bytes(salt))
key
# Out:
# b'2\xce\xdd|\xbc\xa8'

# %%
blowfish = Blowfish()
blowfish.Initialize(key)

# %%
_media_file_stream = open(media_pk2_path, 'rb')

# %%
signature = _media_file_stream.read(30)
version =  struct.unpack('<i', _media_file_stream.read(4))[0]
encrypted = _media_file_stream.read(1)
encryption_checksum = _media_file_stream.read(16)
payload = _media_file_stream.read(205)

# %%
Header = {
    'signature': signature,
    'version': version,
    'encrypted': encrypted,
    'encryption_checksum': encryption_checksum,
    'payload': payload
}

# %%
blowfish_checksum_decoded = "Joymax Pak File"

# %%
if blowfish and encrypted == b'\x01':
    temp_checksum = blowfish.Encode(blowfish_checksum_decoded.encode('ascii'))
    if temp_checksum is None or temp_checksum[0] != encryption_checksum[0] or temp_checksum[1] != encryption_checksum[1] or temp_checksum[2] != encryption_checksum[2]:
        raise Exception('Failed to open JoymaxPackFile: The password or salt is wrong.')

# %%
def read_block_at(position: int):
    _media_file_stream.seek(position, io.SEEK_SET)
    buffer = _media_file_stream.read(128 * 20)
    if blowfish is not None:
      entry_buffer = io.BytesIO(blowfish.Decode(buffer))
    else:
      entry_buffer = io.BytesIO(buffer)

    entries = []
    for _ in range(20):
      entry = {
        "Type": PackEntryType(entry_buffer.read(1)[0]),
        "Name": read_string_with_length(entry_buffer, 89).rstrip('\0'),
        "CreationTime": struct.unpack('<q', entry_buffer.read(8))[0],
        "ModifyTime": struct.unpack('<q', entry_buffer.read(8))[0],
        "DataPosition": struct.unpack('<q', entry_buffer.read(8))[0],
        "DataSize": struct.unpack('<i', entry_buffer.read(4))[0],
        "NextBlock": struct.unpack('<q', entry_buffer.read(8))[0],
        "Payload": entry_buffer.read(2)
      }
      entries.append(entry)
      # print(entry)

    return {
      "Position": position,
      "Entries": entries
    }


def read_blocks_at(position: int):
    result = []

    block = read_block_at(position)
    result.append(block)

    if block["Entries"][19]["NextBlock"] > 0:
        result.extend(read_blocks_at(block["Entries"][19]["NextBlock"]))

    return result

# %%
Root = read_blocks_at(256)

# %%
blocks_in_memory = {
  "": Root
}

# %%
blocks_in_memory
# Out:
# {'': [{'Position': 256,
#    'Entries': [{'Type': <PackEntryType.Folder: 1>,
#      'Name': '.',
#      'CreationTime': 133336205048819447,
#      'ModifyTime': 133336205048819447,
#      'DataPosition': 256,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'acobject',
#      'CreationTime': 133336205048829450,
#      'ModifyTime': 133336205048829450,
#      'DataPosition': 2816,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'config',
#      'CreationTime': 133336205049179438,
#      'ModifyTime': 133336205049179438,
#      'DataPosition': 35136,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Effect',
#      'CreationTime': 133336205049679437,
#      'ModifyTime': 133336205049679437,
#      'DataPosition': 41896,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Fonts',
#      'CreationTime': 133336205051829374,
#      'ModifyTime': 133336205051829374,
#      'DataPosition': 401456,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'icon',
#      'CreationTime': 133336205051849373,
#      'ModifyTime': 133336205051849373,
#      'DataPosition': 404328,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'icon64',
#      'CreationTime': 133336206109740779,
#      'ModifyTime': 133336206109740779,
#      'DataPosition': 35750058,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'interface',
#      'CreationTime': 133336206200969178,
#      'ModifyTime': 133336206200969178,
#      'DataPosition': 49794542,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Launcher',
#      'CreationTime': 133336207373584329,
#      'ModifyTime': 133336207373584329,
#      'DataPosition': 530412246,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Launcher_Europe',
#      'CreationTime': 133336207379694215,
#      'ModifyTime': 133336207379694215,
#      'DataPosition': 533020067,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'minimap',
#      'CreationTime': 133336207380240850,
#      'ModifyTime': 133336207380240850,
#      'DataPosition': 533900707,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'minimap_d',
#      'CreationTime': 133336208820638962,
#      'ModifyTime': 133336208820638962,
#      'DataPosition': 770423083,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'resinfo',
#      'CreationTime': 133336209064184553,
#      'ModifyTime': 133336209064184553,
#      'DataPosition': 868076619,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'res_ui',
#      'CreationTime': 133336209080076171,
#      'ModifyTime': 133336209080076171,
#      'DataPosition': 870428615,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'script',
#      'CreationTime': 133336209089071935,
#      'ModifyTime': 133336209089071935,
#      'DataPosition': 877210479,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'server_dep',
#      'CreationTime': 133336209091748828,
#      'ModifyTime': 133336209091748828,
#      'DataPosition': 886879815,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'silk.dat',
#      'CreationTime': 133287856801795247,
#      'ModifyTime': 127918116330156250,
#      'DataPosition': 1017317431,
#      'DataSize': 768,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'type.txt',
#      'CreationTime': 133336205046882029,
#      'ModifyTime': 133330897532736718,
#      'DataPosition': 1017318199,
#      'DataSize': 423,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'DIVISIONINFO.TXT',
#      'CreationTime': 133336210349991177,
#      'ModifyTime': 133336210349991177,
#      'DataPosition': 1017319424,
#      'DataSize': 57,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'SV.T',
#      'CreationTime': 133795825379609632,
#      'ModifyTime': 133795825379609632,
#      'DataPosition': 1017319481,
#      'DataSize': 1024,
#      'NextBlock': 1017320505,
#      'Payload': b'\x00\x00'}]},
#   {'Position': 1017320505,
#    'Entries': [{'Type': <PackEntryType.File: 2>,
#      'Name': 'GATEPORT.TXT',
#      'CreationTime': 133336210351001190,
#      'ModifyTime': 133336210351001190,
#      'DataPosition': 1017323065,
#      'DataSize': 8,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'}]}]}

# %%
server_dep = os.path.join('server_dep', 'silkroad', 'textdata')
server_dep
# Out:
# 'server_dep\\silkroad\\textdata'

# %%
data_text = dict()

# %% [markdown]
# ## TextUISystem.txt

# %%
text_ui_system = os.path.join(server_dep, 'TextUISystem.txt')
text_ui_system
# Out:
# 'server_dep\\silkroad\\textdata\\TextUISystem.txt'

# %%
def get_entry_buffer(file_path: str) -> Optional[dict]:
  parent_folder_path = os.path.dirname(file_path)
  file_name = os.path.basename(file_path)
  if parent_folder_path not in blocks_in_memory:
    paths = parent_folder_path.split(os.path.sep)
    blocks = blocks_in_memory[""]
    current_path = ""

    for sub_folder_name in paths:
        for block in blocks:
            entries = block["Entries"]
            entry = next((e for e in entries if e["Name"] == sub_folder_name and e["Type"] == PackEntryType.Folder), None)
            if entry is None:
                continue
            
            current_path = os.path.join(current_path, entry["Name"])
            if current_path in blocks_in_memory:
                blocks = blocks_in_memory[current_path]
                break
            
            blocks = read_blocks_at(entry["DataPosition"])
            blocks_in_memory[current_path] = blocks
            break
        
  root = blocks_in_memory[parent_folder_path]
  entry = None
  for entries in root:
    entry = next((x for x in entries["Entries"] if x["Name"] == file_name.lower()), None)
    if entry:
      break

  _media_file_stream.seek(entry["DataPosition"], io.SEEK_SET)
  # _media_file_stream.read(entry["DataSize"])
  buffer = io.BytesIO(_media_file_stream.read(entry["DataSize"])) 

  return buffer
   

def get_lines(file_path: str) -> List[Tuple[str, int]]:

  buffer = get_entry_buffer(file_path)

  text = buffer.read().decode('utf-16', errors="replace")
  lines = text.split('\r\n')
  return lines

# %%
text_ui_system_files = get_lines(text_ui_system)
text_ui_system_files
# Out:
# ['TextUISystem_100.txt',
#  'TextUISystem_1000.txt',
#  'TextUISystem_1100.txt',
#  'TextUISystem_1200.txt',
#  'TextUISystem_1300.txt',
#  'TextUISystem_1400.txt',
#  'TextUISystem_1500.txt',
#  'TextUISystem_1600.txt',
#  'TextUISystem_1700.txt',
#  'TextUISystem_1800.txt',
#  'TextUISystem_1900.txt',
#  'TextUISystem_200.txt',
#  'TextUISystem_2000.txt',
#  'TextUISystem_2100.txt',
#  'TextUISystem_2200.txt',
#  'TextUISystem_2300.txt',
#  'TextUISystem_2400.txt',
#  'TextUISystem_2500.txt',
#  'TextUISystem_2600.txt',
#  'TextUISystem_2700.txt',
#  'TextUISystem_2800.txt',
#  'TextUISystem_2900.txt',
#  'TextUISystem_300.txt',
#  'TextUISystem_3000.txt',
#  'TextUISystem_3100.txt',
#  'TextUISystem_3200.txt',
#  'TextUISystem_3300.txt',
#  'TextUISystem_3400.txt',
#  'TextUISystem_3500.txt',
#  'TextUISystem_3600.txt',
#  'TextUISystem_3700.txt',
#  'TextUISystem_3800.txt',
#  'TextUISystem_3900.txt',
#  'TextUISystem_400.txt',
#  'TextUISystem_4000.txt',
#  'TextUISystem_4100.txt',
#  'TextUISystem_4200.txt',
#  'TextUISystem_4300.txt',
#  'TextUISystem_4400.txt',
#  'TextUISystem_4500.txt',
#  'TextUISystem_4600.txt',
#  'TextUISystem_4700.txt',
#  'TextUISystem_4800.txt',
#  'TextUISystem_4900.txt',
#  'TextUISystem_500.txt',
#  'TextUISystem_5000.txt',
#  'TextUISystem_5100.txt',
#  'TextUISystem_5200.txt',
#  'TextUISystem_5300.txt',
#  'TextUISystem_5400.txt',
#  'TextUISystem_5500.txt',
#  'TextUISystem_5600.txt',
#  'TextUISystem_5700.txt',
#  'TextUISystem_5800.txt',
#  'TextUISystem_5900.txt',
#  'TextUISystem_600.txt',
#  'TextUISystem_6000.txt',
#  'TextUISystem_6100.txt',
#  'TextUISystem_6200.txt',
#  'TextUISystem_6300.txt',
#  'TextUISystem_6400.txt',
#  'TextUISystem_700.txt',
#  'TextUISystem_800.txt',
#  'TextUISystem_900.txt',
#  '']

# %%
text_ui_system_100 = os.path.join(server_dep, 'TextUISystem_100.txt')
text_ui_system_100
# Out:
# 'server_dep\\silkroad\\textdata\\TextUISystem_100.txt'

# %%
for xxx in text_ui_system_files:
  file_name = os.path.join(server_dep, xxx)
  lines = get_lines(file_name)
  for idx, line in enumerate(lines):
    values = line.split('\t')
    if len(values) < 11:
      continue
    Service = values[0]
    name_str_id = values[2]
    Data = values[10]
    data_text[name_str_id] = {
      "Service": Service,
      "Data": Data
    }

# %%
data_text
# Out:
# {'UIC_STT_FONTNAME': {'Service': '1', 'Data': 'Tahoma'},
#  'UIIS_STT_MSG_INSTALL_START': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa"'},
#  'UIIS_STT_MSG_INSTALL_FOLDER': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa" vào thư mục sau'},
#  'UIIS_STT_MSG_INSTALL_END': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt thành công'},
#  'UIIS_STT_INSTALL_FOLDER': {'Service': '1', 'Data': 'Thư mục cài đặt'},
#  'UIIS_STT_INSTALL_FILE': {'Service': '1', 'Data': 'File cài đặt'},
#  'UIIS_CTL_INSTALL': {'Service': '1', 'Data': 'Cài đặt'},
#  'UIIS_CTL_FIND_FOLDER': {'Service': '1', 'Data': 'Tìm kiếm'},
#  'UIIS_CTL_START': {'Service': '1', 'Data': 'Bắt đầu'},
#  'UIIS_CTL_CANCEL': {'Service': '1', 'Data': 'Hủy bỏ'},
#  'UIIS_CTL_CONFIRM': {'Service': '1', 'Data': 'Đồng ý'},
#  'UIIS_MSG_ALREADY_INSTALL': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt'},
#  'UIIS_MSG_UNPACK_ZIP': {'Service': '1',
#   'Data': 'Không thể giải nén Con Đường Tơ Lụa. \\nFile nén bị hỏng.'},
#  'UIIS_MSG_UNPACK_CLOSE': {'Service': '1',
#   'Data': 'Không thể đóng file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_UNPACK_OPEN': {'Service': '1',
#   'Data': 'Không thể mở file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_INSTALL_SPACE': {'Service': '1',
#   'Data': 'Không thể cài đặt do thiếu dung lượng. \\nCần ít nhất %d BYTE dung lượng đĩa'},
#  'UIIS_MSG_BACKBUFFER': {'Service': '1', 'Data': 'Không thể tạo bộ nhớ đệm'},
#  'UIIS_MSG_CHANGE_FOLDER': {'Service': '1',
#   'Data': 'Thư mục cài đặt đã bị thay đổi.\\nKhông thể gỡ bỏ Con Đường Tơ Lụa'},
#  'UIIS_MSG_NOFIND': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa chưa được cài đặt. Việc gỡ bỏ không có tác dụng'},
#  'UIIS_MSG_REMOVE_COMPLETE': {'Service': '1',
#   'Data': 'Tất cả các file đã được xóa bỏ hoàn toàn'},
#  'UIIS_MSG_REMOVE_FAIL': {'Service': '1', 'Data': 'Không thể gỡ bỏ'},
#  'UIIS_STT_DELETE': {'Service': '1', 'Data': 'Xóa thư mục Con Đường Tơ Lụa'},
#  'UIIS_CTL_DELETE': {'Service': '1', 'Data': 'Gỡ bỏ'},
#  'UIIS_CTL_EXIT': {'Service': '1', 'Data': 'Thoát'},
#  'UILM_MSG_PROCESS_ALREADY_EXITS': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đang chạy'},
#  'UILM_MSG_DETECTED_ABNORMAL_PROCESS': {'Service': '1',
#   'Data': 'Phát hiện lỗi chạy chương trình Con Đường Tơ Lụa (Lỗi hệ thống)'},
#  'UILM_MSG_FAILED_LOAD_CLIENT': {'Service': '1',
#   'Data': 'Không thể xác định đặc điểm client. Đang đóng.'},
#  'UILM_MSG_GATEWAY_NOT_IN_SERVICE_CHANNEL': {'Service': '1',
#   'Data': 'Máy chủ đang kiểm tra hoặc không làm việc. Truy cập trang %ssro.vtcgame.vn/ để biết thêm thông tin.'},
#  'UILM_MSG_DRIVER_UPDATE': {'Service': '1',
#   'Data': 'Driver đồ họa của bạn không phải là phiên bản mới nhất. Hãy cập nhật phiên bản mới nhất để xem hình ảnh game đẹp hơn.'},
#  'UILM_MSG_DRIVER_UPDATE_2': {'Service': '1',
#   'Data': 'Không bao giờ xuất hiện lại.'},
#  'UILM_MSG_FAILED_INIT_NETENGINE': {'Service': '1',
#   'Data': 'Không thể khởi chạy NetEngine (Lỗi (%d,%d))'},
#  'UILM_MSG_FAILED_LOAD_VERSION': {'Service': '1',
#   'Data': 'Không thể kiểm tra phiên bản'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_IP': {'Service': '1',
#   'Data': 'Không thể kiểm tra IP kết nối'},
#  'UILM_MSG_INVALID_CONNECT_IP': {'Service': '1',
#   'Data': 'IP kết nối không hợp lệ'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_PORT': {'Service': '1',
#   'Data': 'Không thể kiểm tra cổng kết nối'},
#  'UILM_MSG_INVALID_CONNECT_PORT': {'Service': '1',
#   'Data': 'Cổng kết nối không hợp lệ'},
#  'UILM_MSG_DETECTED_ABNORMAL_DIRECTX': {'Service': '1',
#   'Data': 'DirectX 9.0 chưa được cài đặt hoặc không phải là phiên bản 9.0b. Con Đường Tơ Lụa cần DirectX9.0b hoặc phiên bản mới hơn'},
#  'UILM_MSG_DETECTED_ABNORMAL_MODULE': {'Service': '1',
#   'Data': 'Không xác định client. Kết thúc.'},
#  'UILM_MSG_DETECTED_PATCH_DIABLE': {'Service': '1',
#   'Data': 'Bạn phải cài đặt toàn bộ phiên bản. Kết nối với trang chủ để download toàn bộ phiên bản.'},
#  'UILM_MSG_DETECTED_PATCH_MANUAL': {'Service': '1',
#   'Data': 'Bạn cần cài đặt thủ công. Vui lòng truy cập trang chủ để tải bản cài thủ công về. Bạn có muốn kết nối đến trang chủ không?'},
#  'UILM_MSG_FAILED_EXECUTE_EXPLORER': {'Service': '1',
#   'Data': 'Không thể chạy Internet Explorer.'},
#  'UILM_MSG_FAILED_PATCH': {'Service': '1',
#   'Data': 'Chưa hoàn thành việc sửa lỗi. Hãy thử lại.[Lỗi số(%d)]'},
#  'UILM_MSG_FAILED_EXECUTE_CLIENT': {'Service': '1',
#   'Data': 'Xin lỗi. Không thể chạy Con Đường Tơ Lụa [Lỗi số(%d)]'},
#  'UILM_MSG_NOTEXITS_REPLACERFILE': {'Service': '1',
#   'Data': 'Không tìm thấy file replacer.exe. Chưa hoàn thành việc sửa lỗi.'},
#  'UILM_MSG_DETECTED_ABNORMAL_REPLACERFILE': {'Service': '1',
#   'Data': 'Không thể sửa lỗi vì file replacer.exe đã bị hỏng [lỗi số (%d)]'},
#  'UILM_MSG_FAILED_LOAD_GATEWAY_INFO': {'Service': '1',
#   'Data': 'Không thể đưa ra thuộc tính kết nối của GateWay [lỗi%d]'},
#  'UILM_STT_DIVISION': {'Service': '1', 'Data': 'Bộ phận'},
#  'UILM_STT_DIVISION_LIST': {'Service': '1', 'Data': 'Danh sách bộ phận'},
#  'UILM_STT_DIVISION_SELECTED': {'Service': '1', 'Data': 'Bộ phận lựa chọn'},
#  'UILM_STT_DIVISION_NAME': {'Service': '1', 'Data': 'Tên bộ phận'},
#  'UILM_STT_FARM': {'Service': '1', 'Data': 'Giải'},
#  'UILM_STT_FARM_LIST': {'Service': '1', 'Data': 'Danh sách giải'},
#  'UILM_STT_FARM_NAME': {'Service': '1', 'Data': 'Tên giải'},
#  'FARM0101': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 01 Yahoo'},
#  'FARM0102': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 01 Yahoo'},
#  'FARM0103': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 01 Yahoo'},
#  'FARM0104': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 01 Yahoo'},
#  'FARM0105': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 01 Yahoo'},
#  'FARM0201': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 02 Yahoo'},
#  'FARM0202': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 02 Yahoo'},
#  'FARM0203': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 02 Yahoo'},
#  'FARM0204': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 02 Yahoo'},
#  'FARM0205': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 02 Yahoo'},
#  'FARM0301': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 03 Yahoo'},
#  'FARM0302': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 03 Yahoo'},
#  'FARM0303': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 03 Yahoo'},
#  'FARM0304': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 03 Yahoo'},
#  'FARM0305': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 03 Yahoo'},
#  'FARM0401': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 04 Yahoo'},
#  'FARM0402': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 04 Yahoo'},
#  'FARM0403': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 04 Yahoo'},
#  'FARM0404': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 04 Yahoo'},
#  'FARM0405': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 04 Yahoo'},
#  'UILM_STT_DIVISION_PING': {'Service': '1', 'Data': 'Ping'},
#  'UILM_STT_DIVISION_CONDITION': {'Service': '1', 'Data': 'Tình trạng'},
#  'DIV01': {'Service': '1', 'Data': 'Bộ phận Yahoo 01'},
#  'DIV02': {'Service': '1', 'Data': 'Bộ phận Yahoo 02'},
#  'DIV03': {'Service': '1', 'Data': 'Bộ phận Yahoo 03'},
#  'DIV04': {'Service': '1', 'Data': 'Bộ phận Yahoo 04'},
#  'DIV05': {'Service': '1', 'Data': 'Bộ phận Yahoo 05'},
#  'DIV06': {'Service': '1', 'Data': 'Bộ phận Yahoo 06'},
#  'DIV07': {'Service': '1', 'Data': 'Bộ phận Yahoo 07'},
#  'DIV08': {'Service': '1', 'Data': 'Bộ phận Yahoo 08'},
#  'DIV09': {'Service': '1', 'Data': 'Bộ phận Yahoo 09'},
#  'DIV10': {'Service': '1', 'Data': 'Bộ phận Yahoo 10'},
#  'UILM_STT_DIVISION_RECOMMENDATION': {'Service': '1', 'Data': 'Đề nghị'},
#  'UILM_STT_DIVISION_NOT_RECOMMENDATION': {'Service': '1',
#   'Data': 'Không đề nghị'},
#  'UILM_MSG_SILKROAD_STARTING_HOME': {'Service': '1',
#   'Data': 'Trang chủ của Con đường tơ lụa đã được đặt làm trang chủ mặc định'},
#  'UILM_MSG_YAHOO_STARTING_HOME': {'Service': '1',
#   'Data': 'Đã thiết đặt xong trang chủ https://sro.vtcgame.vn/'},
#  'UILM_MSG_YAHOO_TOOLBAR': {'Service': '1',
#   'Data': 'Đã thiết đặt xong thanh công cụ yahoo'},
#  'UILM_MSG_SERVICE_CLIENT_ERROR_REINSTALL': {'Service': '1',
#   'Data': 'Client của bạn bị lỗi hoặc đã bị phá huỷ nên không thể kết nối đến máy chủ. Hãy cài lại một client mới.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ download bị ngắt. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CANCEL': {'Service': '1',
#   'Data': 'Kết nới với máy chủ download đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_SELECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Launcher sẽ được khởi động lại.'},
#  'UILM_TEXT_CONFIG_GRAPHIC_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UILM_TEXT_CONFIG_GRAPHIC_NORMAL': {'Service': '1', 'Data': 'Bình thường'},
#  'UILM_TEXT_CONFIG_GRAPHIC_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UILM_TEXT_CONFIG_GRAPHIC_USER_DEF': {'Service': '1', 'Data': 'Không đổi'},
#  'UIIT_STT_ETCKEY': {'Service': '1', 'Data': 'Các phím khác'},
#  'UIIT_STT_MOUSE': {'Service': '1', 'Data': 'Chuột'},
#  'UIIT_STT_MOUSE_RIGHT_BUTTON': {'Service': '1', 'Data': 'Ô Nhớ Chuột'},
#  'UIIT_STT_USE_WHEEL_TO_CHANGE_SIGHT': {'Service': '1',
#   'Data': 'Chuột lăn (đổi góc nhìn) chuột phải (dùng Ô Nhớ)'},
#  'UIIT_STT_USE_WHEEL_TO_USE_SKILL': {'Service': '1',
#   'Data': 'Chuột lăn (dùng Ô Nhớ) chuột phải (đổi góc nhìn)'},
#  'UIIT_STT_ITEM_GET': {'Service': '1', 'Data': 'Nhặt đồ'},
#  'UIIT_STT_REFLECT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng phản xạ'},
#  'UIIT_STT_WATER_DETAIL': {'Service': '1', 'Data': 'Chi tiết nước'},
#  'UIIT_STT_LIGHT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng ánh sáng'},
#  'UIIT_STT_BUMP_MAPPING': {'Service': '1', 'Data': 'ánh xạ va chạm'},
#  'UIIT_STT_ENVIRONMENT_MAPPING': {'Service': '1', 'Data': 'ánh xạ môi trường'},
#  'UIIT_STT_LENS_FLAIR': {'Service': '1', 'Data': 'Độ nhạy của thấu kính'},
#  'UIIT_STT_DYNAMIC_ANIMATION': {'Service': '1', 'Data': 'ảnh động sống động'},
#  'UIIT_STT_WATER_REFLECTION': {'Service': '1', 'Data': 'Phản xạ nước'},
#  'UIIT_STT_FILTERING': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_TEXTER_DETAIL': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_GRAPHIC_QUALITY': {'Service': '1', 'Data': 'Chất lượng đồ họa'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL': {'Service': '1',
#   'Data': 'Người dùng tự chọn'},
#  'UIIT_STT_GRAPHIC_QUALITY_USER_CONTROL': {'Service': '1', 'Data': 'Tự chọn'},
#  'UIIT_STT_METAL_DETAIL': {'Service': '1', 'Data': 'Chất liệu kim loại'},
#  'UIIT_STT_BLOOM_EFFECT': {'Service': '1', 'Data': 'Âm lượng'},
#  'UIIT_STT_GRAPHIC': {'Service': '1', 'Data': 'Đồ họa'},
#  'UIIT_STT_RESOLUTION': {'Service': '1', 'Data': 'Độ phân giải'},
#  'UIIT_STT_LUMINOSITY': {'Service': '1', 'Data': 'Độ sáng tối'},
#  'UIIT_STT_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn'},
#  'UIIT_STT_CHAR_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn nhân vật'},
#  'UIIT_STT_SCENERY_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn bối cảnh'},
#  'UIIT_STT_SHADOW_DETAIL': {'Service': '1', 'Data': 'Chi tiết bóng'},
#  'UIIT_STT_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_MIDDLE': {'Service': '1', 'Data': 'Vừa'},
#  'UIIT_STT_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_VERY_DARK': {'Service': '1', 'Data': 'Rất tối'},
#  'UIIT_STT_DARK': {'Service': '1', 'Data': 'Tối'},
#  'UIIT_STT_NORMAL': {'Service': '1', 'Data': 'Trung bình'},
#  'UIIT_STT_LIGHT': {'Service': '1', 'Data': 'Sáng'},
#  'UIIT_STT_VERY_LIGHT': {'Service': '1', 'Data': 'Rất sáng'},
#  'UIIT_STT_SIGHT_VERY_SMALL': {'Service': '1', 'Data': 'Rất hẹp'},
#  'UIIT_STT_SIGHT_SMALL': {'Service': '1', 'Data': 'Hẹp'},
#  'UIIT_STT_SIGHT_LARGE': {'Service': '1', 'Data': 'Rộng'},
#  'UIIT_STT_SIGHT_VERY_LARGE': {'Service': '1', 'Data': 'Rất rộng'},
#  'UIIT_STT_NONE': {'Service': '1', 'Data': 'Không có'},
#  'UIIT_STT_CIRCLE': {'Service': '1', 'Data': 'Vòng tròn'},
#  'UIIT_STT_DETAIL': {'Service': '1', 'Data': 'Chi tiết'},
#  'UIIT_STT_RANK': {'Service': '1', 'Data': '%d bước'},
#  'UIIT_STT_ON': {'Service': '1', 'Data': 'Bật'},
#  'UIIT_STT_OFF': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_GRAPHIC_QUALITY_MIDDLE': {'Service': '1', 'Data': 'Bình thường'},
#  'UIIT_STT_GRAPHIC_QUALITY_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL1': {'Service': '1', 'Data': 'Đồ họa 1'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL2': {'Service': '1', 'Data': 'Đồ họa 2'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_WAR': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_USER': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_VIDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể thay đổi độ phân giải của game'},
#  'UIIT_STT_VIDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể thay đổi độ sáng của game'},
#  'UIIT_STT_VIDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể thay đổi chất lượng đồ hoạ của game. Tìm đến lựa chọn Video và thiết lập các mức độ cao, trung bình hay thấp. Tốc độ tải trò chơi sẽ thay đổi tuỳ theo các mức chất lượng được thiết lập.'},
#  'UIIT_STT_VIDIO_TTDESC_04': {'Service': '1',
#   'Data': 'Có thể thay đổi mức độ chi biết bóng. Tốc độ tải game có thể bị chậm nếu chi tiết bóng được đặt ở mức cao.'},
#  'UIIT_STT_VIDIO_TTDESC_05': {'Service': '1',
#   'Data': 'Khi thiết lập khung cảnh được đặt ở mức cao, có thể nhìn thấy nhiều hình ảnh hơn, tuy nhiên, điều này cũng sẽ làm chậm tốc độ tải game. Có thể thiết lập ở mức thấp, khi đó sẽ chỉ nhìn thấy những khung cảnh ở gần.'},
#  'UIIT_STT_VIDIO_TTDESC_06': {'Service': '1',
#   'Data': 'Khi các thông tin ở nhân vật, quái vật, lâu đài... được lựa chọn hiển thị nhiều, bạn sẽ biết đầy đủ thông tin hơn nhưng như vậy có thể gây chậm tốc độ tải game.'},
#  'UIIT_STT_VIDIO_TTDESC_07': {'Service': '1',
#   'Data': 'Lựa chọn chi tiết bóng nước để hiển thị các hình ảnh được phản chiếu trên mặt nước.'},
#  'UIIT_STT_VIDIO_TTDESC_08': {'Service': '1',
#   'Data': 'Chi tiết nước được lựa chọn với các mức độ hiệu ứng mặt nước, nếu lựa chọn mức độ cao, cảnh mặt nước sẽ đẹp hơn nhưng tốc độ tải game sẽ bị chậm đi.'},
#  'UIIT_STT_VIDIO_TTDESC_09': {'Service': '1',
#   'Data': 'Chi tiết hiển thị kim loại, nếu được lựa chọn, sẽ hiển thị các hiệu ứng ánh kim trên đồ vật kim loại như giáp, vũ khí. Mức độ lựa chọn càng cao thì chất lượng đồ hoạ cũng tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_10': {'Service': '1',
#   'Data': 'Hiệu ứng ánh sáng chỉ hiệu ứng của đèn khi chiếu trên bề mặt đồ vật, khi lựa chọn mức độ hiển thị ánh sáng cao thì độ thật của đồ vật sẽ tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_11': {'Service': '1',
#   'Data': 'Chi tiết chất liệu chỉ mức độ chi tiết của chất liệu. Chất lượng hiển thị chất liệu của đồ vật sẽ tăng lên khi chi tiết chất liệu được lựa chọn ở mức độ cao.'},
#  'UIIT_STT_VIDIO_TTDESC_12': {'Service': '1',
#   'Data': 'Chi tiết thấu kính chỉ tình trạng chiếu sáng giống như một máy quay phim đang hướng về phía mặt trời.'},
#  'UIIT_STT_VIDIO_TTDESC_13': {'Service': '1',
#   'Data': 'Hiệu ứng nở hoa chỉ tình trạng hoà trộn màu sắc giống như muôn ngàn bông hoa đang nở.'},
#  'UIIT_STT_VIDIO_TTDESC_14': {'Service': '1',
#   'Data': 'Chuyển động học chỉ kỹ thuật chuyển động của các động tác, chuyển động của tóc...'},
#  'UIIT_STT_VIDIO_TTDESC_15': {'Service': '1',
#   'Data': 'Bù đắp các phác thảo thô để các đổi tượng trong tự nhiên hơn.'},
#  'UIIT_STT_VIDIO_TTDESC_16': {'Service': '1',
#   'Data': 'Tắt hiệu ứng skill để hệ thống chạy mượt hơn'},
#  'UIIT_STT_VIDIO_TTDESC_17': {'Service': '1',
#   'Data': 'Khi được trang bị bộ đồ chiến đấu lớn, người chơi gần đó sẽ được nâng cao khả năng chiến trận'},
#  'UIIT_STT_VIDIO_TTDESC_18': {'Service': '1',
#   'Data': 'Hiển thị các hiệu ứng của tất cả các đối tượng trên màn hình chi tiết, và ánh kim loại có thể không kiểm soát được. Tùy chọn này được bất hoạt cho hình ảnh đồ họa thấp.'},
#  'UIIT_STT_GAMESET_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của thú như thú nuôi, thú thồ hàng…'},
#  'UIIT_STT_GAMESET_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của người chơi cùng nhóm'},
#  'UIIT_STT_GAMESET_TTDESC_03': {'Service': '1',
#   'Data': 'Báo động khi HP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_04': {'Service': '1',
#   'Data': 'Báo động khi MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_05': {'Service': '1',
#   'Data': 'Báo động thành tiếng khi HP/MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_AUDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể lựa chọn nhạc nền, bật/tắt/điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh pha trộn, bật/tắt điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh theo khu vực, bật/tắt, điều chỉnh âm lượng'},
#  'UIIT_STT_VIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn tự do'},
#  'UIIT_STT_VIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn từ nhân vật thứ ba để theo dõi bản thân từ sau lưng'},
#  'UIIT_STT_VIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn 1/4, tình trạng không thể thay đổi chất lượng màn hình cao/thấp'},
#  'UIIT_STT_INPUT_TTDESC_01': {'Service': '1',
#   'Data': 'sử dụng chuột hoặc phím tắt để thay đổi tầm nhìn.'},
#  'UIIT_STT_INPUT_TTDESC_02': {'Service': '1',
#   'Data': 'Để thay đổi tầm nhìn, sử dụng chuột phải hoặc phím tắt.'},
#  'UIIT_STT_INPUT_TTDESC_03': {'Service': '1',
#   'Data': 'Mở cửa sổ thông tin nhân vật để kiểm tra các thông tin cơ bản về nhân vật như trang bị, chỉ số sức mạnh/trí tuệ...'},
#  'UIIT_STT_INPUT_TTDESC_04': {'Service': '1',
#   'Data': 'Mở cửa sổ kỹ năng để có thể xem /học các kỹ năng, tăng/giảm chỉ số Tuyệt Kỹ.'},
#  'UIIT_STT_INPUT_TTDESC_05': {'Service': '1',
#   'Data': 'Mở cửa sổ nhóm để có thể lập nhóm, gia nhập nhóm hoặc thiết lập các điều kiện của nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_06': {'Service': '1',
#   'Data': 'Mở cửa sổ cộng đồng. Các thông tin về Hội hoặc tin nhắn, danh sách bạn bè... có thể tìm thấy ở đây.'},
#  'UIIT_STT_INPUT_TTDESC_07': {'Service': '1',
#   'Data': 'sử dụng chế độ Cuồng nộ. Bắt đầu bằng việc nhấn chuột phải lên nút năng lượng to nhất ở ô hiển thị chế độ Cuồng Nộ trên góc trái màn hình.'},
#  'UIIT_STT_INPUT_TTDESC_08': {'Service': '1',
#   'Data': 'Cửa sổ trợ giúp. Giải đáp các thắc mắc cơ bản của người chơi.'},
#  'UIIT_STT_INPUT_TTDESC_09': {'Service': '1',
#   'Data': 'sử dụng các ô nhớ nhanh hoặc bấm chuột phải vào các kỹ năng để thi triển kỹ năng.'},
#  'UIIT_STT_INPUT_TTDESC_10': {'Service': '1',
#   'Data': 'Phím tắt để nhặt đồ tự động trên mặt đất.'},
#  'UIIT_STT_INPUT_TTDESC_11': {'Service': '1',
#   'Data': 'Triệu tập hoặc thu hồi thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_12': {'Service': '1', 'Data': 'Để thú nuôi theo sau.'},
#  'UIIT_STT_INPUT_TTDESC_13': {'Service': '1',
#   'Data': 'Thiết lập chế độ nhặt của thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_14': {'Service': '1',
#   'Data': 'Bạn có thể gửi tin nhắn trực tiếp đến người đã nhắn cho bạn bằng cách nhấn vào nút tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_15': {'Service': '1',
#   'Data': 'Bạn có thể thay đổi thú nuôi bằng cách nhấn nút chuyển đổi thú nuôi khi có nhiều thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_16': {'Service': '1',
#   'Data': 'Mở cửa sổ giả kim thuật. Bạn có thể gia tăng sức mạnh của đồ vật và thêm các tính chất cho đồ vật tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_17': {'Service': '1',
#   'Data': 'Khi tắt chế độ hiển thị đồ vật, mọi thứ như các nhân vật khác, quái vật, thú nuôi... sẽ không được hiển thị ngoại trừ bản thân bạn.'},
#  'UIIT_STT_INPUT_TTDESC_18': {'Service': '1', 'Data': 'Mở hành trang'},
#  'UIIT_STT_INPUT_TTDESC_19': {'Service': '1',
#   'Data': 'Mở cửa sổ hành động. Có rất nhiều phím tắt, icon diễn tả cảm giác hay hành động khác nhau như lập gian hàng, chào hỏi...'},
#  'UIIT_STT_INPUT_TTDESC_20': {'Service': '1',
#   'Data': 'Mở cửa sổ nhiệm vụ để kiểm tra danh sách và thông tin về các nhiệm vụ đang thực hiện.'},
#  'UIIT_STT_INPUT_TTDESC_21': {'Service': '1',
#   'Data': 'Mở toàn bộ bản đồ để kiểm tra vị trí của bản thân và các thành viên trong nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_22': {'Service': '1',
#   'Data': 'Thay đổi tầm nhìn: tầm nhìn tự do --> tầm nhìn từ người thứ ba --> tầm nhìn 1/4 --> lặp lại tầm nhìn tự do'},
#  'UIIT_STT_INPUT_TTDESC_23': {'Service': '1',
#   'Data': 'Kiểm tra tên của các đồ vật dưới đất bằng cách sử dụng phím tắt tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_24': {'Service': '1',
#   'Data': 'Thiết lập chế độ đứng\\ngồi của nhân vật. Khi ngồi, tốc độ hồi phục HP/MP của nhân vật sẽ nhanh hơn.'},
#  'UIIT_STT_INPUT_TTDESC_25': {'Service': '1',
#   'Data': 'Cửa sổ kiểm tra tình trạng của thú nuôi: có thể thiết lập tên của thú nuôi, kiểm tra thông tin thú nuôi tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_26': {'Service': '1', 'Data': 'Thu hồi thú nuôi'},
#  'UIIT_STT_INPUT_TTDESC_27': {'Service': '1',
#   'Data': 'Yêu cầu thú nuôi tấn công'},
#  'UIIT_STT_INPUT_TTDESC_28': {'Service': '1',
#   'Data': 'Có thể sử dụng Hệ thống Siêu thị, tại đây, bạn có thể dùng silk để mua các đồ vật hữu dụng.'},
#  'UIIT_STT_INPUT_TTDESC_29': {'Service': '1',
#   'Data': 'Bạn có thể thiết lập chế độ tự động sử dụng giải dược và thuốc hồi phục, khi đó, việc luyện tập của bạn sẽ dễ dàng hơn.'},
#  'UIIT_STT_INPUT_TTDESC_30': {'Service': '1',
#   'Data': 'Mở cửa sổ gia nhập nhóm. Tại đây, bạn có thể tìm các nhóm đang thiếu thành viên để gia nhập.'},
#  'UIIT_STT_INPUT_TTDESC_31': {'Service': '1',
#   'Data': 'Mở cửa sổ hệ thống gian hàng. Tại đây, bạn có thể dễ dàng tìm thấy các đồ vật được bán trong hệ thống.'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị tên nhân vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị tên quái vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Hiển thị tên Hội'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_04': {'Service': '1',
#   'Data': 'Hiển thị tên các nhân vật khác'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_05': {'Service': '1',
#   'Data': 'Hiển thị tên NPC'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_06': {'Service': '1',
#   'Data': 'Hiển thị biểu tượng cấp độ thấp. Nếu lựa chọn, một dấu hiệu sẽ xuất hiện bên cạnh tên nhân vật của bạn và sẽ biến mất khi bạn lên cấp độ cao.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_01': {'Service': '1',
#   'Data': 'Trong trò chơi có rất nhiều chỉ dẫn được hiển thị dưới dạng tin nhắn ngắn trên cửa sổ trò chuyện. Bạn sẽ tìm thấy các thông tin hữu ích tại đây.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_02': {'Service': '1',
#   'Data': 'Cho phép hiển thị cửa sổ chú ý. Các chỉ dẫn chi tiết sẽ được hiển thị hoặc kiểm tra các thông tin quan trọng khi chuyển sang hệ thống mới. Sẽ rất hữu dụng khi bạn mới gia nhập trò chơi.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_03': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_04': {'Service': '1',
#   'Data': 'Ẩn hệ thống Windows một cách tự động. Nếu sử dụng chức năng này, khung của hệ thống Windows sẽ ẩn đi một cách tự động và chỉ xuất hiện trở lại khi bạn đưa con trỏ chuột lên trên.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_05': {'Service': '1',
#   'Data': 'Chuyển màn hình trò chơi sang chế độ cửa sổ. Bạn có thể sử dụng chế độ cửa sổ theo sở thích.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_06': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu mời vào nhóm. Nếu không sử dụng lựa chọn này, mọi lời mời vào nhóm gửi đến sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_07': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu giao dịch. Nếu không sử dụng chọn lựa này, mọi yêu cầu giao dịch gửi đến sẽ bị từ chối. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_08': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn cá nhân. Nếu không chọn chức năng này, mọi tin nhắn cá nhân sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_09': {'Service': '1',
#   'Data': 'Thể hiện thông tin về các trạng thái tăng cường của nhân vật trong phần thông tin nhân vật thuộc nhóm. Nếu không lựa chọn chức năng này, các thông tin sẽ không thể hiện. Không quan sát được trạng thái dị trạng của nhân vật.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_10': {'Service': '1',
#   'Data': 'Khởi động nhanh trò chơi bằng việc nạp hình ảnh bối cảnh trước khi nạp hình ảnh nhân vật. Đánh dấu vào ô này nếu bạn muốn trò chơi khởi động nhanh hơn.'},
#  'UIIT_MSG_CHATWND_HELP_WHISPER': {'Service': '1',
#   'Data': 'Thì thầm  [$tênnhânvật những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_PARTYMSG': {'Service': '1',
#   'Data': 'Tán gẫu trong nhóm [#những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_USECONTROLATSTORE': {'Service': '1',
#   'Data': 'Nếu bạn ấn phím Ctrl, bạn có thể bán hoặc mua đồ nhanh hơn'},
#  'UIIT_MSG_NOTIFY': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_MSG_CHATWND_MESSAGE_FILTER': {'Service': '1',
#   'Data': 'Một số từ ngữ hoặc cách diễn đạt bị cấm dùng'},
#  'UIIT_STT_GAMEGUIDE_START_1': {'Service': '1',
#   'Data': 'Hãy tìm hiểu những thông tin cơ bản về Con Đường Tơ Lụa và làm quen với những thông tin này trước. Thông qua cửa sổ tán gẫu bạn có thể học được thêm những chỉ dẫn vì vậy hãy luyện thói quen thật chú ý tới những hướng dẫn này. Chắc chắn bạn sẽ thu được những thông tin rất bổ ích.'},
#  'UIIT_STT_GAMEGUIDE_START_2': {'Service': '1',
#   'Data': '※ Hướng dẫn trò chơi có thể được sử dụng bất kỳ lúc nào bằng việc bấm phím  [H]'},
#  'UIIT_STT_GAMEGUIDE': {'Service': '1', 'Data': 'Trợ giúp'},
#  'UIIT_STT_EVENTGUIDE': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_QUESTGUIDE1': {'Service': '1', 'Data': 'Nhiệm vụ'},
#  'UIIT_STT_QUESTGUIDE2': {'Service': '1', 'Data': 'Từ điển nhiệm vụ'},
#  'UIIT_STT_GAMEEVENTGUIDE': {'Service': '1', 'Data': 'Hướng dẫn'},
#  'UIIT_STT_CONFIRM_BOX': {'Service': '1', 'Data': 'Cửa sổ xác nhận'},
#  'UIIT_STT_AGREEMENT_BOX': {'Service': '1', 'Data': 'Cửa sổ đồng ý'},
#  'UIIT_STT_INPUT_BOX': {'Service': '1', 'Data': 'Cửa sổ nhập vào'},
#  'UIIT_PAG_WORLDMAP': {'Service': '1', 'Data': 'Bản đồ lớn'},
#  'UIIT_PAG_LOCALMAP': {'Service': '1', 'Data': 'Bản đồ khu vực'},
#  'UIIT_STT_BACK_WORLDMAP': {'Service': '1', 'Data': 'Mở bản đồ lớn'},
#  'UIIT_STT_JANGAN': {'Service': '1', 'Data': 'Trường An'},
#  'UIIT_STT_DONHWANG': {'Service': '1', 'Data': 'Đôn Hoàng'},
#  'UIIT_STT_KHOTAN': {'Service': '1', 'Data': 'Hòa Điền'},
#  'UIIT_STT_SAMARKAND': {'Service': '1', 'Data': 'Samarkand'},
#  'UIIT_STT_CONSTANTINOPLE': {'Service': '1', 'Data': 'Constantinople'},
#  'UIIT_STT_BIJEOKDAN': {'Service': '1', 'Data': 'Bijeokdan'},
#  'UIIT_STT_HEUKMAKDAN': {'Service': '1', 'Data': 'Heukmakdan'},
#  'UIIT_STT_EVILORDER': {'Service': '1', 'Data': 'Pháo đài tà ác'},
#  'UIIT_STT_ARABIA_CITY': {'Service': '1', 'Data': 'Baghdad'},
#  'UIIT_STT_ARABIA_CITY_DUNGEON': {'Service': '1', 'Data': 'Baghdad (Phụ bản)'},
#  'UIIT_STT_MUHAN': {'Service': '1', 'Data': 'Đấu trường Vô Cực'},
#  'UIIT_MSG_CHEATMSG_GO_TOWN': {'Service': '1', 'Data': '/town'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_1': {'Service': '1',
#   'Data': 'Tìm thấy macro (chơi tự động) trong nhân vật đang chơi. Tự động thoát.'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_2': {'Service': '1',
#   'Data': 'Tên của nhân vật có macro và thời gian đã sử dụng sẽ được ghi lại trên máy chủ'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_3': {'Service': '1',
#   'Data': 'Có thể áp dụng hình phạt giới hạn về thời gian của tài khoản và khóa tài khoản'},
#  'UIIT_MSG_APPEAR_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa xuất hiện ở Hổ Huyệt Sơn'},
#  'UIIT_MSG_APPEAR_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã xuất hiện'},
#  'UIIT_MSG_APPEAR_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi xuất hiện ở Karakoram'},
#  'UIIT_MSG_APPEAR_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan xuất hiện ở Taklamakan'},
#  'UIIT_MSG_APPEAR_TAHOMET': {'Service': '1',
#   'Data': 'Sa Y Thần xuất hiện ở Lạc Khắc Sơn'},
#  'UIIT_MSG_APPEAR_UNIC': {'Service': '1', 'Data': '[%s] đã xuất hiện'},
#  'UIIT_MSG_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn đã biến mất'},
#  'UIIT_MSG_DEAD_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã biến mất'},
#  'UIIT_MSG_DEAD_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi từ Karakoram đã biến mất'},
#  'UIIT_MSG_DEAD_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan từ Taklamakan đã biến mất'},
#  'UIIT_MSG_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã biến mất'},
#  'UIIT_MSG_ANYONE_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': '[%s] đã giết Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_URRUCHI': {'Service': '1',
#   'Data': '[%s] đã giết Ô Lỗ Tề từ Tháp Lý Mộc'},
#  'UIIT_MSG_ANYONE_DEAD_IYUTARU': {'Service': '1',
#   'Data': '[%s] đã giết Băng Chúa Nhi từ Karakoram'},
#  'UIIT_MSG_ANYONE_DEAD_BONELORD': {'Service': '1',
#   'Data': '[%s] đã giết Chúa tể Yarkan từ Taklamakan'},
#  'UIIT_MSG_ANYONE_DEAD_TAHOMET': {'Service': '1',
#   'Data': '[%s] đã giết Sa Y Than từ Lạc Khắc Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã giết [%s]'},
#  'UIIT_STT_ROLL_OF_CLOTH': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILK_BUY_RESULT': {'Service': '1', 'Data': 'Bạn đã mua [%d] silk'},
#  'UIIT_STT_SILK_BUY_CANCLE': {'Service': '1',
#   'Data': 'Việc mua bán [%d] silk đã bị hủy bỏ'},
#  'UIIT_STT_SILK_BUY_RECEIVE': {'Service': '1',
#   'Data': 'Bạn nhận được quà là [%d] silk'},
#  'UIIT_STT_SILK_SEND_RESULT': {'Service': '1',
#   'Data': 'Bạn đã gửi [%d] silk đi làm quà'},
#  'UIIT_STT_SILK_POINT_BUY_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được trả tiền'},
#  'UIIT_STT_SILK_POINT_USE_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được sử dụng'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK': {'Service': '1', 'Data': 'Silk đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_MALL': {'Service': '1', 'Data': 'Cửa hàng Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_MALL': {'Service': '1',
#   'Data': 'Cửa hàng đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_TOTAL': {'Service': '1', 'Data': 'Tổng số Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_TOTAL': {'Service': '1',
#   'Data': 'Tổng số Silk đặc biệt'},
#  'UIIT_STT_SILKMALL': {'Service': '1', 'Data': 'Siêu thị'},
#  'UIIT_STT_SILKMALL_MAIN': {'Service': '1', 'Data': 'Phần chính'},
#  'UIIT_STT_SILKMALL_HOT_STORE': {'Service': '1', 'Data': 'HOT Shop'},
#  'UIIT_STT_SILKMALL_CONSUMPTION': {'Service': '1', 'Data': 'Đồ tiêu dùng'},
#  'UIIT_STT_SILKMALL_LEND_ITEM': {'Service': '1', 'Data': 'Tiền thuê đồ'},
#  'UIIT_STT_SILKMALL_AVATA': {'Service': '1', 'Data': 'Trang trí'},
#  'UIIT_STT_SILKMALL_PET': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PACKAGE': {'Service': '1', 'Data': 'Gói hàng'},
#  'UIIT_STT_SILKMALL_SHOPPING_BASKET_LIST': {'Service': '1',
#   'Data': 'Hàng đã chọn'},
#  'UIIT_STT_SILKMALL_NEW_ITEM': {'Service': '1', 'Data': 'Hàng mới'},
#  'UIIT_STT_SILKMALL_EVENT': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_SPECIAL_COAST': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_FAVORITE': {'Service': '1', 'Data': 'Hàng bán chạy'},
#  'UIIT_STT_SILKMALL_SPECIAL': {'Service': '1', 'Data': 'Đặc biệt'},
#  'UIIT_STT_SILKMALL_SCROLL': {'Service': '1', 'Data': 'Hỗ trợ'},
#  'UIIT_STT_SILKMALL_POTION': {'Service': '1', 'Data': 'Hồi phục'},
#  'UIIT_STT_SILKMALL_COMMUNITY': {'Service': '1', 'Data': 'Cộng đồng'},
#  'UIIT_STT_SILKMALL_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY': {'Service': '1', 'Data': 'Giả kim thuật'},
#  'UIIT_STT_SILKMALL_PREMIUM_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ASTRAL': {'Service': '1', 'Data': 'Tinh thạch'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': 'Bất diệt (bảo toàn 99%)'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_3': {'Service': '1', 'Data': 'Áo nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_4': {'Service': '1', 'Data': 'Quần nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_5': {'Service': '1', 'Data': 'Bao tay'},
#  'UIIT_STT_SILKMALL_ARMOR_6': {'Service': '1', 'Data': 'Giầy nặng'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_3': {'Service': '1', 'Data': 'Áo nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_4': {'Service': '1', 'Data': 'Quần nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_6': {'Service': '1', 'Data': 'Giầy nhẹ'},
#  'UIIT_STT_SILKMALL_CLOSE_1': {'Service': '1', 'Data': 'Khăn'},
#  'UIIT_STT_SILKMALL_CLOSE_2': {'Service': '1', 'Data': 'Cầu vai vải'},
#  'UIIT_STT_SILKMALL_CLOSE_3': {'Service': '1', 'Data': 'Áo vải'},
#  'UIIT_STT_SILKMALL_CLOSE_4': {'Service': '1', 'Data': 'Quần vải'},
#  'UIIT_STT_SILKMALL_CLOSE_6': {'Service': '1', 'Data': 'Giầy vải'},
#  'UIIT_STT_SILKMALL_BIG_STORE': {'Service': '1', 'Data': 'Tiệm lớn'},
#  'UIIT_STT_SILKMALL_ASSIST': {'Service': '1', 'Data': 'Chi nhánh'},
#  'UIIT_STT_SILKMALL_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_HAT': {'Service': '1', 'Data': 'Mũ'},
#  'UIIT_STT_SILKMALL_BOOTH': {'Service': '1', 'Data': 'Gian hàng'},
#  'UIIT_STT_SILKMALL_FIREWORK': {'Service': '1', 'Data': 'Kẹo'},
#  'UIIT_STT_SILKMALL_DRESS': {'Service': '1', 'Data': 'Trang phục'},
#  'UIIT_STT_SILKMALL_ATTACH': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_BALLOON': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_PET_SUMMON': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PET_CONSUME': {'Service': '1', 'Data': 'Thú nuôi hết hạn'},
#  'UIIT_STT_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1', 'Data': 'Mua hết'},
#  'UIIT_STT_SILKMALL_BOOK_MARK': {'Service': '1', 'Data': 'Sổ sách'},
#  'UIIT_STT_SILKMALL_PUT_ON': {'Service': '1', 'Data': 'sử dụng thử'},
#  'UIIT_STT_SILKMALL_BUY': {'Service': '1', 'Data': 'Mua'},
#  'UIIT_STT_SILKMALL_PRESENT': {'Service': '1', 'Data': 'Quà'},
#  'UIIT_STT_SILKMALL_DEL': {'Service': '1', 'Data': 'Xóa'},
#  'UIIT_STT_SILKMALL_BUY_LIST': {'Service': '1', 'Data': 'Hàng mua'},
#  'UIIT_STT_SILKMALL_RECEIVE_LIST': {'Service': '1', 'Data': 'Hàng nhận'},
#  'UIIT_STT_SILKMALL_SILKMALL_OUT': {'Service': '1', 'Data': 'Thoát'},
#  'UIIT_STT_SILKMALL_PUT_ON_CLOSE_BUY': {'Service': '1',
#   'Data': 'Mua đồ thời trang'},
#  'UIIT_STT_SILKMALL_ALL_CLOSE_TAKEOFF': {'Service': '1', 'Data': 'Cởi bỏ'},
#  'UIIT_STT_SILKMALL_ADD_INVENTORY': {'Service': '1', 'Data': 'Ô mở rộng'},
#  'UIIT_STT_SILKMALL_ADD_STOREHOUSE_INVENTORY': {'Service': '1',
#   'Data': 'Kho mở rộng'},
#  'UIIT_STT_SILKMALL_SILK': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILKMALL_BUY_SILK': {'Service': '1', 'Data': 'Mua Silk'},
#  'UIIT_STT_SILKMALL_SEND_SILK': {'Service': '1', 'Data': 'Tặng Silk'},
#  'UIIT_STT_SILKMALL_COUPON_EXCHANGE': {'Service': '1',
#   'Data': 'Trao đổi phiếu'},
#  'UIIT_STT_SILKMALL_BUY_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_03': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_USE_INFOMATION': {'Service': '1',
#   'Data': 'Cách sử dụng Siêu thị'},
#  'UIIT_STT_SILKMALL_ENTER': {'Service': '1', 'Data': 'Vào Siêu thị'},
#  'UIIT_STT_SILKMALL_DIRECT_ENTER': {'Service': '1',
#   'Data': 'Vào nhanh Siêu thị'},
#  'UIIT_STT_SILKMALL_NEW_CASHITEM': {'Service': '1',
#   'Data': 'Siêu thị cập nhật đồ vật mới'},
#  'UIIT_STT_SILKMALL_WARNING_1': {'Service': '1',
#   'Data': 'Bạn có thể bị quái vật'},
#  'UIIT_STT_SILKMALL_WARNING_2': {'Service': '1',
#   'Data': 'hoặc những người chơi khác tấn công trong khi vào Siêu thị'},
#  'UIIT_STT_SILKMALL_WARNING_3': {'Service': '1',
#   'Data': 'Nên sử dụng món đồ trong khu vực an toàn'},
#  'UIIT_STT_SILKMALL_MAIN_EXPLAIN': {'Service': '1',
#   'Data': '<sml2><p line_margin="12"><p line_margin="5"><font color="255,255,153,81" style="bold">Siêu Thị là gì?</font><br>Là nơi bán và cho thuê những trang bị để <br>sử dụng trên Con đường tơ lụa. Những trang bị đó phải sử dụng silk để mua.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Mua Silk</font><br>Silk có thể mua bằng cách bấm vào nút Mua silk ở góc trên bên phải màn hình.<br>Bấm vào nút Mua silk bạn sẽ được chuyển đến trang E-Cash.<br>nơi để bạn mua silk.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Tặng Silk</font><font color="255,255,117,117">(Tính năng chưa kích hoạt)</font><br>Trong quá trình mua đồ trong Siêu Thị, bạn có thể bấm vào nút Tặng Silk để gửi <br>tới người chơi khác món đồ bạn chọn.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Coupons exchanges</font><br>Phiếu giảm giá có thể được sử dụng 1 lần để mua silk hoặc sử dụng các item Mall.<br>Điền con số vào phiếu giảm giá để nhận được silk.<br>Số tiền có thể khác nhau tùy thuộc vào các loại phiếu giảm giá.<br></p></p><strong><font color="255,255,153,81">Sổ sách</font></strong><font color="255,255,117,117">(Tính năng chưa được kích hoạt)</font><br>Tất cả những đồ vật bạn mua trong Siêu Thị có thể được lưu giữ trong sổ sách của bạn <br>bằng cách bấm vào Sổ sách. Đồ vật đã lưu trong Sổ của bạn sẽ được hoàn trả <br>ngay cả khi bạn đã mua đồ vật đó.</sml2>'},
#  'UIIT_STT_SILKMALL_MY_INFO': {'Service': '1', 'Data': 'Thông tin cá nhân'},
#  'UIIT_STT_SILKMALL_POSSESSION_GOLD': {'Service': '1',
#   'Data': 'Số lượng hiện có'},
#  'UIIT_STT_SILKMALL_REMAIN_INVENTORY': {'Service': '1', 'Data': '%d ô trống'},
#  'UIIT_STT_SILKMALL_MAIN_INTRO': {'Service': '1',
#   'Data': '<sml2>Chào mừng quý khách đến với cửa hàng bán đồ chất lượng cao của Con Đường Tơ Lụa</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ORDER_SHEET': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_TOOL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_FLEAMARKET': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_ZZIM': {'Service': '1',
#   'Data': '<sml2>Đây là danh sách hàng bạn đặt mua</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_FAVORITY': {'Service': '1',
#   'Data': '<sml2>Có thể xem danh sách những mặt hàng đã mua hoặc chọn trong phần Sổ sách</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COSETC': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'MALL_CONSUME_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'MALL_CONSUME_SCROLL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'MALL_CONSUME_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'MALL_CONSUME_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'MALL_CONSUME_ETC': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'MALL_AVATAR_BOOTH': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'MALL_AVATAR_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_PET_A_GROWTH': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_SILK': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_VEHICLE': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_CART': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_STORES': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PREMIUM_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'MALL_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'MALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'UIIT_STT_SILKMALL_SHORT_KEY': {'Service': '1', 'Data': 'Siêu thị (F10)'},
#  'UIIT_STT_SILKMALL_BUY_CONFIRM': {'Service': '1', 'Data': 'Xác nhận mua'},
#  'UIIT_STT_SILKMALL_DO_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_POPUP_TITLE': {'Service': '1',
#   'Data': 'Đồ trang trí tồn kho'},
#  'UIIT_STT_SILKMALL_POPUP_ADVERTISING': {'Service': '1',
#   'Data': 'Bán có giới hạn'},
#  'UIIT_STT_SILKMALL_POPUP_DATA': {'Service': '1', 'Data': 'Ngày bán:'},
#  'UIIT_STT_SILKMALL_POPUP_REDUCTION': {'Service': '1',
#   'Data': 'Cho tới khi giảm giá'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_M': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nam)'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_W': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nữ)'},
#  'UIIT_MSG_SILKMALL_ZZIM_CONFIRM': {'Service': '1',
#   'Data': '<sml2><font color="255,255,255,255">Bạn sẽ đặt món đồ này chứ?<br>các món đồ được đặt có thể được chọn và mua một tất cả ở danh sách đặt hàng.</font></sml2>'},
#  'UIIT_MSG_SILKMALL_ZZIM_DELITE': {'Service': '1',
#   'Data': 'Xóa món đồ trong danh sách đặt hàng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1',
#   'Data': 'Bạn sẽ mua luôn số hàng đã đặt chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY_TOTAL': {'Service': '1',
#   'Data': 'Tổng cộng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_1': {'Service': '1',
#   'Data': 'Bạn có hủy số hàng đã đặt không ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_2': {'Service': '1',
#   'Data': 'Nếu bạn hủy bỏ việc sử dụng món đồ đã chọn, hiệu ứng của nó sẽ mất'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE': {'Service': '1',
#   'Data': 'Bạn sẽ dùng món đồ đã chọn chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_REVERSE_PORTAL': {'Service': '1',
#   'Data': 'sử dụng bùa dịch chuyển phản hồi. Hãy chọn điểm đến.'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_RETURN': {'Service': '1',
#   'Data': 'Dịch chuyển tới điểm về cuối'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_DEATH': {'Service': '1',
#   'Data': 'Dịch chuyển tới nơi bạn đã chết'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_INS': {'Service': '1',
#   'Data': 'sử dụng các vật phẩm này bạn sẽ không thể dịch chuyển được'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_GNGWC': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật sau khi kết thúc trận chiến'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_BUY_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không thành công do không đủ silk'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_GIFT': {'Service': '1',
#   'Data': 'Silk không đủ để tặng'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng cho loại đồ vật trang bị'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_SINCE_EQUIP_CLASS_TOO_HIGH': {'Service': '1',
#   'Data': 'Không thể thay đổi giới tính do không phù hợp với cấp độ của đồ vật'},
#  'UIIT_MSG_STRGERR_INVALID_TRANSGENDER_TARGET': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể thay đổi giới tính'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_TELEPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi cuối cùng bạn đã quay lại'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_DIEDPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi bạn đã chết'},
#  'UIIT_MSG_STRGERR_ONLY_THE_DEAD_CAN_USE_RESURRECT_SCROLL': {'Service': '1',
#   'Data': 'Chỉ sử dụng trong tình trạng đã chết'},
#  'UIIT_MSG_STRGERR_THERE_IS_NO_ITEM_TO_REPAIR': {'Service': '1',
#   'Data': 'Không có đồ vật nào cần sửa chữa'},
#  'UIIT_MSG_STRGERR_CANT_QUICKSELL_CASHITEM': {'Service': '1',
#   'Data': 'Không có chức năng mua bán nhanh với những món đồ hiếm.'},
#  'UIIT_MSG_STRGERR_TRADE_FAILURE': {'Service': '1',
#   'Data': 'Giao dịch thất bại không có lý do'},
#  'UIIT_STT_SILKMALL_FAIL_ITEMBUY_LOGOUT': {'Service': '1',
#   'Data': 'Trò chơi sẽ chấm dứt do việc mua đồ Premium thất bại'},
#  'UIIT_STT_SILKMALL_DONOT_USE_TELEPORT': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_MSG_SELL_RECONFIRM': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_PAG_CHAR_SKIN_CHANGE': {'Service': '1',
#   'Data': 'Thay đổi hình dáng bên ngoài của nhân vật'},
#  'UIIT_MSG_CHAR_SKIN_ERR_ARMOR': {'Service': '1',
#   'Data': 'Để thay đổi giới tính phải bỏ đồ bảo hộ và gỡ bỏ hết các ô mở rộng'},
#  'UIIT_MSG_CHAR_SKIN_CHANGE_SUCCESS': {'Service': '1',
#   'Data': 'Thay đổi giới tính thành công'},
#  'UIIT_STT_GUILD_INFO': {'Service': '1', 'Data': 'T.Tin Hội'},
#  'UIIT_CTL_LETTER': {'Service': '1', 'Data': 'Hộp thư kết hợp'},
#  'UIIT_CTL_FRIEND': {'Service': '1', 'Data': 'Bạn'},
#  'UIIT_STT_GUILD_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_GUILD_STAFF': {'Service': '1', 'Data': 'Hội phó'},
#  'UIIT_STT_GUILDSMAN': {'Service': '1', 'Data': 'Hội viên'},
#  'UIIT_STT_GUILDSMAN_NUM': {'Service': '1', 'Data': 'Số'},
#  'UIIT_STT_GUILD_COMMON_KNOW': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_GUILD_COMMON_KNOW_WRITE': {'Service': '1',
#   'Data': 'Viết thông báo'},
#  'UIIT_MSG_GUILD_COMMON_NOTEXIST': {'Service': '1',
#   'Data': 'Không có thông báo'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo (%d/Tối đa.%d)'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_TITLE_REMIND': {'Service': '1',
#   'Data': 'Hãy điền tiêu đề lời thông báo'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT_TITLE': {'Service': '1',
#   'Data': 'Chưa điền tiêu đề'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo'},
#  'UIIT_MSG_GUILDERR_TARGET_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Người chơi khác không có quyền'},
#  'UIIT_CTL_GUILD_WRITE_END': {'Service': '1', 'Data': 'Hoàn thành'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND_UPDATE': {'Service': '1',
#   'Data': 'Thông báo của Hội đã thay đổi'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_JOIN': {'Service': '1',
#   'Data': 'Hội chủ Hội [%s] đề nghị liên minh với bạn, bạn có chấp nhận không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_WITHDRAWA': {'Service': '1',
#   'Data': 'Bạn có muốn rời bỏ liên minh không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_BREAKUP': {'Service': '1',
#   'Data': 'Liên minh đã bị giải tán'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_NOTALLY': {'Service': '1',
# ...
#   'Data': 'Đã khỏi bệnh'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CHAOS': {'Service': '1',
#   'Data': 'Đã khỏi lẫn lộn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_PD': {'Service': '1',
#   'Data': 'Đã khỏi bị thối rữa'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_MD': {'Service': '1',
#   'Data': 'Đã được khoẻ lại'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_STR': {'Service': '1',
#   'Data': 'Đã hết bất lực'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_INT': {'Service': '1',
#   'Data': 'Đã hết bị cô lập'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_HP': {'Service': '1',
#   'Data': 'Đã hết hoảng loạn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSIE_MP': {'Service': '1',
#   'Data': 'Đã hết bị thiêu đốt'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_TIME_BOMB': {'Service': '1',
#   'Data': 'Đã hết ẩn nấp'},
#  'UIIT_MSG_BURN': {'Service': '1', 'Data': 'Thiêu đốt'},
#  'UIIT_MSG_FROSTBITE': {'Service': '1', 'Data': 'Tê cóng'},
#  'UIIT_MSG_FREEZING': {'Service': '1', 'Data': 'Đóng băng'},
#  'UIIT_MSG_SHOCK': {'Service': '1', 'Data': 'Nhiễm điện'},
#  'UIIT_MSG_ZOMBIE': {'Service': '1', 'Data': 'Yểm bùa'},
#  'UIIT_MSG_DARK': {'Service': '1', 'Data': 'Mờ mắt'},
#  'UIIT_MSG_STUN': {'Service': '1', 'Data': 'Choáng'},
#  'UIIT_MSG_PARTYERR_OUT_OF_LEVEL': {'Service': '1',
#   'Data': 'Không thể vào nhóm đó do sự chênh lệch về cấp độ.'},
#  'UIIT_MSG_FLEAMARKET_ERR_IM_BUSY': {'Service': '1',
#   'Data': 'Bạn ở trong tình trạng không được mở gian hàng mới'},
#  'UIIT_MSG_JSERR_SINCE_YOU_DIE_IN_MURDERER_SP_DEPRIVED_BY_SERVER': {'Service': '1',
#   'Data': 'Bị mất [%u] điểm kinh nghiệm'},
#  'UIIT_MSG_INTERACTION_FAIL__REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_PORTAL_SCROLL': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_SUMMON_VEHICLE': {'Service': '1',
#   'Data': 'Không thể dùng thú vận chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_INTERACTION_FAIL_MURDERER_CAN_USE_PORTAL_STRUCTURE': {'Service': '1',
#   'Data': 'Không thể qua cổng dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_FLEAMARKET_ERR_CANT_OPEN_MARKET_MURDERER': {'Service': '1',
#   'Data': 'Không thể mở gian hàng mới trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng item trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_ENABLEINPUT_FEWERTHAN_REMAIN': {'Service': '1',
#   'Data': 'Chỉ có thể nhập số đơn vị còn lại'},
#  'UIIT_MSG_STRGERR_CANNOT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy người chơi khác'},
#  'UIIT_MSG_STRGERR_SPECIFY_POSITIVE_NUMBER_ONLY': {'Service': '1',
#   'Data': 'Số không hợp lệ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi bị hủy bỏ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_BEFORE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi lần trước bị hủy bỏ vì đã thực hiện trao đổi với người chơi khác'},
#  'UIIT_MSG_STRGERR_CANNOT_WITDRAW_MORETHAN_DEPOSIT': {'Service': '1',
#   'Data': '-'},
#  'UIIT_MSG_DEAL_ASK': {'Service': '1',
#   'Data': 'Có người muốn trao đổi với bạn. Bạn chấp nhận chứ?'},
#  'UIIT_MSG_DEAL_ASKING': {'Service': '1', 'Data': 'Trao đổi với [%s]'},
#  'UIIT_MSG_STRGERR_INVALID_TARGET': {'Service': '1',
#   'Data': 'Không thấy mục tiêu'},
#  'UIIT_MSG_STRGERR_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận làm việc khác'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_OPPONENT_INV_SPACE': {'Service': '1',
#   'Data': 'Không thể đưa thêm món đồ đó vào cửa sổ trao đổi vì thùng đồ người kia đã đầy.'},
#  'UIIT_MSG_STRGERR_NON_SETUP_KEY': {'Service': '1',
#   'Data': 'Không thể đặt phím đã lựa chọn'},
#  'UIIT_MSG_STRGERR_CHATING_LIMIT': {'Service': '1',
#   'Data': 'Không thể lặp lại cùng nội dung'},
#  'UIIT_MSG_STRGERR_DEAL_FAIL_NON_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không được thực hiện do không có đồ vật giao dịch'},
#  'UIIT_STT_TARGETTING': {'Service': '1', 'Data': 'Mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTLEARN': {'Service': '1',
#   'Data': 'Kỹ năng không xác định'},
#  'UIIT_SKILL_USE_FAIL_TIMEDELAY_REUSEDELAY': {'Service': '1', 'Data': '-'},
#  'UIIT_SKILL_USE_FAIL_WRONGDISTANCE': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng với mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTENOUGHLEVEL': {'Service': '1',
#   'Data': 'Không sử dụng được vì cấp độ của bạn thấp'},
#  'UIIT_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh người chơi khác vì cấp độ của người đó cao hơn bạn'},
#  'UIIT_CHATERR_CANT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy [%s]'},
#  'UIIT_CHATERR_YOU_ARE_SQUELCHED': {'Service': '1',
#   'Data': 'Chức năng thì thầm của  [%s]đã bị tắt'},
#  'UIIT_CHATERR_NOT_A_PARTY_MEMBER': {'Service': '1',
#   'Data': 'Không ở trong nhóm nào'},
#  'UIIT_CHATERR_INVALID_COMMAND': {'Service': '1',
#   'Data': 'Lệnh chat không hợp lệ'},
#  'UIIT_CHATERR_ALLIANCE_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Không sử dụng được chức năng tán gẫu với đồng minh vì Hội được chọn không phải là đồng minh của bạn'},
#  'UIIT_CHATERR_WHISPER_TO_MESSAGE': {'Service': '1', 'Data': 'Tin đi'},
#  'UIIT_CHATERR_WHISPER_FROM_MESSAGE': {'Service': '1', 'Data': 'Tin đến'},
#  'UIIT_TOOLTIP_PK_DAY': {'Service': '1', 'Data': 'PK hàng ngày %d / %d'},
#  'UIIT_TOOLTIP_PK_TOTAL': {'Service': '1', 'Data': 'Tổng PK %d / %d'},
#  'UIIT_TOOLTIP_PK_PENALTY_TIME': {'Service': '1',
#   'Data': 'Chỉ số PK %d (Cấp độ %d)'},
#  'UIIT_TOOLTIP_PENALTY_GOLD': {'Service': '1', 'Data': 'Phạt %d vàng'},
#  'UIIT_TOOLTIP_JOB_PENALTY_TIME': {'Service': '1',
#   'Data': 'Không được hành nghề trong %d phút'},
#  'UIIT_TOOLTIP_EQUIPMENT_CLASS': {'Service': '1', 'Data': 'Cấp: Cấp %d'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_DROPPED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể bỏ đi'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_PICKED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể lấy được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_TRADED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể mang ra mua bán được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể sửa chữa được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể làm lại được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_USED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể dùng được'},
#  'UIIT_MSG_CANNOT_BE_USED_ITEM_CART': {'Service': '1',
#   'Data': 'Không thể dùng mà không có thú di chuyển/ chuyên chở'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_IN_BATTLE_STATE': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang đánh nhau'},
#  'UIIT_MSG_REMAIN_TIME': {'Service': '1', 'Data': '(còn %d giây)'},
#  'UIIT_MSG_STRGERR_ONLY_ROBBER_CAN_USE_THIS_ITEM': {'Service': '1',
#   'Data': 'Món đồ được chọn chỉ sử dụng được khi làm Đạo Tặc'},
#  'UIIT_MSG_STRGERR_CANT_OPERATE_REQUESTED_JOB_DURING_LOGOUT': {'Service': '1',
#   'Data': 'Không thể thực hiện khi đang thoát trò chơi'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED_TO_USE_THISITEM': {'Service': '1',
#   'Data': 'Không thể đung được món đồ đó vì cấp độ của nhân vật còn thấp'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_WHILE_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang dịch chuyển'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME': {'Service': '1',
#   'Data': 'Còn %d giây sẽ thoát trò chơi'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME_CANCLE': {'Service': '1',
#   'Data': 'Hủy bỏ việc thoát khỏi trò chơi'},
#  'UIIT_MSG_STRGERR_CANT_SELL_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể bán món đồ khi đang trang bị'},
#  'UIIT_MSG_STRGERR_CANT_SWAP_JOBITEM': {'Service': '1',
#   'Data': 'Phải bỏ món đồ trước ra thì mới mặc đồ mới vào được'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBCHANGE_COMPLETE': {'Service': '1',
#   'Data': 'Không thể cởi trang bị nghề nghiệp trong vòng 10 giây kể từ lúc đeo vào'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBITEM_DETACH_COMPLETE': {'Service': '1',
#   'Data': 'Không thể đeo trang bị nghề nghiệp khác trong 10 phút kể từ lúc tháo ra'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_JOBITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Bạn chỉ có thể bỏ trang bị nghề nghiệp sau 20 giây kể từ trận chiến cuối cùng.'},
#  'UIIT_MSG_STRGERR_CANT_HAVE_CART': {'Service': '1',
#   'Data': 'Không thể bỏ trang bị nghề nghiệp ra trong khi đang triệu tập thú vận chuyển'},
#  'UIIT_MSG_COSERR_COLLISION_EXIST_BETWEEN_US': {'Service': '1',
#   'Data': 'Không thực hiện được lệnh di chuyển do có chướng ngại vật'},
#  'UIIT_MSG_INTERACTION_FAIL_IM_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận việc khác'},
#  'UIIT_MSG_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh vì kỹ năng hồi sinh của bạn còn thấp'},
#  'UIIT_MSG_SKILL_USE_FAIL_NOTENOUGHHP': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng đó vì không đủ HP'},
#  'UIIT_MSG_SKILL_USE_FAIL_ITS_NOT_A_BATTLE_FIELD': {'Service': '1',
#   'Data': 'Không thể tấn công trong khu vực an toàn'},
#  'UIIT_MSG_SKILL_USE_FAIL_WAITFOR_JOB_ACTIVATE': {'Service': '1',
#   'Data': 'Không thể tấn công trong 10 giây kể từ lúc mang trang bị nghề nghiệp vào'},
#  'UIIT_MSG_STRGERR_DONT_HAVE_ANY_TRADECART_TO_PICK_SPECIALTY': {'Service': '1',
#   'Data': 'Không thể nhận được đặc sản nếu không có thú vận chuyển'},
#  'UIIT_MSG_STRGERR_CANT_BE_STORED': {'Service': '1',
#   'Data': 'Món đồ đó không thể lưu tại nơi đã chỉ định'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị đồ vật vì cấp độ hoặc cấp độ tuyệt kỹ nhân vật còn thấp'},
#  'UIIT_MSG_STRGERR_LOCKED_BY_OTHER_ONE': {'Service': '1',
#   'Data': 'Không thể lấy được món đồ đó vì nó của người chơi khác'},
#  'UIIT_MSG_STRGERR_GENDER_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác giới tính'},
#  'UIIT_MSG_STRGERR_TRADE_BAY_FULL': {'Service': '1',
#   'Data': 'Không thể thêm vào món đồ đã chọn vì cửa sổ trao đổi đã đầy'},
#  'UIIT_MSG_STRGERR_COUNTRY_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác chủng tộc'},
#  'UIIT_MSG_STRGERR_HIGHER_STRENGTH_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì thiếu sức mạnh'},
#  'UIIT_MSG_STRGERR_HIGHER_INTELLECT_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì trí tuệ thấp'},
#  'UIIT_MSG_STRGERR_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_EU_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_CANT_EQUIP_RAZED_ITEM': {'Service': '1',
#   'Data': 'Không thể trang bị món đồ đã hỏng'},
#  'UIIT_MSG_STRGERR_PREV_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển.'},
#  'UIIT_MSG_STRGERR_POSSESSION_LIMIT_EXCEEDED': {'Service': '1',
#   'Data': 'Không thể có nhiều hơn số lượng giới hạn'},
#  'UIIT_MSG_STRGERR_ROBBER_CANT_SUMMON_CART_IN_TOWN': {'Service': '1',
#   'Data': 'Không thể triệu hồi phương tiện chuyên trở khi đang ở Làng Đạo Tặc'},
#  'UIIT_MSG_INTERACTION_FAIL_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển rồi'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_TRADECART': {'Service': '1',
#   'Data': 'Không thể dịch chuyển khi đang có thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_RIDE': {'Service': '1',
#   'Data': 'Không thể sử dụng cổng dịch chuyển khi đang cưỡi thú'},
#  'UIIT_MSG_INTERACTION_FAIL_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Không thể qua đò khi đang ở xa thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không sửa chữa được'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không làm lại được'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_TEMPORARILY': {'Service': '1',
#   'Data': 'Bất khả xâm phạm - Không thể tấn công hoăc bị tấn công trong 5 giây'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_FORTRESS': {'Service': '1',
#   'Data': 'Khi tấn công pháo đài trong tình trạng bất khả xâm phạm - không thể tấn công trong 10 giây'},
#  'UIIT_MSG_COSERR_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Một nhân vật không thể cách xa quá thú vận chuyển %d m'},
#  'UIIT_MSG_RETURN_CANCLE': {'Service': '1',
#   'Data': 'Việc sử dụng bùa dịch chuyển đã bị hủy bỏ'},
#  'UIIT_MSG_QUESTEND_2': {'Service': '1',
#   'Data': 'Hãy mở cửa sổ Nhiệm vụ (Q) để kiểm tra nội dung'},
#  'UIIT_MSG_JSERR_PREVIOUS_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể vào mê cung khi sắp dịch chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_OUT_OF_REQUIRED_LEVEL_FOR_TELEPORT': {'Service': '1',
#   'Data': 'Không thể dịch chuyển vì cấp độ của bạn quá thấp'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_FREEBATTLEITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Không thể bỏ khăn ra trong khi đang đánh nhau'},
#  'UIIT_MSG_STRGERR_STORAGE_OPERATION_BLOCKED': {'Service': '1',
#   'Data': 'Hiện tại bạn không được phép di chuyển các món đồ hoặc trao đổi chúng'},
#  'UIIT_MSG_QUEST_CALLMONSTER_NOTATTACK': {'Service': '1',
#   'Data': 'Cấp độ của bạn còn quá thấp để có thể đánh nhau với quái vật'},
#  'UIIT_MSG_QUEST_GET_ITEM_FAILURE': {'Service': '1',
#   'Data': 'Không thể nhặt được món đồ'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_MONSTER': {'Service': '1',
#   'Data': 'Không thể di chuyển vì bạn đã ở cách quái vật %d m.'},
#  'UIIT_MSG_QUEST_FAIL_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Đã thất bại trong việc bắt giữ quái vật.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_CHATTING_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn đang làm nhiệm vụ nên không thể tán gẫu được.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MOVING_IN_DUNGEON': {'Service': '1',
#   'Data': 'Đã ra khỏi vị trí chỉ định nên không thể di chuyển được nữa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_DO_IT_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này vì bạn đang làm một nhiệm vụ khác có liên quan.'},
#  'UIIT_MSG_QUEST_ERR_TOO_LOW_LEVEL': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này do cấp độ của bạn còn thấp'},
#  'UIIT_MSG_QUEST_END_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ kết thúc sau %d phút'},
#  'UIIT_MSG_QUEST_START_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ bắt đầu trong %d giây (s)'},
#  'UIIT_MSG_QUEST_ERR_USE_WHANITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật này trong trạng thái Cuồng nộ'},
#  'UIIT_MSG_QUEST_ERR_CAPTUREMONSTER_ATTACK': {'Service': '1',
#   'Data': 'Không thể tấn công quái vật đã sập bẫy'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Không thể bắt quái vật thì khoảng cách quá xa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì đã đặt bẫy rồi'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_EXIST_MONSTER': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì quái vật ở quá gần'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật vì điều kiện nhiệm vụ không cho phép'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_WRONG_PLACE': {'Service': '1',
#   'Data': 'Không thể đặt bẫy trong khu vực này'},
#  'UIIT_MSG_QUEST_ERR_NO_TARGET': {'Service': '1',
#   'Data': 'Mệnh lệnh không thể thực thi do chưa chọn đối tượng'},
#  'UIIT_MSG_CANNOT_BUYBACK_ITEM_SELL': {'Service': '1',
#   'Data': 'Đồ vật không thể mua lại được. Bạn có chắc muốn bán nó đi không?'},
#  'UIIT_MSG_QUEST_INS_TIMEOUT': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ hoàn htành sau %d giây, bạn sẽ được trở lại vị trí ban đầu.'},
#  'UIIT_MSG_QUEST_INS_CONDITION': {'Service': '1',
#   'Data': 'Bạn sẽ trở lại vị trí ban đầu trong 5 giây nữa vì nhận được yêu cầu không thể ở lại khu vực hiện tại.'},
#  'UIIT_MSG_QUEST_INS_DEATH': {'Service': '1',
#   'Data': 'Không thể chuyển đến khu vực khác khi nhân vật của bạn đang bị chết'},
#  'UIIT_MSG_DROP_WARNING_1': {'Service': '1',
#   'Data': 'Nếu bạn vứt đồ vật này ra ngoài, thì bạn sẽ mất đi quyền sở hữu đồ vật này'},
#  'UIIT_MSG_DROP_WARNING_2': {'Service': '1',
#   'Data': 'Người khác có thể nhật chúng. Bạn có chắc là muốn vứt nó ra không?'},
#  ...}

# %% [markdown]
# ## TextZoneName.txt

# %%
text_zone_name = os.path.join(server_dep, 'TextZoneName.txt')
text_zone_name
# Out:
# 'server_dep\\silkroad\\textdata\\TextZoneName.txt'

# %%
text_zone_name_files = get_lines(text_zone_name)
text_zone_name_files
# Out:
# ['TextZoneName_1000.txt',
#  'TextZoneName_1200.txt',
#  'TextZoneName_1400.txt',
#  'TextZoneName_1600.txt',
#  'TextZoneName_1800.txt',
#  'TextZoneName_200.txt',
#  'TextZoneName_2000.txt',
#  'TextZoneName_2200.txt',
#  'TextZoneName_2400.txt',
#  'TextZoneName_2600.txt',
#  'TextZoneName_2800.txt',
#  'TextZoneName_3000.txt',
#  'TextZoneName_3200.txt',
#  'TextZoneName_3400.txt',
#  'TextZoneName_3600.txt',
#  'TextZoneName_3800.txt',
#  'TextZoneName_400.txt',
#  'TextZoneName_4000.txt',
#  'TextZoneName_4200.txt',
#  'TextZoneName_4400.txt',
#  'TextZoneName_4600.txt',
#  'TextZoneName_600.txt',
#  'TextZoneName_800.txt',
#  '']

# %%
for xxx in text_zone_name_files:
  file_name = os.path.join(server_dep, xxx)
  lines = get_lines(file_name)
  for idx, line in enumerate(lines):
    values = line.split('\t')
    if len(values) < 11:
      continue
    Service = values[0]
    name_str_id = values[2]
    Data = values[10]
    data_text[name_str_id] = {
      "Service": Service,
      "Data": Data
    }

# %%
data_text
# Out:
# {'UIC_STT_FONTNAME': {'Service': '1', 'Data': 'Tahoma'},
#  'UIIS_STT_MSG_INSTALL_START': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa"'},
#  'UIIS_STT_MSG_INSTALL_FOLDER': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa" vào thư mục sau'},
#  'UIIS_STT_MSG_INSTALL_END': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt thành công'},
#  'UIIS_STT_INSTALL_FOLDER': {'Service': '1', 'Data': 'Thư mục cài đặt'},
#  'UIIS_STT_INSTALL_FILE': {'Service': '1', 'Data': 'File cài đặt'},
#  'UIIS_CTL_INSTALL': {'Service': '1', 'Data': 'Cài đặt'},
#  'UIIS_CTL_FIND_FOLDER': {'Service': '1', 'Data': 'Tìm kiếm'},
#  'UIIS_CTL_START': {'Service': '1', 'Data': 'Bắt đầu'},
#  'UIIS_CTL_CANCEL': {'Service': '1', 'Data': 'Hủy bỏ'},
#  'UIIS_CTL_CONFIRM': {'Service': '1', 'Data': 'Đồng ý'},
#  'UIIS_MSG_ALREADY_INSTALL': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt'},
#  'UIIS_MSG_UNPACK_ZIP': {'Service': '1',
#   'Data': 'Không thể giải nén Con Đường Tơ Lụa. \\nFile nén bị hỏng.'},
#  'UIIS_MSG_UNPACK_CLOSE': {'Service': '1',
#   'Data': 'Không thể đóng file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_UNPACK_OPEN': {'Service': '1',
#   'Data': 'Không thể mở file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_INSTALL_SPACE': {'Service': '1',
#   'Data': 'Không thể cài đặt do thiếu dung lượng. \\nCần ít nhất %d BYTE dung lượng đĩa'},
#  'UIIS_MSG_BACKBUFFER': {'Service': '1', 'Data': 'Không thể tạo bộ nhớ đệm'},
#  'UIIS_MSG_CHANGE_FOLDER': {'Service': '1',
#   'Data': 'Thư mục cài đặt đã bị thay đổi.\\nKhông thể gỡ bỏ Con Đường Tơ Lụa'},
#  'UIIS_MSG_NOFIND': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa chưa được cài đặt. Việc gỡ bỏ không có tác dụng'},
#  'UIIS_MSG_REMOVE_COMPLETE': {'Service': '1',
#   'Data': 'Tất cả các file đã được xóa bỏ hoàn toàn'},
#  'UIIS_MSG_REMOVE_FAIL': {'Service': '1', 'Data': 'Không thể gỡ bỏ'},
#  'UIIS_STT_DELETE': {'Service': '1', 'Data': 'Xóa thư mục Con Đường Tơ Lụa'},
#  'UIIS_CTL_DELETE': {'Service': '1', 'Data': 'Gỡ bỏ'},
#  'UIIS_CTL_EXIT': {'Service': '1', 'Data': 'Thoát'},
#  'UILM_MSG_PROCESS_ALREADY_EXITS': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đang chạy'},
#  'UILM_MSG_DETECTED_ABNORMAL_PROCESS': {'Service': '1',
#   'Data': 'Phát hiện lỗi chạy chương trình Con Đường Tơ Lụa (Lỗi hệ thống)'},
#  'UILM_MSG_FAILED_LOAD_CLIENT': {'Service': '1',
#   'Data': 'Không thể xác định đặc điểm client. Đang đóng.'},
#  'UILM_MSG_GATEWAY_NOT_IN_SERVICE_CHANNEL': {'Service': '1',
#   'Data': 'Máy chủ đang kiểm tra hoặc không làm việc. Truy cập trang %ssro.vtcgame.vn/ để biết thêm thông tin.'},
#  'UILM_MSG_DRIVER_UPDATE': {'Service': '1',
#   'Data': 'Driver đồ họa của bạn không phải là phiên bản mới nhất. Hãy cập nhật phiên bản mới nhất để xem hình ảnh game đẹp hơn.'},
#  'UILM_MSG_DRIVER_UPDATE_2': {'Service': '1',
#   'Data': 'Không bao giờ xuất hiện lại.'},
#  'UILM_MSG_FAILED_INIT_NETENGINE': {'Service': '1',
#   'Data': 'Không thể khởi chạy NetEngine (Lỗi (%d,%d))'},
#  'UILM_MSG_FAILED_LOAD_VERSION': {'Service': '1',
#   'Data': 'Không thể kiểm tra phiên bản'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_IP': {'Service': '1',
#   'Data': 'Không thể kiểm tra IP kết nối'},
#  'UILM_MSG_INVALID_CONNECT_IP': {'Service': '1',
#   'Data': 'IP kết nối không hợp lệ'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_PORT': {'Service': '1',
#   'Data': 'Không thể kiểm tra cổng kết nối'},
#  'UILM_MSG_INVALID_CONNECT_PORT': {'Service': '1',
#   'Data': 'Cổng kết nối không hợp lệ'},
#  'UILM_MSG_DETECTED_ABNORMAL_DIRECTX': {'Service': '1',
#   'Data': 'DirectX 9.0 chưa được cài đặt hoặc không phải là phiên bản 9.0b. Con Đường Tơ Lụa cần DirectX9.0b hoặc phiên bản mới hơn'},
#  'UILM_MSG_DETECTED_ABNORMAL_MODULE': {'Service': '1',
#   'Data': 'Không xác định client. Kết thúc.'},
#  'UILM_MSG_DETECTED_PATCH_DIABLE': {'Service': '1',
#   'Data': 'Bạn phải cài đặt toàn bộ phiên bản. Kết nối với trang chủ để download toàn bộ phiên bản.'},
#  'UILM_MSG_DETECTED_PATCH_MANUAL': {'Service': '1',
#   'Data': 'Bạn cần cài đặt thủ công. Vui lòng truy cập trang chủ để tải bản cài thủ công về. Bạn có muốn kết nối đến trang chủ không?'},
#  'UILM_MSG_FAILED_EXECUTE_EXPLORER': {'Service': '1',
#   'Data': 'Không thể chạy Internet Explorer.'},
#  'UILM_MSG_FAILED_PATCH': {'Service': '1',
#   'Data': 'Chưa hoàn thành việc sửa lỗi. Hãy thử lại.[Lỗi số(%d)]'},
#  'UILM_MSG_FAILED_EXECUTE_CLIENT': {'Service': '1',
#   'Data': 'Xin lỗi. Không thể chạy Con Đường Tơ Lụa [Lỗi số(%d)]'},
#  'UILM_MSG_NOTEXITS_REPLACERFILE': {'Service': '1',
#   'Data': 'Không tìm thấy file replacer.exe. Chưa hoàn thành việc sửa lỗi.'},
#  'UILM_MSG_DETECTED_ABNORMAL_REPLACERFILE': {'Service': '1',
#   'Data': 'Không thể sửa lỗi vì file replacer.exe đã bị hỏng [lỗi số (%d)]'},
#  'UILM_MSG_FAILED_LOAD_GATEWAY_INFO': {'Service': '1',
#   'Data': 'Không thể đưa ra thuộc tính kết nối của GateWay [lỗi%d]'},
#  'UILM_STT_DIVISION': {'Service': '1', 'Data': 'Bộ phận'},
#  'UILM_STT_DIVISION_LIST': {'Service': '1', 'Data': 'Danh sách bộ phận'},
#  'UILM_STT_DIVISION_SELECTED': {'Service': '1', 'Data': 'Bộ phận lựa chọn'},
#  'UILM_STT_DIVISION_NAME': {'Service': '1', 'Data': 'Tên bộ phận'},
#  'UILM_STT_FARM': {'Service': '1', 'Data': 'Giải'},
#  'UILM_STT_FARM_LIST': {'Service': '1', 'Data': 'Danh sách giải'},
#  'UILM_STT_FARM_NAME': {'Service': '1', 'Data': 'Tên giải'},
#  'FARM0101': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 01 Yahoo'},
#  'FARM0102': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 01 Yahoo'},
#  'FARM0103': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 01 Yahoo'},
#  'FARM0104': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 01 Yahoo'},
#  'FARM0105': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 01 Yahoo'},
#  'FARM0201': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 02 Yahoo'},
#  'FARM0202': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 02 Yahoo'},
#  'FARM0203': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 02 Yahoo'},
#  'FARM0204': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 02 Yahoo'},
#  'FARM0205': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 02 Yahoo'},
#  'FARM0301': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 03 Yahoo'},
#  'FARM0302': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 03 Yahoo'},
#  'FARM0303': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 03 Yahoo'},
#  'FARM0304': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 03 Yahoo'},
#  'FARM0305': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 03 Yahoo'},
#  'FARM0401': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 04 Yahoo'},
#  'FARM0402': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 04 Yahoo'},
#  'FARM0403': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 04 Yahoo'},
#  'FARM0404': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 04 Yahoo'},
#  'FARM0405': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 04 Yahoo'},
#  'UILM_STT_DIVISION_PING': {'Service': '1', 'Data': 'Ping'},
#  'UILM_STT_DIVISION_CONDITION': {'Service': '1', 'Data': 'Tình trạng'},
#  'DIV01': {'Service': '1', 'Data': 'Bộ phận Yahoo 01'},
#  'DIV02': {'Service': '1', 'Data': 'Bộ phận Yahoo 02'},
#  'DIV03': {'Service': '1', 'Data': 'Bộ phận Yahoo 03'},
#  'DIV04': {'Service': '1', 'Data': 'Bộ phận Yahoo 04'},
#  'DIV05': {'Service': '1', 'Data': 'Bộ phận Yahoo 05'},
#  'DIV06': {'Service': '1', 'Data': 'Bộ phận Yahoo 06'},
#  'DIV07': {'Service': '1', 'Data': 'Bộ phận Yahoo 07'},
#  'DIV08': {'Service': '1', 'Data': 'Bộ phận Yahoo 08'},
#  'DIV09': {'Service': '1', 'Data': 'Bộ phận Yahoo 09'},
#  'DIV10': {'Service': '1', 'Data': 'Bộ phận Yahoo 10'},
#  'UILM_STT_DIVISION_RECOMMENDATION': {'Service': '1', 'Data': 'Đề nghị'},
#  'UILM_STT_DIVISION_NOT_RECOMMENDATION': {'Service': '1',
#   'Data': 'Không đề nghị'},
#  'UILM_MSG_SILKROAD_STARTING_HOME': {'Service': '1',
#   'Data': 'Trang chủ của Con đường tơ lụa đã được đặt làm trang chủ mặc định'},
#  'UILM_MSG_YAHOO_STARTING_HOME': {'Service': '1',
#   'Data': 'Đã thiết đặt xong trang chủ https://sro.vtcgame.vn/'},
#  'UILM_MSG_YAHOO_TOOLBAR': {'Service': '1',
#   'Data': 'Đã thiết đặt xong thanh công cụ yahoo'},
#  'UILM_MSG_SERVICE_CLIENT_ERROR_REINSTALL': {'Service': '1',
#   'Data': 'Client của bạn bị lỗi hoặc đã bị phá huỷ nên không thể kết nối đến máy chủ. Hãy cài lại một client mới.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ download bị ngắt. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CANCEL': {'Service': '1',
#   'Data': 'Kết nới với máy chủ download đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_SELECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Launcher sẽ được khởi động lại.'},
#  'UILM_TEXT_CONFIG_GRAPHIC_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UILM_TEXT_CONFIG_GRAPHIC_NORMAL': {'Service': '1', 'Data': 'Bình thường'},
#  'UILM_TEXT_CONFIG_GRAPHIC_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UILM_TEXT_CONFIG_GRAPHIC_USER_DEF': {'Service': '1', 'Data': 'Không đổi'},
#  'UIIT_STT_ETCKEY': {'Service': '1', 'Data': 'Các phím khác'},
#  'UIIT_STT_MOUSE': {'Service': '1', 'Data': 'Chuột'},
#  'UIIT_STT_MOUSE_RIGHT_BUTTON': {'Service': '1', 'Data': 'Ô Nhớ Chuột'},
#  'UIIT_STT_USE_WHEEL_TO_CHANGE_SIGHT': {'Service': '1',
#   'Data': 'Chuột lăn (đổi góc nhìn) chuột phải (dùng Ô Nhớ)'},
#  'UIIT_STT_USE_WHEEL_TO_USE_SKILL': {'Service': '1',
#   'Data': 'Chuột lăn (dùng Ô Nhớ) chuột phải (đổi góc nhìn)'},
#  'UIIT_STT_ITEM_GET': {'Service': '1', 'Data': 'Nhặt đồ'},
#  'UIIT_STT_REFLECT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng phản xạ'},
#  'UIIT_STT_WATER_DETAIL': {'Service': '1', 'Data': 'Chi tiết nước'},
#  'UIIT_STT_LIGHT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng ánh sáng'},
#  'UIIT_STT_BUMP_MAPPING': {'Service': '1', 'Data': 'ánh xạ va chạm'},
#  'UIIT_STT_ENVIRONMENT_MAPPING': {'Service': '1', 'Data': 'ánh xạ môi trường'},
#  'UIIT_STT_LENS_FLAIR': {'Service': '1', 'Data': 'Độ nhạy của thấu kính'},
#  'UIIT_STT_DYNAMIC_ANIMATION': {'Service': '1', 'Data': 'ảnh động sống động'},
#  'UIIT_STT_WATER_REFLECTION': {'Service': '1', 'Data': 'Phản xạ nước'},
#  'UIIT_STT_FILTERING': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_TEXTER_DETAIL': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_GRAPHIC_QUALITY': {'Service': '1', 'Data': 'Chất lượng đồ họa'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL': {'Service': '1',
#   'Data': 'Người dùng tự chọn'},
#  'UIIT_STT_GRAPHIC_QUALITY_USER_CONTROL': {'Service': '1', 'Data': 'Tự chọn'},
#  'UIIT_STT_METAL_DETAIL': {'Service': '1', 'Data': 'Chất liệu kim loại'},
#  'UIIT_STT_BLOOM_EFFECT': {'Service': '1', 'Data': 'Âm lượng'},
#  'UIIT_STT_GRAPHIC': {'Service': '1', 'Data': 'Đồ họa'},
#  'UIIT_STT_RESOLUTION': {'Service': '1', 'Data': 'Độ phân giải'},
#  'UIIT_STT_LUMINOSITY': {'Service': '1', 'Data': 'Độ sáng tối'},
#  'UIIT_STT_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn'},
#  'UIIT_STT_CHAR_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn nhân vật'},
#  'UIIT_STT_SCENERY_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn bối cảnh'},
#  'UIIT_STT_SHADOW_DETAIL': {'Service': '1', 'Data': 'Chi tiết bóng'},
#  'UIIT_STT_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_MIDDLE': {'Service': '1', 'Data': 'Vừa'},
#  'UIIT_STT_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_VERY_DARK': {'Service': '1', 'Data': 'Rất tối'},
#  'UIIT_STT_DARK': {'Service': '1', 'Data': 'Tối'},
#  'UIIT_STT_NORMAL': {'Service': '1', 'Data': 'Trung bình'},
#  'UIIT_STT_LIGHT': {'Service': '1', 'Data': 'Sáng'},
#  'UIIT_STT_VERY_LIGHT': {'Service': '1', 'Data': 'Rất sáng'},
#  'UIIT_STT_SIGHT_VERY_SMALL': {'Service': '1', 'Data': 'Rất hẹp'},
#  'UIIT_STT_SIGHT_SMALL': {'Service': '1', 'Data': 'Hẹp'},
#  'UIIT_STT_SIGHT_LARGE': {'Service': '1', 'Data': 'Rộng'},
#  'UIIT_STT_SIGHT_VERY_LARGE': {'Service': '1', 'Data': 'Rất rộng'},
#  'UIIT_STT_NONE': {'Service': '1', 'Data': 'Không có'},
#  'UIIT_STT_CIRCLE': {'Service': '1', 'Data': 'Vòng tròn'},
#  'UIIT_STT_DETAIL': {'Service': '1', 'Data': 'Chi tiết'},
#  'UIIT_STT_RANK': {'Service': '1', 'Data': '%d bước'},
#  'UIIT_STT_ON': {'Service': '1', 'Data': 'Bật'},
#  'UIIT_STT_OFF': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_GRAPHIC_QUALITY_MIDDLE': {'Service': '1', 'Data': 'Bình thường'},
#  'UIIT_STT_GRAPHIC_QUALITY_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL1': {'Service': '1', 'Data': 'Đồ họa 1'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL2': {'Service': '1', 'Data': 'Đồ họa 2'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_WAR': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_USER': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_VIDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể thay đổi độ phân giải của game'},
#  'UIIT_STT_VIDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể thay đổi độ sáng của game'},
#  'UIIT_STT_VIDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể thay đổi chất lượng đồ hoạ của game. Tìm đến lựa chọn Video và thiết lập các mức độ cao, trung bình hay thấp. Tốc độ tải trò chơi sẽ thay đổi tuỳ theo các mức chất lượng được thiết lập.'},
#  'UIIT_STT_VIDIO_TTDESC_04': {'Service': '1',
#   'Data': 'Có thể thay đổi mức độ chi biết bóng. Tốc độ tải game có thể bị chậm nếu chi tiết bóng được đặt ở mức cao.'},
#  'UIIT_STT_VIDIO_TTDESC_05': {'Service': '1',
#   'Data': 'Khi thiết lập khung cảnh được đặt ở mức cao, có thể nhìn thấy nhiều hình ảnh hơn, tuy nhiên, điều này cũng sẽ làm chậm tốc độ tải game. Có thể thiết lập ở mức thấp, khi đó sẽ chỉ nhìn thấy những khung cảnh ở gần.'},
#  'UIIT_STT_VIDIO_TTDESC_06': {'Service': '1',
#   'Data': 'Khi các thông tin ở nhân vật, quái vật, lâu đài... được lựa chọn hiển thị nhiều, bạn sẽ biết đầy đủ thông tin hơn nhưng như vậy có thể gây chậm tốc độ tải game.'},
#  'UIIT_STT_VIDIO_TTDESC_07': {'Service': '1',
#   'Data': 'Lựa chọn chi tiết bóng nước để hiển thị các hình ảnh được phản chiếu trên mặt nước.'},
#  'UIIT_STT_VIDIO_TTDESC_08': {'Service': '1',
#   'Data': 'Chi tiết nước được lựa chọn với các mức độ hiệu ứng mặt nước, nếu lựa chọn mức độ cao, cảnh mặt nước sẽ đẹp hơn nhưng tốc độ tải game sẽ bị chậm đi.'},
#  'UIIT_STT_VIDIO_TTDESC_09': {'Service': '1',
#   'Data': 'Chi tiết hiển thị kim loại, nếu được lựa chọn, sẽ hiển thị các hiệu ứng ánh kim trên đồ vật kim loại như giáp, vũ khí. Mức độ lựa chọn càng cao thì chất lượng đồ hoạ cũng tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_10': {'Service': '1',
#   'Data': 'Hiệu ứng ánh sáng chỉ hiệu ứng của đèn khi chiếu trên bề mặt đồ vật, khi lựa chọn mức độ hiển thị ánh sáng cao thì độ thật của đồ vật sẽ tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_11': {'Service': '1',
#   'Data': 'Chi tiết chất liệu chỉ mức độ chi tiết của chất liệu. Chất lượng hiển thị chất liệu của đồ vật sẽ tăng lên khi chi tiết chất liệu được lựa chọn ở mức độ cao.'},
#  'UIIT_STT_VIDIO_TTDESC_12': {'Service': '1',
#   'Data': 'Chi tiết thấu kính chỉ tình trạng chiếu sáng giống như một máy quay phim đang hướng về phía mặt trời.'},
#  'UIIT_STT_VIDIO_TTDESC_13': {'Service': '1',
#   'Data': 'Hiệu ứng nở hoa chỉ tình trạng hoà trộn màu sắc giống như muôn ngàn bông hoa đang nở.'},
#  'UIIT_STT_VIDIO_TTDESC_14': {'Service': '1',
#   'Data': 'Chuyển động học chỉ kỹ thuật chuyển động của các động tác, chuyển động của tóc...'},
#  'UIIT_STT_VIDIO_TTDESC_15': {'Service': '1',
#   'Data': 'Bù đắp các phác thảo thô để các đổi tượng trong tự nhiên hơn.'},
#  'UIIT_STT_VIDIO_TTDESC_16': {'Service': '1',
#   'Data': 'Tắt hiệu ứng skill để hệ thống chạy mượt hơn'},
#  'UIIT_STT_VIDIO_TTDESC_17': {'Service': '1',
#   'Data': 'Khi được trang bị bộ đồ chiến đấu lớn, người chơi gần đó sẽ được nâng cao khả năng chiến trận'},
#  'UIIT_STT_VIDIO_TTDESC_18': {'Service': '1',
#   'Data': 'Hiển thị các hiệu ứng của tất cả các đối tượng trên màn hình chi tiết, và ánh kim loại có thể không kiểm soát được. Tùy chọn này được bất hoạt cho hình ảnh đồ họa thấp.'},
#  'UIIT_STT_GAMESET_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của thú như thú nuôi, thú thồ hàng…'},
#  'UIIT_STT_GAMESET_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của người chơi cùng nhóm'},
#  'UIIT_STT_GAMESET_TTDESC_03': {'Service': '1',
#   'Data': 'Báo động khi HP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_04': {'Service': '1',
#   'Data': 'Báo động khi MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_05': {'Service': '1',
#   'Data': 'Báo động thành tiếng khi HP/MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_AUDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể lựa chọn nhạc nền, bật/tắt/điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh pha trộn, bật/tắt điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh theo khu vực, bật/tắt, điều chỉnh âm lượng'},
#  'UIIT_STT_VIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn tự do'},
#  'UIIT_STT_VIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn từ nhân vật thứ ba để theo dõi bản thân từ sau lưng'},
#  'UIIT_STT_VIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn 1/4, tình trạng không thể thay đổi chất lượng màn hình cao/thấp'},
#  'UIIT_STT_INPUT_TTDESC_01': {'Service': '1',
#   'Data': 'sử dụng chuột hoặc phím tắt để thay đổi tầm nhìn.'},
#  'UIIT_STT_INPUT_TTDESC_02': {'Service': '1',
#   'Data': 'Để thay đổi tầm nhìn, sử dụng chuột phải hoặc phím tắt.'},
#  'UIIT_STT_INPUT_TTDESC_03': {'Service': '1',
#   'Data': 'Mở cửa sổ thông tin nhân vật để kiểm tra các thông tin cơ bản về nhân vật như trang bị, chỉ số sức mạnh/trí tuệ...'},
#  'UIIT_STT_INPUT_TTDESC_04': {'Service': '1',
#   'Data': 'Mở cửa sổ kỹ năng để có thể xem /học các kỹ năng, tăng/giảm chỉ số Tuyệt Kỹ.'},
#  'UIIT_STT_INPUT_TTDESC_05': {'Service': '1',
#   'Data': 'Mở cửa sổ nhóm để có thể lập nhóm, gia nhập nhóm hoặc thiết lập các điều kiện của nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_06': {'Service': '1',
#   'Data': 'Mở cửa sổ cộng đồng. Các thông tin về Hội hoặc tin nhắn, danh sách bạn bè... có thể tìm thấy ở đây.'},
#  'UIIT_STT_INPUT_TTDESC_07': {'Service': '1',
#   'Data': 'sử dụng chế độ Cuồng nộ. Bắt đầu bằng việc nhấn chuột phải lên nút năng lượng to nhất ở ô hiển thị chế độ Cuồng Nộ trên góc trái màn hình.'},
#  'UIIT_STT_INPUT_TTDESC_08': {'Service': '1',
#   'Data': 'Cửa sổ trợ giúp. Giải đáp các thắc mắc cơ bản của người chơi.'},
#  'UIIT_STT_INPUT_TTDESC_09': {'Service': '1',
#   'Data': 'sử dụng các ô nhớ nhanh hoặc bấm chuột phải vào các kỹ năng để thi triển kỹ năng.'},
#  'UIIT_STT_INPUT_TTDESC_10': {'Service': '1',
#   'Data': 'Phím tắt để nhặt đồ tự động trên mặt đất.'},
#  'UIIT_STT_INPUT_TTDESC_11': {'Service': '1',
#   'Data': 'Triệu tập hoặc thu hồi thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_12': {'Service': '1', 'Data': 'Để thú nuôi theo sau.'},
#  'UIIT_STT_INPUT_TTDESC_13': {'Service': '1',
#   'Data': 'Thiết lập chế độ nhặt của thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_14': {'Service': '1',
#   'Data': 'Bạn có thể gửi tin nhắn trực tiếp đến người đã nhắn cho bạn bằng cách nhấn vào nút tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_15': {'Service': '1',
#   'Data': 'Bạn có thể thay đổi thú nuôi bằng cách nhấn nút chuyển đổi thú nuôi khi có nhiều thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_16': {'Service': '1',
#   'Data': 'Mở cửa sổ giả kim thuật. Bạn có thể gia tăng sức mạnh của đồ vật và thêm các tính chất cho đồ vật tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_17': {'Service': '1',
#   'Data': 'Khi tắt chế độ hiển thị đồ vật, mọi thứ như các nhân vật khác, quái vật, thú nuôi... sẽ không được hiển thị ngoại trừ bản thân bạn.'},
#  'UIIT_STT_INPUT_TTDESC_18': {'Service': '1', 'Data': 'Mở hành trang'},
#  'UIIT_STT_INPUT_TTDESC_19': {'Service': '1',
#   'Data': 'Mở cửa sổ hành động. Có rất nhiều phím tắt, icon diễn tả cảm giác hay hành động khác nhau như lập gian hàng, chào hỏi...'},
#  'UIIT_STT_INPUT_TTDESC_20': {'Service': '1',
#   'Data': 'Mở cửa sổ nhiệm vụ để kiểm tra danh sách và thông tin về các nhiệm vụ đang thực hiện.'},
#  'UIIT_STT_INPUT_TTDESC_21': {'Service': '1',
#   'Data': 'Mở toàn bộ bản đồ để kiểm tra vị trí của bản thân và các thành viên trong nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_22': {'Service': '1',
#   'Data': 'Thay đổi tầm nhìn: tầm nhìn tự do --> tầm nhìn từ người thứ ba --> tầm nhìn 1/4 --> lặp lại tầm nhìn tự do'},
#  'UIIT_STT_INPUT_TTDESC_23': {'Service': '1',
#   'Data': 'Kiểm tra tên của các đồ vật dưới đất bằng cách sử dụng phím tắt tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_24': {'Service': '1',
#   'Data': 'Thiết lập chế độ đứng\\ngồi của nhân vật. Khi ngồi, tốc độ hồi phục HP/MP của nhân vật sẽ nhanh hơn.'},
#  'UIIT_STT_INPUT_TTDESC_25': {'Service': '1',
#   'Data': 'Cửa sổ kiểm tra tình trạng của thú nuôi: có thể thiết lập tên của thú nuôi, kiểm tra thông tin thú nuôi tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_26': {'Service': '1', 'Data': 'Thu hồi thú nuôi'},
#  'UIIT_STT_INPUT_TTDESC_27': {'Service': '1',
#   'Data': 'Yêu cầu thú nuôi tấn công'},
#  'UIIT_STT_INPUT_TTDESC_28': {'Service': '1',
#   'Data': 'Có thể sử dụng Hệ thống Siêu thị, tại đây, bạn có thể dùng silk để mua các đồ vật hữu dụng.'},
#  'UIIT_STT_INPUT_TTDESC_29': {'Service': '1',
#   'Data': 'Bạn có thể thiết lập chế độ tự động sử dụng giải dược và thuốc hồi phục, khi đó, việc luyện tập của bạn sẽ dễ dàng hơn.'},
#  'UIIT_STT_INPUT_TTDESC_30': {'Service': '1',
#   'Data': 'Mở cửa sổ gia nhập nhóm. Tại đây, bạn có thể tìm các nhóm đang thiếu thành viên để gia nhập.'},
#  'UIIT_STT_INPUT_TTDESC_31': {'Service': '1',
#   'Data': 'Mở cửa sổ hệ thống gian hàng. Tại đây, bạn có thể dễ dàng tìm thấy các đồ vật được bán trong hệ thống.'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị tên nhân vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị tên quái vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Hiển thị tên Hội'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_04': {'Service': '1',
#   'Data': 'Hiển thị tên các nhân vật khác'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_05': {'Service': '1',
#   'Data': 'Hiển thị tên NPC'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_06': {'Service': '1',
#   'Data': 'Hiển thị biểu tượng cấp độ thấp. Nếu lựa chọn, một dấu hiệu sẽ xuất hiện bên cạnh tên nhân vật của bạn và sẽ biến mất khi bạn lên cấp độ cao.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_01': {'Service': '1',
#   'Data': 'Trong trò chơi có rất nhiều chỉ dẫn được hiển thị dưới dạng tin nhắn ngắn trên cửa sổ trò chuyện. Bạn sẽ tìm thấy các thông tin hữu ích tại đây.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_02': {'Service': '1',
#   'Data': 'Cho phép hiển thị cửa sổ chú ý. Các chỉ dẫn chi tiết sẽ được hiển thị hoặc kiểm tra các thông tin quan trọng khi chuyển sang hệ thống mới. Sẽ rất hữu dụng khi bạn mới gia nhập trò chơi.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_03': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_04': {'Service': '1',
#   'Data': 'Ẩn hệ thống Windows một cách tự động. Nếu sử dụng chức năng này, khung của hệ thống Windows sẽ ẩn đi một cách tự động và chỉ xuất hiện trở lại khi bạn đưa con trỏ chuột lên trên.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_05': {'Service': '1',
#   'Data': 'Chuyển màn hình trò chơi sang chế độ cửa sổ. Bạn có thể sử dụng chế độ cửa sổ theo sở thích.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_06': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu mời vào nhóm. Nếu không sử dụng lựa chọn này, mọi lời mời vào nhóm gửi đến sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_07': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu giao dịch. Nếu không sử dụng chọn lựa này, mọi yêu cầu giao dịch gửi đến sẽ bị từ chối. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_08': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn cá nhân. Nếu không chọn chức năng này, mọi tin nhắn cá nhân sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_09': {'Service': '1',
#   'Data': 'Thể hiện thông tin về các trạng thái tăng cường của nhân vật trong phần thông tin nhân vật thuộc nhóm. Nếu không lựa chọn chức năng này, các thông tin sẽ không thể hiện. Không quan sát được trạng thái dị trạng của nhân vật.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_10': {'Service': '1',
#   'Data': 'Khởi động nhanh trò chơi bằng việc nạp hình ảnh bối cảnh trước khi nạp hình ảnh nhân vật. Đánh dấu vào ô này nếu bạn muốn trò chơi khởi động nhanh hơn.'},
#  'UIIT_MSG_CHATWND_HELP_WHISPER': {'Service': '1',
#   'Data': 'Thì thầm  [$tênnhânvật những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_PARTYMSG': {'Service': '1',
#   'Data': 'Tán gẫu trong nhóm [#những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_USECONTROLATSTORE': {'Service': '1',
#   'Data': 'Nếu bạn ấn phím Ctrl, bạn có thể bán hoặc mua đồ nhanh hơn'},
#  'UIIT_MSG_NOTIFY': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_MSG_CHATWND_MESSAGE_FILTER': {'Service': '1',
#   'Data': 'Một số từ ngữ hoặc cách diễn đạt bị cấm dùng'},
#  'UIIT_STT_GAMEGUIDE_START_1': {'Service': '1',
#   'Data': 'Hãy tìm hiểu những thông tin cơ bản về Con Đường Tơ Lụa và làm quen với những thông tin này trước. Thông qua cửa sổ tán gẫu bạn có thể học được thêm những chỉ dẫn vì vậy hãy luyện thói quen thật chú ý tới những hướng dẫn này. Chắc chắn bạn sẽ thu được những thông tin rất bổ ích.'},
#  'UIIT_STT_GAMEGUIDE_START_2': {'Service': '1',
#   'Data': '※ Hướng dẫn trò chơi có thể được sử dụng bất kỳ lúc nào bằng việc bấm phím  [H]'},
#  'UIIT_STT_GAMEGUIDE': {'Service': '1', 'Data': 'Trợ giúp'},
#  'UIIT_STT_EVENTGUIDE': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_QUESTGUIDE1': {'Service': '1', 'Data': 'Nhiệm vụ'},
#  'UIIT_STT_QUESTGUIDE2': {'Service': '1', 'Data': 'Từ điển nhiệm vụ'},
#  'UIIT_STT_GAMEEVENTGUIDE': {'Service': '1', 'Data': 'Hướng dẫn'},
#  'UIIT_STT_CONFIRM_BOX': {'Service': '1', 'Data': 'Cửa sổ xác nhận'},
#  'UIIT_STT_AGREEMENT_BOX': {'Service': '1', 'Data': 'Cửa sổ đồng ý'},
#  'UIIT_STT_INPUT_BOX': {'Service': '1', 'Data': 'Cửa sổ nhập vào'},
#  'UIIT_PAG_WORLDMAP': {'Service': '1', 'Data': 'Bản đồ lớn'},
#  'UIIT_PAG_LOCALMAP': {'Service': '1', 'Data': 'Bản đồ khu vực'},
#  'UIIT_STT_BACK_WORLDMAP': {'Service': '1', 'Data': 'Mở bản đồ lớn'},
#  'UIIT_STT_JANGAN': {'Service': '1', 'Data': 'Trường An'},
#  'UIIT_STT_DONHWANG': {'Service': '1', 'Data': 'Đôn Hoàng'},
#  'UIIT_STT_KHOTAN': {'Service': '1', 'Data': 'Hòa Điền'},
#  'UIIT_STT_SAMARKAND': {'Service': '1', 'Data': 'Samarkand'},
#  'UIIT_STT_CONSTANTINOPLE': {'Service': '1', 'Data': 'Constantinople'},
#  'UIIT_STT_BIJEOKDAN': {'Service': '1', 'Data': 'Bijeokdan'},
#  'UIIT_STT_HEUKMAKDAN': {'Service': '1', 'Data': 'Heukmakdan'},
#  'UIIT_STT_EVILORDER': {'Service': '1', 'Data': 'Pháo đài tà ác'},
#  'UIIT_STT_ARABIA_CITY': {'Service': '1', 'Data': 'Baghdad'},
#  'UIIT_STT_ARABIA_CITY_DUNGEON': {'Service': '1', 'Data': 'Baghdad (Phụ bản)'},
#  'UIIT_STT_MUHAN': {'Service': '1', 'Data': 'Đấu trường Vô Cực'},
#  'UIIT_MSG_CHEATMSG_GO_TOWN': {'Service': '1', 'Data': '/town'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_1': {'Service': '1',
#   'Data': 'Tìm thấy macro (chơi tự động) trong nhân vật đang chơi. Tự động thoát.'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_2': {'Service': '1',
#   'Data': 'Tên của nhân vật có macro và thời gian đã sử dụng sẽ được ghi lại trên máy chủ'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_3': {'Service': '1',
#   'Data': 'Có thể áp dụng hình phạt giới hạn về thời gian của tài khoản và khóa tài khoản'},
#  'UIIT_MSG_APPEAR_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa xuất hiện ở Hổ Huyệt Sơn'},
#  'UIIT_MSG_APPEAR_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã xuất hiện'},
#  'UIIT_MSG_APPEAR_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi xuất hiện ở Karakoram'},
#  'UIIT_MSG_APPEAR_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan xuất hiện ở Taklamakan'},
#  'UIIT_MSG_APPEAR_TAHOMET': {'Service': '1',
#   'Data': 'Sa Y Thần xuất hiện ở Lạc Khắc Sơn'},
#  'UIIT_MSG_APPEAR_UNIC': {'Service': '1', 'Data': '[%s] đã xuất hiện'},
#  'UIIT_MSG_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn đã biến mất'},
#  'UIIT_MSG_DEAD_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã biến mất'},
#  'UIIT_MSG_DEAD_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi từ Karakoram đã biến mất'},
#  'UIIT_MSG_DEAD_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan từ Taklamakan đã biến mất'},
#  'UIIT_MSG_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã biến mất'},
#  'UIIT_MSG_ANYONE_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': '[%s] đã giết Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_URRUCHI': {'Service': '1',
#   'Data': '[%s] đã giết Ô Lỗ Tề từ Tháp Lý Mộc'},
#  'UIIT_MSG_ANYONE_DEAD_IYUTARU': {'Service': '1',
#   'Data': '[%s] đã giết Băng Chúa Nhi từ Karakoram'},
#  'UIIT_MSG_ANYONE_DEAD_BONELORD': {'Service': '1',
#   'Data': '[%s] đã giết Chúa tể Yarkan từ Taklamakan'},
#  'UIIT_MSG_ANYONE_DEAD_TAHOMET': {'Service': '1',
#   'Data': '[%s] đã giết Sa Y Than từ Lạc Khắc Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã giết [%s]'},
#  'UIIT_STT_ROLL_OF_CLOTH': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILK_BUY_RESULT': {'Service': '1', 'Data': 'Bạn đã mua [%d] silk'},
#  'UIIT_STT_SILK_BUY_CANCLE': {'Service': '1',
#   'Data': 'Việc mua bán [%d] silk đã bị hủy bỏ'},
#  'UIIT_STT_SILK_BUY_RECEIVE': {'Service': '1',
#   'Data': 'Bạn nhận được quà là [%d] silk'},
#  'UIIT_STT_SILK_SEND_RESULT': {'Service': '1',
#   'Data': 'Bạn đã gửi [%d] silk đi làm quà'},
#  'UIIT_STT_SILK_POINT_BUY_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được trả tiền'},
#  'UIIT_STT_SILK_POINT_USE_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được sử dụng'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK': {'Service': '1', 'Data': 'Silk đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_MALL': {'Service': '1', 'Data': 'Cửa hàng Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_MALL': {'Service': '1',
#   'Data': 'Cửa hàng đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_TOTAL': {'Service': '1', 'Data': 'Tổng số Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_TOTAL': {'Service': '1',
#   'Data': 'Tổng số Silk đặc biệt'},
#  'UIIT_STT_SILKMALL': {'Service': '1', 'Data': 'Siêu thị'},
#  'UIIT_STT_SILKMALL_MAIN': {'Service': '1', 'Data': 'Phần chính'},
#  'UIIT_STT_SILKMALL_HOT_STORE': {'Service': '1', 'Data': 'HOT Shop'},
#  'UIIT_STT_SILKMALL_CONSUMPTION': {'Service': '1', 'Data': 'Đồ tiêu dùng'},
#  'UIIT_STT_SILKMALL_LEND_ITEM': {'Service': '1', 'Data': 'Tiền thuê đồ'},
#  'UIIT_STT_SILKMALL_AVATA': {'Service': '1', 'Data': 'Trang trí'},
#  'UIIT_STT_SILKMALL_PET': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PACKAGE': {'Service': '1', 'Data': 'Gói hàng'},
#  'UIIT_STT_SILKMALL_SHOPPING_BASKET_LIST': {'Service': '1',
#   'Data': 'Hàng đã chọn'},
#  'UIIT_STT_SILKMALL_NEW_ITEM': {'Service': '1', 'Data': 'Hàng mới'},
#  'UIIT_STT_SILKMALL_EVENT': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_SPECIAL_COAST': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_FAVORITE': {'Service': '1', 'Data': 'Hàng bán chạy'},
#  'UIIT_STT_SILKMALL_SPECIAL': {'Service': '1', 'Data': 'Đặc biệt'},
#  'UIIT_STT_SILKMALL_SCROLL': {'Service': '1', 'Data': 'Hỗ trợ'},
#  'UIIT_STT_SILKMALL_POTION': {'Service': '1', 'Data': 'Hồi phục'},
#  'UIIT_STT_SILKMALL_COMMUNITY': {'Service': '1', 'Data': 'Cộng đồng'},
#  'UIIT_STT_SILKMALL_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY': {'Service': '1', 'Data': 'Giả kim thuật'},
#  'UIIT_STT_SILKMALL_PREMIUM_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ASTRAL': {'Service': '1', 'Data': 'Tinh thạch'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': 'Bất diệt (bảo toàn 99%)'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_3': {'Service': '1', 'Data': 'Áo nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_4': {'Service': '1', 'Data': 'Quần nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_5': {'Service': '1', 'Data': 'Bao tay'},
#  'UIIT_STT_SILKMALL_ARMOR_6': {'Service': '1', 'Data': 'Giầy nặng'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_3': {'Service': '1', 'Data': 'Áo nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_4': {'Service': '1', 'Data': 'Quần nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_6': {'Service': '1', 'Data': 'Giầy nhẹ'},
#  'UIIT_STT_SILKMALL_CLOSE_1': {'Service': '1', 'Data': 'Khăn'},
#  'UIIT_STT_SILKMALL_CLOSE_2': {'Service': '1', 'Data': 'Cầu vai vải'},
#  'UIIT_STT_SILKMALL_CLOSE_3': {'Service': '1', 'Data': 'Áo vải'},
#  'UIIT_STT_SILKMALL_CLOSE_4': {'Service': '1', 'Data': 'Quần vải'},
#  'UIIT_STT_SILKMALL_CLOSE_6': {'Service': '1', 'Data': 'Giầy vải'},
#  'UIIT_STT_SILKMALL_BIG_STORE': {'Service': '1', 'Data': 'Tiệm lớn'},
#  'UIIT_STT_SILKMALL_ASSIST': {'Service': '1', 'Data': 'Chi nhánh'},
#  'UIIT_STT_SILKMALL_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_HAT': {'Service': '1', 'Data': 'Mũ'},
#  'UIIT_STT_SILKMALL_BOOTH': {'Service': '1', 'Data': 'Gian hàng'},
#  'UIIT_STT_SILKMALL_FIREWORK': {'Service': '1', 'Data': 'Kẹo'},
#  'UIIT_STT_SILKMALL_DRESS': {'Service': '1', 'Data': 'Trang phục'},
#  'UIIT_STT_SILKMALL_ATTACH': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_BALLOON': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_PET_SUMMON': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PET_CONSUME': {'Service': '1', 'Data': 'Thú nuôi hết hạn'},
#  'UIIT_STT_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1', 'Data': 'Mua hết'},
#  'UIIT_STT_SILKMALL_BOOK_MARK': {'Service': '1', 'Data': 'Sổ sách'},
#  'UIIT_STT_SILKMALL_PUT_ON': {'Service': '1', 'Data': 'sử dụng thử'},
#  'UIIT_STT_SILKMALL_BUY': {'Service': '1', 'Data': 'Mua'},
#  'UIIT_STT_SILKMALL_PRESENT': {'Service': '1', 'Data': 'Quà'},
#  'UIIT_STT_SILKMALL_DEL': {'Service': '1', 'Data': 'Xóa'},
#  'UIIT_STT_SILKMALL_BUY_LIST': {'Service': '1', 'Data': 'Hàng mua'},
#  'UIIT_STT_SILKMALL_RECEIVE_LIST': {'Service': '1', 'Data': 'Hàng nhận'},
#  'UIIT_STT_SILKMALL_SILKMALL_OUT': {'Service': '1', 'Data': 'Thoát'},
#  'UIIT_STT_SILKMALL_PUT_ON_CLOSE_BUY': {'Service': '1',
#   'Data': 'Mua đồ thời trang'},
#  'UIIT_STT_SILKMALL_ALL_CLOSE_TAKEOFF': {'Service': '1', 'Data': 'Cởi bỏ'},
#  'UIIT_STT_SILKMALL_ADD_INVENTORY': {'Service': '1', 'Data': 'Ô mở rộng'},
#  'UIIT_STT_SILKMALL_ADD_STOREHOUSE_INVENTORY': {'Service': '1',
#   'Data': 'Kho mở rộng'},
#  'UIIT_STT_SILKMALL_SILK': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILKMALL_BUY_SILK': {'Service': '1', 'Data': 'Mua Silk'},
#  'UIIT_STT_SILKMALL_SEND_SILK': {'Service': '1', 'Data': 'Tặng Silk'},
#  'UIIT_STT_SILKMALL_COUPON_EXCHANGE': {'Service': '1',
#   'Data': 'Trao đổi phiếu'},
#  'UIIT_STT_SILKMALL_BUY_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_03': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_USE_INFOMATION': {'Service': '1',
#   'Data': 'Cách sử dụng Siêu thị'},
#  'UIIT_STT_SILKMALL_ENTER': {'Service': '1', 'Data': 'Vào Siêu thị'},
#  'UIIT_STT_SILKMALL_DIRECT_ENTER': {'Service': '1',
#   'Data': 'Vào nhanh Siêu thị'},
#  'UIIT_STT_SILKMALL_NEW_CASHITEM': {'Service': '1',
#   'Data': 'Siêu thị cập nhật đồ vật mới'},
#  'UIIT_STT_SILKMALL_WARNING_1': {'Service': '1',
#   'Data': 'Bạn có thể bị quái vật'},
#  'UIIT_STT_SILKMALL_WARNING_2': {'Service': '1',
#   'Data': 'hoặc những người chơi khác tấn công trong khi vào Siêu thị'},
#  'UIIT_STT_SILKMALL_WARNING_3': {'Service': '1',
#   'Data': 'Nên sử dụng món đồ trong khu vực an toàn'},
#  'UIIT_STT_SILKMALL_MAIN_EXPLAIN': {'Service': '1',
#   'Data': '<sml2><p line_margin="12"><p line_margin="5"><font color="255,255,153,81" style="bold">Siêu Thị là gì?</font><br>Là nơi bán và cho thuê những trang bị để <br>sử dụng trên Con đường tơ lụa. Những trang bị đó phải sử dụng silk để mua.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Mua Silk</font><br>Silk có thể mua bằng cách bấm vào nút Mua silk ở góc trên bên phải màn hình.<br>Bấm vào nút Mua silk bạn sẽ được chuyển đến trang E-Cash.<br>nơi để bạn mua silk.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Tặng Silk</font><font color="255,255,117,117">(Tính năng chưa kích hoạt)</font><br>Trong quá trình mua đồ trong Siêu Thị, bạn có thể bấm vào nút Tặng Silk để gửi <br>tới người chơi khác món đồ bạn chọn.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Coupons exchanges</font><br>Phiếu giảm giá có thể được sử dụng 1 lần để mua silk hoặc sử dụng các item Mall.<br>Điền con số vào phiếu giảm giá để nhận được silk.<br>Số tiền có thể khác nhau tùy thuộc vào các loại phiếu giảm giá.<br></p></p><strong><font color="255,255,153,81">Sổ sách</font></strong><font color="255,255,117,117">(Tính năng chưa được kích hoạt)</font><br>Tất cả những đồ vật bạn mua trong Siêu Thị có thể được lưu giữ trong sổ sách của bạn <br>bằng cách bấm vào Sổ sách. Đồ vật đã lưu trong Sổ của bạn sẽ được hoàn trả <br>ngay cả khi bạn đã mua đồ vật đó.</sml2>'},
#  'UIIT_STT_SILKMALL_MY_INFO': {'Service': '1', 'Data': 'Thông tin cá nhân'},
#  'UIIT_STT_SILKMALL_POSSESSION_GOLD': {'Service': '1',
#   'Data': 'Số lượng hiện có'},
#  'UIIT_STT_SILKMALL_REMAIN_INVENTORY': {'Service': '1', 'Data': '%d ô trống'},
#  'UIIT_STT_SILKMALL_MAIN_INTRO': {'Service': '1',
#   'Data': '<sml2>Chào mừng quý khách đến với cửa hàng bán đồ chất lượng cao của Con Đường Tơ Lụa</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ORDER_SHEET': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_TOOL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_FLEAMARKET': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_ZZIM': {'Service': '1',
#   'Data': '<sml2>Đây là danh sách hàng bạn đặt mua</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_FAVORITY': {'Service': '1',
#   'Data': '<sml2>Có thể xem danh sách những mặt hàng đã mua hoặc chọn trong phần Sổ sách</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COSETC': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'MALL_CONSUME_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'MALL_CONSUME_SCROLL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'MALL_CONSUME_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'MALL_CONSUME_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'MALL_CONSUME_ETC': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'MALL_AVATAR_BOOTH': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'MALL_AVATAR_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_PET_A_GROWTH': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_SILK': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_VEHICLE': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_CART': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_STORES': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PREMIUM_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'MALL_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'MALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'UIIT_STT_SILKMALL_SHORT_KEY': {'Service': '1', 'Data': 'Siêu thị (F10)'},
#  'UIIT_STT_SILKMALL_BUY_CONFIRM': {'Service': '1', 'Data': 'Xác nhận mua'},
#  'UIIT_STT_SILKMALL_DO_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_POPUP_TITLE': {'Service': '1',
#   'Data': 'Đồ trang trí tồn kho'},
#  'UIIT_STT_SILKMALL_POPUP_ADVERTISING': {'Service': '1',
#   'Data': 'Bán có giới hạn'},
#  'UIIT_STT_SILKMALL_POPUP_DATA': {'Service': '1', 'Data': 'Ngày bán:'},
#  'UIIT_STT_SILKMALL_POPUP_REDUCTION': {'Service': '1',
#   'Data': 'Cho tới khi giảm giá'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_M': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nam)'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_W': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nữ)'},
#  'UIIT_MSG_SILKMALL_ZZIM_CONFIRM': {'Service': '1',
#   'Data': '<sml2><font color="255,255,255,255">Bạn sẽ đặt món đồ này chứ?<br>các món đồ được đặt có thể được chọn và mua một tất cả ở danh sách đặt hàng.</font></sml2>'},
#  'UIIT_MSG_SILKMALL_ZZIM_DELITE': {'Service': '1',
#   'Data': 'Xóa món đồ trong danh sách đặt hàng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1',
#   'Data': 'Bạn sẽ mua luôn số hàng đã đặt chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY_TOTAL': {'Service': '1',
#   'Data': 'Tổng cộng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_1': {'Service': '1',
#   'Data': 'Bạn có hủy số hàng đã đặt không ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_2': {'Service': '1',
#   'Data': 'Nếu bạn hủy bỏ việc sử dụng món đồ đã chọn, hiệu ứng của nó sẽ mất'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE': {'Service': '1',
#   'Data': 'Bạn sẽ dùng món đồ đã chọn chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_REVERSE_PORTAL': {'Service': '1',
#   'Data': 'sử dụng bùa dịch chuyển phản hồi. Hãy chọn điểm đến.'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_RETURN': {'Service': '1',
#   'Data': 'Dịch chuyển tới điểm về cuối'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_DEATH': {'Service': '1',
#   'Data': 'Dịch chuyển tới nơi bạn đã chết'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_INS': {'Service': '1',
#   'Data': 'sử dụng các vật phẩm này bạn sẽ không thể dịch chuyển được'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_GNGWC': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật sau khi kết thúc trận chiến'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_BUY_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không thành công do không đủ silk'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_GIFT': {'Service': '1',
#   'Data': 'Silk không đủ để tặng'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng cho loại đồ vật trang bị'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_SINCE_EQUIP_CLASS_TOO_HIGH': {'Service': '1',
#   'Data': 'Không thể thay đổi giới tính do không phù hợp với cấp độ của đồ vật'},
#  'UIIT_MSG_STRGERR_INVALID_TRANSGENDER_TARGET': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể thay đổi giới tính'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_TELEPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi cuối cùng bạn đã quay lại'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_DIEDPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi bạn đã chết'},
#  'UIIT_MSG_STRGERR_ONLY_THE_DEAD_CAN_USE_RESURRECT_SCROLL': {'Service': '1',
#   'Data': 'Chỉ sử dụng trong tình trạng đã chết'},
#  'UIIT_MSG_STRGERR_THERE_IS_NO_ITEM_TO_REPAIR': {'Service': '1',
#   'Data': 'Không có đồ vật nào cần sửa chữa'},
#  'UIIT_MSG_STRGERR_CANT_QUICKSELL_CASHITEM': {'Service': '1',
#   'Data': 'Không có chức năng mua bán nhanh với những món đồ hiếm.'},
#  'UIIT_MSG_STRGERR_TRADE_FAILURE': {'Service': '1',
#   'Data': 'Giao dịch thất bại không có lý do'},
#  'UIIT_STT_SILKMALL_FAIL_ITEMBUY_LOGOUT': {'Service': '1',
#   'Data': 'Trò chơi sẽ chấm dứt do việc mua đồ Premium thất bại'},
#  'UIIT_STT_SILKMALL_DONOT_USE_TELEPORT': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_MSG_SELL_RECONFIRM': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_PAG_CHAR_SKIN_CHANGE': {'Service': '1',
#   'Data': 'Thay đổi hình dáng bên ngoài của nhân vật'},
#  'UIIT_MSG_CHAR_SKIN_ERR_ARMOR': {'Service': '1',
#   'Data': 'Để thay đổi giới tính phải bỏ đồ bảo hộ và gỡ bỏ hết các ô mở rộng'},
#  'UIIT_MSG_CHAR_SKIN_CHANGE_SUCCESS': {'Service': '1',
#   'Data': 'Thay đổi giới tính thành công'},
#  'UIIT_STT_GUILD_INFO': {'Service': '1', 'Data': 'T.Tin Hội'},
#  'UIIT_CTL_LETTER': {'Service': '1', 'Data': 'Hộp thư kết hợp'},
#  'UIIT_CTL_FRIEND': {'Service': '1', 'Data': 'Bạn'},
#  'UIIT_STT_GUILD_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_GUILD_STAFF': {'Service': '1', 'Data': 'Hội phó'},
#  'UIIT_STT_GUILDSMAN': {'Service': '1', 'Data': 'Hội viên'},
#  'UIIT_STT_GUILDSMAN_NUM': {'Service': '1', 'Data': 'Số'},
#  'UIIT_STT_GUILD_COMMON_KNOW': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_GUILD_COMMON_KNOW_WRITE': {'Service': '1',
#   'Data': 'Viết thông báo'},
#  'UIIT_MSG_GUILD_COMMON_NOTEXIST': {'Service': '1',
#   'Data': 'Không có thông báo'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo (%d/Tối đa.%d)'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_TITLE_REMIND': {'Service': '1',
#   'Data': 'Hãy điền tiêu đề lời thông báo'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT_TITLE': {'Service': '1',
#   'Data': 'Chưa điền tiêu đề'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo'},
#  'UIIT_MSG_GUILDERR_TARGET_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Người chơi khác không có quyền'},
#  'UIIT_CTL_GUILD_WRITE_END': {'Service': '1', 'Data': 'Hoàn thành'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND_UPDATE': {'Service': '1',
#   'Data': 'Thông báo của Hội đã thay đổi'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_JOIN': {'Service': '1',
#   'Data': 'Hội chủ Hội [%s] đề nghị liên minh với bạn, bạn có chấp nhận không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_WITHDRAWA': {'Service': '1',
#   'Data': 'Bạn có muốn rời bỏ liên minh không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_BREAKUP': {'Service': '1',
#   'Data': 'Liên minh đã bị giải tán'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_NOTALLY': {'Service': '1',
# ...
#   'Data': 'Đã khỏi bệnh'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CHAOS': {'Service': '1',
#   'Data': 'Đã khỏi lẫn lộn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_PD': {'Service': '1',
#   'Data': 'Đã khỏi bị thối rữa'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_MD': {'Service': '1',
#   'Data': 'Đã được khoẻ lại'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_STR': {'Service': '1',
#   'Data': 'Đã hết bất lực'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_INT': {'Service': '1',
#   'Data': 'Đã hết bị cô lập'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_HP': {'Service': '1',
#   'Data': 'Đã hết hoảng loạn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSIE_MP': {'Service': '1',
#   'Data': 'Đã hết bị thiêu đốt'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_TIME_BOMB': {'Service': '1',
#   'Data': 'Đã hết ẩn nấp'},
#  'UIIT_MSG_BURN': {'Service': '1', 'Data': 'Thiêu đốt'},
#  'UIIT_MSG_FROSTBITE': {'Service': '1', 'Data': 'Tê cóng'},
#  'UIIT_MSG_FREEZING': {'Service': '1', 'Data': 'Đóng băng'},
#  'UIIT_MSG_SHOCK': {'Service': '1', 'Data': 'Nhiễm điện'},
#  'UIIT_MSG_ZOMBIE': {'Service': '1', 'Data': 'Yểm bùa'},
#  'UIIT_MSG_DARK': {'Service': '1', 'Data': 'Mờ mắt'},
#  'UIIT_MSG_STUN': {'Service': '1', 'Data': 'Choáng'},
#  'UIIT_MSG_PARTYERR_OUT_OF_LEVEL': {'Service': '1',
#   'Data': 'Không thể vào nhóm đó do sự chênh lệch về cấp độ.'},
#  'UIIT_MSG_FLEAMARKET_ERR_IM_BUSY': {'Service': '1',
#   'Data': 'Bạn ở trong tình trạng không được mở gian hàng mới'},
#  'UIIT_MSG_JSERR_SINCE_YOU_DIE_IN_MURDERER_SP_DEPRIVED_BY_SERVER': {'Service': '1',
#   'Data': 'Bị mất [%u] điểm kinh nghiệm'},
#  'UIIT_MSG_INTERACTION_FAIL__REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_PORTAL_SCROLL': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_SUMMON_VEHICLE': {'Service': '1',
#   'Data': 'Không thể dùng thú vận chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_INTERACTION_FAIL_MURDERER_CAN_USE_PORTAL_STRUCTURE': {'Service': '1',
#   'Data': 'Không thể qua cổng dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_FLEAMARKET_ERR_CANT_OPEN_MARKET_MURDERER': {'Service': '1',
#   'Data': 'Không thể mở gian hàng mới trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng item trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_ENABLEINPUT_FEWERTHAN_REMAIN': {'Service': '1',
#   'Data': 'Chỉ có thể nhập số đơn vị còn lại'},
#  'UIIT_MSG_STRGERR_CANNOT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy người chơi khác'},
#  'UIIT_MSG_STRGERR_SPECIFY_POSITIVE_NUMBER_ONLY': {'Service': '1',
#   'Data': 'Số không hợp lệ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi bị hủy bỏ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_BEFORE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi lần trước bị hủy bỏ vì đã thực hiện trao đổi với người chơi khác'},
#  'UIIT_MSG_STRGERR_CANNOT_WITDRAW_MORETHAN_DEPOSIT': {'Service': '1',
#   'Data': '-'},
#  'UIIT_MSG_DEAL_ASK': {'Service': '1',
#   'Data': 'Có người muốn trao đổi với bạn. Bạn chấp nhận chứ?'},
#  'UIIT_MSG_DEAL_ASKING': {'Service': '1', 'Data': 'Trao đổi với [%s]'},
#  'UIIT_MSG_STRGERR_INVALID_TARGET': {'Service': '1',
#   'Data': 'Không thấy mục tiêu'},
#  'UIIT_MSG_STRGERR_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận làm việc khác'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_OPPONENT_INV_SPACE': {'Service': '1',
#   'Data': 'Không thể đưa thêm món đồ đó vào cửa sổ trao đổi vì thùng đồ người kia đã đầy.'},
#  'UIIT_MSG_STRGERR_NON_SETUP_KEY': {'Service': '1',
#   'Data': 'Không thể đặt phím đã lựa chọn'},
#  'UIIT_MSG_STRGERR_CHATING_LIMIT': {'Service': '1',
#   'Data': 'Không thể lặp lại cùng nội dung'},
#  'UIIT_MSG_STRGERR_DEAL_FAIL_NON_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không được thực hiện do không có đồ vật giao dịch'},
#  'UIIT_STT_TARGETTING': {'Service': '1', 'Data': 'Mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTLEARN': {'Service': '1',
#   'Data': 'Kỹ năng không xác định'},
#  'UIIT_SKILL_USE_FAIL_TIMEDELAY_REUSEDELAY': {'Service': '1', 'Data': '-'},
#  'UIIT_SKILL_USE_FAIL_WRONGDISTANCE': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng với mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTENOUGHLEVEL': {'Service': '1',
#   'Data': 'Không sử dụng được vì cấp độ của bạn thấp'},
#  'UIIT_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh người chơi khác vì cấp độ của người đó cao hơn bạn'},
#  'UIIT_CHATERR_CANT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy [%s]'},
#  'UIIT_CHATERR_YOU_ARE_SQUELCHED': {'Service': '1',
#   'Data': 'Chức năng thì thầm của  [%s]đã bị tắt'},
#  'UIIT_CHATERR_NOT_A_PARTY_MEMBER': {'Service': '1',
#   'Data': 'Không ở trong nhóm nào'},
#  'UIIT_CHATERR_INVALID_COMMAND': {'Service': '1',
#   'Data': 'Lệnh chat không hợp lệ'},
#  'UIIT_CHATERR_ALLIANCE_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Không sử dụng được chức năng tán gẫu với đồng minh vì Hội được chọn không phải là đồng minh của bạn'},
#  'UIIT_CHATERR_WHISPER_TO_MESSAGE': {'Service': '1', 'Data': 'Tin đi'},
#  'UIIT_CHATERR_WHISPER_FROM_MESSAGE': {'Service': '1', 'Data': 'Tin đến'},
#  'UIIT_TOOLTIP_PK_DAY': {'Service': '1', 'Data': 'PK hàng ngày %d / %d'},
#  'UIIT_TOOLTIP_PK_TOTAL': {'Service': '1', 'Data': 'Tổng PK %d / %d'},
#  'UIIT_TOOLTIP_PK_PENALTY_TIME': {'Service': '1',
#   'Data': 'Chỉ số PK %d (Cấp độ %d)'},
#  'UIIT_TOOLTIP_PENALTY_GOLD': {'Service': '1', 'Data': 'Phạt %d vàng'},
#  'UIIT_TOOLTIP_JOB_PENALTY_TIME': {'Service': '1',
#   'Data': 'Không được hành nghề trong %d phút'},
#  'UIIT_TOOLTIP_EQUIPMENT_CLASS': {'Service': '1', 'Data': 'Cấp: Cấp %d'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_DROPPED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể bỏ đi'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_PICKED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể lấy được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_TRADED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể mang ra mua bán được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể sửa chữa được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể làm lại được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_USED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể dùng được'},
#  'UIIT_MSG_CANNOT_BE_USED_ITEM_CART': {'Service': '1',
#   'Data': 'Không thể dùng mà không có thú di chuyển/ chuyên chở'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_IN_BATTLE_STATE': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang đánh nhau'},
#  'UIIT_MSG_REMAIN_TIME': {'Service': '1', 'Data': '(còn %d giây)'},
#  'UIIT_MSG_STRGERR_ONLY_ROBBER_CAN_USE_THIS_ITEM': {'Service': '1',
#   'Data': 'Món đồ được chọn chỉ sử dụng được khi làm Đạo Tặc'},
#  'UIIT_MSG_STRGERR_CANT_OPERATE_REQUESTED_JOB_DURING_LOGOUT': {'Service': '1',
#   'Data': 'Không thể thực hiện khi đang thoát trò chơi'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED_TO_USE_THISITEM': {'Service': '1',
#   'Data': 'Không thể đung được món đồ đó vì cấp độ của nhân vật còn thấp'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_WHILE_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang dịch chuyển'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME': {'Service': '1',
#   'Data': 'Còn %d giây sẽ thoát trò chơi'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME_CANCLE': {'Service': '1',
#   'Data': 'Hủy bỏ việc thoát khỏi trò chơi'},
#  'UIIT_MSG_STRGERR_CANT_SELL_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể bán món đồ khi đang trang bị'},
#  'UIIT_MSG_STRGERR_CANT_SWAP_JOBITEM': {'Service': '1',
#   'Data': 'Phải bỏ món đồ trước ra thì mới mặc đồ mới vào được'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBCHANGE_COMPLETE': {'Service': '1',
#   'Data': 'Không thể cởi trang bị nghề nghiệp trong vòng 10 giây kể từ lúc đeo vào'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBITEM_DETACH_COMPLETE': {'Service': '1',
#   'Data': 'Không thể đeo trang bị nghề nghiệp khác trong 10 phút kể từ lúc tháo ra'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_JOBITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Bạn chỉ có thể bỏ trang bị nghề nghiệp sau 20 giây kể từ trận chiến cuối cùng.'},
#  'UIIT_MSG_STRGERR_CANT_HAVE_CART': {'Service': '1',
#   'Data': 'Không thể bỏ trang bị nghề nghiệp ra trong khi đang triệu tập thú vận chuyển'},
#  'UIIT_MSG_COSERR_COLLISION_EXIST_BETWEEN_US': {'Service': '1',
#   'Data': 'Không thực hiện được lệnh di chuyển do có chướng ngại vật'},
#  'UIIT_MSG_INTERACTION_FAIL_IM_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận việc khác'},
#  'UIIT_MSG_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh vì kỹ năng hồi sinh của bạn còn thấp'},
#  'UIIT_MSG_SKILL_USE_FAIL_NOTENOUGHHP': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng đó vì không đủ HP'},
#  'UIIT_MSG_SKILL_USE_FAIL_ITS_NOT_A_BATTLE_FIELD': {'Service': '1',
#   'Data': 'Không thể tấn công trong khu vực an toàn'},
#  'UIIT_MSG_SKILL_USE_FAIL_WAITFOR_JOB_ACTIVATE': {'Service': '1',
#   'Data': 'Không thể tấn công trong 10 giây kể từ lúc mang trang bị nghề nghiệp vào'},
#  'UIIT_MSG_STRGERR_DONT_HAVE_ANY_TRADECART_TO_PICK_SPECIALTY': {'Service': '1',
#   'Data': 'Không thể nhận được đặc sản nếu không có thú vận chuyển'},
#  'UIIT_MSG_STRGERR_CANT_BE_STORED': {'Service': '1',
#   'Data': 'Món đồ đó không thể lưu tại nơi đã chỉ định'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị đồ vật vì cấp độ hoặc cấp độ tuyệt kỹ nhân vật còn thấp'},
#  'UIIT_MSG_STRGERR_LOCKED_BY_OTHER_ONE': {'Service': '1',
#   'Data': 'Không thể lấy được món đồ đó vì nó của người chơi khác'},
#  'UIIT_MSG_STRGERR_GENDER_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác giới tính'},
#  'UIIT_MSG_STRGERR_TRADE_BAY_FULL': {'Service': '1',
#   'Data': 'Không thể thêm vào món đồ đã chọn vì cửa sổ trao đổi đã đầy'},
#  'UIIT_MSG_STRGERR_COUNTRY_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác chủng tộc'},
#  'UIIT_MSG_STRGERR_HIGHER_STRENGTH_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì thiếu sức mạnh'},
#  'UIIT_MSG_STRGERR_HIGHER_INTELLECT_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì trí tuệ thấp'},
#  'UIIT_MSG_STRGERR_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_EU_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_CANT_EQUIP_RAZED_ITEM': {'Service': '1',
#   'Data': 'Không thể trang bị món đồ đã hỏng'},
#  'UIIT_MSG_STRGERR_PREV_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển.'},
#  'UIIT_MSG_STRGERR_POSSESSION_LIMIT_EXCEEDED': {'Service': '1',
#   'Data': 'Không thể có nhiều hơn số lượng giới hạn'},
#  'UIIT_MSG_STRGERR_ROBBER_CANT_SUMMON_CART_IN_TOWN': {'Service': '1',
#   'Data': 'Không thể triệu hồi phương tiện chuyên trở khi đang ở Làng Đạo Tặc'},
#  'UIIT_MSG_INTERACTION_FAIL_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển rồi'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_TRADECART': {'Service': '1',
#   'Data': 'Không thể dịch chuyển khi đang có thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_RIDE': {'Service': '1',
#   'Data': 'Không thể sử dụng cổng dịch chuyển khi đang cưỡi thú'},
#  'UIIT_MSG_INTERACTION_FAIL_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Không thể qua đò khi đang ở xa thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không sửa chữa được'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không làm lại được'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_TEMPORARILY': {'Service': '1',
#   'Data': 'Bất khả xâm phạm - Không thể tấn công hoăc bị tấn công trong 5 giây'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_FORTRESS': {'Service': '1',
#   'Data': 'Khi tấn công pháo đài trong tình trạng bất khả xâm phạm - không thể tấn công trong 10 giây'},
#  'UIIT_MSG_COSERR_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Một nhân vật không thể cách xa quá thú vận chuyển %d m'},
#  'UIIT_MSG_RETURN_CANCLE': {'Service': '1',
#   'Data': 'Việc sử dụng bùa dịch chuyển đã bị hủy bỏ'},
#  'UIIT_MSG_QUESTEND_2': {'Service': '1',
#   'Data': 'Hãy mở cửa sổ Nhiệm vụ (Q) để kiểm tra nội dung'},
#  'UIIT_MSG_JSERR_PREVIOUS_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể vào mê cung khi sắp dịch chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_OUT_OF_REQUIRED_LEVEL_FOR_TELEPORT': {'Service': '1',
#   'Data': 'Không thể dịch chuyển vì cấp độ của bạn quá thấp'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_FREEBATTLEITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Không thể bỏ khăn ra trong khi đang đánh nhau'},
#  'UIIT_MSG_STRGERR_STORAGE_OPERATION_BLOCKED': {'Service': '1',
#   'Data': 'Hiện tại bạn không được phép di chuyển các món đồ hoặc trao đổi chúng'},
#  'UIIT_MSG_QUEST_CALLMONSTER_NOTATTACK': {'Service': '1',
#   'Data': 'Cấp độ của bạn còn quá thấp để có thể đánh nhau với quái vật'},
#  'UIIT_MSG_QUEST_GET_ITEM_FAILURE': {'Service': '1',
#   'Data': 'Không thể nhặt được món đồ'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_MONSTER': {'Service': '1',
#   'Data': 'Không thể di chuyển vì bạn đã ở cách quái vật %d m.'},
#  'UIIT_MSG_QUEST_FAIL_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Đã thất bại trong việc bắt giữ quái vật.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_CHATTING_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn đang làm nhiệm vụ nên không thể tán gẫu được.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MOVING_IN_DUNGEON': {'Service': '1',
#   'Data': 'Đã ra khỏi vị trí chỉ định nên không thể di chuyển được nữa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_DO_IT_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này vì bạn đang làm một nhiệm vụ khác có liên quan.'},
#  'UIIT_MSG_QUEST_ERR_TOO_LOW_LEVEL': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này do cấp độ của bạn còn thấp'},
#  'UIIT_MSG_QUEST_END_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ kết thúc sau %d phút'},
#  'UIIT_MSG_QUEST_START_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ bắt đầu trong %d giây (s)'},
#  'UIIT_MSG_QUEST_ERR_USE_WHANITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật này trong trạng thái Cuồng nộ'},
#  'UIIT_MSG_QUEST_ERR_CAPTUREMONSTER_ATTACK': {'Service': '1',
#   'Data': 'Không thể tấn công quái vật đã sập bẫy'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Không thể bắt quái vật thì khoảng cách quá xa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì đã đặt bẫy rồi'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_EXIST_MONSTER': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì quái vật ở quá gần'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật vì điều kiện nhiệm vụ không cho phép'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_WRONG_PLACE': {'Service': '1',
#   'Data': 'Không thể đặt bẫy trong khu vực này'},
#  'UIIT_MSG_QUEST_ERR_NO_TARGET': {'Service': '1',
#   'Data': 'Mệnh lệnh không thể thực thi do chưa chọn đối tượng'},
#  'UIIT_MSG_CANNOT_BUYBACK_ITEM_SELL': {'Service': '1',
#   'Data': 'Đồ vật không thể mua lại được. Bạn có chắc muốn bán nó đi không?'},
#  'UIIT_MSG_QUEST_INS_TIMEOUT': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ hoàn htành sau %d giây, bạn sẽ được trở lại vị trí ban đầu.'},
#  'UIIT_MSG_QUEST_INS_CONDITION': {'Service': '1',
#   'Data': 'Bạn sẽ trở lại vị trí ban đầu trong 5 giây nữa vì nhận được yêu cầu không thể ở lại khu vực hiện tại.'},
#  'UIIT_MSG_QUEST_INS_DEATH': {'Service': '1',
#   'Data': 'Không thể chuyển đến khu vực khác khi nhân vật của bạn đang bị chết'},
#  'UIIT_MSG_DROP_WARNING_1': {'Service': '1',
#   'Data': 'Nếu bạn vứt đồ vật này ra ngoài, thì bạn sẽ mất đi quyền sở hữu đồ vật này'},
#  'UIIT_MSG_DROP_WARNING_2': {'Service': '1',
#   'Data': 'Người khác có thể nhật chúng. Bạn có chắc là muốn vứt nó ra không?'},
#  ...}

# %% [markdown]
# ## TextQuest_OtherString.txt

# %%
text_quest_other_string = os.path.join(server_dep, 'TextQuest_OtherString.txt')
text_quest_other_string
# Out:
# 'server_dep\\silkroad\\textdata\\TextQuest_OtherString.txt'

# %%
text_quest_other_string_files = get_lines(text_quest_other_string)
text_quest_other_string_files
# Out:
# ['TextQuest_OtherString_1000.txt',
#  'TextQuest_OtherString_1200.txt',
#  'TextQuest_OtherString_1400.txt',
#  'TextQuest_OtherString_1600.txt',
#  'TextQuest_OtherString_1800.txt',
#  'TextQuest_OtherString_200.txt',
#  'TextQuest_OtherString_2000.txt',
#  'TextQuest_OtherString_2200.txt',
#  'TextQuest_OtherString_2400.txt',
#  'TextQuest_OtherString_2600.txt',
#  'TextQuest_OtherString_2800.txt',
#  'TextQuest_OtherString_3000.txt',
#  'TextQuest_OtherString_3200.txt',
#  'TextQuest_OtherString_3400.txt',
#  'TextQuest_OtherString_3600.txt',
#  'TextQuest_OtherString_3800.txt',
#  'TextQuest_OtherString_400.txt',
#  'TextQuest_OtherString_4000.txt',
#  'TextQuest_OtherString_4200.txt',
#  'TextQuest_OtherString_4400.txt',
#  'TextQuest_OtherString_4600.txt',
#  'TextQuest_OtherString_4800.txt',
#  'TextQuest_OtherString_5000.txt',
#  'TextQuest_OtherString_600.txt',
#  'TextQuest_OtherString_800.txt',
#  '']

# %%
for xxx in text_quest_other_string_files:
  file_name = os.path.join(server_dep, xxx)
  lines = get_lines(file_name)
  for idx, line in enumerate(lines):
    values = line.split('\t')
    if len(values) < 11:
      continue
    Service = values[0]
    name_str_id = values[2]
    Data = values[10]
    data_text[name_str_id] = {
      "Service": Service,
      "Data": Data
    }

# %%
data_text
# Out:
# {'UIC_STT_FONTNAME': {'Service': '1', 'Data': 'Tahoma'},
#  'UIIS_STT_MSG_INSTALL_START': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa"'},
#  'UIIS_STT_MSG_INSTALL_FOLDER': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa" vào thư mục sau'},
#  'UIIS_STT_MSG_INSTALL_END': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt thành công'},
#  'UIIS_STT_INSTALL_FOLDER': {'Service': '1', 'Data': 'Thư mục cài đặt'},
#  'UIIS_STT_INSTALL_FILE': {'Service': '1', 'Data': 'File cài đặt'},
#  'UIIS_CTL_INSTALL': {'Service': '1', 'Data': 'Cài đặt'},
#  'UIIS_CTL_FIND_FOLDER': {'Service': '1', 'Data': 'Tìm kiếm'},
#  'UIIS_CTL_START': {'Service': '1', 'Data': 'Bắt đầu'},
#  'UIIS_CTL_CANCEL': {'Service': '1', 'Data': 'Hủy bỏ'},
#  'UIIS_CTL_CONFIRM': {'Service': '1', 'Data': 'Đồng ý'},
#  'UIIS_MSG_ALREADY_INSTALL': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt'},
#  'UIIS_MSG_UNPACK_ZIP': {'Service': '1',
#   'Data': 'Không thể giải nén Con Đường Tơ Lụa. \\nFile nén bị hỏng.'},
#  'UIIS_MSG_UNPACK_CLOSE': {'Service': '1',
#   'Data': 'Không thể đóng file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_UNPACK_OPEN': {'Service': '1',
#   'Data': 'Không thể mở file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_INSTALL_SPACE': {'Service': '1',
#   'Data': 'Không thể cài đặt do thiếu dung lượng. \\nCần ít nhất %d BYTE dung lượng đĩa'},
#  'UIIS_MSG_BACKBUFFER': {'Service': '1', 'Data': 'Không thể tạo bộ nhớ đệm'},
#  'UIIS_MSG_CHANGE_FOLDER': {'Service': '1',
#   'Data': 'Thư mục cài đặt đã bị thay đổi.\\nKhông thể gỡ bỏ Con Đường Tơ Lụa'},
#  'UIIS_MSG_NOFIND': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa chưa được cài đặt. Việc gỡ bỏ không có tác dụng'},
#  'UIIS_MSG_REMOVE_COMPLETE': {'Service': '1',
#   'Data': 'Tất cả các file đã được xóa bỏ hoàn toàn'},
#  'UIIS_MSG_REMOVE_FAIL': {'Service': '1', 'Data': 'Không thể gỡ bỏ'},
#  'UIIS_STT_DELETE': {'Service': '1', 'Data': 'Xóa thư mục Con Đường Tơ Lụa'},
#  'UIIS_CTL_DELETE': {'Service': '1', 'Data': 'Gỡ bỏ'},
#  'UIIS_CTL_EXIT': {'Service': '1', 'Data': 'Thoát'},
#  'UILM_MSG_PROCESS_ALREADY_EXITS': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đang chạy'},
#  'UILM_MSG_DETECTED_ABNORMAL_PROCESS': {'Service': '1',
#   'Data': 'Phát hiện lỗi chạy chương trình Con Đường Tơ Lụa (Lỗi hệ thống)'},
#  'UILM_MSG_FAILED_LOAD_CLIENT': {'Service': '1',
#   'Data': 'Không thể xác định đặc điểm client. Đang đóng.'},
#  'UILM_MSG_GATEWAY_NOT_IN_SERVICE_CHANNEL': {'Service': '1',
#   'Data': 'Máy chủ đang kiểm tra hoặc không làm việc. Truy cập trang %ssro.vtcgame.vn/ để biết thêm thông tin.'},
#  'UILM_MSG_DRIVER_UPDATE': {'Service': '1',
#   'Data': 'Driver đồ họa của bạn không phải là phiên bản mới nhất. Hãy cập nhật phiên bản mới nhất để xem hình ảnh game đẹp hơn.'},
#  'UILM_MSG_DRIVER_UPDATE_2': {'Service': '1',
#   'Data': 'Không bao giờ xuất hiện lại.'},
#  'UILM_MSG_FAILED_INIT_NETENGINE': {'Service': '1',
#   'Data': 'Không thể khởi chạy NetEngine (Lỗi (%d,%d))'},
#  'UILM_MSG_FAILED_LOAD_VERSION': {'Service': '1',
#   'Data': 'Không thể kiểm tra phiên bản'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_IP': {'Service': '1',
#   'Data': 'Không thể kiểm tra IP kết nối'},
#  'UILM_MSG_INVALID_CONNECT_IP': {'Service': '1',
#   'Data': 'IP kết nối không hợp lệ'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_PORT': {'Service': '1',
#   'Data': 'Không thể kiểm tra cổng kết nối'},
#  'UILM_MSG_INVALID_CONNECT_PORT': {'Service': '1',
#   'Data': 'Cổng kết nối không hợp lệ'},
#  'UILM_MSG_DETECTED_ABNORMAL_DIRECTX': {'Service': '1',
#   'Data': 'DirectX 9.0 chưa được cài đặt hoặc không phải là phiên bản 9.0b. Con Đường Tơ Lụa cần DirectX9.0b hoặc phiên bản mới hơn'},
#  'UILM_MSG_DETECTED_ABNORMAL_MODULE': {'Service': '1',
#   'Data': 'Không xác định client. Kết thúc.'},
#  'UILM_MSG_DETECTED_PATCH_DIABLE': {'Service': '1',
#   'Data': 'Bạn phải cài đặt toàn bộ phiên bản. Kết nối với trang chủ để download toàn bộ phiên bản.'},
#  'UILM_MSG_DETECTED_PATCH_MANUAL': {'Service': '1',
#   'Data': 'Bạn cần cài đặt thủ công. Vui lòng truy cập trang chủ để tải bản cài thủ công về. Bạn có muốn kết nối đến trang chủ không?'},
#  'UILM_MSG_FAILED_EXECUTE_EXPLORER': {'Service': '1',
#   'Data': 'Không thể chạy Internet Explorer.'},
#  'UILM_MSG_FAILED_PATCH': {'Service': '1',
#   'Data': 'Chưa hoàn thành việc sửa lỗi. Hãy thử lại.[Lỗi số(%d)]'},
#  'UILM_MSG_FAILED_EXECUTE_CLIENT': {'Service': '1',
#   'Data': 'Xin lỗi. Không thể chạy Con Đường Tơ Lụa [Lỗi số(%d)]'},
#  'UILM_MSG_NOTEXITS_REPLACERFILE': {'Service': '1',
#   'Data': 'Không tìm thấy file replacer.exe. Chưa hoàn thành việc sửa lỗi.'},
#  'UILM_MSG_DETECTED_ABNORMAL_REPLACERFILE': {'Service': '1',
#   'Data': 'Không thể sửa lỗi vì file replacer.exe đã bị hỏng [lỗi số (%d)]'},
#  'UILM_MSG_FAILED_LOAD_GATEWAY_INFO': {'Service': '1',
#   'Data': 'Không thể đưa ra thuộc tính kết nối của GateWay [lỗi%d]'},
#  'UILM_STT_DIVISION': {'Service': '1', 'Data': 'Bộ phận'},
#  'UILM_STT_DIVISION_LIST': {'Service': '1', 'Data': 'Danh sách bộ phận'},
#  'UILM_STT_DIVISION_SELECTED': {'Service': '1', 'Data': 'Bộ phận lựa chọn'},
#  'UILM_STT_DIVISION_NAME': {'Service': '1', 'Data': 'Tên bộ phận'},
#  'UILM_STT_FARM': {'Service': '1', 'Data': 'Giải'},
#  'UILM_STT_FARM_LIST': {'Service': '1', 'Data': 'Danh sách giải'},
#  'UILM_STT_FARM_NAME': {'Service': '1', 'Data': 'Tên giải'},
#  'FARM0101': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 01 Yahoo'},
#  'FARM0102': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 01 Yahoo'},
#  'FARM0103': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 01 Yahoo'},
#  'FARM0104': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 01 Yahoo'},
#  'FARM0105': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 01 Yahoo'},
#  'FARM0201': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 02 Yahoo'},
#  'FARM0202': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 02 Yahoo'},
#  'FARM0203': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 02 Yahoo'},
#  'FARM0204': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 02 Yahoo'},
#  'FARM0205': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 02 Yahoo'},
#  'FARM0301': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 03 Yahoo'},
#  'FARM0302': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 03 Yahoo'},
#  'FARM0303': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 03 Yahoo'},
#  'FARM0304': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 03 Yahoo'},
#  'FARM0305': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 03 Yahoo'},
#  'FARM0401': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 04 Yahoo'},
#  'FARM0402': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 04 Yahoo'},
#  'FARM0403': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 04 Yahoo'},
#  'FARM0404': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 04 Yahoo'},
#  'FARM0405': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 04 Yahoo'},
#  'UILM_STT_DIVISION_PING': {'Service': '1', 'Data': 'Ping'},
#  'UILM_STT_DIVISION_CONDITION': {'Service': '1', 'Data': 'Tình trạng'},
#  'DIV01': {'Service': '1', 'Data': 'Bộ phận Yahoo 01'},
#  'DIV02': {'Service': '1', 'Data': 'Bộ phận Yahoo 02'},
#  'DIV03': {'Service': '1', 'Data': 'Bộ phận Yahoo 03'},
#  'DIV04': {'Service': '1', 'Data': 'Bộ phận Yahoo 04'},
#  'DIV05': {'Service': '1', 'Data': 'Bộ phận Yahoo 05'},
#  'DIV06': {'Service': '1', 'Data': 'Bộ phận Yahoo 06'},
#  'DIV07': {'Service': '1', 'Data': 'Bộ phận Yahoo 07'},
#  'DIV08': {'Service': '1', 'Data': 'Bộ phận Yahoo 08'},
#  'DIV09': {'Service': '1', 'Data': 'Bộ phận Yahoo 09'},
#  'DIV10': {'Service': '1', 'Data': 'Bộ phận Yahoo 10'},
#  'UILM_STT_DIVISION_RECOMMENDATION': {'Service': '1', 'Data': 'Đề nghị'},
#  'UILM_STT_DIVISION_NOT_RECOMMENDATION': {'Service': '1',
#   'Data': 'Không đề nghị'},
#  'UILM_MSG_SILKROAD_STARTING_HOME': {'Service': '1',
#   'Data': 'Trang chủ của Con đường tơ lụa đã được đặt làm trang chủ mặc định'},
#  'UILM_MSG_YAHOO_STARTING_HOME': {'Service': '1',
#   'Data': 'Đã thiết đặt xong trang chủ https://sro.vtcgame.vn/'},
#  'UILM_MSG_YAHOO_TOOLBAR': {'Service': '1',
#   'Data': 'Đã thiết đặt xong thanh công cụ yahoo'},
#  'UILM_MSG_SERVICE_CLIENT_ERROR_REINSTALL': {'Service': '1',
#   'Data': 'Client của bạn bị lỗi hoặc đã bị phá huỷ nên không thể kết nối đến máy chủ. Hãy cài lại một client mới.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ download bị ngắt. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CANCEL': {'Service': '1',
#   'Data': 'Kết nới với máy chủ download đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_SELECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Launcher sẽ được khởi động lại.'},
#  'UILM_TEXT_CONFIG_GRAPHIC_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UILM_TEXT_CONFIG_GRAPHIC_NORMAL': {'Service': '1', 'Data': 'Bình thường'},
#  'UILM_TEXT_CONFIG_GRAPHIC_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UILM_TEXT_CONFIG_GRAPHIC_USER_DEF': {'Service': '1', 'Data': 'Không đổi'},
#  'UIIT_STT_ETCKEY': {'Service': '1', 'Data': 'Các phím khác'},
#  'UIIT_STT_MOUSE': {'Service': '1', 'Data': 'Chuột'},
#  'UIIT_STT_MOUSE_RIGHT_BUTTON': {'Service': '1', 'Data': 'Ô Nhớ Chuột'},
#  'UIIT_STT_USE_WHEEL_TO_CHANGE_SIGHT': {'Service': '1',
#   'Data': 'Chuột lăn (đổi góc nhìn) chuột phải (dùng Ô Nhớ)'},
#  'UIIT_STT_USE_WHEEL_TO_USE_SKILL': {'Service': '1',
#   'Data': 'Chuột lăn (dùng Ô Nhớ) chuột phải (đổi góc nhìn)'},
#  'UIIT_STT_ITEM_GET': {'Service': '1', 'Data': 'Nhặt đồ'},
#  'UIIT_STT_REFLECT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng phản xạ'},
#  'UIIT_STT_WATER_DETAIL': {'Service': '1', 'Data': 'Chi tiết nước'},
#  'UIIT_STT_LIGHT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng ánh sáng'},
#  'UIIT_STT_BUMP_MAPPING': {'Service': '1', 'Data': 'ánh xạ va chạm'},
#  'UIIT_STT_ENVIRONMENT_MAPPING': {'Service': '1', 'Data': 'ánh xạ môi trường'},
#  'UIIT_STT_LENS_FLAIR': {'Service': '1', 'Data': 'Độ nhạy của thấu kính'},
#  'UIIT_STT_DYNAMIC_ANIMATION': {'Service': '1', 'Data': 'ảnh động sống động'},
#  'UIIT_STT_WATER_REFLECTION': {'Service': '1', 'Data': 'Phản xạ nước'},
#  'UIIT_STT_FILTERING': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_TEXTER_DETAIL': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_GRAPHIC_QUALITY': {'Service': '1', 'Data': 'Chất lượng đồ họa'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL': {'Service': '1',
#   'Data': 'Người dùng tự chọn'},
#  'UIIT_STT_GRAPHIC_QUALITY_USER_CONTROL': {'Service': '1', 'Data': 'Tự chọn'},
#  'UIIT_STT_METAL_DETAIL': {'Service': '1', 'Data': 'Chất liệu kim loại'},
#  'UIIT_STT_BLOOM_EFFECT': {'Service': '1', 'Data': 'Âm lượng'},
#  'UIIT_STT_GRAPHIC': {'Service': '1', 'Data': 'Đồ họa'},
#  'UIIT_STT_RESOLUTION': {'Service': '1', 'Data': 'Độ phân giải'},
#  'UIIT_STT_LUMINOSITY': {'Service': '1', 'Data': 'Độ sáng tối'},
#  'UIIT_STT_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn'},
#  'UIIT_STT_CHAR_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn nhân vật'},
#  'UIIT_STT_SCENERY_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn bối cảnh'},
#  'UIIT_STT_SHADOW_DETAIL': {'Service': '1', 'Data': 'Chi tiết bóng'},
#  'UIIT_STT_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_MIDDLE': {'Service': '1', 'Data': 'Vừa'},
#  'UIIT_STT_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_VERY_DARK': {'Service': '1', 'Data': 'Rất tối'},
#  'UIIT_STT_DARK': {'Service': '1', 'Data': 'Tối'},
#  'UIIT_STT_NORMAL': {'Service': '1', 'Data': 'Trung bình'},
#  'UIIT_STT_LIGHT': {'Service': '1', 'Data': 'Sáng'},
#  'UIIT_STT_VERY_LIGHT': {'Service': '1', 'Data': 'Rất sáng'},
#  'UIIT_STT_SIGHT_VERY_SMALL': {'Service': '1', 'Data': 'Rất hẹp'},
#  'UIIT_STT_SIGHT_SMALL': {'Service': '1', 'Data': 'Hẹp'},
#  'UIIT_STT_SIGHT_LARGE': {'Service': '1', 'Data': 'Rộng'},
#  'UIIT_STT_SIGHT_VERY_LARGE': {'Service': '1', 'Data': 'Rất rộng'},
#  'UIIT_STT_NONE': {'Service': '1', 'Data': 'Không có'},
#  'UIIT_STT_CIRCLE': {'Service': '1', 'Data': 'Vòng tròn'},
#  'UIIT_STT_DETAIL': {'Service': '1', 'Data': 'Chi tiết'},
#  'UIIT_STT_RANK': {'Service': '1', 'Data': '%d bước'},
#  'UIIT_STT_ON': {'Service': '1', 'Data': 'Bật'},
#  'UIIT_STT_OFF': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_GRAPHIC_QUALITY_MIDDLE': {'Service': '1', 'Data': 'Bình thường'},
#  'UIIT_STT_GRAPHIC_QUALITY_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL1': {'Service': '1', 'Data': 'Đồ họa 1'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL2': {'Service': '1', 'Data': 'Đồ họa 2'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_WAR': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_USER': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_VIDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể thay đổi độ phân giải của game'},
#  'UIIT_STT_VIDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể thay đổi độ sáng của game'},
#  'UIIT_STT_VIDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể thay đổi chất lượng đồ hoạ của game. Tìm đến lựa chọn Video và thiết lập các mức độ cao, trung bình hay thấp. Tốc độ tải trò chơi sẽ thay đổi tuỳ theo các mức chất lượng được thiết lập.'},
#  'UIIT_STT_VIDIO_TTDESC_04': {'Service': '1',
#   'Data': 'Có thể thay đổi mức độ chi biết bóng. Tốc độ tải game có thể bị chậm nếu chi tiết bóng được đặt ở mức cao.'},
#  'UIIT_STT_VIDIO_TTDESC_05': {'Service': '1',
#   'Data': 'Khi thiết lập khung cảnh được đặt ở mức cao, có thể nhìn thấy nhiều hình ảnh hơn, tuy nhiên, điều này cũng sẽ làm chậm tốc độ tải game. Có thể thiết lập ở mức thấp, khi đó sẽ chỉ nhìn thấy những khung cảnh ở gần.'},
#  'UIIT_STT_VIDIO_TTDESC_06': {'Service': '1',
#   'Data': 'Khi các thông tin ở nhân vật, quái vật, lâu đài... được lựa chọn hiển thị nhiều, bạn sẽ biết đầy đủ thông tin hơn nhưng như vậy có thể gây chậm tốc độ tải game.'},
#  'UIIT_STT_VIDIO_TTDESC_07': {'Service': '1',
#   'Data': 'Lựa chọn chi tiết bóng nước để hiển thị các hình ảnh được phản chiếu trên mặt nước.'},
#  'UIIT_STT_VIDIO_TTDESC_08': {'Service': '1',
#   'Data': 'Chi tiết nước được lựa chọn với các mức độ hiệu ứng mặt nước, nếu lựa chọn mức độ cao, cảnh mặt nước sẽ đẹp hơn nhưng tốc độ tải game sẽ bị chậm đi.'},
#  'UIIT_STT_VIDIO_TTDESC_09': {'Service': '1',
#   'Data': 'Chi tiết hiển thị kim loại, nếu được lựa chọn, sẽ hiển thị các hiệu ứng ánh kim trên đồ vật kim loại như giáp, vũ khí. Mức độ lựa chọn càng cao thì chất lượng đồ hoạ cũng tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_10': {'Service': '1',
#   'Data': 'Hiệu ứng ánh sáng chỉ hiệu ứng của đèn khi chiếu trên bề mặt đồ vật, khi lựa chọn mức độ hiển thị ánh sáng cao thì độ thật của đồ vật sẽ tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_11': {'Service': '1',
#   'Data': 'Chi tiết chất liệu chỉ mức độ chi tiết của chất liệu. Chất lượng hiển thị chất liệu của đồ vật sẽ tăng lên khi chi tiết chất liệu được lựa chọn ở mức độ cao.'},
#  'UIIT_STT_VIDIO_TTDESC_12': {'Service': '1',
#   'Data': 'Chi tiết thấu kính chỉ tình trạng chiếu sáng giống như một máy quay phim đang hướng về phía mặt trời.'},
#  'UIIT_STT_VIDIO_TTDESC_13': {'Service': '1',
#   'Data': 'Hiệu ứng nở hoa chỉ tình trạng hoà trộn màu sắc giống như muôn ngàn bông hoa đang nở.'},
#  'UIIT_STT_VIDIO_TTDESC_14': {'Service': '1',
#   'Data': 'Chuyển động học chỉ kỹ thuật chuyển động của các động tác, chuyển động của tóc...'},
#  'UIIT_STT_VIDIO_TTDESC_15': {'Service': '1',
#   'Data': 'Bù đắp các phác thảo thô để các đổi tượng trong tự nhiên hơn.'},
#  'UIIT_STT_VIDIO_TTDESC_16': {'Service': '1',
#   'Data': 'Tắt hiệu ứng skill để hệ thống chạy mượt hơn'},
#  'UIIT_STT_VIDIO_TTDESC_17': {'Service': '1',
#   'Data': 'Khi được trang bị bộ đồ chiến đấu lớn, người chơi gần đó sẽ được nâng cao khả năng chiến trận'},
#  'UIIT_STT_VIDIO_TTDESC_18': {'Service': '1',
#   'Data': 'Hiển thị các hiệu ứng của tất cả các đối tượng trên màn hình chi tiết, và ánh kim loại có thể không kiểm soát được. Tùy chọn này được bất hoạt cho hình ảnh đồ họa thấp.'},
#  'UIIT_STT_GAMESET_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của thú như thú nuôi, thú thồ hàng…'},
#  'UIIT_STT_GAMESET_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của người chơi cùng nhóm'},
#  'UIIT_STT_GAMESET_TTDESC_03': {'Service': '1',
#   'Data': 'Báo động khi HP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_04': {'Service': '1',
#   'Data': 'Báo động khi MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_05': {'Service': '1',
#   'Data': 'Báo động thành tiếng khi HP/MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_AUDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể lựa chọn nhạc nền, bật/tắt/điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh pha trộn, bật/tắt điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh theo khu vực, bật/tắt, điều chỉnh âm lượng'},
#  'UIIT_STT_VIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn tự do'},
#  'UIIT_STT_VIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn từ nhân vật thứ ba để theo dõi bản thân từ sau lưng'},
#  'UIIT_STT_VIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn 1/4, tình trạng không thể thay đổi chất lượng màn hình cao/thấp'},
#  'UIIT_STT_INPUT_TTDESC_01': {'Service': '1',
#   'Data': 'sử dụng chuột hoặc phím tắt để thay đổi tầm nhìn.'},
#  'UIIT_STT_INPUT_TTDESC_02': {'Service': '1',
#   'Data': 'Để thay đổi tầm nhìn, sử dụng chuột phải hoặc phím tắt.'},
#  'UIIT_STT_INPUT_TTDESC_03': {'Service': '1',
#   'Data': 'Mở cửa sổ thông tin nhân vật để kiểm tra các thông tin cơ bản về nhân vật như trang bị, chỉ số sức mạnh/trí tuệ...'},
#  'UIIT_STT_INPUT_TTDESC_04': {'Service': '1',
#   'Data': 'Mở cửa sổ kỹ năng để có thể xem /học các kỹ năng, tăng/giảm chỉ số Tuyệt Kỹ.'},
#  'UIIT_STT_INPUT_TTDESC_05': {'Service': '1',
#   'Data': 'Mở cửa sổ nhóm để có thể lập nhóm, gia nhập nhóm hoặc thiết lập các điều kiện của nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_06': {'Service': '1',
#   'Data': 'Mở cửa sổ cộng đồng. Các thông tin về Hội hoặc tin nhắn, danh sách bạn bè... có thể tìm thấy ở đây.'},
#  'UIIT_STT_INPUT_TTDESC_07': {'Service': '1',
#   'Data': 'sử dụng chế độ Cuồng nộ. Bắt đầu bằng việc nhấn chuột phải lên nút năng lượng to nhất ở ô hiển thị chế độ Cuồng Nộ trên góc trái màn hình.'},
#  'UIIT_STT_INPUT_TTDESC_08': {'Service': '1',
#   'Data': 'Cửa sổ trợ giúp. Giải đáp các thắc mắc cơ bản của người chơi.'},
#  'UIIT_STT_INPUT_TTDESC_09': {'Service': '1',
#   'Data': 'sử dụng các ô nhớ nhanh hoặc bấm chuột phải vào các kỹ năng để thi triển kỹ năng.'},
#  'UIIT_STT_INPUT_TTDESC_10': {'Service': '1',
#   'Data': 'Phím tắt để nhặt đồ tự động trên mặt đất.'},
#  'UIIT_STT_INPUT_TTDESC_11': {'Service': '1',
#   'Data': 'Triệu tập hoặc thu hồi thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_12': {'Service': '1', 'Data': 'Để thú nuôi theo sau.'},
#  'UIIT_STT_INPUT_TTDESC_13': {'Service': '1',
#   'Data': 'Thiết lập chế độ nhặt của thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_14': {'Service': '1',
#   'Data': 'Bạn có thể gửi tin nhắn trực tiếp đến người đã nhắn cho bạn bằng cách nhấn vào nút tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_15': {'Service': '1',
#   'Data': 'Bạn có thể thay đổi thú nuôi bằng cách nhấn nút chuyển đổi thú nuôi khi có nhiều thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_16': {'Service': '1',
#   'Data': 'Mở cửa sổ giả kim thuật. Bạn có thể gia tăng sức mạnh của đồ vật và thêm các tính chất cho đồ vật tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_17': {'Service': '1',
#   'Data': 'Khi tắt chế độ hiển thị đồ vật, mọi thứ như các nhân vật khác, quái vật, thú nuôi... sẽ không được hiển thị ngoại trừ bản thân bạn.'},
#  'UIIT_STT_INPUT_TTDESC_18': {'Service': '1', 'Data': 'Mở hành trang'},
#  'UIIT_STT_INPUT_TTDESC_19': {'Service': '1',
#   'Data': 'Mở cửa sổ hành động. Có rất nhiều phím tắt, icon diễn tả cảm giác hay hành động khác nhau như lập gian hàng, chào hỏi...'},
#  'UIIT_STT_INPUT_TTDESC_20': {'Service': '1',
#   'Data': 'Mở cửa sổ nhiệm vụ để kiểm tra danh sách và thông tin về các nhiệm vụ đang thực hiện.'},
#  'UIIT_STT_INPUT_TTDESC_21': {'Service': '1',
#   'Data': 'Mở toàn bộ bản đồ để kiểm tra vị trí của bản thân và các thành viên trong nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_22': {'Service': '1',
#   'Data': 'Thay đổi tầm nhìn: tầm nhìn tự do --> tầm nhìn từ người thứ ba --> tầm nhìn 1/4 --> lặp lại tầm nhìn tự do'},
#  'UIIT_STT_INPUT_TTDESC_23': {'Service': '1',
#   'Data': 'Kiểm tra tên của các đồ vật dưới đất bằng cách sử dụng phím tắt tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_24': {'Service': '1',
#   'Data': 'Thiết lập chế độ đứng\\ngồi của nhân vật. Khi ngồi, tốc độ hồi phục HP/MP của nhân vật sẽ nhanh hơn.'},
#  'UIIT_STT_INPUT_TTDESC_25': {'Service': '1',
#   'Data': 'Cửa sổ kiểm tra tình trạng của thú nuôi: có thể thiết lập tên của thú nuôi, kiểm tra thông tin thú nuôi tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_26': {'Service': '1', 'Data': 'Thu hồi thú nuôi'},
#  'UIIT_STT_INPUT_TTDESC_27': {'Service': '1',
#   'Data': 'Yêu cầu thú nuôi tấn công'},
#  'UIIT_STT_INPUT_TTDESC_28': {'Service': '1',
#   'Data': 'Có thể sử dụng Hệ thống Siêu thị, tại đây, bạn có thể dùng silk để mua các đồ vật hữu dụng.'},
#  'UIIT_STT_INPUT_TTDESC_29': {'Service': '1',
#   'Data': 'Bạn có thể thiết lập chế độ tự động sử dụng giải dược và thuốc hồi phục, khi đó, việc luyện tập của bạn sẽ dễ dàng hơn.'},
#  'UIIT_STT_INPUT_TTDESC_30': {'Service': '1',
#   'Data': 'Mở cửa sổ gia nhập nhóm. Tại đây, bạn có thể tìm các nhóm đang thiếu thành viên để gia nhập.'},
#  'UIIT_STT_INPUT_TTDESC_31': {'Service': '1',
#   'Data': 'Mở cửa sổ hệ thống gian hàng. Tại đây, bạn có thể dễ dàng tìm thấy các đồ vật được bán trong hệ thống.'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị tên nhân vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị tên quái vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Hiển thị tên Hội'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_04': {'Service': '1',
#   'Data': 'Hiển thị tên các nhân vật khác'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_05': {'Service': '1',
#   'Data': 'Hiển thị tên NPC'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_06': {'Service': '1',
#   'Data': 'Hiển thị biểu tượng cấp độ thấp. Nếu lựa chọn, một dấu hiệu sẽ xuất hiện bên cạnh tên nhân vật của bạn và sẽ biến mất khi bạn lên cấp độ cao.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_01': {'Service': '1',
#   'Data': 'Trong trò chơi có rất nhiều chỉ dẫn được hiển thị dưới dạng tin nhắn ngắn trên cửa sổ trò chuyện. Bạn sẽ tìm thấy các thông tin hữu ích tại đây.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_02': {'Service': '1',
#   'Data': 'Cho phép hiển thị cửa sổ chú ý. Các chỉ dẫn chi tiết sẽ được hiển thị hoặc kiểm tra các thông tin quan trọng khi chuyển sang hệ thống mới. Sẽ rất hữu dụng khi bạn mới gia nhập trò chơi.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_03': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_04': {'Service': '1',
#   'Data': 'Ẩn hệ thống Windows một cách tự động. Nếu sử dụng chức năng này, khung của hệ thống Windows sẽ ẩn đi một cách tự động và chỉ xuất hiện trở lại khi bạn đưa con trỏ chuột lên trên.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_05': {'Service': '1',
#   'Data': 'Chuyển màn hình trò chơi sang chế độ cửa sổ. Bạn có thể sử dụng chế độ cửa sổ theo sở thích.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_06': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu mời vào nhóm. Nếu không sử dụng lựa chọn này, mọi lời mời vào nhóm gửi đến sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_07': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu giao dịch. Nếu không sử dụng chọn lựa này, mọi yêu cầu giao dịch gửi đến sẽ bị từ chối. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_08': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn cá nhân. Nếu không chọn chức năng này, mọi tin nhắn cá nhân sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_09': {'Service': '1',
#   'Data': 'Thể hiện thông tin về các trạng thái tăng cường của nhân vật trong phần thông tin nhân vật thuộc nhóm. Nếu không lựa chọn chức năng này, các thông tin sẽ không thể hiện. Không quan sát được trạng thái dị trạng của nhân vật.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_10': {'Service': '1',
#   'Data': 'Khởi động nhanh trò chơi bằng việc nạp hình ảnh bối cảnh trước khi nạp hình ảnh nhân vật. Đánh dấu vào ô này nếu bạn muốn trò chơi khởi động nhanh hơn.'},
#  'UIIT_MSG_CHATWND_HELP_WHISPER': {'Service': '1',
#   'Data': 'Thì thầm  [$tênnhânvật những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_PARTYMSG': {'Service': '1',
#   'Data': 'Tán gẫu trong nhóm [#những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_USECONTROLATSTORE': {'Service': '1',
#   'Data': 'Nếu bạn ấn phím Ctrl, bạn có thể bán hoặc mua đồ nhanh hơn'},
#  'UIIT_MSG_NOTIFY': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_MSG_CHATWND_MESSAGE_FILTER': {'Service': '1',
#   'Data': 'Một số từ ngữ hoặc cách diễn đạt bị cấm dùng'},
#  'UIIT_STT_GAMEGUIDE_START_1': {'Service': '1',
#   'Data': 'Hãy tìm hiểu những thông tin cơ bản về Con Đường Tơ Lụa và làm quen với những thông tin này trước. Thông qua cửa sổ tán gẫu bạn có thể học được thêm những chỉ dẫn vì vậy hãy luyện thói quen thật chú ý tới những hướng dẫn này. Chắc chắn bạn sẽ thu được những thông tin rất bổ ích.'},
#  'UIIT_STT_GAMEGUIDE_START_2': {'Service': '1',
#   'Data': '※ Hướng dẫn trò chơi có thể được sử dụng bất kỳ lúc nào bằng việc bấm phím  [H]'},
#  'UIIT_STT_GAMEGUIDE': {'Service': '1', 'Data': 'Trợ giúp'},
#  'UIIT_STT_EVENTGUIDE': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_QUESTGUIDE1': {'Service': '1', 'Data': 'Nhiệm vụ'},
#  'UIIT_STT_QUESTGUIDE2': {'Service': '1', 'Data': 'Từ điển nhiệm vụ'},
#  'UIIT_STT_GAMEEVENTGUIDE': {'Service': '1', 'Data': 'Hướng dẫn'},
#  'UIIT_STT_CONFIRM_BOX': {'Service': '1', 'Data': 'Cửa sổ xác nhận'},
#  'UIIT_STT_AGREEMENT_BOX': {'Service': '1', 'Data': 'Cửa sổ đồng ý'},
#  'UIIT_STT_INPUT_BOX': {'Service': '1', 'Data': 'Cửa sổ nhập vào'},
#  'UIIT_PAG_WORLDMAP': {'Service': '1', 'Data': 'Bản đồ lớn'},
#  'UIIT_PAG_LOCALMAP': {'Service': '1', 'Data': 'Bản đồ khu vực'},
#  'UIIT_STT_BACK_WORLDMAP': {'Service': '1', 'Data': 'Mở bản đồ lớn'},
#  'UIIT_STT_JANGAN': {'Service': '1', 'Data': 'Trường An'},
#  'UIIT_STT_DONHWANG': {'Service': '1', 'Data': 'Đôn Hoàng'},
#  'UIIT_STT_KHOTAN': {'Service': '1', 'Data': 'Hòa Điền'},
#  'UIIT_STT_SAMARKAND': {'Service': '1', 'Data': 'Samarkand'},
#  'UIIT_STT_CONSTANTINOPLE': {'Service': '1', 'Data': 'Constantinople'},
#  'UIIT_STT_BIJEOKDAN': {'Service': '1', 'Data': 'Bijeokdan'},
#  'UIIT_STT_HEUKMAKDAN': {'Service': '1', 'Data': 'Heukmakdan'},
#  'UIIT_STT_EVILORDER': {'Service': '1', 'Data': 'Pháo đài tà ác'},
#  'UIIT_STT_ARABIA_CITY': {'Service': '1', 'Data': 'Baghdad'},
#  'UIIT_STT_ARABIA_CITY_DUNGEON': {'Service': '1', 'Data': 'Baghdad (Phụ bản)'},
#  'UIIT_STT_MUHAN': {'Service': '1', 'Data': 'Đấu trường Vô Cực'},
#  'UIIT_MSG_CHEATMSG_GO_TOWN': {'Service': '1', 'Data': '/town'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_1': {'Service': '1',
#   'Data': 'Tìm thấy macro (chơi tự động) trong nhân vật đang chơi. Tự động thoát.'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_2': {'Service': '1',
#   'Data': 'Tên của nhân vật có macro và thời gian đã sử dụng sẽ được ghi lại trên máy chủ'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_3': {'Service': '1',
#   'Data': 'Có thể áp dụng hình phạt giới hạn về thời gian của tài khoản và khóa tài khoản'},
#  'UIIT_MSG_APPEAR_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa xuất hiện ở Hổ Huyệt Sơn'},
#  'UIIT_MSG_APPEAR_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã xuất hiện'},
#  'UIIT_MSG_APPEAR_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi xuất hiện ở Karakoram'},
#  'UIIT_MSG_APPEAR_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan xuất hiện ở Taklamakan'},
#  'UIIT_MSG_APPEAR_TAHOMET': {'Service': '1',
#   'Data': 'Sa Y Thần xuất hiện ở Lạc Khắc Sơn'},
#  'UIIT_MSG_APPEAR_UNIC': {'Service': '1', 'Data': '[%s] đã xuất hiện'},
#  'UIIT_MSG_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn đã biến mất'},
#  'UIIT_MSG_DEAD_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã biến mất'},
#  'UIIT_MSG_DEAD_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi từ Karakoram đã biến mất'},
#  'UIIT_MSG_DEAD_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan từ Taklamakan đã biến mất'},
#  'UIIT_MSG_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã biến mất'},
#  'UIIT_MSG_ANYONE_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': '[%s] đã giết Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_URRUCHI': {'Service': '1',
#   'Data': '[%s] đã giết Ô Lỗ Tề từ Tháp Lý Mộc'},
#  'UIIT_MSG_ANYONE_DEAD_IYUTARU': {'Service': '1',
#   'Data': '[%s] đã giết Băng Chúa Nhi từ Karakoram'},
#  'UIIT_MSG_ANYONE_DEAD_BONELORD': {'Service': '1',
#   'Data': '[%s] đã giết Chúa tể Yarkan từ Taklamakan'},
#  'UIIT_MSG_ANYONE_DEAD_TAHOMET': {'Service': '1',
#   'Data': '[%s] đã giết Sa Y Than từ Lạc Khắc Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã giết [%s]'},
#  'UIIT_STT_ROLL_OF_CLOTH': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILK_BUY_RESULT': {'Service': '1', 'Data': 'Bạn đã mua [%d] silk'},
#  'UIIT_STT_SILK_BUY_CANCLE': {'Service': '1',
#   'Data': 'Việc mua bán [%d] silk đã bị hủy bỏ'},
#  'UIIT_STT_SILK_BUY_RECEIVE': {'Service': '1',
#   'Data': 'Bạn nhận được quà là [%d] silk'},
#  'UIIT_STT_SILK_SEND_RESULT': {'Service': '1',
#   'Data': 'Bạn đã gửi [%d] silk đi làm quà'},
#  'UIIT_STT_SILK_POINT_BUY_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được trả tiền'},
#  'UIIT_STT_SILK_POINT_USE_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được sử dụng'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK': {'Service': '1', 'Data': 'Silk đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_MALL': {'Service': '1', 'Data': 'Cửa hàng Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_MALL': {'Service': '1',
#   'Data': 'Cửa hàng đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_TOTAL': {'Service': '1', 'Data': 'Tổng số Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_TOTAL': {'Service': '1',
#   'Data': 'Tổng số Silk đặc biệt'},
#  'UIIT_STT_SILKMALL': {'Service': '1', 'Data': 'Siêu thị'},
#  'UIIT_STT_SILKMALL_MAIN': {'Service': '1', 'Data': 'Phần chính'},
#  'UIIT_STT_SILKMALL_HOT_STORE': {'Service': '1', 'Data': 'HOT Shop'},
#  'UIIT_STT_SILKMALL_CONSUMPTION': {'Service': '1', 'Data': 'Đồ tiêu dùng'},
#  'UIIT_STT_SILKMALL_LEND_ITEM': {'Service': '1', 'Data': 'Tiền thuê đồ'},
#  'UIIT_STT_SILKMALL_AVATA': {'Service': '1', 'Data': 'Trang trí'},
#  'UIIT_STT_SILKMALL_PET': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PACKAGE': {'Service': '1', 'Data': 'Gói hàng'},
#  'UIIT_STT_SILKMALL_SHOPPING_BASKET_LIST': {'Service': '1',
#   'Data': 'Hàng đã chọn'},
#  'UIIT_STT_SILKMALL_NEW_ITEM': {'Service': '1', 'Data': 'Hàng mới'},
#  'UIIT_STT_SILKMALL_EVENT': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_SPECIAL_COAST': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_FAVORITE': {'Service': '1', 'Data': 'Hàng bán chạy'},
#  'UIIT_STT_SILKMALL_SPECIAL': {'Service': '1', 'Data': 'Đặc biệt'},
#  'UIIT_STT_SILKMALL_SCROLL': {'Service': '1', 'Data': 'Hỗ trợ'},
#  'UIIT_STT_SILKMALL_POTION': {'Service': '1', 'Data': 'Hồi phục'},
#  'UIIT_STT_SILKMALL_COMMUNITY': {'Service': '1', 'Data': 'Cộng đồng'},
#  'UIIT_STT_SILKMALL_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY': {'Service': '1', 'Data': 'Giả kim thuật'},
#  'UIIT_STT_SILKMALL_PREMIUM_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ASTRAL': {'Service': '1', 'Data': 'Tinh thạch'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': 'Bất diệt (bảo toàn 99%)'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_3': {'Service': '1', 'Data': 'Áo nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_4': {'Service': '1', 'Data': 'Quần nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_5': {'Service': '1', 'Data': 'Bao tay'},
#  'UIIT_STT_SILKMALL_ARMOR_6': {'Service': '1', 'Data': 'Giầy nặng'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_3': {'Service': '1', 'Data': 'Áo nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_4': {'Service': '1', 'Data': 'Quần nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_6': {'Service': '1', 'Data': 'Giầy nhẹ'},
#  'UIIT_STT_SILKMALL_CLOSE_1': {'Service': '1', 'Data': 'Khăn'},
#  'UIIT_STT_SILKMALL_CLOSE_2': {'Service': '1', 'Data': 'Cầu vai vải'},
#  'UIIT_STT_SILKMALL_CLOSE_3': {'Service': '1', 'Data': 'Áo vải'},
#  'UIIT_STT_SILKMALL_CLOSE_4': {'Service': '1', 'Data': 'Quần vải'},
#  'UIIT_STT_SILKMALL_CLOSE_6': {'Service': '1', 'Data': 'Giầy vải'},
#  'UIIT_STT_SILKMALL_BIG_STORE': {'Service': '1', 'Data': 'Tiệm lớn'},
#  'UIIT_STT_SILKMALL_ASSIST': {'Service': '1', 'Data': 'Chi nhánh'},
#  'UIIT_STT_SILKMALL_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_HAT': {'Service': '1', 'Data': 'Mũ'},
#  'UIIT_STT_SILKMALL_BOOTH': {'Service': '1', 'Data': 'Gian hàng'},
#  'UIIT_STT_SILKMALL_FIREWORK': {'Service': '1', 'Data': 'Kẹo'},
#  'UIIT_STT_SILKMALL_DRESS': {'Service': '1', 'Data': 'Trang phục'},
#  'UIIT_STT_SILKMALL_ATTACH': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_BALLOON': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_PET_SUMMON': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PET_CONSUME': {'Service': '1', 'Data': 'Thú nuôi hết hạn'},
#  'UIIT_STT_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1', 'Data': 'Mua hết'},
#  'UIIT_STT_SILKMALL_BOOK_MARK': {'Service': '1', 'Data': 'Sổ sách'},
#  'UIIT_STT_SILKMALL_PUT_ON': {'Service': '1', 'Data': 'sử dụng thử'},
#  'UIIT_STT_SILKMALL_BUY': {'Service': '1', 'Data': 'Mua'},
#  'UIIT_STT_SILKMALL_PRESENT': {'Service': '1', 'Data': 'Quà'},
#  'UIIT_STT_SILKMALL_DEL': {'Service': '1', 'Data': 'Xóa'},
#  'UIIT_STT_SILKMALL_BUY_LIST': {'Service': '1', 'Data': 'Hàng mua'},
#  'UIIT_STT_SILKMALL_RECEIVE_LIST': {'Service': '1', 'Data': 'Hàng nhận'},
#  'UIIT_STT_SILKMALL_SILKMALL_OUT': {'Service': '1', 'Data': 'Thoát'},
#  'UIIT_STT_SILKMALL_PUT_ON_CLOSE_BUY': {'Service': '1',
#   'Data': 'Mua đồ thời trang'},
#  'UIIT_STT_SILKMALL_ALL_CLOSE_TAKEOFF': {'Service': '1', 'Data': 'Cởi bỏ'},
#  'UIIT_STT_SILKMALL_ADD_INVENTORY': {'Service': '1', 'Data': 'Ô mở rộng'},
#  'UIIT_STT_SILKMALL_ADD_STOREHOUSE_INVENTORY': {'Service': '1',
#   'Data': 'Kho mở rộng'},
#  'UIIT_STT_SILKMALL_SILK': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILKMALL_BUY_SILK': {'Service': '1', 'Data': 'Mua Silk'},
#  'UIIT_STT_SILKMALL_SEND_SILK': {'Service': '1', 'Data': 'Tặng Silk'},
#  'UIIT_STT_SILKMALL_COUPON_EXCHANGE': {'Service': '1',
#   'Data': 'Trao đổi phiếu'},
#  'UIIT_STT_SILKMALL_BUY_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_03': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_USE_INFOMATION': {'Service': '1',
#   'Data': 'Cách sử dụng Siêu thị'},
#  'UIIT_STT_SILKMALL_ENTER': {'Service': '1', 'Data': 'Vào Siêu thị'},
#  'UIIT_STT_SILKMALL_DIRECT_ENTER': {'Service': '1',
#   'Data': 'Vào nhanh Siêu thị'},
#  'UIIT_STT_SILKMALL_NEW_CASHITEM': {'Service': '1',
#   'Data': 'Siêu thị cập nhật đồ vật mới'},
#  'UIIT_STT_SILKMALL_WARNING_1': {'Service': '1',
#   'Data': 'Bạn có thể bị quái vật'},
#  'UIIT_STT_SILKMALL_WARNING_2': {'Service': '1',
#   'Data': 'hoặc những người chơi khác tấn công trong khi vào Siêu thị'},
#  'UIIT_STT_SILKMALL_WARNING_3': {'Service': '1',
#   'Data': 'Nên sử dụng món đồ trong khu vực an toàn'},
#  'UIIT_STT_SILKMALL_MAIN_EXPLAIN': {'Service': '1',
#   'Data': '<sml2><p line_margin="12"><p line_margin="5"><font color="255,255,153,81" style="bold">Siêu Thị là gì?</font><br>Là nơi bán và cho thuê những trang bị để <br>sử dụng trên Con đường tơ lụa. Những trang bị đó phải sử dụng silk để mua.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Mua Silk</font><br>Silk có thể mua bằng cách bấm vào nút Mua silk ở góc trên bên phải màn hình.<br>Bấm vào nút Mua silk bạn sẽ được chuyển đến trang E-Cash.<br>nơi để bạn mua silk.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Tặng Silk</font><font color="255,255,117,117">(Tính năng chưa kích hoạt)</font><br>Trong quá trình mua đồ trong Siêu Thị, bạn có thể bấm vào nút Tặng Silk để gửi <br>tới người chơi khác món đồ bạn chọn.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Coupons exchanges</font><br>Phiếu giảm giá có thể được sử dụng 1 lần để mua silk hoặc sử dụng các item Mall.<br>Điền con số vào phiếu giảm giá để nhận được silk.<br>Số tiền có thể khác nhau tùy thuộc vào các loại phiếu giảm giá.<br></p></p><strong><font color="255,255,153,81">Sổ sách</font></strong><font color="255,255,117,117">(Tính năng chưa được kích hoạt)</font><br>Tất cả những đồ vật bạn mua trong Siêu Thị có thể được lưu giữ trong sổ sách của bạn <br>bằng cách bấm vào Sổ sách. Đồ vật đã lưu trong Sổ của bạn sẽ được hoàn trả <br>ngay cả khi bạn đã mua đồ vật đó.</sml2>'},
#  'UIIT_STT_SILKMALL_MY_INFO': {'Service': '1', 'Data': 'Thông tin cá nhân'},
#  'UIIT_STT_SILKMALL_POSSESSION_GOLD': {'Service': '1',
#   'Data': 'Số lượng hiện có'},
#  'UIIT_STT_SILKMALL_REMAIN_INVENTORY': {'Service': '1', 'Data': '%d ô trống'},
#  'UIIT_STT_SILKMALL_MAIN_INTRO': {'Service': '1',
#   'Data': '<sml2>Chào mừng quý khách đến với cửa hàng bán đồ chất lượng cao của Con Đường Tơ Lụa</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ORDER_SHEET': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_TOOL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_FLEAMARKET': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_ZZIM': {'Service': '1',
#   'Data': '<sml2>Đây là danh sách hàng bạn đặt mua</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_FAVORITY': {'Service': '1',
#   'Data': '<sml2>Có thể xem danh sách những mặt hàng đã mua hoặc chọn trong phần Sổ sách</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COSETC': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'MALL_CONSUME_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'MALL_CONSUME_SCROLL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'MALL_CONSUME_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'MALL_CONSUME_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'MALL_CONSUME_ETC': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'MALL_AVATAR_BOOTH': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'MALL_AVATAR_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_PET_A_GROWTH': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_SILK': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_VEHICLE': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_CART': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_STORES': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PREMIUM_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'MALL_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'MALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'UIIT_STT_SILKMALL_SHORT_KEY': {'Service': '1', 'Data': 'Siêu thị (F10)'},
#  'UIIT_STT_SILKMALL_BUY_CONFIRM': {'Service': '1', 'Data': 'Xác nhận mua'},
#  'UIIT_STT_SILKMALL_DO_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_POPUP_TITLE': {'Service': '1',
#   'Data': 'Đồ trang trí tồn kho'},
#  'UIIT_STT_SILKMALL_POPUP_ADVERTISING': {'Service': '1',
#   'Data': 'Bán có giới hạn'},
#  'UIIT_STT_SILKMALL_POPUP_DATA': {'Service': '1', 'Data': 'Ngày bán:'},
#  'UIIT_STT_SILKMALL_POPUP_REDUCTION': {'Service': '1',
#   'Data': 'Cho tới khi giảm giá'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_M': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nam)'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_W': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nữ)'},
#  'UIIT_MSG_SILKMALL_ZZIM_CONFIRM': {'Service': '1',
#   'Data': '<sml2><font color="255,255,255,255">Bạn sẽ đặt món đồ này chứ?<br>các món đồ được đặt có thể được chọn và mua một tất cả ở danh sách đặt hàng.</font></sml2>'},
#  'UIIT_MSG_SILKMALL_ZZIM_DELITE': {'Service': '1',
#   'Data': 'Xóa món đồ trong danh sách đặt hàng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1',
#   'Data': 'Bạn sẽ mua luôn số hàng đã đặt chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY_TOTAL': {'Service': '1',
#   'Data': 'Tổng cộng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_1': {'Service': '1',
#   'Data': 'Bạn có hủy số hàng đã đặt không ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_2': {'Service': '1',
#   'Data': 'Nếu bạn hủy bỏ việc sử dụng món đồ đã chọn, hiệu ứng của nó sẽ mất'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE': {'Service': '1',
#   'Data': 'Bạn sẽ dùng món đồ đã chọn chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_REVERSE_PORTAL': {'Service': '1',
#   'Data': 'sử dụng bùa dịch chuyển phản hồi. Hãy chọn điểm đến.'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_RETURN': {'Service': '1',
#   'Data': 'Dịch chuyển tới điểm về cuối'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_DEATH': {'Service': '1',
#   'Data': 'Dịch chuyển tới nơi bạn đã chết'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_INS': {'Service': '1',
#   'Data': 'sử dụng các vật phẩm này bạn sẽ không thể dịch chuyển được'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_GNGWC': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật sau khi kết thúc trận chiến'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_BUY_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không thành công do không đủ silk'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_GIFT': {'Service': '1',
#   'Data': 'Silk không đủ để tặng'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng cho loại đồ vật trang bị'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_SINCE_EQUIP_CLASS_TOO_HIGH': {'Service': '1',
#   'Data': 'Không thể thay đổi giới tính do không phù hợp với cấp độ của đồ vật'},
#  'UIIT_MSG_STRGERR_INVALID_TRANSGENDER_TARGET': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể thay đổi giới tính'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_TELEPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi cuối cùng bạn đã quay lại'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_DIEDPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi bạn đã chết'},
#  'UIIT_MSG_STRGERR_ONLY_THE_DEAD_CAN_USE_RESURRECT_SCROLL': {'Service': '1',
#   'Data': 'Chỉ sử dụng trong tình trạng đã chết'},
#  'UIIT_MSG_STRGERR_THERE_IS_NO_ITEM_TO_REPAIR': {'Service': '1',
#   'Data': 'Không có đồ vật nào cần sửa chữa'},
#  'UIIT_MSG_STRGERR_CANT_QUICKSELL_CASHITEM': {'Service': '1',
#   'Data': 'Không có chức năng mua bán nhanh với những món đồ hiếm.'},
#  'UIIT_MSG_STRGERR_TRADE_FAILURE': {'Service': '1',
#   'Data': 'Giao dịch thất bại không có lý do'},
#  'UIIT_STT_SILKMALL_FAIL_ITEMBUY_LOGOUT': {'Service': '1',
#   'Data': 'Trò chơi sẽ chấm dứt do việc mua đồ Premium thất bại'},
#  'UIIT_STT_SILKMALL_DONOT_USE_TELEPORT': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_MSG_SELL_RECONFIRM': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_PAG_CHAR_SKIN_CHANGE': {'Service': '1',
#   'Data': 'Thay đổi hình dáng bên ngoài của nhân vật'},
#  'UIIT_MSG_CHAR_SKIN_ERR_ARMOR': {'Service': '1',
#   'Data': 'Để thay đổi giới tính phải bỏ đồ bảo hộ và gỡ bỏ hết các ô mở rộng'},
#  'UIIT_MSG_CHAR_SKIN_CHANGE_SUCCESS': {'Service': '1',
#   'Data': 'Thay đổi giới tính thành công'},
#  'UIIT_STT_GUILD_INFO': {'Service': '1', 'Data': 'T.Tin Hội'},
#  'UIIT_CTL_LETTER': {'Service': '1', 'Data': 'Hộp thư kết hợp'},
#  'UIIT_CTL_FRIEND': {'Service': '1', 'Data': 'Bạn'},
#  'UIIT_STT_GUILD_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_GUILD_STAFF': {'Service': '1', 'Data': 'Hội phó'},
#  'UIIT_STT_GUILDSMAN': {'Service': '1', 'Data': 'Hội viên'},
#  'UIIT_STT_GUILDSMAN_NUM': {'Service': '1', 'Data': 'Số'},
#  'UIIT_STT_GUILD_COMMON_KNOW': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_GUILD_COMMON_KNOW_WRITE': {'Service': '1',
#   'Data': 'Viết thông báo'},
#  'UIIT_MSG_GUILD_COMMON_NOTEXIST': {'Service': '1',
#   'Data': 'Không có thông báo'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo (%d/Tối đa.%d)'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_TITLE_REMIND': {'Service': '1',
#   'Data': 'Hãy điền tiêu đề lời thông báo'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT_TITLE': {'Service': '1',
#   'Data': 'Chưa điền tiêu đề'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo'},
#  'UIIT_MSG_GUILDERR_TARGET_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Người chơi khác không có quyền'},
#  'UIIT_CTL_GUILD_WRITE_END': {'Service': '1', 'Data': 'Hoàn thành'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND_UPDATE': {'Service': '1',
#   'Data': 'Thông báo của Hội đã thay đổi'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_JOIN': {'Service': '1',
#   'Data': 'Hội chủ Hội [%s] đề nghị liên minh với bạn, bạn có chấp nhận không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_WITHDRAWA': {'Service': '1',
#   'Data': 'Bạn có muốn rời bỏ liên minh không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_BREAKUP': {'Service': '1',
#   'Data': 'Liên minh đã bị giải tán'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_NOTALLY': {'Service': '1',
# ...
#   'Data': 'Đã khỏi bệnh'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CHAOS': {'Service': '1',
#   'Data': 'Đã khỏi lẫn lộn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_PD': {'Service': '1',
#   'Data': 'Đã khỏi bị thối rữa'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_MD': {'Service': '1',
#   'Data': 'Đã được khoẻ lại'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_STR': {'Service': '1',
#   'Data': 'Đã hết bất lực'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_INT': {'Service': '1',
#   'Data': 'Đã hết bị cô lập'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_HP': {'Service': '1',
#   'Data': 'Đã hết hoảng loạn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSIE_MP': {'Service': '1',
#   'Data': 'Đã hết bị thiêu đốt'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_TIME_BOMB': {'Service': '1',
#   'Data': 'Đã hết ẩn nấp'},
#  'UIIT_MSG_BURN': {'Service': '1', 'Data': 'Thiêu đốt'},
#  'UIIT_MSG_FROSTBITE': {'Service': '1', 'Data': 'Tê cóng'},
#  'UIIT_MSG_FREEZING': {'Service': '1', 'Data': 'Đóng băng'},
#  'UIIT_MSG_SHOCK': {'Service': '1', 'Data': 'Nhiễm điện'},
#  'UIIT_MSG_ZOMBIE': {'Service': '1', 'Data': 'Yểm bùa'},
#  'UIIT_MSG_DARK': {'Service': '1', 'Data': 'Mờ mắt'},
#  'UIIT_MSG_STUN': {'Service': '1', 'Data': 'Choáng'},
#  'UIIT_MSG_PARTYERR_OUT_OF_LEVEL': {'Service': '1',
#   'Data': 'Không thể vào nhóm đó do sự chênh lệch về cấp độ.'},
#  'UIIT_MSG_FLEAMARKET_ERR_IM_BUSY': {'Service': '1',
#   'Data': 'Bạn ở trong tình trạng không được mở gian hàng mới'},
#  'UIIT_MSG_JSERR_SINCE_YOU_DIE_IN_MURDERER_SP_DEPRIVED_BY_SERVER': {'Service': '1',
#   'Data': 'Bị mất [%u] điểm kinh nghiệm'},
#  'UIIT_MSG_INTERACTION_FAIL__REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_PORTAL_SCROLL': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_SUMMON_VEHICLE': {'Service': '1',
#   'Data': 'Không thể dùng thú vận chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_INTERACTION_FAIL_MURDERER_CAN_USE_PORTAL_STRUCTURE': {'Service': '1',
#   'Data': 'Không thể qua cổng dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_FLEAMARKET_ERR_CANT_OPEN_MARKET_MURDERER': {'Service': '1',
#   'Data': 'Không thể mở gian hàng mới trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng item trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_ENABLEINPUT_FEWERTHAN_REMAIN': {'Service': '1',
#   'Data': 'Chỉ có thể nhập số đơn vị còn lại'},
#  'UIIT_MSG_STRGERR_CANNOT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy người chơi khác'},
#  'UIIT_MSG_STRGERR_SPECIFY_POSITIVE_NUMBER_ONLY': {'Service': '1',
#   'Data': 'Số không hợp lệ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi bị hủy bỏ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_BEFORE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi lần trước bị hủy bỏ vì đã thực hiện trao đổi với người chơi khác'},
#  'UIIT_MSG_STRGERR_CANNOT_WITDRAW_MORETHAN_DEPOSIT': {'Service': '1',
#   'Data': '-'},
#  'UIIT_MSG_DEAL_ASK': {'Service': '1',
#   'Data': 'Có người muốn trao đổi với bạn. Bạn chấp nhận chứ?'},
#  'UIIT_MSG_DEAL_ASKING': {'Service': '1', 'Data': 'Trao đổi với [%s]'},
#  'UIIT_MSG_STRGERR_INVALID_TARGET': {'Service': '1',
#   'Data': 'Không thấy mục tiêu'},
#  'UIIT_MSG_STRGERR_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận làm việc khác'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_OPPONENT_INV_SPACE': {'Service': '1',
#   'Data': 'Không thể đưa thêm món đồ đó vào cửa sổ trao đổi vì thùng đồ người kia đã đầy.'},
#  'UIIT_MSG_STRGERR_NON_SETUP_KEY': {'Service': '1',
#   'Data': 'Không thể đặt phím đã lựa chọn'},
#  'UIIT_MSG_STRGERR_CHATING_LIMIT': {'Service': '1',
#   'Data': 'Không thể lặp lại cùng nội dung'},
#  'UIIT_MSG_STRGERR_DEAL_FAIL_NON_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không được thực hiện do không có đồ vật giao dịch'},
#  'UIIT_STT_TARGETTING': {'Service': '1', 'Data': 'Mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTLEARN': {'Service': '1',
#   'Data': 'Kỹ năng không xác định'},
#  'UIIT_SKILL_USE_FAIL_TIMEDELAY_REUSEDELAY': {'Service': '1', 'Data': '-'},
#  'UIIT_SKILL_USE_FAIL_WRONGDISTANCE': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng với mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTENOUGHLEVEL': {'Service': '1',
#   'Data': 'Không sử dụng được vì cấp độ của bạn thấp'},
#  'UIIT_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh người chơi khác vì cấp độ của người đó cao hơn bạn'},
#  'UIIT_CHATERR_CANT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy [%s]'},
#  'UIIT_CHATERR_YOU_ARE_SQUELCHED': {'Service': '1',
#   'Data': 'Chức năng thì thầm của  [%s]đã bị tắt'},
#  'UIIT_CHATERR_NOT_A_PARTY_MEMBER': {'Service': '1',
#   'Data': 'Không ở trong nhóm nào'},
#  'UIIT_CHATERR_INVALID_COMMAND': {'Service': '1',
#   'Data': 'Lệnh chat không hợp lệ'},
#  'UIIT_CHATERR_ALLIANCE_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Không sử dụng được chức năng tán gẫu với đồng minh vì Hội được chọn không phải là đồng minh của bạn'},
#  'UIIT_CHATERR_WHISPER_TO_MESSAGE': {'Service': '1', 'Data': 'Tin đi'},
#  'UIIT_CHATERR_WHISPER_FROM_MESSAGE': {'Service': '1', 'Data': 'Tin đến'},
#  'UIIT_TOOLTIP_PK_DAY': {'Service': '1', 'Data': 'PK hàng ngày %d / %d'},
#  'UIIT_TOOLTIP_PK_TOTAL': {'Service': '1', 'Data': 'Tổng PK %d / %d'},
#  'UIIT_TOOLTIP_PK_PENALTY_TIME': {'Service': '1',
#   'Data': 'Chỉ số PK %d (Cấp độ %d)'},
#  'UIIT_TOOLTIP_PENALTY_GOLD': {'Service': '1', 'Data': 'Phạt %d vàng'},
#  'UIIT_TOOLTIP_JOB_PENALTY_TIME': {'Service': '1',
#   'Data': 'Không được hành nghề trong %d phút'},
#  'UIIT_TOOLTIP_EQUIPMENT_CLASS': {'Service': '1', 'Data': 'Cấp: Cấp %d'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_DROPPED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể bỏ đi'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_PICKED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể lấy được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_TRADED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể mang ra mua bán được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể sửa chữa được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể làm lại được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_USED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể dùng được'},
#  'UIIT_MSG_CANNOT_BE_USED_ITEM_CART': {'Service': '1',
#   'Data': 'Không thể dùng mà không có thú di chuyển/ chuyên chở'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_IN_BATTLE_STATE': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang đánh nhau'},
#  'UIIT_MSG_REMAIN_TIME': {'Service': '1', 'Data': '(còn %d giây)'},
#  'UIIT_MSG_STRGERR_ONLY_ROBBER_CAN_USE_THIS_ITEM': {'Service': '1',
#   'Data': 'Món đồ được chọn chỉ sử dụng được khi làm Đạo Tặc'},
#  'UIIT_MSG_STRGERR_CANT_OPERATE_REQUESTED_JOB_DURING_LOGOUT': {'Service': '1',
#   'Data': 'Không thể thực hiện khi đang thoát trò chơi'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED_TO_USE_THISITEM': {'Service': '1',
#   'Data': 'Không thể đung được món đồ đó vì cấp độ của nhân vật còn thấp'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_WHILE_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang dịch chuyển'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME': {'Service': '1',
#   'Data': 'Còn %d giây sẽ thoát trò chơi'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME_CANCLE': {'Service': '1',
#   'Data': 'Hủy bỏ việc thoát khỏi trò chơi'},
#  'UIIT_MSG_STRGERR_CANT_SELL_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể bán món đồ khi đang trang bị'},
#  'UIIT_MSG_STRGERR_CANT_SWAP_JOBITEM': {'Service': '1',
#   'Data': 'Phải bỏ món đồ trước ra thì mới mặc đồ mới vào được'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBCHANGE_COMPLETE': {'Service': '1',
#   'Data': 'Không thể cởi trang bị nghề nghiệp trong vòng 10 giây kể từ lúc đeo vào'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBITEM_DETACH_COMPLETE': {'Service': '1',
#   'Data': 'Không thể đeo trang bị nghề nghiệp khác trong 10 phút kể từ lúc tháo ra'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_JOBITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Bạn chỉ có thể bỏ trang bị nghề nghiệp sau 20 giây kể từ trận chiến cuối cùng.'},
#  'UIIT_MSG_STRGERR_CANT_HAVE_CART': {'Service': '1',
#   'Data': 'Không thể bỏ trang bị nghề nghiệp ra trong khi đang triệu tập thú vận chuyển'},
#  'UIIT_MSG_COSERR_COLLISION_EXIST_BETWEEN_US': {'Service': '1',
#   'Data': 'Không thực hiện được lệnh di chuyển do có chướng ngại vật'},
#  'UIIT_MSG_INTERACTION_FAIL_IM_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận việc khác'},
#  'UIIT_MSG_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh vì kỹ năng hồi sinh của bạn còn thấp'},
#  'UIIT_MSG_SKILL_USE_FAIL_NOTENOUGHHP': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng đó vì không đủ HP'},
#  'UIIT_MSG_SKILL_USE_FAIL_ITS_NOT_A_BATTLE_FIELD': {'Service': '1',
#   'Data': 'Không thể tấn công trong khu vực an toàn'},
#  'UIIT_MSG_SKILL_USE_FAIL_WAITFOR_JOB_ACTIVATE': {'Service': '1',
#   'Data': 'Không thể tấn công trong 10 giây kể từ lúc mang trang bị nghề nghiệp vào'},
#  'UIIT_MSG_STRGERR_DONT_HAVE_ANY_TRADECART_TO_PICK_SPECIALTY': {'Service': '1',
#   'Data': 'Không thể nhận được đặc sản nếu không có thú vận chuyển'},
#  'UIIT_MSG_STRGERR_CANT_BE_STORED': {'Service': '1',
#   'Data': 'Món đồ đó không thể lưu tại nơi đã chỉ định'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị đồ vật vì cấp độ hoặc cấp độ tuyệt kỹ nhân vật còn thấp'},
#  'UIIT_MSG_STRGERR_LOCKED_BY_OTHER_ONE': {'Service': '1',
#   'Data': 'Không thể lấy được món đồ đó vì nó của người chơi khác'},
#  'UIIT_MSG_STRGERR_GENDER_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác giới tính'},
#  'UIIT_MSG_STRGERR_TRADE_BAY_FULL': {'Service': '1',
#   'Data': 'Không thể thêm vào món đồ đã chọn vì cửa sổ trao đổi đã đầy'},
#  'UIIT_MSG_STRGERR_COUNTRY_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác chủng tộc'},
#  'UIIT_MSG_STRGERR_HIGHER_STRENGTH_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì thiếu sức mạnh'},
#  'UIIT_MSG_STRGERR_HIGHER_INTELLECT_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì trí tuệ thấp'},
#  'UIIT_MSG_STRGERR_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_EU_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_CANT_EQUIP_RAZED_ITEM': {'Service': '1',
#   'Data': 'Không thể trang bị món đồ đã hỏng'},
#  'UIIT_MSG_STRGERR_PREV_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển.'},
#  'UIIT_MSG_STRGERR_POSSESSION_LIMIT_EXCEEDED': {'Service': '1',
#   'Data': 'Không thể có nhiều hơn số lượng giới hạn'},
#  'UIIT_MSG_STRGERR_ROBBER_CANT_SUMMON_CART_IN_TOWN': {'Service': '1',
#   'Data': 'Không thể triệu hồi phương tiện chuyên trở khi đang ở Làng Đạo Tặc'},
#  'UIIT_MSG_INTERACTION_FAIL_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển rồi'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_TRADECART': {'Service': '1',
#   'Data': 'Không thể dịch chuyển khi đang có thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_RIDE': {'Service': '1',
#   'Data': 'Không thể sử dụng cổng dịch chuyển khi đang cưỡi thú'},
#  'UIIT_MSG_INTERACTION_FAIL_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Không thể qua đò khi đang ở xa thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không sửa chữa được'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không làm lại được'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_TEMPORARILY': {'Service': '1',
#   'Data': 'Bất khả xâm phạm - Không thể tấn công hoăc bị tấn công trong 5 giây'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_FORTRESS': {'Service': '1',
#   'Data': 'Khi tấn công pháo đài trong tình trạng bất khả xâm phạm - không thể tấn công trong 10 giây'},
#  'UIIT_MSG_COSERR_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Một nhân vật không thể cách xa quá thú vận chuyển %d m'},
#  'UIIT_MSG_RETURN_CANCLE': {'Service': '1',
#   'Data': 'Việc sử dụng bùa dịch chuyển đã bị hủy bỏ'},
#  'UIIT_MSG_QUESTEND_2': {'Service': '1',
#   'Data': 'Hãy mở cửa sổ Nhiệm vụ (Q) để kiểm tra nội dung'},
#  'UIIT_MSG_JSERR_PREVIOUS_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể vào mê cung khi sắp dịch chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_OUT_OF_REQUIRED_LEVEL_FOR_TELEPORT': {'Service': '1',
#   'Data': 'Không thể dịch chuyển vì cấp độ của bạn quá thấp'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_FREEBATTLEITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Không thể bỏ khăn ra trong khi đang đánh nhau'},
#  'UIIT_MSG_STRGERR_STORAGE_OPERATION_BLOCKED': {'Service': '1',
#   'Data': 'Hiện tại bạn không được phép di chuyển các món đồ hoặc trao đổi chúng'},
#  'UIIT_MSG_QUEST_CALLMONSTER_NOTATTACK': {'Service': '1',
#   'Data': 'Cấp độ của bạn còn quá thấp để có thể đánh nhau với quái vật'},
#  'UIIT_MSG_QUEST_GET_ITEM_FAILURE': {'Service': '1',
#   'Data': 'Không thể nhặt được món đồ'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_MONSTER': {'Service': '1',
#   'Data': 'Không thể di chuyển vì bạn đã ở cách quái vật %d m.'},
#  'UIIT_MSG_QUEST_FAIL_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Đã thất bại trong việc bắt giữ quái vật.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_CHATTING_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn đang làm nhiệm vụ nên không thể tán gẫu được.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MOVING_IN_DUNGEON': {'Service': '1',
#   'Data': 'Đã ra khỏi vị trí chỉ định nên không thể di chuyển được nữa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_DO_IT_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này vì bạn đang làm một nhiệm vụ khác có liên quan.'},
#  'UIIT_MSG_QUEST_ERR_TOO_LOW_LEVEL': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này do cấp độ của bạn còn thấp'},
#  'UIIT_MSG_QUEST_END_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ kết thúc sau %d phút'},
#  'UIIT_MSG_QUEST_START_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ bắt đầu trong %d giây (s)'},
#  'UIIT_MSG_QUEST_ERR_USE_WHANITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật này trong trạng thái Cuồng nộ'},
#  'UIIT_MSG_QUEST_ERR_CAPTUREMONSTER_ATTACK': {'Service': '1',
#   'Data': 'Không thể tấn công quái vật đã sập bẫy'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Không thể bắt quái vật thì khoảng cách quá xa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì đã đặt bẫy rồi'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_EXIST_MONSTER': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì quái vật ở quá gần'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật vì điều kiện nhiệm vụ không cho phép'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_WRONG_PLACE': {'Service': '1',
#   'Data': 'Không thể đặt bẫy trong khu vực này'},
#  'UIIT_MSG_QUEST_ERR_NO_TARGET': {'Service': '1',
#   'Data': 'Mệnh lệnh không thể thực thi do chưa chọn đối tượng'},
#  'UIIT_MSG_CANNOT_BUYBACK_ITEM_SELL': {'Service': '1',
#   'Data': 'Đồ vật không thể mua lại được. Bạn có chắc muốn bán nó đi không?'},
#  'UIIT_MSG_QUEST_INS_TIMEOUT': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ hoàn htành sau %d giây, bạn sẽ được trở lại vị trí ban đầu.'},
#  'UIIT_MSG_QUEST_INS_CONDITION': {'Service': '1',
#   'Data': 'Bạn sẽ trở lại vị trí ban đầu trong 5 giây nữa vì nhận được yêu cầu không thể ở lại khu vực hiện tại.'},
#  'UIIT_MSG_QUEST_INS_DEATH': {'Service': '1',
#   'Data': 'Không thể chuyển đến khu vực khác khi nhân vật của bạn đang bị chết'},
#  'UIIT_MSG_DROP_WARNING_1': {'Service': '1',
#   'Data': 'Nếu bạn vứt đồ vật này ra ngoài, thì bạn sẽ mất đi quyền sở hữu đồ vật này'},
#  'UIIT_MSG_DROP_WARNING_2': {'Service': '1',
#   'Data': 'Người khác có thể nhật chúng. Bạn có chắc là muốn vứt nó ra không?'},
#  ...}

# %% [markdown]
# ## TextData_Object.txt

# %%
text_data_object = os.path.join(server_dep, 'TextData_Object.txt')
text_data_object
# Out:
# 'server_dep\\silkroad\\textdata\\TextData_Object.txt'

# %%
text_data_object_files = get_lines(text_data_object)
text_data_object_files
# Out:
# ['TextData_Object_1000.txt',
#  'TextData_Object_10000.txt',
#  'TextData_Object_10200.txt',
#  'TextData_Object_10400.txt',
#  'TextData_Object_10600.txt',
#  'TextData_Object_10800.txt',
#  'TextData_Object_11000.txt',
#  'TextData_Object_11200.txt',
#  'TextData_Object_11400.txt',
#  'TextData_Object_11600.txt',
#  'TextData_Object_11800.txt',
#  'TextData_Object_1200.txt',
#  'TextData_Object_12000.txt',
#  'TextData_Object_12200.txt',
#  'TextData_Object_12400.txt',
#  'TextData_Object_12600.txt',
#  'TextData_Object_1400.txt',
#  'TextData_Object_1600.txt',
#  'TextData_Object_1800.txt',
#  'TextData_Object_200.txt',
#  'TextData_Object_2000.txt',
#  'TextData_Object_2200.txt',
#  'TextData_Object_2400.txt',
#  'TextData_Object_2600.txt',
#  'TextData_Object_2800.txt',
#  'TextData_Object_3000.txt',
#  'TextData_Object_3200.txt',
#  'TextData_Object_3400.txt',
#  'TextData_Object_3600.txt',
#  'TextData_Object_3800.txt',
#  'TextData_Object_400.txt',
#  'TextData_Object_4000.txt',
#  'TextData_Object_4200.txt',
#  'TextData_Object_4400.txt',
#  'TextData_Object_4600.txt',
#  'TextData_Object_4800.txt',
#  'TextData_Object_5000.txt',
#  'TextData_Object_5200.txt',
#  'TextData_Object_5400.txt',
#  'TextData_Object_5600.txt',
#  'TextData_Object_5800.txt',
#  'TextData_Object_600.txt',
#  'TextData_Object_6000.txt',
#  'TextData_Object_6200.txt',
#  'TextData_Object_6400.txt',
#  'TextData_Object_6600.txt',
#  'TextData_Object_6800.txt',
#  'TextData_Object_7000.txt',
#  'TextData_Object_7200.txt',
#  'TextData_Object_7400.txt',
#  'TextData_Object_7600.txt',
#  'TextData_Object_7800.txt',
#  'TextData_Object_800.txt',
#  'TextData_Object_8000.txt',
#  'TextData_Object_8200.txt',
#  'TextData_Object_8400.txt',
#  'TextData_Object_8600.txt',
#  'TextData_Object_8800.txt',
#  'TextData_Object_9000.txt',
#  'TextData_Object_9200.txt',
#  'TextData_Object_9400.txt',
#  'TextData_Object_9600.txt',
#  'TextData_Object_9800.txt',
#  '']

# %%
for xxx in text_data_object_files:
  file_name = os.path.join(server_dep, xxx)
  lines = get_lines(file_name)
  for idx, line in enumerate(lines):
    values = line.split('\t')
    if len(values) < 11:
      continue
    Service = values[0]
    name_str_id = values[2]
    Data = values[10]
    data_text[name_str_id] = {
      "Service": Service,
      "Data": Data
    }
data_text
# Out:
# {'UIC_STT_FONTNAME': {'Service': '1', 'Data': 'Tahoma'},
#  'UIIS_STT_MSG_INSTALL_START': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa"'},
#  'UIIS_STT_MSG_INSTALL_FOLDER': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa" vào thư mục sau'},
#  'UIIS_STT_MSG_INSTALL_END': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt thành công'},
#  'UIIS_STT_INSTALL_FOLDER': {'Service': '1', 'Data': 'Thư mục cài đặt'},
#  'UIIS_STT_INSTALL_FILE': {'Service': '1', 'Data': 'File cài đặt'},
#  'UIIS_CTL_INSTALL': {'Service': '1', 'Data': 'Cài đặt'},
#  'UIIS_CTL_FIND_FOLDER': {'Service': '1', 'Data': 'Tìm kiếm'},
#  'UIIS_CTL_START': {'Service': '1', 'Data': 'Bắt đầu'},
#  'UIIS_CTL_CANCEL': {'Service': '1', 'Data': 'Hủy bỏ'},
#  'UIIS_CTL_CONFIRM': {'Service': '1', 'Data': 'Đồng ý'},
#  'UIIS_MSG_ALREADY_INSTALL': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt'},
#  'UIIS_MSG_UNPACK_ZIP': {'Service': '1',
#   'Data': 'Không thể giải nén Con Đường Tơ Lụa. \\nFile nén bị hỏng.'},
#  'UIIS_MSG_UNPACK_CLOSE': {'Service': '1',
#   'Data': 'Không thể đóng file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_UNPACK_OPEN': {'Service': '1',
#   'Data': 'Không thể mở file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_INSTALL_SPACE': {'Service': '1',
#   'Data': 'Không thể cài đặt do thiếu dung lượng. \\nCần ít nhất %d BYTE dung lượng đĩa'},
#  'UIIS_MSG_BACKBUFFER': {'Service': '1', 'Data': 'Không thể tạo bộ nhớ đệm'},
#  'UIIS_MSG_CHANGE_FOLDER': {'Service': '1',
#   'Data': 'Thư mục cài đặt đã bị thay đổi.\\nKhông thể gỡ bỏ Con Đường Tơ Lụa'},
#  'UIIS_MSG_NOFIND': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa chưa được cài đặt. Việc gỡ bỏ không có tác dụng'},
#  'UIIS_MSG_REMOVE_COMPLETE': {'Service': '1',
#   'Data': 'Tất cả các file đã được xóa bỏ hoàn toàn'},
#  'UIIS_MSG_REMOVE_FAIL': {'Service': '1', 'Data': 'Không thể gỡ bỏ'},
#  'UIIS_STT_DELETE': {'Service': '1', 'Data': 'Xóa thư mục Con Đường Tơ Lụa'},
#  'UIIS_CTL_DELETE': {'Service': '1', 'Data': 'Gỡ bỏ'},
#  'UIIS_CTL_EXIT': {'Service': '1', 'Data': 'Thoát'},
#  'UILM_MSG_PROCESS_ALREADY_EXITS': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đang chạy'},
#  'UILM_MSG_DETECTED_ABNORMAL_PROCESS': {'Service': '1',
#   'Data': 'Phát hiện lỗi chạy chương trình Con Đường Tơ Lụa (Lỗi hệ thống)'},
#  'UILM_MSG_FAILED_LOAD_CLIENT': {'Service': '1',
#   'Data': 'Không thể xác định đặc điểm client. Đang đóng.'},
#  'UILM_MSG_GATEWAY_NOT_IN_SERVICE_CHANNEL': {'Service': '1',
#   'Data': 'Máy chủ đang kiểm tra hoặc không làm việc. Truy cập trang %ssro.vtcgame.vn/ để biết thêm thông tin.'},
#  'UILM_MSG_DRIVER_UPDATE': {'Service': '1',
#   'Data': 'Driver đồ họa của bạn không phải là phiên bản mới nhất. Hãy cập nhật phiên bản mới nhất để xem hình ảnh game đẹp hơn.'},
#  'UILM_MSG_DRIVER_UPDATE_2': {'Service': '1',
#   'Data': 'Không bao giờ xuất hiện lại.'},
#  'UILM_MSG_FAILED_INIT_NETENGINE': {'Service': '1',
#   'Data': 'Không thể khởi chạy NetEngine (Lỗi (%d,%d))'},
#  'UILM_MSG_FAILED_LOAD_VERSION': {'Service': '1',
#   'Data': 'Không thể kiểm tra phiên bản'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_IP': {'Service': '1',
#   'Data': 'Không thể kiểm tra IP kết nối'},
#  'UILM_MSG_INVALID_CONNECT_IP': {'Service': '1',
#   'Data': 'IP kết nối không hợp lệ'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_PORT': {'Service': '1',
#   'Data': 'Không thể kiểm tra cổng kết nối'},
#  'UILM_MSG_INVALID_CONNECT_PORT': {'Service': '1',
#   'Data': 'Cổng kết nối không hợp lệ'},
#  'UILM_MSG_DETECTED_ABNORMAL_DIRECTX': {'Service': '1',
#   'Data': 'DirectX 9.0 chưa được cài đặt hoặc không phải là phiên bản 9.0b. Con Đường Tơ Lụa cần DirectX9.0b hoặc phiên bản mới hơn'},
#  'UILM_MSG_DETECTED_ABNORMAL_MODULE': {'Service': '1',
#   'Data': 'Không xác định client. Kết thúc.'},
#  'UILM_MSG_DETECTED_PATCH_DIABLE': {'Service': '1',
#   'Data': 'Bạn phải cài đặt toàn bộ phiên bản. Kết nối với trang chủ để download toàn bộ phiên bản.'},
#  'UILM_MSG_DETECTED_PATCH_MANUAL': {'Service': '1',
#   'Data': 'Bạn cần cài đặt thủ công. Vui lòng truy cập trang chủ để tải bản cài thủ công về. Bạn có muốn kết nối đến trang chủ không?'},
#  'UILM_MSG_FAILED_EXECUTE_EXPLORER': {'Service': '1',
#   'Data': 'Không thể chạy Internet Explorer.'},
#  'UILM_MSG_FAILED_PATCH': {'Service': '1',
#   'Data': 'Chưa hoàn thành việc sửa lỗi. Hãy thử lại.[Lỗi số(%d)]'},
#  'UILM_MSG_FAILED_EXECUTE_CLIENT': {'Service': '1',
#   'Data': 'Xin lỗi. Không thể chạy Con Đường Tơ Lụa [Lỗi số(%d)]'},
#  'UILM_MSG_NOTEXITS_REPLACERFILE': {'Service': '1',
#   'Data': 'Không tìm thấy file replacer.exe. Chưa hoàn thành việc sửa lỗi.'},
#  'UILM_MSG_DETECTED_ABNORMAL_REPLACERFILE': {'Service': '1',
#   'Data': 'Không thể sửa lỗi vì file replacer.exe đã bị hỏng [lỗi số (%d)]'},
#  'UILM_MSG_FAILED_LOAD_GATEWAY_INFO': {'Service': '1',
#   'Data': 'Không thể đưa ra thuộc tính kết nối của GateWay [lỗi%d]'},
#  'UILM_STT_DIVISION': {'Service': '1', 'Data': 'Bộ phận'},
#  'UILM_STT_DIVISION_LIST': {'Service': '1', 'Data': 'Danh sách bộ phận'},
#  'UILM_STT_DIVISION_SELECTED': {'Service': '1', 'Data': 'Bộ phận lựa chọn'},
#  'UILM_STT_DIVISION_NAME': {'Service': '1', 'Data': 'Tên bộ phận'},
#  'UILM_STT_FARM': {'Service': '1', 'Data': 'Giải'},
#  'UILM_STT_FARM_LIST': {'Service': '1', 'Data': 'Danh sách giải'},
#  'UILM_STT_FARM_NAME': {'Service': '1', 'Data': 'Tên giải'},
#  'FARM0101': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 01 Yahoo'},
#  'FARM0102': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 01 Yahoo'},
#  'FARM0103': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 01 Yahoo'},
#  'FARM0104': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 01 Yahoo'},
#  'FARM0105': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 01 Yahoo'},
#  'FARM0201': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 02 Yahoo'},
#  'FARM0202': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 02 Yahoo'},
#  'FARM0203': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 02 Yahoo'},
#  'FARM0204': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 02 Yahoo'},
#  'FARM0205': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 02 Yahoo'},
#  'FARM0301': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 03 Yahoo'},
#  'FARM0302': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 03 Yahoo'},
#  'FARM0303': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 03 Yahoo'},
#  'FARM0304': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 03 Yahoo'},
#  'FARM0305': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 03 Yahoo'},
#  'FARM0401': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 04 Yahoo'},
#  'FARM0402': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 04 Yahoo'},
#  'FARM0403': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 04 Yahoo'},
#  'FARM0404': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 04 Yahoo'},
#  'FARM0405': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 04 Yahoo'},
#  'UILM_STT_DIVISION_PING': {'Service': '1', 'Data': 'Ping'},
#  'UILM_STT_DIVISION_CONDITION': {'Service': '1', 'Data': 'Tình trạng'},
#  'DIV01': {'Service': '1', 'Data': 'Bộ phận Yahoo 01'},
#  'DIV02': {'Service': '1', 'Data': 'Bộ phận Yahoo 02'},
#  'DIV03': {'Service': '1', 'Data': 'Bộ phận Yahoo 03'},
#  'DIV04': {'Service': '1', 'Data': 'Bộ phận Yahoo 04'},
#  'DIV05': {'Service': '1', 'Data': 'Bộ phận Yahoo 05'},
#  'DIV06': {'Service': '1', 'Data': 'Bộ phận Yahoo 06'},
#  'DIV07': {'Service': '1', 'Data': 'Bộ phận Yahoo 07'},
#  'DIV08': {'Service': '1', 'Data': 'Bộ phận Yahoo 08'},
#  'DIV09': {'Service': '1', 'Data': 'Bộ phận Yahoo 09'},
#  'DIV10': {'Service': '1', 'Data': 'Bộ phận Yahoo 10'},
#  'UILM_STT_DIVISION_RECOMMENDATION': {'Service': '1', 'Data': 'Đề nghị'},
#  'UILM_STT_DIVISION_NOT_RECOMMENDATION': {'Service': '1',
#   'Data': 'Không đề nghị'},
#  'UILM_MSG_SILKROAD_STARTING_HOME': {'Service': '1',
#   'Data': 'Trang chủ của Con đường tơ lụa đã được đặt làm trang chủ mặc định'},
#  'UILM_MSG_YAHOO_STARTING_HOME': {'Service': '1',
#   'Data': 'Đã thiết đặt xong trang chủ https://sro.vtcgame.vn/'},
#  'UILM_MSG_YAHOO_TOOLBAR': {'Service': '1',
#   'Data': 'Đã thiết đặt xong thanh công cụ yahoo'},
#  'UILM_MSG_SERVICE_CLIENT_ERROR_REINSTALL': {'Service': '1',
#   'Data': 'Client của bạn bị lỗi hoặc đã bị phá huỷ nên không thể kết nối đến máy chủ. Hãy cài lại một client mới.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ download bị ngắt. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CANCEL': {'Service': '1',
#   'Data': 'Kết nới với máy chủ download đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_SELECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Launcher sẽ được khởi động lại.'},
#  'UILM_TEXT_CONFIG_GRAPHIC_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UILM_TEXT_CONFIG_GRAPHIC_NORMAL': {'Service': '1', 'Data': 'Bình thường'},
#  'UILM_TEXT_CONFIG_GRAPHIC_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UILM_TEXT_CONFIG_GRAPHIC_USER_DEF': {'Service': '1', 'Data': 'Không đổi'},
#  'UIIT_STT_ETCKEY': {'Service': '1', 'Data': 'Các phím khác'},
#  'UIIT_STT_MOUSE': {'Service': '1', 'Data': 'Chuột'},
#  'UIIT_STT_MOUSE_RIGHT_BUTTON': {'Service': '1', 'Data': 'Ô Nhớ Chuột'},
#  'UIIT_STT_USE_WHEEL_TO_CHANGE_SIGHT': {'Service': '1',
#   'Data': 'Chuột lăn (đổi góc nhìn) chuột phải (dùng Ô Nhớ)'},
#  'UIIT_STT_USE_WHEEL_TO_USE_SKILL': {'Service': '1',
#   'Data': 'Chuột lăn (dùng Ô Nhớ) chuột phải (đổi góc nhìn)'},
#  'UIIT_STT_ITEM_GET': {'Service': '1', 'Data': 'Nhặt đồ'},
#  'UIIT_STT_REFLECT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng phản xạ'},
#  'UIIT_STT_WATER_DETAIL': {'Service': '1', 'Data': 'Chi tiết nước'},
#  'UIIT_STT_LIGHT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng ánh sáng'},
#  'UIIT_STT_BUMP_MAPPING': {'Service': '1', 'Data': 'ánh xạ va chạm'},
#  'UIIT_STT_ENVIRONMENT_MAPPING': {'Service': '1', 'Data': 'ánh xạ môi trường'},
#  'UIIT_STT_LENS_FLAIR': {'Service': '1', 'Data': 'Độ nhạy của thấu kính'},
#  'UIIT_STT_DYNAMIC_ANIMATION': {'Service': '1', 'Data': 'ảnh động sống động'},
#  'UIIT_STT_WATER_REFLECTION': {'Service': '1', 'Data': 'Phản xạ nước'},
#  'UIIT_STT_FILTERING': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_TEXTER_DETAIL': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_GRAPHIC_QUALITY': {'Service': '1', 'Data': 'Chất lượng đồ họa'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL': {'Service': '1',
#   'Data': 'Người dùng tự chọn'},
#  'UIIT_STT_GRAPHIC_QUALITY_USER_CONTROL': {'Service': '1', 'Data': 'Tự chọn'},
#  'UIIT_STT_METAL_DETAIL': {'Service': '1', 'Data': 'Chất liệu kim loại'},
#  'UIIT_STT_BLOOM_EFFECT': {'Service': '1', 'Data': 'Âm lượng'},
#  'UIIT_STT_GRAPHIC': {'Service': '1', 'Data': 'Đồ họa'},
#  'UIIT_STT_RESOLUTION': {'Service': '1', 'Data': 'Độ phân giải'},
#  'UIIT_STT_LUMINOSITY': {'Service': '1', 'Data': 'Độ sáng tối'},
#  'UIIT_STT_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn'},
#  'UIIT_STT_CHAR_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn nhân vật'},
#  'UIIT_STT_SCENERY_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn bối cảnh'},
#  'UIIT_STT_SHADOW_DETAIL': {'Service': '1', 'Data': 'Chi tiết bóng'},
#  'UIIT_STT_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_MIDDLE': {'Service': '1', 'Data': 'Vừa'},
#  'UIIT_STT_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_VERY_DARK': {'Service': '1', 'Data': 'Rất tối'},
#  'UIIT_STT_DARK': {'Service': '1', 'Data': 'Tối'},
#  'UIIT_STT_NORMAL': {'Service': '1', 'Data': 'Trung bình'},
#  'UIIT_STT_LIGHT': {'Service': '1', 'Data': 'Sáng'},
#  'UIIT_STT_VERY_LIGHT': {'Service': '1', 'Data': 'Rất sáng'},
#  'UIIT_STT_SIGHT_VERY_SMALL': {'Service': '1', 'Data': 'Rất hẹp'},
#  'UIIT_STT_SIGHT_SMALL': {'Service': '1', 'Data': 'Hẹp'},
#  'UIIT_STT_SIGHT_LARGE': {'Service': '1', 'Data': 'Rộng'},
#  'UIIT_STT_SIGHT_VERY_LARGE': {'Service': '1', 'Data': 'Rất rộng'},
#  'UIIT_STT_NONE': {'Service': '1', 'Data': 'Không có'},
#  'UIIT_STT_CIRCLE': {'Service': '1', 'Data': 'Vòng tròn'},
#  'UIIT_STT_DETAIL': {'Service': '1', 'Data': 'Chi tiết'},
#  'UIIT_STT_RANK': {'Service': '1', 'Data': '%d bước'},
#  'UIIT_STT_ON': {'Service': '1', 'Data': 'Bật'},
#  'UIIT_STT_OFF': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_GRAPHIC_QUALITY_MIDDLE': {'Service': '1', 'Data': 'Bình thường'},
#  'UIIT_STT_GRAPHIC_QUALITY_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL1': {'Service': '1', 'Data': 'Đồ họa 1'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL2': {'Service': '1', 'Data': 'Đồ họa 2'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_WAR': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_USER': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_VIDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể thay đổi độ phân giải của game'},
#  'UIIT_STT_VIDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể thay đổi độ sáng của game'},
#  'UIIT_STT_VIDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể thay đổi chất lượng đồ hoạ của game. Tìm đến lựa chọn Video và thiết lập các mức độ cao, trung bình hay thấp. Tốc độ tải trò chơi sẽ thay đổi tuỳ theo các mức chất lượng được thiết lập.'},
#  'UIIT_STT_VIDIO_TTDESC_04': {'Service': '1',
#   'Data': 'Có thể thay đổi mức độ chi biết bóng. Tốc độ tải game có thể bị chậm nếu chi tiết bóng được đặt ở mức cao.'},
#  'UIIT_STT_VIDIO_TTDESC_05': {'Service': '1',
#   'Data': 'Khi thiết lập khung cảnh được đặt ở mức cao, có thể nhìn thấy nhiều hình ảnh hơn, tuy nhiên, điều này cũng sẽ làm chậm tốc độ tải game. Có thể thiết lập ở mức thấp, khi đó sẽ chỉ nhìn thấy những khung cảnh ở gần.'},
#  'UIIT_STT_VIDIO_TTDESC_06': {'Service': '1',
#   'Data': 'Khi các thông tin ở nhân vật, quái vật, lâu đài... được lựa chọn hiển thị nhiều, bạn sẽ biết đầy đủ thông tin hơn nhưng như vậy có thể gây chậm tốc độ tải game.'},
#  'UIIT_STT_VIDIO_TTDESC_07': {'Service': '1',
#   'Data': 'Lựa chọn chi tiết bóng nước để hiển thị các hình ảnh được phản chiếu trên mặt nước.'},
#  'UIIT_STT_VIDIO_TTDESC_08': {'Service': '1',
#   'Data': 'Chi tiết nước được lựa chọn với các mức độ hiệu ứng mặt nước, nếu lựa chọn mức độ cao, cảnh mặt nước sẽ đẹp hơn nhưng tốc độ tải game sẽ bị chậm đi.'},
#  'UIIT_STT_VIDIO_TTDESC_09': {'Service': '1',
#   'Data': 'Chi tiết hiển thị kim loại, nếu được lựa chọn, sẽ hiển thị các hiệu ứng ánh kim trên đồ vật kim loại như giáp, vũ khí. Mức độ lựa chọn càng cao thì chất lượng đồ hoạ cũng tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_10': {'Service': '1',
#   'Data': 'Hiệu ứng ánh sáng chỉ hiệu ứng của đèn khi chiếu trên bề mặt đồ vật, khi lựa chọn mức độ hiển thị ánh sáng cao thì độ thật của đồ vật sẽ tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_11': {'Service': '1',
#   'Data': 'Chi tiết chất liệu chỉ mức độ chi tiết của chất liệu. Chất lượng hiển thị chất liệu của đồ vật sẽ tăng lên khi chi tiết chất liệu được lựa chọn ở mức độ cao.'},
#  'UIIT_STT_VIDIO_TTDESC_12': {'Service': '1',
#   'Data': 'Chi tiết thấu kính chỉ tình trạng chiếu sáng giống như một máy quay phim đang hướng về phía mặt trời.'},
#  'UIIT_STT_VIDIO_TTDESC_13': {'Service': '1',
#   'Data': 'Hiệu ứng nở hoa chỉ tình trạng hoà trộn màu sắc giống như muôn ngàn bông hoa đang nở.'},
#  'UIIT_STT_VIDIO_TTDESC_14': {'Service': '1',
#   'Data': 'Chuyển động học chỉ kỹ thuật chuyển động của các động tác, chuyển động của tóc...'},
#  'UIIT_STT_VIDIO_TTDESC_15': {'Service': '1',
#   'Data': 'Bù đắp các phác thảo thô để các đổi tượng trong tự nhiên hơn.'},
#  'UIIT_STT_VIDIO_TTDESC_16': {'Service': '1',
#   'Data': 'Tắt hiệu ứng skill để hệ thống chạy mượt hơn'},
#  'UIIT_STT_VIDIO_TTDESC_17': {'Service': '1',
#   'Data': 'Khi được trang bị bộ đồ chiến đấu lớn, người chơi gần đó sẽ được nâng cao khả năng chiến trận'},
#  'UIIT_STT_VIDIO_TTDESC_18': {'Service': '1',
#   'Data': 'Hiển thị các hiệu ứng của tất cả các đối tượng trên màn hình chi tiết, và ánh kim loại có thể không kiểm soát được. Tùy chọn này được bất hoạt cho hình ảnh đồ họa thấp.'},
#  'UIIT_STT_GAMESET_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của thú như thú nuôi, thú thồ hàng…'},
#  'UIIT_STT_GAMESET_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của người chơi cùng nhóm'},
#  'UIIT_STT_GAMESET_TTDESC_03': {'Service': '1',
#   'Data': 'Báo động khi HP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_04': {'Service': '1',
#   'Data': 'Báo động khi MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_05': {'Service': '1',
#   'Data': 'Báo động thành tiếng khi HP/MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_AUDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể lựa chọn nhạc nền, bật/tắt/điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh pha trộn, bật/tắt điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh theo khu vực, bật/tắt, điều chỉnh âm lượng'},
#  'UIIT_STT_VIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn tự do'},
#  'UIIT_STT_VIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn từ nhân vật thứ ba để theo dõi bản thân từ sau lưng'},
#  'UIIT_STT_VIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn 1/4, tình trạng không thể thay đổi chất lượng màn hình cao/thấp'},
#  'UIIT_STT_INPUT_TTDESC_01': {'Service': '1',
#   'Data': 'sử dụng chuột hoặc phím tắt để thay đổi tầm nhìn.'},
#  'UIIT_STT_INPUT_TTDESC_02': {'Service': '1',
#   'Data': 'Để thay đổi tầm nhìn, sử dụng chuột phải hoặc phím tắt.'},
#  'UIIT_STT_INPUT_TTDESC_03': {'Service': '1',
#   'Data': 'Mở cửa sổ thông tin nhân vật để kiểm tra các thông tin cơ bản về nhân vật như trang bị, chỉ số sức mạnh/trí tuệ...'},
#  'UIIT_STT_INPUT_TTDESC_04': {'Service': '1',
#   'Data': 'Mở cửa sổ kỹ năng để có thể xem /học các kỹ năng, tăng/giảm chỉ số Tuyệt Kỹ.'},
#  'UIIT_STT_INPUT_TTDESC_05': {'Service': '1',
#   'Data': 'Mở cửa sổ nhóm để có thể lập nhóm, gia nhập nhóm hoặc thiết lập các điều kiện của nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_06': {'Service': '1',
#   'Data': 'Mở cửa sổ cộng đồng. Các thông tin về Hội hoặc tin nhắn, danh sách bạn bè... có thể tìm thấy ở đây.'},
#  'UIIT_STT_INPUT_TTDESC_07': {'Service': '1',
#   'Data': 'sử dụng chế độ Cuồng nộ. Bắt đầu bằng việc nhấn chuột phải lên nút năng lượng to nhất ở ô hiển thị chế độ Cuồng Nộ trên góc trái màn hình.'},
#  'UIIT_STT_INPUT_TTDESC_08': {'Service': '1',
#   'Data': 'Cửa sổ trợ giúp. Giải đáp các thắc mắc cơ bản của người chơi.'},
#  'UIIT_STT_INPUT_TTDESC_09': {'Service': '1',
#   'Data': 'sử dụng các ô nhớ nhanh hoặc bấm chuột phải vào các kỹ năng để thi triển kỹ năng.'},
#  'UIIT_STT_INPUT_TTDESC_10': {'Service': '1',
#   'Data': 'Phím tắt để nhặt đồ tự động trên mặt đất.'},
#  'UIIT_STT_INPUT_TTDESC_11': {'Service': '1',
#   'Data': 'Triệu tập hoặc thu hồi thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_12': {'Service': '1', 'Data': 'Để thú nuôi theo sau.'},
#  'UIIT_STT_INPUT_TTDESC_13': {'Service': '1',
#   'Data': 'Thiết lập chế độ nhặt của thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_14': {'Service': '1',
#   'Data': 'Bạn có thể gửi tin nhắn trực tiếp đến người đã nhắn cho bạn bằng cách nhấn vào nút tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_15': {'Service': '1',
#   'Data': 'Bạn có thể thay đổi thú nuôi bằng cách nhấn nút chuyển đổi thú nuôi khi có nhiều thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_16': {'Service': '1',
#   'Data': 'Mở cửa sổ giả kim thuật. Bạn có thể gia tăng sức mạnh của đồ vật và thêm các tính chất cho đồ vật tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_17': {'Service': '1',
#   'Data': 'Khi tắt chế độ hiển thị đồ vật, mọi thứ như các nhân vật khác, quái vật, thú nuôi... sẽ không được hiển thị ngoại trừ bản thân bạn.'},
#  'UIIT_STT_INPUT_TTDESC_18': {'Service': '1', 'Data': 'Mở hành trang'},
#  'UIIT_STT_INPUT_TTDESC_19': {'Service': '1',
#   'Data': 'Mở cửa sổ hành động. Có rất nhiều phím tắt, icon diễn tả cảm giác hay hành động khác nhau như lập gian hàng, chào hỏi...'},
#  'UIIT_STT_INPUT_TTDESC_20': {'Service': '1',
#   'Data': 'Mở cửa sổ nhiệm vụ để kiểm tra danh sách và thông tin về các nhiệm vụ đang thực hiện.'},
#  'UIIT_STT_INPUT_TTDESC_21': {'Service': '1',
#   'Data': 'Mở toàn bộ bản đồ để kiểm tra vị trí của bản thân và các thành viên trong nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_22': {'Service': '1',
#   'Data': 'Thay đổi tầm nhìn: tầm nhìn tự do --> tầm nhìn từ người thứ ba --> tầm nhìn 1/4 --> lặp lại tầm nhìn tự do'},
#  'UIIT_STT_INPUT_TTDESC_23': {'Service': '1',
#   'Data': 'Kiểm tra tên của các đồ vật dưới đất bằng cách sử dụng phím tắt tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_24': {'Service': '1',
#   'Data': 'Thiết lập chế độ đứng\\ngồi của nhân vật. Khi ngồi, tốc độ hồi phục HP/MP của nhân vật sẽ nhanh hơn.'},
#  'UIIT_STT_INPUT_TTDESC_25': {'Service': '1',
#   'Data': 'Cửa sổ kiểm tra tình trạng của thú nuôi: có thể thiết lập tên của thú nuôi, kiểm tra thông tin thú nuôi tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_26': {'Service': '1', 'Data': 'Thu hồi thú nuôi'},
#  'UIIT_STT_INPUT_TTDESC_27': {'Service': '1',
#   'Data': 'Yêu cầu thú nuôi tấn công'},
#  'UIIT_STT_INPUT_TTDESC_28': {'Service': '1',
#   'Data': 'Có thể sử dụng Hệ thống Siêu thị, tại đây, bạn có thể dùng silk để mua các đồ vật hữu dụng.'},
#  'UIIT_STT_INPUT_TTDESC_29': {'Service': '1',
#   'Data': 'Bạn có thể thiết lập chế độ tự động sử dụng giải dược và thuốc hồi phục, khi đó, việc luyện tập của bạn sẽ dễ dàng hơn.'},
#  'UIIT_STT_INPUT_TTDESC_30': {'Service': '1',
#   'Data': 'Mở cửa sổ gia nhập nhóm. Tại đây, bạn có thể tìm các nhóm đang thiếu thành viên để gia nhập.'},
#  'UIIT_STT_INPUT_TTDESC_31': {'Service': '1',
#   'Data': 'Mở cửa sổ hệ thống gian hàng. Tại đây, bạn có thể dễ dàng tìm thấy các đồ vật được bán trong hệ thống.'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị tên nhân vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị tên quái vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Hiển thị tên Hội'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_04': {'Service': '1',
#   'Data': 'Hiển thị tên các nhân vật khác'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_05': {'Service': '1',
#   'Data': 'Hiển thị tên NPC'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_06': {'Service': '1',
#   'Data': 'Hiển thị biểu tượng cấp độ thấp. Nếu lựa chọn, một dấu hiệu sẽ xuất hiện bên cạnh tên nhân vật của bạn và sẽ biến mất khi bạn lên cấp độ cao.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_01': {'Service': '1',
#   'Data': 'Trong trò chơi có rất nhiều chỉ dẫn được hiển thị dưới dạng tin nhắn ngắn trên cửa sổ trò chuyện. Bạn sẽ tìm thấy các thông tin hữu ích tại đây.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_02': {'Service': '1',
#   'Data': 'Cho phép hiển thị cửa sổ chú ý. Các chỉ dẫn chi tiết sẽ được hiển thị hoặc kiểm tra các thông tin quan trọng khi chuyển sang hệ thống mới. Sẽ rất hữu dụng khi bạn mới gia nhập trò chơi.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_03': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_04': {'Service': '1',
#   'Data': 'Ẩn hệ thống Windows một cách tự động. Nếu sử dụng chức năng này, khung của hệ thống Windows sẽ ẩn đi một cách tự động và chỉ xuất hiện trở lại khi bạn đưa con trỏ chuột lên trên.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_05': {'Service': '1',
#   'Data': 'Chuyển màn hình trò chơi sang chế độ cửa sổ. Bạn có thể sử dụng chế độ cửa sổ theo sở thích.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_06': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu mời vào nhóm. Nếu không sử dụng lựa chọn này, mọi lời mời vào nhóm gửi đến sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_07': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu giao dịch. Nếu không sử dụng chọn lựa này, mọi yêu cầu giao dịch gửi đến sẽ bị từ chối. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_08': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn cá nhân. Nếu không chọn chức năng này, mọi tin nhắn cá nhân sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_09': {'Service': '1',
#   'Data': 'Thể hiện thông tin về các trạng thái tăng cường của nhân vật trong phần thông tin nhân vật thuộc nhóm. Nếu không lựa chọn chức năng này, các thông tin sẽ không thể hiện. Không quan sát được trạng thái dị trạng của nhân vật.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_10': {'Service': '1',
#   'Data': 'Khởi động nhanh trò chơi bằng việc nạp hình ảnh bối cảnh trước khi nạp hình ảnh nhân vật. Đánh dấu vào ô này nếu bạn muốn trò chơi khởi động nhanh hơn.'},
#  'UIIT_MSG_CHATWND_HELP_WHISPER': {'Service': '1',
#   'Data': 'Thì thầm  [$tênnhânvật những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_PARTYMSG': {'Service': '1',
#   'Data': 'Tán gẫu trong nhóm [#những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_USECONTROLATSTORE': {'Service': '1',
#   'Data': 'Nếu bạn ấn phím Ctrl, bạn có thể bán hoặc mua đồ nhanh hơn'},
#  'UIIT_MSG_NOTIFY': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_MSG_CHATWND_MESSAGE_FILTER': {'Service': '1',
#   'Data': 'Một số từ ngữ hoặc cách diễn đạt bị cấm dùng'},
#  'UIIT_STT_GAMEGUIDE_START_1': {'Service': '1',
#   'Data': 'Hãy tìm hiểu những thông tin cơ bản về Con Đường Tơ Lụa và làm quen với những thông tin này trước. Thông qua cửa sổ tán gẫu bạn có thể học được thêm những chỉ dẫn vì vậy hãy luyện thói quen thật chú ý tới những hướng dẫn này. Chắc chắn bạn sẽ thu được những thông tin rất bổ ích.'},
#  'UIIT_STT_GAMEGUIDE_START_2': {'Service': '1',
#   'Data': '※ Hướng dẫn trò chơi có thể được sử dụng bất kỳ lúc nào bằng việc bấm phím  [H]'},
#  'UIIT_STT_GAMEGUIDE': {'Service': '1', 'Data': 'Trợ giúp'},
#  'UIIT_STT_EVENTGUIDE': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_QUESTGUIDE1': {'Service': '1', 'Data': 'Nhiệm vụ'},
#  'UIIT_STT_QUESTGUIDE2': {'Service': '1', 'Data': 'Từ điển nhiệm vụ'},
#  'UIIT_STT_GAMEEVENTGUIDE': {'Service': '1', 'Data': 'Hướng dẫn'},
#  'UIIT_STT_CONFIRM_BOX': {'Service': '1', 'Data': 'Cửa sổ xác nhận'},
#  'UIIT_STT_AGREEMENT_BOX': {'Service': '1', 'Data': 'Cửa sổ đồng ý'},
#  'UIIT_STT_INPUT_BOX': {'Service': '1', 'Data': 'Cửa sổ nhập vào'},
#  'UIIT_PAG_WORLDMAP': {'Service': '1', 'Data': 'Bản đồ lớn'},
#  'UIIT_PAG_LOCALMAP': {'Service': '1', 'Data': 'Bản đồ khu vực'},
#  'UIIT_STT_BACK_WORLDMAP': {'Service': '1', 'Data': 'Mở bản đồ lớn'},
#  'UIIT_STT_JANGAN': {'Service': '1', 'Data': 'Trường An'},
#  'UIIT_STT_DONHWANG': {'Service': '1', 'Data': 'Đôn Hoàng'},
#  'UIIT_STT_KHOTAN': {'Service': '1', 'Data': 'Hòa Điền'},
#  'UIIT_STT_SAMARKAND': {'Service': '1', 'Data': 'Samarkand'},
#  'UIIT_STT_CONSTANTINOPLE': {'Service': '1', 'Data': 'Constantinople'},
#  'UIIT_STT_BIJEOKDAN': {'Service': '1', 'Data': 'Bijeokdan'},
#  'UIIT_STT_HEUKMAKDAN': {'Service': '1', 'Data': 'Heukmakdan'},
#  'UIIT_STT_EVILORDER': {'Service': '1', 'Data': 'Pháo đài tà ác'},
#  'UIIT_STT_ARABIA_CITY': {'Service': '1', 'Data': 'Baghdad'},
#  'UIIT_STT_ARABIA_CITY_DUNGEON': {'Service': '1', 'Data': 'Baghdad (Phụ bản)'},
#  'UIIT_STT_MUHAN': {'Service': '1', 'Data': 'Đấu trường Vô Cực'},
#  'UIIT_MSG_CHEATMSG_GO_TOWN': {'Service': '1', 'Data': '/town'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_1': {'Service': '1',
#   'Data': 'Tìm thấy macro (chơi tự động) trong nhân vật đang chơi. Tự động thoát.'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_2': {'Service': '1',
#   'Data': 'Tên của nhân vật có macro và thời gian đã sử dụng sẽ được ghi lại trên máy chủ'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_3': {'Service': '1',
#   'Data': 'Có thể áp dụng hình phạt giới hạn về thời gian của tài khoản và khóa tài khoản'},
#  'UIIT_MSG_APPEAR_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa xuất hiện ở Hổ Huyệt Sơn'},
#  'UIIT_MSG_APPEAR_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã xuất hiện'},
#  'UIIT_MSG_APPEAR_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi xuất hiện ở Karakoram'},
#  'UIIT_MSG_APPEAR_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan xuất hiện ở Taklamakan'},
#  'UIIT_MSG_APPEAR_TAHOMET': {'Service': '1',
#   'Data': 'Sa Y Thần xuất hiện ở Lạc Khắc Sơn'},
#  'UIIT_MSG_APPEAR_UNIC': {'Service': '1', 'Data': '[%s] đã xuất hiện'},
#  'UIIT_MSG_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn đã biến mất'},
#  'UIIT_MSG_DEAD_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã biến mất'},
#  'UIIT_MSG_DEAD_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi từ Karakoram đã biến mất'},
#  'UIIT_MSG_DEAD_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan từ Taklamakan đã biến mất'},
#  'UIIT_MSG_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã biến mất'},
#  'UIIT_MSG_ANYONE_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': '[%s] đã giết Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_URRUCHI': {'Service': '1',
#   'Data': '[%s] đã giết Ô Lỗ Tề từ Tháp Lý Mộc'},
#  'UIIT_MSG_ANYONE_DEAD_IYUTARU': {'Service': '1',
#   'Data': '[%s] đã giết Băng Chúa Nhi từ Karakoram'},
#  'UIIT_MSG_ANYONE_DEAD_BONELORD': {'Service': '1',
#   'Data': '[%s] đã giết Chúa tể Yarkan từ Taklamakan'},
#  'UIIT_MSG_ANYONE_DEAD_TAHOMET': {'Service': '1',
#   'Data': '[%s] đã giết Sa Y Than từ Lạc Khắc Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã giết [%s]'},
#  'UIIT_STT_ROLL_OF_CLOTH': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILK_BUY_RESULT': {'Service': '1', 'Data': 'Bạn đã mua [%d] silk'},
#  'UIIT_STT_SILK_BUY_CANCLE': {'Service': '1',
#   'Data': 'Việc mua bán [%d] silk đã bị hủy bỏ'},
#  'UIIT_STT_SILK_BUY_RECEIVE': {'Service': '1',
#   'Data': 'Bạn nhận được quà là [%d] silk'},
#  'UIIT_STT_SILK_SEND_RESULT': {'Service': '1',
#   'Data': 'Bạn đã gửi [%d] silk đi làm quà'},
#  'UIIT_STT_SILK_POINT_BUY_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được trả tiền'},
#  'UIIT_STT_SILK_POINT_USE_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được sử dụng'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK': {'Service': '1', 'Data': 'Silk đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_MALL': {'Service': '1', 'Data': 'Cửa hàng Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_MALL': {'Service': '1',
#   'Data': 'Cửa hàng đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_TOTAL': {'Service': '1', 'Data': 'Tổng số Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_TOTAL': {'Service': '1',
#   'Data': 'Tổng số Silk đặc biệt'},
#  'UIIT_STT_SILKMALL': {'Service': '1', 'Data': 'Siêu thị'},
#  'UIIT_STT_SILKMALL_MAIN': {'Service': '1', 'Data': 'Phần chính'},
#  'UIIT_STT_SILKMALL_HOT_STORE': {'Service': '1', 'Data': 'HOT Shop'},
#  'UIIT_STT_SILKMALL_CONSUMPTION': {'Service': '1', 'Data': 'Đồ tiêu dùng'},
#  'UIIT_STT_SILKMALL_LEND_ITEM': {'Service': '1', 'Data': 'Tiền thuê đồ'},
#  'UIIT_STT_SILKMALL_AVATA': {'Service': '1', 'Data': 'Trang trí'},
#  'UIIT_STT_SILKMALL_PET': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PACKAGE': {'Service': '1', 'Data': 'Gói hàng'},
#  'UIIT_STT_SILKMALL_SHOPPING_BASKET_LIST': {'Service': '1',
#   'Data': 'Hàng đã chọn'},
#  'UIIT_STT_SILKMALL_NEW_ITEM': {'Service': '1', 'Data': 'Hàng mới'},
#  'UIIT_STT_SILKMALL_EVENT': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_SPECIAL_COAST': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_FAVORITE': {'Service': '1', 'Data': 'Hàng bán chạy'},
#  'UIIT_STT_SILKMALL_SPECIAL': {'Service': '1', 'Data': 'Đặc biệt'},
#  'UIIT_STT_SILKMALL_SCROLL': {'Service': '1', 'Data': 'Hỗ trợ'},
#  'UIIT_STT_SILKMALL_POTION': {'Service': '1', 'Data': 'Hồi phục'},
#  'UIIT_STT_SILKMALL_COMMUNITY': {'Service': '1', 'Data': 'Cộng đồng'},
#  'UIIT_STT_SILKMALL_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY': {'Service': '1', 'Data': 'Giả kim thuật'},
#  'UIIT_STT_SILKMALL_PREMIUM_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ASTRAL': {'Service': '1', 'Data': 'Tinh thạch'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': 'Bất diệt (bảo toàn 99%)'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_3': {'Service': '1', 'Data': 'Áo nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_4': {'Service': '1', 'Data': 'Quần nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_5': {'Service': '1', 'Data': 'Bao tay'},
#  'UIIT_STT_SILKMALL_ARMOR_6': {'Service': '1', 'Data': 'Giầy nặng'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_3': {'Service': '1', 'Data': 'Áo nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_4': {'Service': '1', 'Data': 'Quần nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_6': {'Service': '1', 'Data': 'Giầy nhẹ'},
#  'UIIT_STT_SILKMALL_CLOSE_1': {'Service': '1', 'Data': 'Khăn'},
#  'UIIT_STT_SILKMALL_CLOSE_2': {'Service': '1', 'Data': 'Cầu vai vải'},
#  'UIIT_STT_SILKMALL_CLOSE_3': {'Service': '1', 'Data': 'Áo vải'},
#  'UIIT_STT_SILKMALL_CLOSE_4': {'Service': '1', 'Data': 'Quần vải'},
#  'UIIT_STT_SILKMALL_CLOSE_6': {'Service': '1', 'Data': 'Giầy vải'},
#  'UIIT_STT_SILKMALL_BIG_STORE': {'Service': '1', 'Data': 'Tiệm lớn'},
#  'UIIT_STT_SILKMALL_ASSIST': {'Service': '1', 'Data': 'Chi nhánh'},
#  'UIIT_STT_SILKMALL_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_HAT': {'Service': '1', 'Data': 'Mũ'},
#  'UIIT_STT_SILKMALL_BOOTH': {'Service': '1', 'Data': 'Gian hàng'},
#  'UIIT_STT_SILKMALL_FIREWORK': {'Service': '1', 'Data': 'Kẹo'},
#  'UIIT_STT_SILKMALL_DRESS': {'Service': '1', 'Data': 'Trang phục'},
#  'UIIT_STT_SILKMALL_ATTACH': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_BALLOON': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_PET_SUMMON': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PET_CONSUME': {'Service': '1', 'Data': 'Thú nuôi hết hạn'},
#  'UIIT_STT_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1', 'Data': 'Mua hết'},
#  'UIIT_STT_SILKMALL_BOOK_MARK': {'Service': '1', 'Data': 'Sổ sách'},
#  'UIIT_STT_SILKMALL_PUT_ON': {'Service': '1', 'Data': 'sử dụng thử'},
#  'UIIT_STT_SILKMALL_BUY': {'Service': '1', 'Data': 'Mua'},
#  'UIIT_STT_SILKMALL_PRESENT': {'Service': '1', 'Data': 'Quà'},
#  'UIIT_STT_SILKMALL_DEL': {'Service': '1', 'Data': 'Xóa'},
#  'UIIT_STT_SILKMALL_BUY_LIST': {'Service': '1', 'Data': 'Hàng mua'},
#  'UIIT_STT_SILKMALL_RECEIVE_LIST': {'Service': '1', 'Data': 'Hàng nhận'},
#  'UIIT_STT_SILKMALL_SILKMALL_OUT': {'Service': '1', 'Data': 'Thoát'},
#  'UIIT_STT_SILKMALL_PUT_ON_CLOSE_BUY': {'Service': '1',
#   'Data': 'Mua đồ thời trang'},
#  'UIIT_STT_SILKMALL_ALL_CLOSE_TAKEOFF': {'Service': '1', 'Data': 'Cởi bỏ'},
#  'UIIT_STT_SILKMALL_ADD_INVENTORY': {'Service': '1', 'Data': 'Ô mở rộng'},
#  'UIIT_STT_SILKMALL_ADD_STOREHOUSE_INVENTORY': {'Service': '1',
#   'Data': 'Kho mở rộng'},
#  'UIIT_STT_SILKMALL_SILK': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILKMALL_BUY_SILK': {'Service': '1', 'Data': 'Mua Silk'},
#  'UIIT_STT_SILKMALL_SEND_SILK': {'Service': '1', 'Data': 'Tặng Silk'},
#  'UIIT_STT_SILKMALL_COUPON_EXCHANGE': {'Service': '1',
#   'Data': 'Trao đổi phiếu'},
#  'UIIT_STT_SILKMALL_BUY_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_03': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_USE_INFOMATION': {'Service': '1',
#   'Data': 'Cách sử dụng Siêu thị'},
#  'UIIT_STT_SILKMALL_ENTER': {'Service': '1', 'Data': 'Vào Siêu thị'},
#  'UIIT_STT_SILKMALL_DIRECT_ENTER': {'Service': '1',
#   'Data': 'Vào nhanh Siêu thị'},
#  'UIIT_STT_SILKMALL_NEW_CASHITEM': {'Service': '1',
#   'Data': 'Siêu thị cập nhật đồ vật mới'},
#  'UIIT_STT_SILKMALL_WARNING_1': {'Service': '1',
#   'Data': 'Bạn có thể bị quái vật'},
#  'UIIT_STT_SILKMALL_WARNING_2': {'Service': '1',
#   'Data': 'hoặc những người chơi khác tấn công trong khi vào Siêu thị'},
#  'UIIT_STT_SILKMALL_WARNING_3': {'Service': '1',
#   'Data': 'Nên sử dụng món đồ trong khu vực an toàn'},
#  'UIIT_STT_SILKMALL_MAIN_EXPLAIN': {'Service': '1',
#   'Data': '<sml2><p line_margin="12"><p line_margin="5"><font color="255,255,153,81" style="bold">Siêu Thị là gì?</font><br>Là nơi bán và cho thuê những trang bị để <br>sử dụng trên Con đường tơ lụa. Những trang bị đó phải sử dụng silk để mua.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Mua Silk</font><br>Silk có thể mua bằng cách bấm vào nút Mua silk ở góc trên bên phải màn hình.<br>Bấm vào nút Mua silk bạn sẽ được chuyển đến trang E-Cash.<br>nơi để bạn mua silk.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Tặng Silk</font><font color="255,255,117,117">(Tính năng chưa kích hoạt)</font><br>Trong quá trình mua đồ trong Siêu Thị, bạn có thể bấm vào nút Tặng Silk để gửi <br>tới người chơi khác món đồ bạn chọn.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Coupons exchanges</font><br>Phiếu giảm giá có thể được sử dụng 1 lần để mua silk hoặc sử dụng các item Mall.<br>Điền con số vào phiếu giảm giá để nhận được silk.<br>Số tiền có thể khác nhau tùy thuộc vào các loại phiếu giảm giá.<br></p></p><strong><font color="255,255,153,81">Sổ sách</font></strong><font color="255,255,117,117">(Tính năng chưa được kích hoạt)</font><br>Tất cả những đồ vật bạn mua trong Siêu Thị có thể được lưu giữ trong sổ sách của bạn <br>bằng cách bấm vào Sổ sách. Đồ vật đã lưu trong Sổ của bạn sẽ được hoàn trả <br>ngay cả khi bạn đã mua đồ vật đó.</sml2>'},
#  'UIIT_STT_SILKMALL_MY_INFO': {'Service': '1', 'Data': 'Thông tin cá nhân'},
#  'UIIT_STT_SILKMALL_POSSESSION_GOLD': {'Service': '1',
#   'Data': 'Số lượng hiện có'},
#  'UIIT_STT_SILKMALL_REMAIN_INVENTORY': {'Service': '1', 'Data': '%d ô trống'},
#  'UIIT_STT_SILKMALL_MAIN_INTRO': {'Service': '1',
#   'Data': '<sml2>Chào mừng quý khách đến với cửa hàng bán đồ chất lượng cao của Con Đường Tơ Lụa</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ORDER_SHEET': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_TOOL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_FLEAMARKET': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_ZZIM': {'Service': '1',
#   'Data': '<sml2>Đây là danh sách hàng bạn đặt mua</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_FAVORITY': {'Service': '1',
#   'Data': '<sml2>Có thể xem danh sách những mặt hàng đã mua hoặc chọn trong phần Sổ sách</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COSETC': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'MALL_CONSUME_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'MALL_CONSUME_SCROLL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'MALL_CONSUME_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'MALL_CONSUME_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'MALL_CONSUME_ETC': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'MALL_AVATAR_BOOTH': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'MALL_AVATAR_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_PET_A_GROWTH': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_SILK': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_VEHICLE': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_CART': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_STORES': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PREMIUM_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'MALL_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'MALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'UIIT_STT_SILKMALL_SHORT_KEY': {'Service': '1', 'Data': 'Siêu thị (F10)'},
#  'UIIT_STT_SILKMALL_BUY_CONFIRM': {'Service': '1', 'Data': 'Xác nhận mua'},
#  'UIIT_STT_SILKMALL_DO_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_POPUP_TITLE': {'Service': '1',
#   'Data': 'Đồ trang trí tồn kho'},
#  'UIIT_STT_SILKMALL_POPUP_ADVERTISING': {'Service': '1',
#   'Data': 'Bán có giới hạn'},
#  'UIIT_STT_SILKMALL_POPUP_DATA': {'Service': '1', 'Data': 'Ngày bán:'},
#  'UIIT_STT_SILKMALL_POPUP_REDUCTION': {'Service': '1',
#   'Data': 'Cho tới khi giảm giá'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_M': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nam)'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_W': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nữ)'},
#  'UIIT_MSG_SILKMALL_ZZIM_CONFIRM': {'Service': '1',
#   'Data': '<sml2><font color="255,255,255,255">Bạn sẽ đặt món đồ này chứ?<br>các món đồ được đặt có thể được chọn và mua một tất cả ở danh sách đặt hàng.</font></sml2>'},
#  'UIIT_MSG_SILKMALL_ZZIM_DELITE': {'Service': '1',
#   'Data': 'Xóa món đồ trong danh sách đặt hàng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1',
#   'Data': 'Bạn sẽ mua luôn số hàng đã đặt chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY_TOTAL': {'Service': '1',
#   'Data': 'Tổng cộng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_1': {'Service': '1',
#   'Data': 'Bạn có hủy số hàng đã đặt không ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_2': {'Service': '1',
#   'Data': 'Nếu bạn hủy bỏ việc sử dụng món đồ đã chọn, hiệu ứng của nó sẽ mất'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE': {'Service': '1',
#   'Data': 'Bạn sẽ dùng món đồ đã chọn chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_REVERSE_PORTAL': {'Service': '1',
#   'Data': 'sử dụng bùa dịch chuyển phản hồi. Hãy chọn điểm đến.'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_RETURN': {'Service': '1',
#   'Data': 'Dịch chuyển tới điểm về cuối'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_DEATH': {'Service': '1',
#   'Data': 'Dịch chuyển tới nơi bạn đã chết'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_INS': {'Service': '1',
#   'Data': 'sử dụng các vật phẩm này bạn sẽ không thể dịch chuyển được'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_GNGWC': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật sau khi kết thúc trận chiến'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_BUY_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không thành công do không đủ silk'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_GIFT': {'Service': '1',
#   'Data': 'Silk không đủ để tặng'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng cho loại đồ vật trang bị'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_SINCE_EQUIP_CLASS_TOO_HIGH': {'Service': '1',
#   'Data': 'Không thể thay đổi giới tính do không phù hợp với cấp độ của đồ vật'},
#  'UIIT_MSG_STRGERR_INVALID_TRANSGENDER_TARGET': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể thay đổi giới tính'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_TELEPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi cuối cùng bạn đã quay lại'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_DIEDPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi bạn đã chết'},
#  'UIIT_MSG_STRGERR_ONLY_THE_DEAD_CAN_USE_RESURRECT_SCROLL': {'Service': '1',
#   'Data': 'Chỉ sử dụng trong tình trạng đã chết'},
#  'UIIT_MSG_STRGERR_THERE_IS_NO_ITEM_TO_REPAIR': {'Service': '1',
#   'Data': 'Không có đồ vật nào cần sửa chữa'},
#  'UIIT_MSG_STRGERR_CANT_QUICKSELL_CASHITEM': {'Service': '1',
#   'Data': 'Không có chức năng mua bán nhanh với những món đồ hiếm.'},
#  'UIIT_MSG_STRGERR_TRADE_FAILURE': {'Service': '1',
#   'Data': 'Giao dịch thất bại không có lý do'},
#  'UIIT_STT_SILKMALL_FAIL_ITEMBUY_LOGOUT': {'Service': '1',
#   'Data': 'Trò chơi sẽ chấm dứt do việc mua đồ Premium thất bại'},
#  'UIIT_STT_SILKMALL_DONOT_USE_TELEPORT': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_MSG_SELL_RECONFIRM': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_PAG_CHAR_SKIN_CHANGE': {'Service': '1',
#   'Data': 'Thay đổi hình dáng bên ngoài của nhân vật'},
#  'UIIT_MSG_CHAR_SKIN_ERR_ARMOR': {'Service': '1',
#   'Data': 'Để thay đổi giới tính phải bỏ đồ bảo hộ và gỡ bỏ hết các ô mở rộng'},
#  'UIIT_MSG_CHAR_SKIN_CHANGE_SUCCESS': {'Service': '1',
#   'Data': 'Thay đổi giới tính thành công'},
#  'UIIT_STT_GUILD_INFO': {'Service': '1', 'Data': 'T.Tin Hội'},
#  'UIIT_CTL_LETTER': {'Service': '1', 'Data': 'Hộp thư kết hợp'},
#  'UIIT_CTL_FRIEND': {'Service': '1', 'Data': 'Bạn'},
#  'UIIT_STT_GUILD_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_GUILD_STAFF': {'Service': '1', 'Data': 'Hội phó'},
#  'UIIT_STT_GUILDSMAN': {'Service': '1', 'Data': 'Hội viên'},
#  'UIIT_STT_GUILDSMAN_NUM': {'Service': '1', 'Data': 'Số'},
#  'UIIT_STT_GUILD_COMMON_KNOW': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_GUILD_COMMON_KNOW_WRITE': {'Service': '1',
#   'Data': 'Viết thông báo'},
#  'UIIT_MSG_GUILD_COMMON_NOTEXIST': {'Service': '1',
#   'Data': 'Không có thông báo'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo (%d/Tối đa.%d)'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_TITLE_REMIND': {'Service': '1',
#   'Data': 'Hãy điền tiêu đề lời thông báo'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT_TITLE': {'Service': '1',
#   'Data': 'Chưa điền tiêu đề'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo'},
#  'UIIT_MSG_GUILDERR_TARGET_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Người chơi khác không có quyền'},
#  'UIIT_CTL_GUILD_WRITE_END': {'Service': '1', 'Data': 'Hoàn thành'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND_UPDATE': {'Service': '1',
#   'Data': 'Thông báo của Hội đã thay đổi'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_JOIN': {'Service': '1',
#   'Data': 'Hội chủ Hội [%s] đề nghị liên minh với bạn, bạn có chấp nhận không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_WITHDRAWA': {'Service': '1',
#   'Data': 'Bạn có muốn rời bỏ liên minh không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_BREAKUP': {'Service': '1',
#   'Data': 'Liên minh đã bị giải tán'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_NOTALLY': {'Service': '1',
# ...
#   'Data': 'Đã khỏi bệnh'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CHAOS': {'Service': '1',
#   'Data': 'Đã khỏi lẫn lộn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_PD': {'Service': '1',
#   'Data': 'Đã khỏi bị thối rữa'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_MD': {'Service': '1',
#   'Data': 'Đã được khoẻ lại'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_STR': {'Service': '1',
#   'Data': 'Đã hết bất lực'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_INT': {'Service': '1',
#   'Data': 'Đã hết bị cô lập'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_HP': {'Service': '1',
#   'Data': 'Đã hết hoảng loạn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSIE_MP': {'Service': '1',
#   'Data': 'Đã hết bị thiêu đốt'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_TIME_BOMB': {'Service': '1',
#   'Data': 'Đã hết ẩn nấp'},
#  'UIIT_MSG_BURN': {'Service': '1', 'Data': 'Thiêu đốt'},
#  'UIIT_MSG_FROSTBITE': {'Service': '1', 'Data': 'Tê cóng'},
#  'UIIT_MSG_FREEZING': {'Service': '1', 'Data': 'Đóng băng'},
#  'UIIT_MSG_SHOCK': {'Service': '1', 'Data': 'Nhiễm điện'},
#  'UIIT_MSG_ZOMBIE': {'Service': '1', 'Data': 'Yểm bùa'},
#  'UIIT_MSG_DARK': {'Service': '1', 'Data': 'Mờ mắt'},
#  'UIIT_MSG_STUN': {'Service': '1', 'Data': 'Choáng'},
#  'UIIT_MSG_PARTYERR_OUT_OF_LEVEL': {'Service': '1',
#   'Data': 'Không thể vào nhóm đó do sự chênh lệch về cấp độ.'},
#  'UIIT_MSG_FLEAMARKET_ERR_IM_BUSY': {'Service': '1',
#   'Data': 'Bạn ở trong tình trạng không được mở gian hàng mới'},
#  'UIIT_MSG_JSERR_SINCE_YOU_DIE_IN_MURDERER_SP_DEPRIVED_BY_SERVER': {'Service': '1',
#   'Data': 'Bị mất [%u] điểm kinh nghiệm'},
#  'UIIT_MSG_INTERACTION_FAIL__REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_PORTAL_SCROLL': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_SUMMON_VEHICLE': {'Service': '1',
#   'Data': 'Không thể dùng thú vận chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_INTERACTION_FAIL_MURDERER_CAN_USE_PORTAL_STRUCTURE': {'Service': '1',
#   'Data': 'Không thể qua cổng dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_FLEAMARKET_ERR_CANT_OPEN_MARKET_MURDERER': {'Service': '1',
#   'Data': 'Không thể mở gian hàng mới trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng item trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_ENABLEINPUT_FEWERTHAN_REMAIN': {'Service': '1',
#   'Data': 'Chỉ có thể nhập số đơn vị còn lại'},
#  'UIIT_MSG_STRGERR_CANNOT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy người chơi khác'},
#  'UIIT_MSG_STRGERR_SPECIFY_POSITIVE_NUMBER_ONLY': {'Service': '1',
#   'Data': 'Số không hợp lệ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi bị hủy bỏ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_BEFORE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi lần trước bị hủy bỏ vì đã thực hiện trao đổi với người chơi khác'},
#  'UIIT_MSG_STRGERR_CANNOT_WITDRAW_MORETHAN_DEPOSIT': {'Service': '1',
#   'Data': '-'},
#  'UIIT_MSG_DEAL_ASK': {'Service': '1',
#   'Data': 'Có người muốn trao đổi với bạn. Bạn chấp nhận chứ?'},
#  'UIIT_MSG_DEAL_ASKING': {'Service': '1', 'Data': 'Trao đổi với [%s]'},
#  'UIIT_MSG_STRGERR_INVALID_TARGET': {'Service': '1',
#   'Data': 'Không thấy mục tiêu'},
#  'UIIT_MSG_STRGERR_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận làm việc khác'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_OPPONENT_INV_SPACE': {'Service': '1',
#   'Data': 'Không thể đưa thêm món đồ đó vào cửa sổ trao đổi vì thùng đồ người kia đã đầy.'},
#  'UIIT_MSG_STRGERR_NON_SETUP_KEY': {'Service': '1',
#   'Data': 'Không thể đặt phím đã lựa chọn'},
#  'UIIT_MSG_STRGERR_CHATING_LIMIT': {'Service': '1',
#   'Data': 'Không thể lặp lại cùng nội dung'},
#  'UIIT_MSG_STRGERR_DEAL_FAIL_NON_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không được thực hiện do không có đồ vật giao dịch'},
#  'UIIT_STT_TARGETTING': {'Service': '1', 'Data': 'Mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTLEARN': {'Service': '1',
#   'Data': 'Kỹ năng không xác định'},
#  'UIIT_SKILL_USE_FAIL_TIMEDELAY_REUSEDELAY': {'Service': '1', 'Data': '-'},
#  'UIIT_SKILL_USE_FAIL_WRONGDISTANCE': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng với mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTENOUGHLEVEL': {'Service': '1',
#   'Data': 'Không sử dụng được vì cấp độ của bạn thấp'},
#  'UIIT_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh người chơi khác vì cấp độ của người đó cao hơn bạn'},
#  'UIIT_CHATERR_CANT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy [%s]'},
#  'UIIT_CHATERR_YOU_ARE_SQUELCHED': {'Service': '1',
#   'Data': 'Chức năng thì thầm của  [%s]đã bị tắt'},
#  'UIIT_CHATERR_NOT_A_PARTY_MEMBER': {'Service': '1',
#   'Data': 'Không ở trong nhóm nào'},
#  'UIIT_CHATERR_INVALID_COMMAND': {'Service': '1',
#   'Data': 'Lệnh chat không hợp lệ'},
#  'UIIT_CHATERR_ALLIANCE_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Không sử dụng được chức năng tán gẫu với đồng minh vì Hội được chọn không phải là đồng minh của bạn'},
#  'UIIT_CHATERR_WHISPER_TO_MESSAGE': {'Service': '1', 'Data': 'Tin đi'},
#  'UIIT_CHATERR_WHISPER_FROM_MESSAGE': {'Service': '1', 'Data': 'Tin đến'},
#  'UIIT_TOOLTIP_PK_DAY': {'Service': '1', 'Data': 'PK hàng ngày %d / %d'},
#  'UIIT_TOOLTIP_PK_TOTAL': {'Service': '1', 'Data': 'Tổng PK %d / %d'},
#  'UIIT_TOOLTIP_PK_PENALTY_TIME': {'Service': '1',
#   'Data': 'Chỉ số PK %d (Cấp độ %d)'},
#  'UIIT_TOOLTIP_PENALTY_GOLD': {'Service': '1', 'Data': 'Phạt %d vàng'},
#  'UIIT_TOOLTIP_JOB_PENALTY_TIME': {'Service': '1',
#   'Data': 'Không được hành nghề trong %d phút'},
#  'UIIT_TOOLTIP_EQUIPMENT_CLASS': {'Service': '1', 'Data': 'Cấp: Cấp %d'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_DROPPED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể bỏ đi'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_PICKED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể lấy được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_TRADED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể mang ra mua bán được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể sửa chữa được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể làm lại được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_USED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể dùng được'},
#  'UIIT_MSG_CANNOT_BE_USED_ITEM_CART': {'Service': '1',
#   'Data': 'Không thể dùng mà không có thú di chuyển/ chuyên chở'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_IN_BATTLE_STATE': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang đánh nhau'},
#  'UIIT_MSG_REMAIN_TIME': {'Service': '1', 'Data': '(còn %d giây)'},
#  'UIIT_MSG_STRGERR_ONLY_ROBBER_CAN_USE_THIS_ITEM': {'Service': '1',
#   'Data': 'Món đồ được chọn chỉ sử dụng được khi làm Đạo Tặc'},
#  'UIIT_MSG_STRGERR_CANT_OPERATE_REQUESTED_JOB_DURING_LOGOUT': {'Service': '1',
#   'Data': 'Không thể thực hiện khi đang thoát trò chơi'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED_TO_USE_THISITEM': {'Service': '1',
#   'Data': 'Không thể đung được món đồ đó vì cấp độ của nhân vật còn thấp'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_WHILE_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang dịch chuyển'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME': {'Service': '1',
#   'Data': 'Còn %d giây sẽ thoát trò chơi'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME_CANCLE': {'Service': '1',
#   'Data': 'Hủy bỏ việc thoát khỏi trò chơi'},
#  'UIIT_MSG_STRGERR_CANT_SELL_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể bán món đồ khi đang trang bị'},
#  'UIIT_MSG_STRGERR_CANT_SWAP_JOBITEM': {'Service': '1',
#   'Data': 'Phải bỏ món đồ trước ra thì mới mặc đồ mới vào được'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBCHANGE_COMPLETE': {'Service': '1',
#   'Data': 'Không thể cởi trang bị nghề nghiệp trong vòng 10 giây kể từ lúc đeo vào'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBITEM_DETACH_COMPLETE': {'Service': '1',
#   'Data': 'Không thể đeo trang bị nghề nghiệp khác trong 10 phút kể từ lúc tháo ra'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_JOBITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Bạn chỉ có thể bỏ trang bị nghề nghiệp sau 20 giây kể từ trận chiến cuối cùng.'},
#  'UIIT_MSG_STRGERR_CANT_HAVE_CART': {'Service': '1',
#   'Data': 'Không thể bỏ trang bị nghề nghiệp ra trong khi đang triệu tập thú vận chuyển'},
#  'UIIT_MSG_COSERR_COLLISION_EXIST_BETWEEN_US': {'Service': '1',
#   'Data': 'Không thực hiện được lệnh di chuyển do có chướng ngại vật'},
#  'UIIT_MSG_INTERACTION_FAIL_IM_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận việc khác'},
#  'UIIT_MSG_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh vì kỹ năng hồi sinh của bạn còn thấp'},
#  'UIIT_MSG_SKILL_USE_FAIL_NOTENOUGHHP': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng đó vì không đủ HP'},
#  'UIIT_MSG_SKILL_USE_FAIL_ITS_NOT_A_BATTLE_FIELD': {'Service': '1',
#   'Data': 'Không thể tấn công trong khu vực an toàn'},
#  'UIIT_MSG_SKILL_USE_FAIL_WAITFOR_JOB_ACTIVATE': {'Service': '1',
#   'Data': 'Không thể tấn công trong 10 giây kể từ lúc mang trang bị nghề nghiệp vào'},
#  'UIIT_MSG_STRGERR_DONT_HAVE_ANY_TRADECART_TO_PICK_SPECIALTY': {'Service': '1',
#   'Data': 'Không thể nhận được đặc sản nếu không có thú vận chuyển'},
#  'UIIT_MSG_STRGERR_CANT_BE_STORED': {'Service': '1',
#   'Data': 'Món đồ đó không thể lưu tại nơi đã chỉ định'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị đồ vật vì cấp độ hoặc cấp độ tuyệt kỹ nhân vật còn thấp'},
#  'UIIT_MSG_STRGERR_LOCKED_BY_OTHER_ONE': {'Service': '1',
#   'Data': 'Không thể lấy được món đồ đó vì nó của người chơi khác'},
#  'UIIT_MSG_STRGERR_GENDER_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác giới tính'},
#  'UIIT_MSG_STRGERR_TRADE_BAY_FULL': {'Service': '1',
#   'Data': 'Không thể thêm vào món đồ đã chọn vì cửa sổ trao đổi đã đầy'},
#  'UIIT_MSG_STRGERR_COUNTRY_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác chủng tộc'},
#  'UIIT_MSG_STRGERR_HIGHER_STRENGTH_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì thiếu sức mạnh'},
#  'UIIT_MSG_STRGERR_HIGHER_INTELLECT_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì trí tuệ thấp'},
#  'UIIT_MSG_STRGERR_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_EU_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_CANT_EQUIP_RAZED_ITEM': {'Service': '1',
#   'Data': 'Không thể trang bị món đồ đã hỏng'},
#  'UIIT_MSG_STRGERR_PREV_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển.'},
#  'UIIT_MSG_STRGERR_POSSESSION_LIMIT_EXCEEDED': {'Service': '1',
#   'Data': 'Không thể có nhiều hơn số lượng giới hạn'},
#  'UIIT_MSG_STRGERR_ROBBER_CANT_SUMMON_CART_IN_TOWN': {'Service': '1',
#   'Data': 'Không thể triệu hồi phương tiện chuyên trở khi đang ở Làng Đạo Tặc'},
#  'UIIT_MSG_INTERACTION_FAIL_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển rồi'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_TRADECART': {'Service': '1',
#   'Data': 'Không thể dịch chuyển khi đang có thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_RIDE': {'Service': '1',
#   'Data': 'Không thể sử dụng cổng dịch chuyển khi đang cưỡi thú'},
#  'UIIT_MSG_INTERACTION_FAIL_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Không thể qua đò khi đang ở xa thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không sửa chữa được'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không làm lại được'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_TEMPORARILY': {'Service': '1',
#   'Data': 'Bất khả xâm phạm - Không thể tấn công hoăc bị tấn công trong 5 giây'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_FORTRESS': {'Service': '1',
#   'Data': 'Khi tấn công pháo đài trong tình trạng bất khả xâm phạm - không thể tấn công trong 10 giây'},
#  'UIIT_MSG_COSERR_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Một nhân vật không thể cách xa quá thú vận chuyển %d m'},
#  'UIIT_MSG_RETURN_CANCLE': {'Service': '1',
#   'Data': 'Việc sử dụng bùa dịch chuyển đã bị hủy bỏ'},
#  'UIIT_MSG_QUESTEND_2': {'Service': '1',
#   'Data': 'Hãy mở cửa sổ Nhiệm vụ (Q) để kiểm tra nội dung'},
#  'UIIT_MSG_JSERR_PREVIOUS_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể vào mê cung khi sắp dịch chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_OUT_OF_REQUIRED_LEVEL_FOR_TELEPORT': {'Service': '1',
#   'Data': 'Không thể dịch chuyển vì cấp độ của bạn quá thấp'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_FREEBATTLEITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Không thể bỏ khăn ra trong khi đang đánh nhau'},
#  'UIIT_MSG_STRGERR_STORAGE_OPERATION_BLOCKED': {'Service': '1',
#   'Data': 'Hiện tại bạn không được phép di chuyển các món đồ hoặc trao đổi chúng'},
#  'UIIT_MSG_QUEST_CALLMONSTER_NOTATTACK': {'Service': '1',
#   'Data': 'Cấp độ của bạn còn quá thấp để có thể đánh nhau với quái vật'},
#  'UIIT_MSG_QUEST_GET_ITEM_FAILURE': {'Service': '1',
#   'Data': 'Không thể nhặt được món đồ'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_MONSTER': {'Service': '1',
#   'Data': 'Không thể di chuyển vì bạn đã ở cách quái vật %d m.'},
#  'UIIT_MSG_QUEST_FAIL_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Đã thất bại trong việc bắt giữ quái vật.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_CHATTING_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn đang làm nhiệm vụ nên không thể tán gẫu được.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MOVING_IN_DUNGEON': {'Service': '1',
#   'Data': 'Đã ra khỏi vị trí chỉ định nên không thể di chuyển được nữa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_DO_IT_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này vì bạn đang làm một nhiệm vụ khác có liên quan.'},
#  'UIIT_MSG_QUEST_ERR_TOO_LOW_LEVEL': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này do cấp độ của bạn còn thấp'},
#  'UIIT_MSG_QUEST_END_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ kết thúc sau %d phút'},
#  'UIIT_MSG_QUEST_START_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ bắt đầu trong %d giây (s)'},
#  'UIIT_MSG_QUEST_ERR_USE_WHANITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật này trong trạng thái Cuồng nộ'},
#  'UIIT_MSG_QUEST_ERR_CAPTUREMONSTER_ATTACK': {'Service': '1',
#   'Data': 'Không thể tấn công quái vật đã sập bẫy'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Không thể bắt quái vật thì khoảng cách quá xa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì đã đặt bẫy rồi'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_EXIST_MONSTER': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì quái vật ở quá gần'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật vì điều kiện nhiệm vụ không cho phép'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_WRONG_PLACE': {'Service': '1',
#   'Data': 'Không thể đặt bẫy trong khu vực này'},
#  'UIIT_MSG_QUEST_ERR_NO_TARGET': {'Service': '1',
#   'Data': 'Mệnh lệnh không thể thực thi do chưa chọn đối tượng'},
#  'UIIT_MSG_CANNOT_BUYBACK_ITEM_SELL': {'Service': '1',
#   'Data': 'Đồ vật không thể mua lại được. Bạn có chắc muốn bán nó đi không?'},
#  'UIIT_MSG_QUEST_INS_TIMEOUT': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ hoàn htành sau %d giây, bạn sẽ được trở lại vị trí ban đầu.'},
#  'UIIT_MSG_QUEST_INS_CONDITION': {'Service': '1',
#   'Data': 'Bạn sẽ trở lại vị trí ban đầu trong 5 giây nữa vì nhận được yêu cầu không thể ở lại khu vực hiện tại.'},
#  'UIIT_MSG_QUEST_INS_DEATH': {'Service': '1',
#   'Data': 'Không thể chuyển đến khu vực khác khi nhân vật của bạn đang bị chết'},
#  'UIIT_MSG_DROP_WARNING_1': {'Service': '1',
#   'Data': 'Nếu bạn vứt đồ vật này ra ngoài, thì bạn sẽ mất đi quyền sở hữu đồ vật này'},
#  'UIIT_MSG_DROP_WARNING_2': {'Service': '1',
#   'Data': 'Người khác có thể nhật chúng. Bạn có chắc là muốn vứt nó ra không?'},
#  ...}

# %% [markdown]
# ## TextData_Equip&Skill.txt

# %%
text_data_equip_skill = os.path.join(server_dep, 'TextData_Equip&Skill.txt')
text_data_equip_skill
# Out:
# 'server_dep\\silkroad\\textdata\\TextData_Equip&Skill.txt'

# %%
text_data_equip_skill_files = get_lines(text_data_equip_skill)
text_data_equip_skill_files
# Out:
# ['TextData_Equip&Skill_10050.txt',
#  'TextData_Equip&Skill_1050.txt',
#  'TextData_Equip&Skill_1200.txt',
#  'TextData_Equip&Skill_1350.txt',
#  'TextData_Equip&Skill_150.txt',
#  'TextData_Equip&Skill_1500.txt',
#  'TextData_Equip&Skill_1650.txt',
#  'TextData_Equip&Skill_1800.txt',
#  'TextData_Equip&Skill_1950.txt',
#  'TextData_Equip&Skill_2100.txt',
#  'TextData_Equip&Skill_2250.txt',
#  'TextData_Equip&Skill_2400.txt',
#  'TextData_Equip&Skill_2550.txt',
#  'TextData_Equip&Skill_2700.txt',
#  'TextData_Equip&Skill_2850.txt',
#  'TextData_Equip&Skill_300.txt',
#  'TextData_Equip&Skill_3000.txt',
#  'TextData_Equip&Skill_3150.txt',
#  'TextData_Equip&Skill_3300.txt',
#  'TextData_Equip&Skill_3450.txt',
#  'TextData_Equip&Skill_3600.txt',
#  'TextData_Equip&Skill_3750.txt',
#  'TextData_Equip&Skill_3900.txt',
#  'TextData_Equip&Skill_4050.txt',
#  'TextData_Equip&Skill_4200.txt',
#  'TextData_Equip&Skill_4350.txt',
#  'TextData_Equip&Skill_450.txt',
#  'TextData_Equip&Skill_4500.txt',
#  'TextData_Equip&Skill_4650.txt',
#  'TextData_Equip&Skill_4800.txt',
#  'TextData_Equip&Skill_4950.txt',
#  'TextData_Equip&Skill_5100.txt',
#  'TextData_Equip&Skill_5250.txt',
#  'TextData_Equip&Skill_5400.txt',
#  'TextData_Equip&Skill_5550.txt',
#  'TextData_Equip&Skill_5700.txt',
#  'TextData_Equip&Skill_5850.txt',
#  'TextData_Equip&Skill_600.txt',
#  'TextData_Equip&Skill_6000.txt',
#  'TextData_Equip&Skill_6150.txt',
#  'TextData_Equip&Skill_6300.txt',
#  'TextData_Equip&Skill_6450.txt',
#  'TextData_Equip&Skill_6600.txt',
#  'TextData_Equip&Skill_6750.txt',
#  'TextData_Equip&Skill_6900.txt',
#  'TextData_Equip&Skill_7050.txt',
#  'TextData_Equip&Skill_7200.txt',
#  'TextData_Equip&Skill_7350.txt',
#  'TextData_Equip&Skill_750.txt',
#  'TextData_Equip&Skill_7500.txt',
#  'TextData_Equip&Skill_7650.txt',
#  'TextData_Equip&Skill_7800.txt',
#  'TextData_Equip&Skill_7950.txt',
#  'TextData_Equip&Skill_8100.txt',
#  'TextData_Equip&Skill_8250.txt',
#  'TextData_Equip&Skill_8400.txt',
#  'TextData_Equip&Skill_8550.txt',
#  'TextData_Equip&Skill_8700.txt',
#  'TextData_Equip&Skill_8850.txt',
#  'TextData_Equip&Skill_900.txt',
#  'TextData_Equip&Skill_9000.txt',
#  'TextData_Equip&Skill_9150.txt',
#  'TextData_Equip&Skill_9300.txt',
#  'TextData_Equip&Skill_9450.txt',
#  'TextData_Equip&Skill_9600.txt',
#  'TextData_Equip&Skill_9750.txt',
#  'TextData_Equip&Skill_9900.txt',
#  '']

# %%
for xxx in text_data_equip_skill_files:
  file_name = os.path.join(server_dep, xxx)
  lines = get_lines(file_name)
  for idx, line in enumerate(lines):
    values = line.split('\t')
    if len(values) < 11:
      continue
    Service = values[0]
    name_str_id = values[2]
    Data = values[10]
    data_text[name_str_id] = {
      "Service": Service,
      "Data": Data
    }
data_text
# Out:
# {'UIC_STT_FONTNAME': {'Service': '1', 'Data': 'Tahoma'},
#  'UIIS_STT_MSG_INSTALL_START': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa"'},
#  'UIIS_STT_MSG_INSTALL_FOLDER': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa" vào thư mục sau'},
#  'UIIS_STT_MSG_INSTALL_END': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt thành công'},
#  'UIIS_STT_INSTALL_FOLDER': {'Service': '1', 'Data': 'Thư mục cài đặt'},
#  'UIIS_STT_INSTALL_FILE': {'Service': '1', 'Data': 'File cài đặt'},
#  'UIIS_CTL_INSTALL': {'Service': '1', 'Data': 'Cài đặt'},
#  'UIIS_CTL_FIND_FOLDER': {'Service': '1', 'Data': 'Tìm kiếm'},
#  'UIIS_CTL_START': {'Service': '1', 'Data': 'Bắt đầu'},
#  'UIIS_CTL_CANCEL': {'Service': '1', 'Data': 'Hủy bỏ'},
#  'UIIS_CTL_CONFIRM': {'Service': '1', 'Data': 'Đồng ý'},
#  'UIIS_MSG_ALREADY_INSTALL': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt'},
#  'UIIS_MSG_UNPACK_ZIP': {'Service': '1',
#   'Data': 'Không thể giải nén Con Đường Tơ Lụa. \\nFile nén bị hỏng.'},
#  'UIIS_MSG_UNPACK_CLOSE': {'Service': '1',
#   'Data': 'Không thể đóng file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_UNPACK_OPEN': {'Service': '1',
#   'Data': 'Không thể mở file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_INSTALL_SPACE': {'Service': '1',
#   'Data': 'Không thể cài đặt do thiếu dung lượng. \\nCần ít nhất %d BYTE dung lượng đĩa'},
#  'UIIS_MSG_BACKBUFFER': {'Service': '1', 'Data': 'Không thể tạo bộ nhớ đệm'},
#  'UIIS_MSG_CHANGE_FOLDER': {'Service': '1',
#   'Data': 'Thư mục cài đặt đã bị thay đổi.\\nKhông thể gỡ bỏ Con Đường Tơ Lụa'},
#  'UIIS_MSG_NOFIND': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa chưa được cài đặt. Việc gỡ bỏ không có tác dụng'},
#  'UIIS_MSG_REMOVE_COMPLETE': {'Service': '1',
#   'Data': 'Tất cả các file đã được xóa bỏ hoàn toàn'},
#  'UIIS_MSG_REMOVE_FAIL': {'Service': '1', 'Data': 'Không thể gỡ bỏ'},
#  'UIIS_STT_DELETE': {'Service': '1', 'Data': 'Xóa thư mục Con Đường Tơ Lụa'},
#  'UIIS_CTL_DELETE': {'Service': '1', 'Data': 'Gỡ bỏ'},
#  'UIIS_CTL_EXIT': {'Service': '1', 'Data': 'Thoát'},
#  'UILM_MSG_PROCESS_ALREADY_EXITS': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đang chạy'},
#  'UILM_MSG_DETECTED_ABNORMAL_PROCESS': {'Service': '1',
#   'Data': 'Phát hiện lỗi chạy chương trình Con Đường Tơ Lụa (Lỗi hệ thống)'},
#  'UILM_MSG_FAILED_LOAD_CLIENT': {'Service': '1',
#   'Data': 'Không thể xác định đặc điểm client. Đang đóng.'},
#  'UILM_MSG_GATEWAY_NOT_IN_SERVICE_CHANNEL': {'Service': '1',
#   'Data': 'Máy chủ đang kiểm tra hoặc không làm việc. Truy cập trang %ssro.vtcgame.vn/ để biết thêm thông tin.'},
#  'UILM_MSG_DRIVER_UPDATE': {'Service': '1',
#   'Data': 'Driver đồ họa của bạn không phải là phiên bản mới nhất. Hãy cập nhật phiên bản mới nhất để xem hình ảnh game đẹp hơn.'},
#  'UILM_MSG_DRIVER_UPDATE_2': {'Service': '1',
#   'Data': 'Không bao giờ xuất hiện lại.'},
#  'UILM_MSG_FAILED_INIT_NETENGINE': {'Service': '1',
#   'Data': 'Không thể khởi chạy NetEngine (Lỗi (%d,%d))'},
#  'UILM_MSG_FAILED_LOAD_VERSION': {'Service': '1',
#   'Data': 'Không thể kiểm tra phiên bản'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_IP': {'Service': '1',
#   'Data': 'Không thể kiểm tra IP kết nối'},
#  'UILM_MSG_INVALID_CONNECT_IP': {'Service': '1',
#   'Data': 'IP kết nối không hợp lệ'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_PORT': {'Service': '1',
#   'Data': 'Không thể kiểm tra cổng kết nối'},
#  'UILM_MSG_INVALID_CONNECT_PORT': {'Service': '1',
#   'Data': 'Cổng kết nối không hợp lệ'},
#  'UILM_MSG_DETECTED_ABNORMAL_DIRECTX': {'Service': '1',
#   'Data': 'DirectX 9.0 chưa được cài đặt hoặc không phải là phiên bản 9.0b. Con Đường Tơ Lụa cần DirectX9.0b hoặc phiên bản mới hơn'},
#  'UILM_MSG_DETECTED_ABNORMAL_MODULE': {'Service': '1',
#   'Data': 'Không xác định client. Kết thúc.'},
#  'UILM_MSG_DETECTED_PATCH_DIABLE': {'Service': '1',
#   'Data': 'Bạn phải cài đặt toàn bộ phiên bản. Kết nối với trang chủ để download toàn bộ phiên bản.'},
#  'UILM_MSG_DETECTED_PATCH_MANUAL': {'Service': '1',
#   'Data': 'Bạn cần cài đặt thủ công. Vui lòng truy cập trang chủ để tải bản cài thủ công về. Bạn có muốn kết nối đến trang chủ không?'},
#  'UILM_MSG_FAILED_EXECUTE_EXPLORER': {'Service': '1',
#   'Data': 'Không thể chạy Internet Explorer.'},
#  'UILM_MSG_FAILED_PATCH': {'Service': '1',
#   'Data': 'Chưa hoàn thành việc sửa lỗi. Hãy thử lại.[Lỗi số(%d)]'},
#  'UILM_MSG_FAILED_EXECUTE_CLIENT': {'Service': '1',
#   'Data': 'Xin lỗi. Không thể chạy Con Đường Tơ Lụa [Lỗi số(%d)]'},
#  'UILM_MSG_NOTEXITS_REPLACERFILE': {'Service': '1',
#   'Data': 'Không tìm thấy file replacer.exe. Chưa hoàn thành việc sửa lỗi.'},
#  'UILM_MSG_DETECTED_ABNORMAL_REPLACERFILE': {'Service': '1',
#   'Data': 'Không thể sửa lỗi vì file replacer.exe đã bị hỏng [lỗi số (%d)]'},
#  'UILM_MSG_FAILED_LOAD_GATEWAY_INFO': {'Service': '1',
#   'Data': 'Không thể đưa ra thuộc tính kết nối của GateWay [lỗi%d]'},
#  'UILM_STT_DIVISION': {'Service': '1', 'Data': 'Bộ phận'},
#  'UILM_STT_DIVISION_LIST': {'Service': '1', 'Data': 'Danh sách bộ phận'},
#  'UILM_STT_DIVISION_SELECTED': {'Service': '1', 'Data': 'Bộ phận lựa chọn'},
#  'UILM_STT_DIVISION_NAME': {'Service': '1', 'Data': 'Tên bộ phận'},
#  'UILM_STT_FARM': {'Service': '1', 'Data': 'Giải'},
#  'UILM_STT_FARM_LIST': {'Service': '1', 'Data': 'Danh sách giải'},
#  'UILM_STT_FARM_NAME': {'Service': '1', 'Data': 'Tên giải'},
#  'FARM0101': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 01 Yahoo'},
#  'FARM0102': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 01 Yahoo'},
#  'FARM0103': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 01 Yahoo'},
#  'FARM0104': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 01 Yahoo'},
#  'FARM0105': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 01 Yahoo'},
#  'FARM0201': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 02 Yahoo'},
#  'FARM0202': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 02 Yahoo'},
#  'FARM0203': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 02 Yahoo'},
#  'FARM0204': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 02 Yahoo'},
#  'FARM0205': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 02 Yahoo'},
#  'FARM0301': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 03 Yahoo'},
#  'FARM0302': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 03 Yahoo'},
#  'FARM0303': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 03 Yahoo'},
#  'FARM0304': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 03 Yahoo'},
#  'FARM0305': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 03 Yahoo'},
#  'FARM0401': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 04 Yahoo'},
#  'FARM0402': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 04 Yahoo'},
#  'FARM0403': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 04 Yahoo'},
#  'FARM0404': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 04 Yahoo'},
#  'FARM0405': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 04 Yahoo'},
#  'UILM_STT_DIVISION_PING': {'Service': '1', 'Data': 'Ping'},
#  'UILM_STT_DIVISION_CONDITION': {'Service': '1', 'Data': 'Tình trạng'},
#  'DIV01': {'Service': '1', 'Data': 'Bộ phận Yahoo 01'},
#  'DIV02': {'Service': '1', 'Data': 'Bộ phận Yahoo 02'},
#  'DIV03': {'Service': '1', 'Data': 'Bộ phận Yahoo 03'},
#  'DIV04': {'Service': '1', 'Data': 'Bộ phận Yahoo 04'},
#  'DIV05': {'Service': '1', 'Data': 'Bộ phận Yahoo 05'},
#  'DIV06': {'Service': '1', 'Data': 'Bộ phận Yahoo 06'},
#  'DIV07': {'Service': '1', 'Data': 'Bộ phận Yahoo 07'},
#  'DIV08': {'Service': '1', 'Data': 'Bộ phận Yahoo 08'},
#  'DIV09': {'Service': '1', 'Data': 'Bộ phận Yahoo 09'},
#  'DIV10': {'Service': '1', 'Data': 'Bộ phận Yahoo 10'},
#  'UILM_STT_DIVISION_RECOMMENDATION': {'Service': '1', 'Data': 'Đề nghị'},
#  'UILM_STT_DIVISION_NOT_RECOMMENDATION': {'Service': '1',
#   'Data': 'Không đề nghị'},
#  'UILM_MSG_SILKROAD_STARTING_HOME': {'Service': '1',
#   'Data': 'Trang chủ của Con đường tơ lụa đã được đặt làm trang chủ mặc định'},
#  'UILM_MSG_YAHOO_STARTING_HOME': {'Service': '1',
#   'Data': 'Đã thiết đặt xong trang chủ https://sro.vtcgame.vn/'},
#  'UILM_MSG_YAHOO_TOOLBAR': {'Service': '1',
#   'Data': 'Đã thiết đặt xong thanh công cụ yahoo'},
#  'UILM_MSG_SERVICE_CLIENT_ERROR_REINSTALL': {'Service': '1',
#   'Data': 'Client của bạn bị lỗi hoặc đã bị phá huỷ nên không thể kết nối đến máy chủ. Hãy cài lại một client mới.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ download bị ngắt. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CANCEL': {'Service': '1',
#   'Data': 'Kết nới với máy chủ download đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_SELECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Launcher sẽ được khởi động lại.'},
#  'UILM_TEXT_CONFIG_GRAPHIC_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UILM_TEXT_CONFIG_GRAPHIC_NORMAL': {'Service': '1', 'Data': 'Bình thường'},
#  'UILM_TEXT_CONFIG_GRAPHIC_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UILM_TEXT_CONFIG_GRAPHIC_USER_DEF': {'Service': '1', 'Data': 'Không đổi'},
#  'UIIT_STT_ETCKEY': {'Service': '1', 'Data': 'Các phím khác'},
#  'UIIT_STT_MOUSE': {'Service': '1', 'Data': 'Chuột'},
#  'UIIT_STT_MOUSE_RIGHT_BUTTON': {'Service': '1', 'Data': 'Ô Nhớ Chuột'},
#  'UIIT_STT_USE_WHEEL_TO_CHANGE_SIGHT': {'Service': '1',
#   'Data': 'Chuột lăn (đổi góc nhìn) chuột phải (dùng Ô Nhớ)'},
#  'UIIT_STT_USE_WHEEL_TO_USE_SKILL': {'Service': '1',
#   'Data': 'Chuột lăn (dùng Ô Nhớ) chuột phải (đổi góc nhìn)'},
#  'UIIT_STT_ITEM_GET': {'Service': '1', 'Data': 'Nhặt đồ'},
#  'UIIT_STT_REFLECT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng phản xạ'},
#  'UIIT_STT_WATER_DETAIL': {'Service': '1', 'Data': 'Chi tiết nước'},
#  'UIIT_STT_LIGHT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng ánh sáng'},
#  'UIIT_STT_BUMP_MAPPING': {'Service': '1', 'Data': 'ánh xạ va chạm'},
#  'UIIT_STT_ENVIRONMENT_MAPPING': {'Service': '1', 'Data': 'ánh xạ môi trường'},
#  'UIIT_STT_LENS_FLAIR': {'Service': '1', 'Data': 'Độ nhạy của thấu kính'},
#  'UIIT_STT_DYNAMIC_ANIMATION': {'Service': '1', 'Data': 'ảnh động sống động'},
#  'UIIT_STT_WATER_REFLECTION': {'Service': '1', 'Data': 'Phản xạ nước'},
#  'UIIT_STT_FILTERING': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_TEXTER_DETAIL': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_GRAPHIC_QUALITY': {'Service': '1', 'Data': 'Chất lượng đồ họa'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL': {'Service': '1',
#   'Data': 'Người dùng tự chọn'},
#  'UIIT_STT_GRAPHIC_QUALITY_USER_CONTROL': {'Service': '1', 'Data': 'Tự chọn'},
#  'UIIT_STT_METAL_DETAIL': {'Service': '1', 'Data': 'Chất liệu kim loại'},
#  'UIIT_STT_BLOOM_EFFECT': {'Service': '1', 'Data': 'Âm lượng'},
#  'UIIT_STT_GRAPHIC': {'Service': '1', 'Data': 'Đồ họa'},
#  'UIIT_STT_RESOLUTION': {'Service': '1', 'Data': 'Độ phân giải'},
#  'UIIT_STT_LUMINOSITY': {'Service': '1', 'Data': 'Độ sáng tối'},
#  'UIIT_STT_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn'},
#  'UIIT_STT_CHAR_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn nhân vật'},
#  'UIIT_STT_SCENERY_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn bối cảnh'},
#  'UIIT_STT_SHADOW_DETAIL': {'Service': '1', 'Data': 'Chi tiết bóng'},
#  'UIIT_STT_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_MIDDLE': {'Service': '1', 'Data': 'Vừa'},
#  'UIIT_STT_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_VERY_DARK': {'Service': '1', 'Data': 'Rất tối'},
#  'UIIT_STT_DARK': {'Service': '1', 'Data': 'Tối'},
#  'UIIT_STT_NORMAL': {'Service': '1', 'Data': 'Trung bình'},
#  'UIIT_STT_LIGHT': {'Service': '1', 'Data': 'Sáng'},
#  'UIIT_STT_VERY_LIGHT': {'Service': '1', 'Data': 'Rất sáng'},
#  'UIIT_STT_SIGHT_VERY_SMALL': {'Service': '1', 'Data': 'Rất hẹp'},
#  'UIIT_STT_SIGHT_SMALL': {'Service': '1', 'Data': 'Hẹp'},
#  'UIIT_STT_SIGHT_LARGE': {'Service': '1', 'Data': 'Rộng'},
#  'UIIT_STT_SIGHT_VERY_LARGE': {'Service': '1', 'Data': 'Rất rộng'},
#  'UIIT_STT_NONE': {'Service': '1', 'Data': 'Không có'},
#  'UIIT_STT_CIRCLE': {'Service': '1', 'Data': 'Vòng tròn'},
#  'UIIT_STT_DETAIL': {'Service': '1', 'Data': 'Chi tiết'},
#  'UIIT_STT_RANK': {'Service': '1', 'Data': '%d bước'},
#  'UIIT_STT_ON': {'Service': '1', 'Data': 'Bật'},
#  'UIIT_STT_OFF': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_GRAPHIC_QUALITY_MIDDLE': {'Service': '1', 'Data': 'Bình thường'},
#  'UIIT_STT_GRAPHIC_QUALITY_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL1': {'Service': '1', 'Data': 'Đồ họa 1'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL2': {'Service': '1', 'Data': 'Đồ họa 2'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_WAR': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_USER': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_VIDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể thay đổi độ phân giải của game'},
#  'UIIT_STT_VIDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể thay đổi độ sáng của game'},
#  'UIIT_STT_VIDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể thay đổi chất lượng đồ hoạ của game. Tìm đến lựa chọn Video và thiết lập các mức độ cao, trung bình hay thấp. Tốc độ tải trò chơi sẽ thay đổi tuỳ theo các mức chất lượng được thiết lập.'},
#  'UIIT_STT_VIDIO_TTDESC_04': {'Service': '1',
#   'Data': 'Có thể thay đổi mức độ chi biết bóng. Tốc độ tải game có thể bị chậm nếu chi tiết bóng được đặt ở mức cao.'},
#  'UIIT_STT_VIDIO_TTDESC_05': {'Service': '1',
#   'Data': 'Khi thiết lập khung cảnh được đặt ở mức cao, có thể nhìn thấy nhiều hình ảnh hơn, tuy nhiên, điều này cũng sẽ làm chậm tốc độ tải game. Có thể thiết lập ở mức thấp, khi đó sẽ chỉ nhìn thấy những khung cảnh ở gần.'},
#  'UIIT_STT_VIDIO_TTDESC_06': {'Service': '1',
#   'Data': 'Khi các thông tin ở nhân vật, quái vật, lâu đài... được lựa chọn hiển thị nhiều, bạn sẽ biết đầy đủ thông tin hơn nhưng như vậy có thể gây chậm tốc độ tải game.'},
#  'UIIT_STT_VIDIO_TTDESC_07': {'Service': '1',
#   'Data': 'Lựa chọn chi tiết bóng nước để hiển thị các hình ảnh được phản chiếu trên mặt nước.'},
#  'UIIT_STT_VIDIO_TTDESC_08': {'Service': '1',
#   'Data': 'Chi tiết nước được lựa chọn với các mức độ hiệu ứng mặt nước, nếu lựa chọn mức độ cao, cảnh mặt nước sẽ đẹp hơn nhưng tốc độ tải game sẽ bị chậm đi.'},
#  'UIIT_STT_VIDIO_TTDESC_09': {'Service': '1',
#   'Data': 'Chi tiết hiển thị kim loại, nếu được lựa chọn, sẽ hiển thị các hiệu ứng ánh kim trên đồ vật kim loại như giáp, vũ khí. Mức độ lựa chọn càng cao thì chất lượng đồ hoạ cũng tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_10': {'Service': '1',
#   'Data': 'Hiệu ứng ánh sáng chỉ hiệu ứng của đèn khi chiếu trên bề mặt đồ vật, khi lựa chọn mức độ hiển thị ánh sáng cao thì độ thật của đồ vật sẽ tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_11': {'Service': '1',
#   'Data': 'Chi tiết chất liệu chỉ mức độ chi tiết của chất liệu. Chất lượng hiển thị chất liệu của đồ vật sẽ tăng lên khi chi tiết chất liệu được lựa chọn ở mức độ cao.'},
#  'UIIT_STT_VIDIO_TTDESC_12': {'Service': '1',
#   'Data': 'Chi tiết thấu kính chỉ tình trạng chiếu sáng giống như một máy quay phim đang hướng về phía mặt trời.'},
#  'UIIT_STT_VIDIO_TTDESC_13': {'Service': '1',
#   'Data': 'Hiệu ứng nở hoa chỉ tình trạng hoà trộn màu sắc giống như muôn ngàn bông hoa đang nở.'},
#  'UIIT_STT_VIDIO_TTDESC_14': {'Service': '1',
#   'Data': 'Chuyển động học chỉ kỹ thuật chuyển động của các động tác, chuyển động của tóc...'},
#  'UIIT_STT_VIDIO_TTDESC_15': {'Service': '1',
#   'Data': 'Bù đắp các phác thảo thô để các đổi tượng trong tự nhiên hơn.'},
#  'UIIT_STT_VIDIO_TTDESC_16': {'Service': '1',
#   'Data': 'Tắt hiệu ứng skill để hệ thống chạy mượt hơn'},
#  'UIIT_STT_VIDIO_TTDESC_17': {'Service': '1',
#   'Data': 'Khi được trang bị bộ đồ chiến đấu lớn, người chơi gần đó sẽ được nâng cao khả năng chiến trận'},
#  'UIIT_STT_VIDIO_TTDESC_18': {'Service': '1',
#   'Data': 'Hiển thị các hiệu ứng của tất cả các đối tượng trên màn hình chi tiết, và ánh kim loại có thể không kiểm soát được. Tùy chọn này được bất hoạt cho hình ảnh đồ họa thấp.'},
#  'UIIT_STT_GAMESET_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của thú như thú nuôi, thú thồ hàng…'},
#  'UIIT_STT_GAMESET_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của người chơi cùng nhóm'},
#  'UIIT_STT_GAMESET_TTDESC_03': {'Service': '1',
#   'Data': 'Báo động khi HP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_04': {'Service': '1',
#   'Data': 'Báo động khi MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_05': {'Service': '1',
#   'Data': 'Báo động thành tiếng khi HP/MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_AUDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể lựa chọn nhạc nền, bật/tắt/điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh pha trộn, bật/tắt điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh theo khu vực, bật/tắt, điều chỉnh âm lượng'},
#  'UIIT_STT_VIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn tự do'},
#  'UIIT_STT_VIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn từ nhân vật thứ ba để theo dõi bản thân từ sau lưng'},
#  'UIIT_STT_VIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn 1/4, tình trạng không thể thay đổi chất lượng màn hình cao/thấp'},
#  'UIIT_STT_INPUT_TTDESC_01': {'Service': '1',
#   'Data': 'sử dụng chuột hoặc phím tắt để thay đổi tầm nhìn.'},
#  'UIIT_STT_INPUT_TTDESC_02': {'Service': '1',
#   'Data': 'Để thay đổi tầm nhìn, sử dụng chuột phải hoặc phím tắt.'},
#  'UIIT_STT_INPUT_TTDESC_03': {'Service': '1',
#   'Data': 'Mở cửa sổ thông tin nhân vật để kiểm tra các thông tin cơ bản về nhân vật như trang bị, chỉ số sức mạnh/trí tuệ...'},
#  'UIIT_STT_INPUT_TTDESC_04': {'Service': '1',
#   'Data': 'Mở cửa sổ kỹ năng để có thể xem /học các kỹ năng, tăng/giảm chỉ số Tuyệt Kỹ.'},
#  'UIIT_STT_INPUT_TTDESC_05': {'Service': '1',
#   'Data': 'Mở cửa sổ nhóm để có thể lập nhóm, gia nhập nhóm hoặc thiết lập các điều kiện của nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_06': {'Service': '1',
#   'Data': 'Mở cửa sổ cộng đồng. Các thông tin về Hội hoặc tin nhắn, danh sách bạn bè... có thể tìm thấy ở đây.'},
#  'UIIT_STT_INPUT_TTDESC_07': {'Service': '1',
#   'Data': 'sử dụng chế độ Cuồng nộ. Bắt đầu bằng việc nhấn chuột phải lên nút năng lượng to nhất ở ô hiển thị chế độ Cuồng Nộ trên góc trái màn hình.'},
#  'UIIT_STT_INPUT_TTDESC_08': {'Service': '1',
#   'Data': 'Cửa sổ trợ giúp. Giải đáp các thắc mắc cơ bản của người chơi.'},
#  'UIIT_STT_INPUT_TTDESC_09': {'Service': '1',
#   'Data': 'sử dụng các ô nhớ nhanh hoặc bấm chuột phải vào các kỹ năng để thi triển kỹ năng.'},
#  'UIIT_STT_INPUT_TTDESC_10': {'Service': '1',
#   'Data': 'Phím tắt để nhặt đồ tự động trên mặt đất.'},
#  'UIIT_STT_INPUT_TTDESC_11': {'Service': '1',
#   'Data': 'Triệu tập hoặc thu hồi thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_12': {'Service': '1', 'Data': 'Để thú nuôi theo sau.'},
#  'UIIT_STT_INPUT_TTDESC_13': {'Service': '1',
#   'Data': 'Thiết lập chế độ nhặt của thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_14': {'Service': '1',
#   'Data': 'Bạn có thể gửi tin nhắn trực tiếp đến người đã nhắn cho bạn bằng cách nhấn vào nút tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_15': {'Service': '1',
#   'Data': 'Bạn có thể thay đổi thú nuôi bằng cách nhấn nút chuyển đổi thú nuôi khi có nhiều thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_16': {'Service': '1',
#   'Data': 'Mở cửa sổ giả kim thuật. Bạn có thể gia tăng sức mạnh của đồ vật và thêm các tính chất cho đồ vật tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_17': {'Service': '1',
#   'Data': 'Khi tắt chế độ hiển thị đồ vật, mọi thứ như các nhân vật khác, quái vật, thú nuôi... sẽ không được hiển thị ngoại trừ bản thân bạn.'},
#  'UIIT_STT_INPUT_TTDESC_18': {'Service': '1', 'Data': 'Mở hành trang'},
#  'UIIT_STT_INPUT_TTDESC_19': {'Service': '1',
#   'Data': 'Mở cửa sổ hành động. Có rất nhiều phím tắt, icon diễn tả cảm giác hay hành động khác nhau như lập gian hàng, chào hỏi...'},
#  'UIIT_STT_INPUT_TTDESC_20': {'Service': '1',
#   'Data': 'Mở cửa sổ nhiệm vụ để kiểm tra danh sách và thông tin về các nhiệm vụ đang thực hiện.'},
#  'UIIT_STT_INPUT_TTDESC_21': {'Service': '1',
#   'Data': 'Mở toàn bộ bản đồ để kiểm tra vị trí của bản thân và các thành viên trong nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_22': {'Service': '1',
#   'Data': 'Thay đổi tầm nhìn: tầm nhìn tự do --> tầm nhìn từ người thứ ba --> tầm nhìn 1/4 --> lặp lại tầm nhìn tự do'},
#  'UIIT_STT_INPUT_TTDESC_23': {'Service': '1',
#   'Data': 'Kiểm tra tên của các đồ vật dưới đất bằng cách sử dụng phím tắt tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_24': {'Service': '1',
#   'Data': 'Thiết lập chế độ đứng\\ngồi của nhân vật. Khi ngồi, tốc độ hồi phục HP/MP của nhân vật sẽ nhanh hơn.'},
#  'UIIT_STT_INPUT_TTDESC_25': {'Service': '1',
#   'Data': 'Cửa sổ kiểm tra tình trạng của thú nuôi: có thể thiết lập tên của thú nuôi, kiểm tra thông tin thú nuôi tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_26': {'Service': '1', 'Data': 'Thu hồi thú nuôi'},
#  'UIIT_STT_INPUT_TTDESC_27': {'Service': '1',
#   'Data': 'Yêu cầu thú nuôi tấn công'},
#  'UIIT_STT_INPUT_TTDESC_28': {'Service': '1',
#   'Data': 'Có thể sử dụng Hệ thống Siêu thị, tại đây, bạn có thể dùng silk để mua các đồ vật hữu dụng.'},
#  'UIIT_STT_INPUT_TTDESC_29': {'Service': '1',
#   'Data': 'Bạn có thể thiết lập chế độ tự động sử dụng giải dược và thuốc hồi phục, khi đó, việc luyện tập của bạn sẽ dễ dàng hơn.'},
#  'UIIT_STT_INPUT_TTDESC_30': {'Service': '1',
#   'Data': 'Mở cửa sổ gia nhập nhóm. Tại đây, bạn có thể tìm các nhóm đang thiếu thành viên để gia nhập.'},
#  'UIIT_STT_INPUT_TTDESC_31': {'Service': '1',
#   'Data': 'Mở cửa sổ hệ thống gian hàng. Tại đây, bạn có thể dễ dàng tìm thấy các đồ vật được bán trong hệ thống.'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị tên nhân vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị tên quái vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Hiển thị tên Hội'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_04': {'Service': '1',
#   'Data': 'Hiển thị tên các nhân vật khác'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_05': {'Service': '1',
#   'Data': 'Hiển thị tên NPC'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_06': {'Service': '1',
#   'Data': 'Hiển thị biểu tượng cấp độ thấp. Nếu lựa chọn, một dấu hiệu sẽ xuất hiện bên cạnh tên nhân vật của bạn và sẽ biến mất khi bạn lên cấp độ cao.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_01': {'Service': '1',
#   'Data': 'Trong trò chơi có rất nhiều chỉ dẫn được hiển thị dưới dạng tin nhắn ngắn trên cửa sổ trò chuyện. Bạn sẽ tìm thấy các thông tin hữu ích tại đây.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_02': {'Service': '1',
#   'Data': 'Cho phép hiển thị cửa sổ chú ý. Các chỉ dẫn chi tiết sẽ được hiển thị hoặc kiểm tra các thông tin quan trọng khi chuyển sang hệ thống mới. Sẽ rất hữu dụng khi bạn mới gia nhập trò chơi.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_03': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_04': {'Service': '1',
#   'Data': 'Ẩn hệ thống Windows một cách tự động. Nếu sử dụng chức năng này, khung của hệ thống Windows sẽ ẩn đi một cách tự động và chỉ xuất hiện trở lại khi bạn đưa con trỏ chuột lên trên.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_05': {'Service': '1',
#   'Data': 'Chuyển màn hình trò chơi sang chế độ cửa sổ. Bạn có thể sử dụng chế độ cửa sổ theo sở thích.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_06': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu mời vào nhóm. Nếu không sử dụng lựa chọn này, mọi lời mời vào nhóm gửi đến sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_07': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu giao dịch. Nếu không sử dụng chọn lựa này, mọi yêu cầu giao dịch gửi đến sẽ bị từ chối. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_08': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn cá nhân. Nếu không chọn chức năng này, mọi tin nhắn cá nhân sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_09': {'Service': '1',
#   'Data': 'Thể hiện thông tin về các trạng thái tăng cường của nhân vật trong phần thông tin nhân vật thuộc nhóm. Nếu không lựa chọn chức năng này, các thông tin sẽ không thể hiện. Không quan sát được trạng thái dị trạng của nhân vật.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_10': {'Service': '1',
#   'Data': 'Khởi động nhanh trò chơi bằng việc nạp hình ảnh bối cảnh trước khi nạp hình ảnh nhân vật. Đánh dấu vào ô này nếu bạn muốn trò chơi khởi động nhanh hơn.'},
#  'UIIT_MSG_CHATWND_HELP_WHISPER': {'Service': '1',
#   'Data': 'Thì thầm  [$tênnhânvật những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_PARTYMSG': {'Service': '1',
#   'Data': 'Tán gẫu trong nhóm [#những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_USECONTROLATSTORE': {'Service': '1',
#   'Data': 'Nếu bạn ấn phím Ctrl, bạn có thể bán hoặc mua đồ nhanh hơn'},
#  'UIIT_MSG_NOTIFY': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_MSG_CHATWND_MESSAGE_FILTER': {'Service': '1',
#   'Data': 'Một số từ ngữ hoặc cách diễn đạt bị cấm dùng'},
#  'UIIT_STT_GAMEGUIDE_START_1': {'Service': '1',
#   'Data': 'Hãy tìm hiểu những thông tin cơ bản về Con Đường Tơ Lụa và làm quen với những thông tin này trước. Thông qua cửa sổ tán gẫu bạn có thể học được thêm những chỉ dẫn vì vậy hãy luyện thói quen thật chú ý tới những hướng dẫn này. Chắc chắn bạn sẽ thu được những thông tin rất bổ ích.'},
#  'UIIT_STT_GAMEGUIDE_START_2': {'Service': '1',
#   'Data': '※ Hướng dẫn trò chơi có thể được sử dụng bất kỳ lúc nào bằng việc bấm phím  [H]'},
#  'UIIT_STT_GAMEGUIDE': {'Service': '1', 'Data': 'Trợ giúp'},
#  'UIIT_STT_EVENTGUIDE': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_QUESTGUIDE1': {'Service': '1', 'Data': 'Nhiệm vụ'},
#  'UIIT_STT_QUESTGUIDE2': {'Service': '1', 'Data': 'Từ điển nhiệm vụ'},
#  'UIIT_STT_GAMEEVENTGUIDE': {'Service': '1', 'Data': 'Hướng dẫn'},
#  'UIIT_STT_CONFIRM_BOX': {'Service': '1', 'Data': 'Cửa sổ xác nhận'},
#  'UIIT_STT_AGREEMENT_BOX': {'Service': '1', 'Data': 'Cửa sổ đồng ý'},
#  'UIIT_STT_INPUT_BOX': {'Service': '1', 'Data': 'Cửa sổ nhập vào'},
#  'UIIT_PAG_WORLDMAP': {'Service': '1', 'Data': 'Bản đồ lớn'},
#  'UIIT_PAG_LOCALMAP': {'Service': '1', 'Data': 'Bản đồ khu vực'},
#  'UIIT_STT_BACK_WORLDMAP': {'Service': '1', 'Data': 'Mở bản đồ lớn'},
#  'UIIT_STT_JANGAN': {'Service': '1', 'Data': 'Trường An'},
#  'UIIT_STT_DONHWANG': {'Service': '1', 'Data': 'Đôn Hoàng'},
#  'UIIT_STT_KHOTAN': {'Service': '1', 'Data': 'Hòa Điền'},
#  'UIIT_STT_SAMARKAND': {'Service': '1', 'Data': 'Samarkand'},
#  'UIIT_STT_CONSTANTINOPLE': {'Service': '1', 'Data': 'Constantinople'},
#  'UIIT_STT_BIJEOKDAN': {'Service': '1', 'Data': 'Bijeokdan'},
#  'UIIT_STT_HEUKMAKDAN': {'Service': '1', 'Data': 'Heukmakdan'},
#  'UIIT_STT_EVILORDER': {'Service': '1', 'Data': 'Pháo đài tà ác'},
#  'UIIT_STT_ARABIA_CITY': {'Service': '1', 'Data': 'Baghdad'},
#  'UIIT_STT_ARABIA_CITY_DUNGEON': {'Service': '1', 'Data': 'Baghdad (Phụ bản)'},
#  'UIIT_STT_MUHAN': {'Service': '1', 'Data': 'Đấu trường Vô Cực'},
#  'UIIT_MSG_CHEATMSG_GO_TOWN': {'Service': '1', 'Data': '/town'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_1': {'Service': '1',
#   'Data': 'Tìm thấy macro (chơi tự động) trong nhân vật đang chơi. Tự động thoát.'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_2': {'Service': '1',
#   'Data': 'Tên của nhân vật có macro và thời gian đã sử dụng sẽ được ghi lại trên máy chủ'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_3': {'Service': '1',
#   'Data': 'Có thể áp dụng hình phạt giới hạn về thời gian của tài khoản và khóa tài khoản'},
#  'UIIT_MSG_APPEAR_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa xuất hiện ở Hổ Huyệt Sơn'},
#  'UIIT_MSG_APPEAR_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã xuất hiện'},
#  'UIIT_MSG_APPEAR_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi xuất hiện ở Karakoram'},
#  'UIIT_MSG_APPEAR_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan xuất hiện ở Taklamakan'},
#  'UIIT_MSG_APPEAR_TAHOMET': {'Service': '1',
#   'Data': 'Sa Y Thần xuất hiện ở Lạc Khắc Sơn'},
#  'UIIT_MSG_APPEAR_UNIC': {'Service': '1', 'Data': '[%s] đã xuất hiện'},
#  'UIIT_MSG_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn đã biến mất'},
#  'UIIT_MSG_DEAD_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã biến mất'},
#  'UIIT_MSG_DEAD_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi từ Karakoram đã biến mất'},
#  'UIIT_MSG_DEAD_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan từ Taklamakan đã biến mất'},
#  'UIIT_MSG_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã biến mất'},
#  'UIIT_MSG_ANYONE_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': '[%s] đã giết Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_URRUCHI': {'Service': '1',
#   'Data': '[%s] đã giết Ô Lỗ Tề từ Tháp Lý Mộc'},
#  'UIIT_MSG_ANYONE_DEAD_IYUTARU': {'Service': '1',
#   'Data': '[%s] đã giết Băng Chúa Nhi từ Karakoram'},
#  'UIIT_MSG_ANYONE_DEAD_BONELORD': {'Service': '1',
#   'Data': '[%s] đã giết Chúa tể Yarkan từ Taklamakan'},
#  'UIIT_MSG_ANYONE_DEAD_TAHOMET': {'Service': '1',
#   'Data': '[%s] đã giết Sa Y Than từ Lạc Khắc Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã giết [%s]'},
#  'UIIT_STT_ROLL_OF_CLOTH': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILK_BUY_RESULT': {'Service': '1', 'Data': 'Bạn đã mua [%d] silk'},
#  'UIIT_STT_SILK_BUY_CANCLE': {'Service': '1',
#   'Data': 'Việc mua bán [%d] silk đã bị hủy bỏ'},
#  'UIIT_STT_SILK_BUY_RECEIVE': {'Service': '1',
#   'Data': 'Bạn nhận được quà là [%d] silk'},
#  'UIIT_STT_SILK_SEND_RESULT': {'Service': '1',
#   'Data': 'Bạn đã gửi [%d] silk đi làm quà'},
#  'UIIT_STT_SILK_POINT_BUY_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được trả tiền'},
#  'UIIT_STT_SILK_POINT_USE_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được sử dụng'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK': {'Service': '1', 'Data': 'Silk đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_MALL': {'Service': '1', 'Data': 'Cửa hàng Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_MALL': {'Service': '1',
#   'Data': 'Cửa hàng đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_TOTAL': {'Service': '1', 'Data': 'Tổng số Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_TOTAL': {'Service': '1',
#   'Data': 'Tổng số Silk đặc biệt'},
#  'UIIT_STT_SILKMALL': {'Service': '1', 'Data': 'Siêu thị'},
#  'UIIT_STT_SILKMALL_MAIN': {'Service': '1', 'Data': 'Phần chính'},
#  'UIIT_STT_SILKMALL_HOT_STORE': {'Service': '1', 'Data': 'HOT Shop'},
#  'UIIT_STT_SILKMALL_CONSUMPTION': {'Service': '1', 'Data': 'Đồ tiêu dùng'},
#  'UIIT_STT_SILKMALL_LEND_ITEM': {'Service': '1', 'Data': 'Tiền thuê đồ'},
#  'UIIT_STT_SILKMALL_AVATA': {'Service': '1', 'Data': 'Trang trí'},
#  'UIIT_STT_SILKMALL_PET': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PACKAGE': {'Service': '1', 'Data': 'Gói hàng'},
#  'UIIT_STT_SILKMALL_SHOPPING_BASKET_LIST': {'Service': '1',
#   'Data': 'Hàng đã chọn'},
#  'UIIT_STT_SILKMALL_NEW_ITEM': {'Service': '1', 'Data': 'Hàng mới'},
#  'UIIT_STT_SILKMALL_EVENT': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_SPECIAL_COAST': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_FAVORITE': {'Service': '1', 'Data': 'Hàng bán chạy'},
#  'UIIT_STT_SILKMALL_SPECIAL': {'Service': '1', 'Data': 'Đặc biệt'},
#  'UIIT_STT_SILKMALL_SCROLL': {'Service': '1', 'Data': 'Hỗ trợ'},
#  'UIIT_STT_SILKMALL_POTION': {'Service': '1', 'Data': 'Hồi phục'},
#  'UIIT_STT_SILKMALL_COMMUNITY': {'Service': '1', 'Data': 'Cộng đồng'},
#  'UIIT_STT_SILKMALL_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY': {'Service': '1', 'Data': 'Giả kim thuật'},
#  'UIIT_STT_SILKMALL_PREMIUM_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ASTRAL': {'Service': '1', 'Data': 'Tinh thạch'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': 'Bất diệt (bảo toàn 99%)'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_3': {'Service': '1', 'Data': 'Áo nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_4': {'Service': '1', 'Data': 'Quần nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_5': {'Service': '1', 'Data': 'Bao tay'},
#  'UIIT_STT_SILKMALL_ARMOR_6': {'Service': '1', 'Data': 'Giầy nặng'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_3': {'Service': '1', 'Data': 'Áo nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_4': {'Service': '1', 'Data': 'Quần nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_6': {'Service': '1', 'Data': 'Giầy nhẹ'},
#  'UIIT_STT_SILKMALL_CLOSE_1': {'Service': '1', 'Data': 'Khăn'},
#  'UIIT_STT_SILKMALL_CLOSE_2': {'Service': '1', 'Data': 'Cầu vai vải'},
#  'UIIT_STT_SILKMALL_CLOSE_3': {'Service': '1', 'Data': 'Áo vải'},
#  'UIIT_STT_SILKMALL_CLOSE_4': {'Service': '1', 'Data': 'Quần vải'},
#  'UIIT_STT_SILKMALL_CLOSE_6': {'Service': '1', 'Data': 'Giầy vải'},
#  'UIIT_STT_SILKMALL_BIG_STORE': {'Service': '1', 'Data': 'Tiệm lớn'},
#  'UIIT_STT_SILKMALL_ASSIST': {'Service': '1', 'Data': 'Chi nhánh'},
#  'UIIT_STT_SILKMALL_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_HAT': {'Service': '1', 'Data': 'Mũ'},
#  'UIIT_STT_SILKMALL_BOOTH': {'Service': '1', 'Data': 'Gian hàng'},
#  'UIIT_STT_SILKMALL_FIREWORK': {'Service': '1', 'Data': 'Kẹo'},
#  'UIIT_STT_SILKMALL_DRESS': {'Service': '1', 'Data': 'Trang phục'},
#  'UIIT_STT_SILKMALL_ATTACH': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_BALLOON': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_PET_SUMMON': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PET_CONSUME': {'Service': '1', 'Data': 'Thú nuôi hết hạn'},
#  'UIIT_STT_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1', 'Data': 'Mua hết'},
#  'UIIT_STT_SILKMALL_BOOK_MARK': {'Service': '1', 'Data': 'Sổ sách'},
#  'UIIT_STT_SILKMALL_PUT_ON': {'Service': '1', 'Data': 'sử dụng thử'},
#  'UIIT_STT_SILKMALL_BUY': {'Service': '1', 'Data': 'Mua'},
#  'UIIT_STT_SILKMALL_PRESENT': {'Service': '1', 'Data': 'Quà'},
#  'UIIT_STT_SILKMALL_DEL': {'Service': '1', 'Data': 'Xóa'},
#  'UIIT_STT_SILKMALL_BUY_LIST': {'Service': '1', 'Data': 'Hàng mua'},
#  'UIIT_STT_SILKMALL_RECEIVE_LIST': {'Service': '1', 'Data': 'Hàng nhận'},
#  'UIIT_STT_SILKMALL_SILKMALL_OUT': {'Service': '1', 'Data': 'Thoát'},
#  'UIIT_STT_SILKMALL_PUT_ON_CLOSE_BUY': {'Service': '1',
#   'Data': 'Mua đồ thời trang'},
#  'UIIT_STT_SILKMALL_ALL_CLOSE_TAKEOFF': {'Service': '1', 'Data': 'Cởi bỏ'},
#  'UIIT_STT_SILKMALL_ADD_INVENTORY': {'Service': '1', 'Data': 'Ô mở rộng'},
#  'UIIT_STT_SILKMALL_ADD_STOREHOUSE_INVENTORY': {'Service': '1',
#   'Data': 'Kho mở rộng'},
#  'UIIT_STT_SILKMALL_SILK': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILKMALL_BUY_SILK': {'Service': '1', 'Data': 'Mua Silk'},
#  'UIIT_STT_SILKMALL_SEND_SILK': {'Service': '1', 'Data': 'Tặng Silk'},
#  'UIIT_STT_SILKMALL_COUPON_EXCHANGE': {'Service': '1',
#   'Data': 'Trao đổi phiếu'},
#  'UIIT_STT_SILKMALL_BUY_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_03': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_USE_INFOMATION': {'Service': '1',
#   'Data': 'Cách sử dụng Siêu thị'},
#  'UIIT_STT_SILKMALL_ENTER': {'Service': '1', 'Data': 'Vào Siêu thị'},
#  'UIIT_STT_SILKMALL_DIRECT_ENTER': {'Service': '1',
#   'Data': 'Vào nhanh Siêu thị'},
#  'UIIT_STT_SILKMALL_NEW_CASHITEM': {'Service': '1',
#   'Data': 'Siêu thị cập nhật đồ vật mới'},
#  'UIIT_STT_SILKMALL_WARNING_1': {'Service': '1',
#   'Data': 'Bạn có thể bị quái vật'},
#  'UIIT_STT_SILKMALL_WARNING_2': {'Service': '1',
#   'Data': 'hoặc những người chơi khác tấn công trong khi vào Siêu thị'},
#  'UIIT_STT_SILKMALL_WARNING_3': {'Service': '1',
#   'Data': 'Nên sử dụng món đồ trong khu vực an toàn'},
#  'UIIT_STT_SILKMALL_MAIN_EXPLAIN': {'Service': '1',
#   'Data': '<sml2><p line_margin="12"><p line_margin="5"><font color="255,255,153,81" style="bold">Siêu Thị là gì?</font><br>Là nơi bán và cho thuê những trang bị để <br>sử dụng trên Con đường tơ lụa. Những trang bị đó phải sử dụng silk để mua.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Mua Silk</font><br>Silk có thể mua bằng cách bấm vào nút Mua silk ở góc trên bên phải màn hình.<br>Bấm vào nút Mua silk bạn sẽ được chuyển đến trang E-Cash.<br>nơi để bạn mua silk.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Tặng Silk</font><font color="255,255,117,117">(Tính năng chưa kích hoạt)</font><br>Trong quá trình mua đồ trong Siêu Thị, bạn có thể bấm vào nút Tặng Silk để gửi <br>tới người chơi khác món đồ bạn chọn.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Coupons exchanges</font><br>Phiếu giảm giá có thể được sử dụng 1 lần để mua silk hoặc sử dụng các item Mall.<br>Điền con số vào phiếu giảm giá để nhận được silk.<br>Số tiền có thể khác nhau tùy thuộc vào các loại phiếu giảm giá.<br></p></p><strong><font color="255,255,153,81">Sổ sách</font></strong><font color="255,255,117,117">(Tính năng chưa được kích hoạt)</font><br>Tất cả những đồ vật bạn mua trong Siêu Thị có thể được lưu giữ trong sổ sách của bạn <br>bằng cách bấm vào Sổ sách. Đồ vật đã lưu trong Sổ của bạn sẽ được hoàn trả <br>ngay cả khi bạn đã mua đồ vật đó.</sml2>'},
#  'UIIT_STT_SILKMALL_MY_INFO': {'Service': '1', 'Data': 'Thông tin cá nhân'},
#  'UIIT_STT_SILKMALL_POSSESSION_GOLD': {'Service': '1',
#   'Data': 'Số lượng hiện có'},
#  'UIIT_STT_SILKMALL_REMAIN_INVENTORY': {'Service': '1', 'Data': '%d ô trống'},
#  'UIIT_STT_SILKMALL_MAIN_INTRO': {'Service': '1',
#   'Data': '<sml2>Chào mừng quý khách đến với cửa hàng bán đồ chất lượng cao của Con Đường Tơ Lụa</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ORDER_SHEET': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_TOOL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_FLEAMARKET': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_ZZIM': {'Service': '1',
#   'Data': '<sml2>Đây là danh sách hàng bạn đặt mua</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_FAVORITY': {'Service': '1',
#   'Data': '<sml2>Có thể xem danh sách những mặt hàng đã mua hoặc chọn trong phần Sổ sách</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COSETC': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'MALL_CONSUME_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'MALL_CONSUME_SCROLL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'MALL_CONSUME_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'MALL_CONSUME_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'MALL_CONSUME_ETC': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'MALL_AVATAR_BOOTH': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'MALL_AVATAR_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_PET_A_GROWTH': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_SILK': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_VEHICLE': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_CART': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_STORES': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PREMIUM_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'MALL_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'MALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'UIIT_STT_SILKMALL_SHORT_KEY': {'Service': '1', 'Data': 'Siêu thị (F10)'},
#  'UIIT_STT_SILKMALL_BUY_CONFIRM': {'Service': '1', 'Data': 'Xác nhận mua'},
#  'UIIT_STT_SILKMALL_DO_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_POPUP_TITLE': {'Service': '1',
#   'Data': 'Đồ trang trí tồn kho'},
#  'UIIT_STT_SILKMALL_POPUP_ADVERTISING': {'Service': '1',
#   'Data': 'Bán có giới hạn'},
#  'UIIT_STT_SILKMALL_POPUP_DATA': {'Service': '1', 'Data': 'Ngày bán:'},
#  'UIIT_STT_SILKMALL_POPUP_REDUCTION': {'Service': '1',
#   'Data': 'Cho tới khi giảm giá'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_M': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nam)'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_W': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nữ)'},
#  'UIIT_MSG_SILKMALL_ZZIM_CONFIRM': {'Service': '1',
#   'Data': '<sml2><font color="255,255,255,255">Bạn sẽ đặt món đồ này chứ?<br>các món đồ được đặt có thể được chọn và mua một tất cả ở danh sách đặt hàng.</font></sml2>'},
#  'UIIT_MSG_SILKMALL_ZZIM_DELITE': {'Service': '1',
#   'Data': 'Xóa món đồ trong danh sách đặt hàng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1',
#   'Data': 'Bạn sẽ mua luôn số hàng đã đặt chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY_TOTAL': {'Service': '1',
#   'Data': 'Tổng cộng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_1': {'Service': '1',
#   'Data': 'Bạn có hủy số hàng đã đặt không ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_2': {'Service': '1',
#   'Data': 'Nếu bạn hủy bỏ việc sử dụng món đồ đã chọn, hiệu ứng của nó sẽ mất'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE': {'Service': '1',
#   'Data': 'Bạn sẽ dùng món đồ đã chọn chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_REVERSE_PORTAL': {'Service': '1',
#   'Data': 'sử dụng bùa dịch chuyển phản hồi. Hãy chọn điểm đến.'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_RETURN': {'Service': '1',
#   'Data': 'Dịch chuyển tới điểm về cuối'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_DEATH': {'Service': '1',
#   'Data': 'Dịch chuyển tới nơi bạn đã chết'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_INS': {'Service': '1',
#   'Data': 'sử dụng các vật phẩm này bạn sẽ không thể dịch chuyển được'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_GNGWC': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật sau khi kết thúc trận chiến'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_BUY_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không thành công do không đủ silk'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_GIFT': {'Service': '1',
#   'Data': 'Silk không đủ để tặng'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng cho loại đồ vật trang bị'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_SINCE_EQUIP_CLASS_TOO_HIGH': {'Service': '1',
#   'Data': 'Không thể thay đổi giới tính do không phù hợp với cấp độ của đồ vật'},
#  'UIIT_MSG_STRGERR_INVALID_TRANSGENDER_TARGET': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể thay đổi giới tính'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_TELEPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi cuối cùng bạn đã quay lại'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_DIEDPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi bạn đã chết'},
#  'UIIT_MSG_STRGERR_ONLY_THE_DEAD_CAN_USE_RESURRECT_SCROLL': {'Service': '1',
#   'Data': 'Chỉ sử dụng trong tình trạng đã chết'},
#  'UIIT_MSG_STRGERR_THERE_IS_NO_ITEM_TO_REPAIR': {'Service': '1',
#   'Data': 'Không có đồ vật nào cần sửa chữa'},
#  'UIIT_MSG_STRGERR_CANT_QUICKSELL_CASHITEM': {'Service': '1',
#   'Data': 'Không có chức năng mua bán nhanh với những món đồ hiếm.'},
#  'UIIT_MSG_STRGERR_TRADE_FAILURE': {'Service': '1',
#   'Data': 'Giao dịch thất bại không có lý do'},
#  'UIIT_STT_SILKMALL_FAIL_ITEMBUY_LOGOUT': {'Service': '1',
#   'Data': 'Trò chơi sẽ chấm dứt do việc mua đồ Premium thất bại'},
#  'UIIT_STT_SILKMALL_DONOT_USE_TELEPORT': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_MSG_SELL_RECONFIRM': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_PAG_CHAR_SKIN_CHANGE': {'Service': '1',
#   'Data': 'Thay đổi hình dáng bên ngoài của nhân vật'},
#  'UIIT_MSG_CHAR_SKIN_ERR_ARMOR': {'Service': '1',
#   'Data': 'Để thay đổi giới tính phải bỏ đồ bảo hộ và gỡ bỏ hết các ô mở rộng'},
#  'UIIT_MSG_CHAR_SKIN_CHANGE_SUCCESS': {'Service': '1',
#   'Data': 'Thay đổi giới tính thành công'},
#  'UIIT_STT_GUILD_INFO': {'Service': '1', 'Data': 'T.Tin Hội'},
#  'UIIT_CTL_LETTER': {'Service': '1', 'Data': 'Hộp thư kết hợp'},
#  'UIIT_CTL_FRIEND': {'Service': '1', 'Data': 'Bạn'},
#  'UIIT_STT_GUILD_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_GUILD_STAFF': {'Service': '1', 'Data': 'Hội phó'},
#  'UIIT_STT_GUILDSMAN': {'Service': '1', 'Data': 'Hội viên'},
#  'UIIT_STT_GUILDSMAN_NUM': {'Service': '1', 'Data': 'Số'},
#  'UIIT_STT_GUILD_COMMON_KNOW': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_GUILD_COMMON_KNOW_WRITE': {'Service': '1',
#   'Data': 'Viết thông báo'},
#  'UIIT_MSG_GUILD_COMMON_NOTEXIST': {'Service': '1',
#   'Data': 'Không có thông báo'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo (%d/Tối đa.%d)'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_TITLE_REMIND': {'Service': '1',
#   'Data': 'Hãy điền tiêu đề lời thông báo'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT_TITLE': {'Service': '1',
#   'Data': 'Chưa điền tiêu đề'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo'},
#  'UIIT_MSG_GUILDERR_TARGET_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Người chơi khác không có quyền'},
#  'UIIT_CTL_GUILD_WRITE_END': {'Service': '1', 'Data': 'Hoàn thành'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND_UPDATE': {'Service': '1',
#   'Data': 'Thông báo của Hội đã thay đổi'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_JOIN': {'Service': '1',
#   'Data': 'Hội chủ Hội [%s] đề nghị liên minh với bạn, bạn có chấp nhận không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_WITHDRAWA': {'Service': '1',
#   'Data': 'Bạn có muốn rời bỏ liên minh không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_BREAKUP': {'Service': '1',
#   'Data': 'Liên minh đã bị giải tán'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_NOTALLY': {'Service': '1',
# ...
#   'Data': 'Đã khỏi bệnh'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CHAOS': {'Service': '1',
#   'Data': 'Đã khỏi lẫn lộn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_PD': {'Service': '1',
#   'Data': 'Đã khỏi bị thối rữa'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_MD': {'Service': '1',
#   'Data': 'Đã được khoẻ lại'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_STR': {'Service': '1',
#   'Data': 'Đã hết bất lực'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_INT': {'Service': '1',
#   'Data': 'Đã hết bị cô lập'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_HP': {'Service': '1',
#   'Data': 'Đã hết hoảng loạn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSIE_MP': {'Service': '1',
#   'Data': 'Đã hết bị thiêu đốt'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_TIME_BOMB': {'Service': '1',
#   'Data': 'Đã hết ẩn nấp'},
#  'UIIT_MSG_BURN': {'Service': '1', 'Data': 'Thiêu đốt'},
#  'UIIT_MSG_FROSTBITE': {'Service': '1', 'Data': 'Tê cóng'},
#  'UIIT_MSG_FREEZING': {'Service': '1', 'Data': 'Đóng băng'},
#  'UIIT_MSG_SHOCK': {'Service': '1', 'Data': 'Nhiễm điện'},
#  'UIIT_MSG_ZOMBIE': {'Service': '1', 'Data': 'Yểm bùa'},
#  'UIIT_MSG_DARK': {'Service': '1', 'Data': 'Mờ mắt'},
#  'UIIT_MSG_STUN': {'Service': '1', 'Data': 'Choáng'},
#  'UIIT_MSG_PARTYERR_OUT_OF_LEVEL': {'Service': '1',
#   'Data': 'Không thể vào nhóm đó do sự chênh lệch về cấp độ.'},
#  'UIIT_MSG_FLEAMARKET_ERR_IM_BUSY': {'Service': '1',
#   'Data': 'Bạn ở trong tình trạng không được mở gian hàng mới'},
#  'UIIT_MSG_JSERR_SINCE_YOU_DIE_IN_MURDERER_SP_DEPRIVED_BY_SERVER': {'Service': '1',
#   'Data': 'Bị mất [%u] điểm kinh nghiệm'},
#  'UIIT_MSG_INTERACTION_FAIL__REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_PORTAL_SCROLL': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_SUMMON_VEHICLE': {'Service': '1',
#   'Data': 'Không thể dùng thú vận chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_INTERACTION_FAIL_MURDERER_CAN_USE_PORTAL_STRUCTURE': {'Service': '1',
#   'Data': 'Không thể qua cổng dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_FLEAMARKET_ERR_CANT_OPEN_MARKET_MURDERER': {'Service': '1',
#   'Data': 'Không thể mở gian hàng mới trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng item trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_ENABLEINPUT_FEWERTHAN_REMAIN': {'Service': '1',
#   'Data': 'Chỉ có thể nhập số đơn vị còn lại'},
#  'UIIT_MSG_STRGERR_CANNOT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy người chơi khác'},
#  'UIIT_MSG_STRGERR_SPECIFY_POSITIVE_NUMBER_ONLY': {'Service': '1',
#   'Data': 'Số không hợp lệ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi bị hủy bỏ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_BEFORE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi lần trước bị hủy bỏ vì đã thực hiện trao đổi với người chơi khác'},
#  'UIIT_MSG_STRGERR_CANNOT_WITDRAW_MORETHAN_DEPOSIT': {'Service': '1',
#   'Data': '-'},
#  'UIIT_MSG_DEAL_ASK': {'Service': '1',
#   'Data': 'Có người muốn trao đổi với bạn. Bạn chấp nhận chứ?'},
#  'UIIT_MSG_DEAL_ASKING': {'Service': '1', 'Data': 'Trao đổi với [%s]'},
#  'UIIT_MSG_STRGERR_INVALID_TARGET': {'Service': '1',
#   'Data': 'Không thấy mục tiêu'},
#  'UIIT_MSG_STRGERR_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận làm việc khác'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_OPPONENT_INV_SPACE': {'Service': '1',
#   'Data': 'Không thể đưa thêm món đồ đó vào cửa sổ trao đổi vì thùng đồ người kia đã đầy.'},
#  'UIIT_MSG_STRGERR_NON_SETUP_KEY': {'Service': '1',
#   'Data': 'Không thể đặt phím đã lựa chọn'},
#  'UIIT_MSG_STRGERR_CHATING_LIMIT': {'Service': '1',
#   'Data': 'Không thể lặp lại cùng nội dung'},
#  'UIIT_MSG_STRGERR_DEAL_FAIL_NON_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không được thực hiện do không có đồ vật giao dịch'},
#  'UIIT_STT_TARGETTING': {'Service': '1', 'Data': 'Mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTLEARN': {'Service': '1',
#   'Data': 'Kỹ năng không xác định'},
#  'UIIT_SKILL_USE_FAIL_TIMEDELAY_REUSEDELAY': {'Service': '1', 'Data': '-'},
#  'UIIT_SKILL_USE_FAIL_WRONGDISTANCE': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng với mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTENOUGHLEVEL': {'Service': '1',
#   'Data': 'Không sử dụng được vì cấp độ của bạn thấp'},
#  'UIIT_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh người chơi khác vì cấp độ của người đó cao hơn bạn'},
#  'UIIT_CHATERR_CANT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy [%s]'},
#  'UIIT_CHATERR_YOU_ARE_SQUELCHED': {'Service': '1',
#   'Data': 'Chức năng thì thầm của  [%s]đã bị tắt'},
#  'UIIT_CHATERR_NOT_A_PARTY_MEMBER': {'Service': '1',
#   'Data': 'Không ở trong nhóm nào'},
#  'UIIT_CHATERR_INVALID_COMMAND': {'Service': '1',
#   'Data': 'Lệnh chat không hợp lệ'},
#  'UIIT_CHATERR_ALLIANCE_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Không sử dụng được chức năng tán gẫu với đồng minh vì Hội được chọn không phải là đồng minh của bạn'},
#  'UIIT_CHATERR_WHISPER_TO_MESSAGE': {'Service': '1', 'Data': 'Tin đi'},
#  'UIIT_CHATERR_WHISPER_FROM_MESSAGE': {'Service': '1', 'Data': 'Tin đến'},
#  'UIIT_TOOLTIP_PK_DAY': {'Service': '1', 'Data': 'PK hàng ngày %d / %d'},
#  'UIIT_TOOLTIP_PK_TOTAL': {'Service': '1', 'Data': 'Tổng PK %d / %d'},
#  'UIIT_TOOLTIP_PK_PENALTY_TIME': {'Service': '1',
#   'Data': 'Chỉ số PK %d (Cấp độ %d)'},
#  'UIIT_TOOLTIP_PENALTY_GOLD': {'Service': '1', 'Data': 'Phạt %d vàng'},
#  'UIIT_TOOLTIP_JOB_PENALTY_TIME': {'Service': '1',
#   'Data': 'Không được hành nghề trong %d phút'},
#  'UIIT_TOOLTIP_EQUIPMENT_CLASS': {'Service': '1', 'Data': 'Cấp: Cấp %d'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_DROPPED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể bỏ đi'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_PICKED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể lấy được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_TRADED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể mang ra mua bán được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể sửa chữa được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể làm lại được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_USED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể dùng được'},
#  'UIIT_MSG_CANNOT_BE_USED_ITEM_CART': {'Service': '1',
#   'Data': 'Không thể dùng mà không có thú di chuyển/ chuyên chở'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_IN_BATTLE_STATE': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang đánh nhau'},
#  'UIIT_MSG_REMAIN_TIME': {'Service': '1', 'Data': '(còn %d giây)'},
#  'UIIT_MSG_STRGERR_ONLY_ROBBER_CAN_USE_THIS_ITEM': {'Service': '1',
#   'Data': 'Món đồ được chọn chỉ sử dụng được khi làm Đạo Tặc'},
#  'UIIT_MSG_STRGERR_CANT_OPERATE_REQUESTED_JOB_DURING_LOGOUT': {'Service': '1',
#   'Data': 'Không thể thực hiện khi đang thoát trò chơi'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED_TO_USE_THISITEM': {'Service': '1',
#   'Data': 'Không thể đung được món đồ đó vì cấp độ của nhân vật còn thấp'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_WHILE_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang dịch chuyển'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME': {'Service': '1',
#   'Data': 'Còn %d giây sẽ thoát trò chơi'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME_CANCLE': {'Service': '1',
#   'Data': 'Hủy bỏ việc thoát khỏi trò chơi'},
#  'UIIT_MSG_STRGERR_CANT_SELL_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể bán món đồ khi đang trang bị'},
#  'UIIT_MSG_STRGERR_CANT_SWAP_JOBITEM': {'Service': '1',
#   'Data': 'Phải bỏ món đồ trước ra thì mới mặc đồ mới vào được'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBCHANGE_COMPLETE': {'Service': '1',
#   'Data': 'Không thể cởi trang bị nghề nghiệp trong vòng 10 giây kể từ lúc đeo vào'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBITEM_DETACH_COMPLETE': {'Service': '1',
#   'Data': 'Không thể đeo trang bị nghề nghiệp khác trong 10 phút kể từ lúc tháo ra'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_JOBITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Bạn chỉ có thể bỏ trang bị nghề nghiệp sau 20 giây kể từ trận chiến cuối cùng.'},
#  'UIIT_MSG_STRGERR_CANT_HAVE_CART': {'Service': '1',
#   'Data': 'Không thể bỏ trang bị nghề nghiệp ra trong khi đang triệu tập thú vận chuyển'},
#  'UIIT_MSG_COSERR_COLLISION_EXIST_BETWEEN_US': {'Service': '1',
#   'Data': 'Không thực hiện được lệnh di chuyển do có chướng ngại vật'},
#  'UIIT_MSG_INTERACTION_FAIL_IM_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận việc khác'},
#  'UIIT_MSG_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh vì kỹ năng hồi sinh của bạn còn thấp'},
#  'UIIT_MSG_SKILL_USE_FAIL_NOTENOUGHHP': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng đó vì không đủ HP'},
#  'UIIT_MSG_SKILL_USE_FAIL_ITS_NOT_A_BATTLE_FIELD': {'Service': '1',
#   'Data': 'Không thể tấn công trong khu vực an toàn'},
#  'UIIT_MSG_SKILL_USE_FAIL_WAITFOR_JOB_ACTIVATE': {'Service': '1',
#   'Data': 'Không thể tấn công trong 10 giây kể từ lúc mang trang bị nghề nghiệp vào'},
#  'UIIT_MSG_STRGERR_DONT_HAVE_ANY_TRADECART_TO_PICK_SPECIALTY': {'Service': '1',
#   'Data': 'Không thể nhận được đặc sản nếu không có thú vận chuyển'},
#  'UIIT_MSG_STRGERR_CANT_BE_STORED': {'Service': '1',
#   'Data': 'Món đồ đó không thể lưu tại nơi đã chỉ định'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị đồ vật vì cấp độ hoặc cấp độ tuyệt kỹ nhân vật còn thấp'},
#  'UIIT_MSG_STRGERR_LOCKED_BY_OTHER_ONE': {'Service': '1',
#   'Data': 'Không thể lấy được món đồ đó vì nó của người chơi khác'},
#  'UIIT_MSG_STRGERR_GENDER_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác giới tính'},
#  'UIIT_MSG_STRGERR_TRADE_BAY_FULL': {'Service': '1',
#   'Data': 'Không thể thêm vào món đồ đã chọn vì cửa sổ trao đổi đã đầy'},
#  'UIIT_MSG_STRGERR_COUNTRY_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác chủng tộc'},
#  'UIIT_MSG_STRGERR_HIGHER_STRENGTH_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì thiếu sức mạnh'},
#  'UIIT_MSG_STRGERR_HIGHER_INTELLECT_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì trí tuệ thấp'},
#  'UIIT_MSG_STRGERR_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_EU_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_CANT_EQUIP_RAZED_ITEM': {'Service': '1',
#   'Data': 'Không thể trang bị món đồ đã hỏng'},
#  'UIIT_MSG_STRGERR_PREV_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển.'},
#  'UIIT_MSG_STRGERR_POSSESSION_LIMIT_EXCEEDED': {'Service': '1',
#   'Data': 'Không thể có nhiều hơn số lượng giới hạn'},
#  'UIIT_MSG_STRGERR_ROBBER_CANT_SUMMON_CART_IN_TOWN': {'Service': '1',
#   'Data': 'Không thể triệu hồi phương tiện chuyên trở khi đang ở Làng Đạo Tặc'},
#  'UIIT_MSG_INTERACTION_FAIL_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển rồi'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_TRADECART': {'Service': '1',
#   'Data': 'Không thể dịch chuyển khi đang có thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_RIDE': {'Service': '1',
#   'Data': 'Không thể sử dụng cổng dịch chuyển khi đang cưỡi thú'},
#  'UIIT_MSG_INTERACTION_FAIL_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Không thể qua đò khi đang ở xa thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không sửa chữa được'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không làm lại được'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_TEMPORARILY': {'Service': '1',
#   'Data': 'Bất khả xâm phạm - Không thể tấn công hoăc bị tấn công trong 5 giây'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_FORTRESS': {'Service': '1',
#   'Data': 'Khi tấn công pháo đài trong tình trạng bất khả xâm phạm - không thể tấn công trong 10 giây'},
#  'UIIT_MSG_COSERR_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Một nhân vật không thể cách xa quá thú vận chuyển %d m'},
#  'UIIT_MSG_RETURN_CANCLE': {'Service': '1',
#   'Data': 'Việc sử dụng bùa dịch chuyển đã bị hủy bỏ'},
#  'UIIT_MSG_QUESTEND_2': {'Service': '1',
#   'Data': 'Hãy mở cửa sổ Nhiệm vụ (Q) để kiểm tra nội dung'},
#  'UIIT_MSG_JSERR_PREVIOUS_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể vào mê cung khi sắp dịch chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_OUT_OF_REQUIRED_LEVEL_FOR_TELEPORT': {'Service': '1',
#   'Data': 'Không thể dịch chuyển vì cấp độ của bạn quá thấp'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_FREEBATTLEITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Không thể bỏ khăn ra trong khi đang đánh nhau'},
#  'UIIT_MSG_STRGERR_STORAGE_OPERATION_BLOCKED': {'Service': '1',
#   'Data': 'Hiện tại bạn không được phép di chuyển các món đồ hoặc trao đổi chúng'},
#  'UIIT_MSG_QUEST_CALLMONSTER_NOTATTACK': {'Service': '1',
#   'Data': 'Cấp độ của bạn còn quá thấp để có thể đánh nhau với quái vật'},
#  'UIIT_MSG_QUEST_GET_ITEM_FAILURE': {'Service': '1',
#   'Data': 'Không thể nhặt được món đồ'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_MONSTER': {'Service': '1',
#   'Data': 'Không thể di chuyển vì bạn đã ở cách quái vật %d m.'},
#  'UIIT_MSG_QUEST_FAIL_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Đã thất bại trong việc bắt giữ quái vật.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_CHATTING_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn đang làm nhiệm vụ nên không thể tán gẫu được.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MOVING_IN_DUNGEON': {'Service': '1',
#   'Data': 'Đã ra khỏi vị trí chỉ định nên không thể di chuyển được nữa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_DO_IT_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này vì bạn đang làm một nhiệm vụ khác có liên quan.'},
#  'UIIT_MSG_QUEST_ERR_TOO_LOW_LEVEL': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này do cấp độ của bạn còn thấp'},
#  'UIIT_MSG_QUEST_END_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ kết thúc sau %d phút'},
#  'UIIT_MSG_QUEST_START_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ bắt đầu trong %d giây (s)'},
#  'UIIT_MSG_QUEST_ERR_USE_WHANITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật này trong trạng thái Cuồng nộ'},
#  'UIIT_MSG_QUEST_ERR_CAPTUREMONSTER_ATTACK': {'Service': '1',
#   'Data': 'Không thể tấn công quái vật đã sập bẫy'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Không thể bắt quái vật thì khoảng cách quá xa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì đã đặt bẫy rồi'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_EXIST_MONSTER': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì quái vật ở quá gần'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật vì điều kiện nhiệm vụ không cho phép'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_WRONG_PLACE': {'Service': '1',
#   'Data': 'Không thể đặt bẫy trong khu vực này'},
#  'UIIT_MSG_QUEST_ERR_NO_TARGET': {'Service': '1',
#   'Data': 'Mệnh lệnh không thể thực thi do chưa chọn đối tượng'},
#  'UIIT_MSG_CANNOT_BUYBACK_ITEM_SELL': {'Service': '1',
#   'Data': 'Đồ vật không thể mua lại được. Bạn có chắc muốn bán nó đi không?'},
#  'UIIT_MSG_QUEST_INS_TIMEOUT': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ hoàn htành sau %d giây, bạn sẽ được trở lại vị trí ban đầu.'},
#  'UIIT_MSG_QUEST_INS_CONDITION': {'Service': '1',
#   'Data': 'Bạn sẽ trở lại vị trí ban đầu trong 5 giây nữa vì nhận được yêu cầu không thể ở lại khu vực hiện tại.'},
#  'UIIT_MSG_QUEST_INS_DEATH': {'Service': '1',
#   'Data': 'Không thể chuyển đến khu vực khác khi nhân vật của bạn đang bị chết'},
#  'UIIT_MSG_DROP_WARNING_1': {'Service': '1',
#   'Data': 'Nếu bạn vứt đồ vật này ra ngoài, thì bạn sẽ mất đi quyền sở hữu đồ vật này'},
#  'UIIT_MSG_DROP_WARNING_2': {'Service': '1',
#   'Data': 'Người khác có thể nhật chúng. Bạn có chắc là muốn vứt nó ra không?'},
#  ...}

# %% [markdown]
# ## TextQuest_Speech&Name.txt

# %%
text_quest_speech_name = os.path.join(server_dep, 'TextQuest_Speech&Name.txt')
text_quest_speech_name
# Out:
# 'server_dep\\silkroad\\textdata\\TextQuest_Speech&Name.txt'

# %%
text_quest_speech_name_files = get_lines(text_quest_speech_name)
text_quest_speech_name_files
# Out:
# ['TextQuest_Speech&Name_100.txt',
#  'TextQuest_Speech&Name_1000.txt',
#  'TextQuest_Speech&Name_1100.txt',
#  'TextQuest_Speech&Name_1200.txt',
#  'TextQuest_Speech&Name_1300.txt',
#  'TextQuest_Speech&Name_1400.txt',
#  'TextQuest_Speech&Name_1500.txt',
#  'TextQuest_Speech&Name_1600.txt',
#  'TextQuest_Speech&Name_1700.txt',
#  'TextQuest_Speech&Name_1800.txt',
#  'TextQuest_Speech&Name_1900.txt',
#  'TextQuest_Speech&Name_200.txt',
#  'TextQuest_Speech&Name_2000.txt',
#  'TextQuest_Speech&Name_2100.txt',
#  'TextQuest_Speech&Name_2200.txt',
#  'TextQuest_Speech&Name_2300.txt',
#  'TextQuest_Speech&Name_2400.txt',
#  'TextQuest_Speech&Name_2500.txt',
#  'TextQuest_Speech&Name_2600.txt',
#  'TextQuest_Speech&Name_2700.txt',
#  'TextQuest_Speech&Name_2800.txt',
#  'TextQuest_Speech&Name_2900.txt',
#  'TextQuest_Speech&Name_300.txt',
#  'TextQuest_Speech&Name_3000.txt',
#  'TextQuest_Speech&Name_3100.txt',
#  'TextQuest_Speech&Name_3200.txt',
#  'TextQuest_Speech&Name_3300.txt',
#  'TextQuest_Speech&Name_3400.txt',
#  'TextQuest_Speech&Name_3500.txt',
#  'TextQuest_Speech&Name_3600.txt',
#  'TextQuest_Speech&Name_3700.txt',
#  'TextQuest_Speech&Name_3800.txt',
#  'TextQuest_Speech&Name_3900.txt',
#  'TextQuest_Speech&Name_400.txt',
#  'TextQuest_Speech&Name_4000.txt',
#  'TextQuest_Speech&Name_4100.txt',
#  'TextQuest_Speech&Name_4200.txt',
#  'TextQuest_Speech&Name_4300.txt',
#  'TextQuest_Speech&Name_4400.txt',
#  'TextQuest_Speech&Name_4500.txt',
#  'TextQuest_Speech&Name_4600.txt',
#  'TextQuest_Speech&Name_4700.txt',
#  'TextQuest_Speech&Name_4800.txt',
#  'TextQuest_Speech&Name_4900.txt',
#  'TextQuest_Speech&Name_500.txt',
#  'TextQuest_Speech&Name_5000.txt',
#  'TextQuest_Speech&Name_5100.txt',
#  'TextQuest_Speech&Name_5200.txt',
#  'TextQuest_Speech&Name_5300.txt',
#  'TextQuest_Speech&Name_5400.txt',
#  'TextQuest_Speech&Name_5500.txt',
#  'TextQuest_Speech&Name_5600.txt',
#  'TextQuest_Speech&Name_5700.txt',
#  'TextQuest_Speech&Name_5800.txt',
#  'TextQuest_Speech&Name_5900.txt',
#  'TextQuest_Speech&Name_600.txt',
#  'TextQuest_Speech&Name_6000.txt',
#  'TextQuest_Speech&Name_6100.txt',
#  'TextQuest_Speech&Name_6200.txt',
#  'TextQuest_Speech&Name_6300.txt',
#  'TextQuest_Speech&Name_6400.txt',
#  'TextQuest_Speech&Name_6500.txt',
#  'TextQuest_Speech&Name_6600.txt',
#  'TextQuest_Speech&Name_6700.txt',
#  'TextQuest_Speech&Name_6800.txt',
#  'TextQuest_Speech&Name_6900.txt',
#  'TextQuest_Speech&Name_700.txt',
#  'TextQuest_Speech&Name_7000.txt',
#  'TextQuest_Speech&Name_7100.txt',
#  'TextQuest_Speech&Name_7200.txt',
#  'TextQuest_Speech&Name_800.txt',
#  'TextQuest_Speech&Name_900.txt',
#  '']

# %%
for xxx in text_quest_speech_name_files:
  file_name = os.path.join(server_dep, xxx)
  lines = get_lines(file_name)
  for idx, line in enumerate(lines):
    values = line.split('\t')
    if len(values) < 11:
      continue
    Service = values[0]
    name_str_id = values[2]
    Data = values[10]
    data_text[name_str_id] = {
      "Service": Service,
      "Data": Data
    }
data_text
# Out:
# {'UIC_STT_FONTNAME': {'Service': '1', 'Data': 'Tahoma'},
#  'UIIS_STT_MSG_INSTALL_START': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa"'},
#  'UIIS_STT_MSG_INSTALL_FOLDER': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa" vào thư mục sau'},
#  'UIIS_STT_MSG_INSTALL_END': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt thành công'},
#  'UIIS_STT_INSTALL_FOLDER': {'Service': '1', 'Data': 'Thư mục cài đặt'},
#  'UIIS_STT_INSTALL_FILE': {'Service': '1', 'Data': 'File cài đặt'},
#  'UIIS_CTL_INSTALL': {'Service': '1', 'Data': 'Cài đặt'},
#  'UIIS_CTL_FIND_FOLDER': {'Service': '1', 'Data': 'Tìm kiếm'},
#  'UIIS_CTL_START': {'Service': '1', 'Data': 'Bắt đầu'},
#  'UIIS_CTL_CANCEL': {'Service': '1', 'Data': 'Hủy bỏ'},
#  'UIIS_CTL_CONFIRM': {'Service': '1', 'Data': 'Đồng ý'},
#  'UIIS_MSG_ALREADY_INSTALL': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt'},
#  'UIIS_MSG_UNPACK_ZIP': {'Service': '1',
#   'Data': 'Không thể giải nén Con Đường Tơ Lụa. \\nFile nén bị hỏng.'},
#  'UIIS_MSG_UNPACK_CLOSE': {'Service': '1',
#   'Data': 'Không thể đóng file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_UNPACK_OPEN': {'Service': '1',
#   'Data': 'Không thể mở file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_INSTALL_SPACE': {'Service': '1',
#   'Data': 'Không thể cài đặt do thiếu dung lượng. \\nCần ít nhất %d BYTE dung lượng đĩa'},
#  'UIIS_MSG_BACKBUFFER': {'Service': '1', 'Data': 'Không thể tạo bộ nhớ đệm'},
#  'UIIS_MSG_CHANGE_FOLDER': {'Service': '1',
#   'Data': 'Thư mục cài đặt đã bị thay đổi.\\nKhông thể gỡ bỏ Con Đường Tơ Lụa'},
#  'UIIS_MSG_NOFIND': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa chưa được cài đặt. Việc gỡ bỏ không có tác dụng'},
#  'UIIS_MSG_REMOVE_COMPLETE': {'Service': '1',
#   'Data': 'Tất cả các file đã được xóa bỏ hoàn toàn'},
#  'UIIS_MSG_REMOVE_FAIL': {'Service': '1', 'Data': 'Không thể gỡ bỏ'},
#  'UIIS_STT_DELETE': {'Service': '1', 'Data': 'Xóa thư mục Con Đường Tơ Lụa'},
#  'UIIS_CTL_DELETE': {'Service': '1', 'Data': 'Gỡ bỏ'},
#  'UIIS_CTL_EXIT': {'Service': '1', 'Data': 'Thoát'},
#  'UILM_MSG_PROCESS_ALREADY_EXITS': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đang chạy'},
#  'UILM_MSG_DETECTED_ABNORMAL_PROCESS': {'Service': '1',
#   'Data': 'Phát hiện lỗi chạy chương trình Con Đường Tơ Lụa (Lỗi hệ thống)'},
#  'UILM_MSG_FAILED_LOAD_CLIENT': {'Service': '1',
#   'Data': 'Không thể xác định đặc điểm client. Đang đóng.'},
#  'UILM_MSG_GATEWAY_NOT_IN_SERVICE_CHANNEL': {'Service': '1',
#   'Data': 'Máy chủ đang kiểm tra hoặc không làm việc. Truy cập trang %ssro.vtcgame.vn/ để biết thêm thông tin.'},
#  'UILM_MSG_DRIVER_UPDATE': {'Service': '1',
#   'Data': 'Driver đồ họa của bạn không phải là phiên bản mới nhất. Hãy cập nhật phiên bản mới nhất để xem hình ảnh game đẹp hơn.'},
#  'UILM_MSG_DRIVER_UPDATE_2': {'Service': '1',
#   'Data': 'Không bao giờ xuất hiện lại.'},
#  'UILM_MSG_FAILED_INIT_NETENGINE': {'Service': '1',
#   'Data': 'Không thể khởi chạy NetEngine (Lỗi (%d,%d))'},
#  'UILM_MSG_FAILED_LOAD_VERSION': {'Service': '1',
#   'Data': 'Không thể kiểm tra phiên bản'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_IP': {'Service': '1',
#   'Data': 'Không thể kiểm tra IP kết nối'},
#  'UILM_MSG_INVALID_CONNECT_IP': {'Service': '1',
#   'Data': 'IP kết nối không hợp lệ'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_PORT': {'Service': '1',
#   'Data': 'Không thể kiểm tra cổng kết nối'},
#  'UILM_MSG_INVALID_CONNECT_PORT': {'Service': '1',
#   'Data': 'Cổng kết nối không hợp lệ'},
#  'UILM_MSG_DETECTED_ABNORMAL_DIRECTX': {'Service': '1',
#   'Data': 'DirectX 9.0 chưa được cài đặt hoặc không phải là phiên bản 9.0b. Con Đường Tơ Lụa cần DirectX9.0b hoặc phiên bản mới hơn'},
#  'UILM_MSG_DETECTED_ABNORMAL_MODULE': {'Service': '1',
#   'Data': 'Không xác định client. Kết thúc.'},
#  'UILM_MSG_DETECTED_PATCH_DIABLE': {'Service': '1',
#   'Data': 'Bạn phải cài đặt toàn bộ phiên bản. Kết nối với trang chủ để download toàn bộ phiên bản.'},
#  'UILM_MSG_DETECTED_PATCH_MANUAL': {'Service': '1',
#   'Data': 'Bạn cần cài đặt thủ công. Vui lòng truy cập trang chủ để tải bản cài thủ công về. Bạn có muốn kết nối đến trang chủ không?'},
#  'UILM_MSG_FAILED_EXECUTE_EXPLORER': {'Service': '1',
#   'Data': 'Không thể chạy Internet Explorer.'},
#  'UILM_MSG_FAILED_PATCH': {'Service': '1',
#   'Data': 'Chưa hoàn thành việc sửa lỗi. Hãy thử lại.[Lỗi số(%d)]'},
#  'UILM_MSG_FAILED_EXECUTE_CLIENT': {'Service': '1',
#   'Data': 'Xin lỗi. Không thể chạy Con Đường Tơ Lụa [Lỗi số(%d)]'},
#  'UILM_MSG_NOTEXITS_REPLACERFILE': {'Service': '1',
#   'Data': 'Không tìm thấy file replacer.exe. Chưa hoàn thành việc sửa lỗi.'},
#  'UILM_MSG_DETECTED_ABNORMAL_REPLACERFILE': {'Service': '1',
#   'Data': 'Không thể sửa lỗi vì file replacer.exe đã bị hỏng [lỗi số (%d)]'},
#  'UILM_MSG_FAILED_LOAD_GATEWAY_INFO': {'Service': '1',
#   'Data': 'Không thể đưa ra thuộc tính kết nối của GateWay [lỗi%d]'},
#  'UILM_STT_DIVISION': {'Service': '1', 'Data': 'Bộ phận'},
#  'UILM_STT_DIVISION_LIST': {'Service': '1', 'Data': 'Danh sách bộ phận'},
#  'UILM_STT_DIVISION_SELECTED': {'Service': '1', 'Data': 'Bộ phận lựa chọn'},
#  'UILM_STT_DIVISION_NAME': {'Service': '1', 'Data': 'Tên bộ phận'},
#  'UILM_STT_FARM': {'Service': '1', 'Data': 'Giải'},
#  'UILM_STT_FARM_LIST': {'Service': '1', 'Data': 'Danh sách giải'},
#  'UILM_STT_FARM_NAME': {'Service': '1', 'Data': 'Tên giải'},
#  'FARM0101': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 01 Yahoo'},
#  'FARM0102': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 01 Yahoo'},
#  'FARM0103': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 01 Yahoo'},
#  'FARM0104': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 01 Yahoo'},
#  'FARM0105': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 01 Yahoo'},
#  'FARM0201': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 02 Yahoo'},
#  'FARM0202': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 02 Yahoo'},
#  'FARM0203': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 02 Yahoo'},
#  'FARM0204': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 02 Yahoo'},
#  'FARM0205': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 02 Yahoo'},
#  'FARM0301': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 03 Yahoo'},
#  'FARM0302': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 03 Yahoo'},
#  'FARM0303': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 03 Yahoo'},
#  'FARM0304': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 03 Yahoo'},
#  'FARM0305': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 03 Yahoo'},
#  'FARM0401': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 04 Yahoo'},
#  'FARM0402': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 04 Yahoo'},
#  'FARM0403': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 04 Yahoo'},
#  'FARM0404': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 04 Yahoo'},
#  'FARM0405': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 04 Yahoo'},
#  'UILM_STT_DIVISION_PING': {'Service': '1', 'Data': 'Ping'},
#  'UILM_STT_DIVISION_CONDITION': {'Service': '1', 'Data': 'Tình trạng'},
#  'DIV01': {'Service': '1', 'Data': 'Bộ phận Yahoo 01'},
#  'DIV02': {'Service': '1', 'Data': 'Bộ phận Yahoo 02'},
#  'DIV03': {'Service': '1', 'Data': 'Bộ phận Yahoo 03'},
#  'DIV04': {'Service': '1', 'Data': 'Bộ phận Yahoo 04'},
#  'DIV05': {'Service': '1', 'Data': 'Bộ phận Yahoo 05'},
#  'DIV06': {'Service': '1', 'Data': 'Bộ phận Yahoo 06'},
#  'DIV07': {'Service': '1', 'Data': 'Bộ phận Yahoo 07'},
#  'DIV08': {'Service': '1', 'Data': 'Bộ phận Yahoo 08'},
#  'DIV09': {'Service': '1', 'Data': 'Bộ phận Yahoo 09'},
#  'DIV10': {'Service': '1', 'Data': 'Bộ phận Yahoo 10'},
#  'UILM_STT_DIVISION_RECOMMENDATION': {'Service': '1', 'Data': 'Đề nghị'},
#  'UILM_STT_DIVISION_NOT_RECOMMENDATION': {'Service': '1',
#   'Data': 'Không đề nghị'},
#  'UILM_MSG_SILKROAD_STARTING_HOME': {'Service': '1',
#   'Data': 'Trang chủ của Con đường tơ lụa đã được đặt làm trang chủ mặc định'},
#  'UILM_MSG_YAHOO_STARTING_HOME': {'Service': '1',
#   'Data': 'Đã thiết đặt xong trang chủ https://sro.vtcgame.vn/'},
#  'UILM_MSG_YAHOO_TOOLBAR': {'Service': '1',
#   'Data': 'Đã thiết đặt xong thanh công cụ yahoo'},
#  'UILM_MSG_SERVICE_CLIENT_ERROR_REINSTALL': {'Service': '1',
#   'Data': 'Client của bạn bị lỗi hoặc đã bị phá huỷ nên không thể kết nối đến máy chủ. Hãy cài lại một client mới.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ download bị ngắt. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CANCEL': {'Service': '1',
#   'Data': 'Kết nới với máy chủ download đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_SELECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Launcher sẽ được khởi động lại.'},
#  'UILM_TEXT_CONFIG_GRAPHIC_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UILM_TEXT_CONFIG_GRAPHIC_NORMAL': {'Service': '1', 'Data': 'Bình thường'},
#  'UILM_TEXT_CONFIG_GRAPHIC_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UILM_TEXT_CONFIG_GRAPHIC_USER_DEF': {'Service': '1', 'Data': 'Không đổi'},
#  'UIIT_STT_ETCKEY': {'Service': '1', 'Data': 'Các phím khác'},
#  'UIIT_STT_MOUSE': {'Service': '1', 'Data': 'Chuột'},
#  'UIIT_STT_MOUSE_RIGHT_BUTTON': {'Service': '1', 'Data': 'Ô Nhớ Chuột'},
#  'UIIT_STT_USE_WHEEL_TO_CHANGE_SIGHT': {'Service': '1',
#   'Data': 'Chuột lăn (đổi góc nhìn) chuột phải (dùng Ô Nhớ)'},
#  'UIIT_STT_USE_WHEEL_TO_USE_SKILL': {'Service': '1',
#   'Data': 'Chuột lăn (dùng Ô Nhớ) chuột phải (đổi góc nhìn)'},
#  'UIIT_STT_ITEM_GET': {'Service': '1', 'Data': 'Nhặt đồ'},
#  'UIIT_STT_REFLECT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng phản xạ'},
#  'UIIT_STT_WATER_DETAIL': {'Service': '1', 'Data': 'Chi tiết nước'},
#  'UIIT_STT_LIGHT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng ánh sáng'},
#  'UIIT_STT_BUMP_MAPPING': {'Service': '1', 'Data': 'ánh xạ va chạm'},
#  'UIIT_STT_ENVIRONMENT_MAPPING': {'Service': '1', 'Data': 'ánh xạ môi trường'},
#  'UIIT_STT_LENS_FLAIR': {'Service': '1', 'Data': 'Độ nhạy của thấu kính'},
#  'UIIT_STT_DYNAMIC_ANIMATION': {'Service': '1', 'Data': 'ảnh động sống động'},
#  'UIIT_STT_WATER_REFLECTION': {'Service': '1', 'Data': 'Phản xạ nước'},
#  'UIIT_STT_FILTERING': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_TEXTER_DETAIL': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_GRAPHIC_QUALITY': {'Service': '1', 'Data': 'Chất lượng đồ họa'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL': {'Service': '1',
#   'Data': 'Người dùng tự chọn'},
#  'UIIT_STT_GRAPHIC_QUALITY_USER_CONTROL': {'Service': '1', 'Data': 'Tự chọn'},
#  'UIIT_STT_METAL_DETAIL': {'Service': '1', 'Data': 'Chất liệu kim loại'},
#  'UIIT_STT_BLOOM_EFFECT': {'Service': '1', 'Data': 'Âm lượng'},
#  'UIIT_STT_GRAPHIC': {'Service': '1', 'Data': 'Đồ họa'},
#  'UIIT_STT_RESOLUTION': {'Service': '1', 'Data': 'Độ phân giải'},
#  'UIIT_STT_LUMINOSITY': {'Service': '1', 'Data': 'Độ sáng tối'},
#  'UIIT_STT_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn'},
#  'UIIT_STT_CHAR_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn nhân vật'},
#  'UIIT_STT_SCENERY_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn bối cảnh'},
#  'UIIT_STT_SHADOW_DETAIL': {'Service': '1', 'Data': 'Chi tiết bóng'},
#  'UIIT_STT_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_MIDDLE': {'Service': '1', 'Data': 'Vừa'},
#  'UIIT_STT_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_VERY_DARK': {'Service': '1', 'Data': 'Rất tối'},
#  'UIIT_STT_DARK': {'Service': '1', 'Data': 'Tối'},
#  'UIIT_STT_NORMAL': {'Service': '1', 'Data': 'Trung bình'},
#  'UIIT_STT_LIGHT': {'Service': '1', 'Data': 'Sáng'},
#  'UIIT_STT_VERY_LIGHT': {'Service': '1', 'Data': 'Rất sáng'},
#  'UIIT_STT_SIGHT_VERY_SMALL': {'Service': '1', 'Data': 'Rất hẹp'},
#  'UIIT_STT_SIGHT_SMALL': {'Service': '1', 'Data': 'Hẹp'},
#  'UIIT_STT_SIGHT_LARGE': {'Service': '1', 'Data': 'Rộng'},
#  'UIIT_STT_SIGHT_VERY_LARGE': {'Service': '1', 'Data': 'Rất rộng'},
#  'UIIT_STT_NONE': {'Service': '1', 'Data': 'Không có'},
#  'UIIT_STT_CIRCLE': {'Service': '1', 'Data': 'Vòng tròn'},
#  'UIIT_STT_DETAIL': {'Service': '1', 'Data': 'Chi tiết'},
#  'UIIT_STT_RANK': {'Service': '1', 'Data': '%d bước'},
#  'UIIT_STT_ON': {'Service': '1', 'Data': 'Bật'},
#  'UIIT_STT_OFF': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_GRAPHIC_QUALITY_MIDDLE': {'Service': '1', 'Data': 'Bình thường'},
#  'UIIT_STT_GRAPHIC_QUALITY_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL1': {'Service': '1', 'Data': 'Đồ họa 1'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL2': {'Service': '1', 'Data': 'Đồ họa 2'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_WAR': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_USER': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_VIDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể thay đổi độ phân giải của game'},
#  'UIIT_STT_VIDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể thay đổi độ sáng của game'},
#  'UIIT_STT_VIDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể thay đổi chất lượng đồ hoạ của game. Tìm đến lựa chọn Video và thiết lập các mức độ cao, trung bình hay thấp. Tốc độ tải trò chơi sẽ thay đổi tuỳ theo các mức chất lượng được thiết lập.'},
#  'UIIT_STT_VIDIO_TTDESC_04': {'Service': '1',
#   'Data': 'Có thể thay đổi mức độ chi biết bóng. Tốc độ tải game có thể bị chậm nếu chi tiết bóng được đặt ở mức cao.'},
#  'UIIT_STT_VIDIO_TTDESC_05': {'Service': '1',
#   'Data': 'Khi thiết lập khung cảnh được đặt ở mức cao, có thể nhìn thấy nhiều hình ảnh hơn, tuy nhiên, điều này cũng sẽ làm chậm tốc độ tải game. Có thể thiết lập ở mức thấp, khi đó sẽ chỉ nhìn thấy những khung cảnh ở gần.'},
#  'UIIT_STT_VIDIO_TTDESC_06': {'Service': '1',
#   'Data': 'Khi các thông tin ở nhân vật, quái vật, lâu đài... được lựa chọn hiển thị nhiều, bạn sẽ biết đầy đủ thông tin hơn nhưng như vậy có thể gây chậm tốc độ tải game.'},
#  'UIIT_STT_VIDIO_TTDESC_07': {'Service': '1',
#   'Data': 'Lựa chọn chi tiết bóng nước để hiển thị các hình ảnh được phản chiếu trên mặt nước.'},
#  'UIIT_STT_VIDIO_TTDESC_08': {'Service': '1',
#   'Data': 'Chi tiết nước được lựa chọn với các mức độ hiệu ứng mặt nước, nếu lựa chọn mức độ cao, cảnh mặt nước sẽ đẹp hơn nhưng tốc độ tải game sẽ bị chậm đi.'},
#  'UIIT_STT_VIDIO_TTDESC_09': {'Service': '1',
#   'Data': 'Chi tiết hiển thị kim loại, nếu được lựa chọn, sẽ hiển thị các hiệu ứng ánh kim trên đồ vật kim loại như giáp, vũ khí. Mức độ lựa chọn càng cao thì chất lượng đồ hoạ cũng tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_10': {'Service': '1',
#   'Data': 'Hiệu ứng ánh sáng chỉ hiệu ứng của đèn khi chiếu trên bề mặt đồ vật, khi lựa chọn mức độ hiển thị ánh sáng cao thì độ thật của đồ vật sẽ tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_11': {'Service': '1',
#   'Data': 'Chi tiết chất liệu chỉ mức độ chi tiết của chất liệu. Chất lượng hiển thị chất liệu của đồ vật sẽ tăng lên khi chi tiết chất liệu được lựa chọn ở mức độ cao.'},
#  'UIIT_STT_VIDIO_TTDESC_12': {'Service': '1',
#   'Data': 'Chi tiết thấu kính chỉ tình trạng chiếu sáng giống như một máy quay phim đang hướng về phía mặt trời.'},
#  'UIIT_STT_VIDIO_TTDESC_13': {'Service': '1',
#   'Data': 'Hiệu ứng nở hoa chỉ tình trạng hoà trộn màu sắc giống như muôn ngàn bông hoa đang nở.'},
#  'UIIT_STT_VIDIO_TTDESC_14': {'Service': '1',
#   'Data': 'Chuyển động học chỉ kỹ thuật chuyển động của các động tác, chuyển động của tóc...'},
#  'UIIT_STT_VIDIO_TTDESC_15': {'Service': '1',
#   'Data': 'Bù đắp các phác thảo thô để các đổi tượng trong tự nhiên hơn.'},
#  'UIIT_STT_VIDIO_TTDESC_16': {'Service': '1',
#   'Data': 'Tắt hiệu ứng skill để hệ thống chạy mượt hơn'},
#  'UIIT_STT_VIDIO_TTDESC_17': {'Service': '1',
#   'Data': 'Khi được trang bị bộ đồ chiến đấu lớn, người chơi gần đó sẽ được nâng cao khả năng chiến trận'},
#  'UIIT_STT_VIDIO_TTDESC_18': {'Service': '1',
#   'Data': 'Hiển thị các hiệu ứng của tất cả các đối tượng trên màn hình chi tiết, và ánh kim loại có thể không kiểm soát được. Tùy chọn này được bất hoạt cho hình ảnh đồ họa thấp.'},
#  'UIIT_STT_GAMESET_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của thú như thú nuôi, thú thồ hàng…'},
#  'UIIT_STT_GAMESET_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của người chơi cùng nhóm'},
#  'UIIT_STT_GAMESET_TTDESC_03': {'Service': '1',
#   'Data': 'Báo động khi HP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_04': {'Service': '1',
#   'Data': 'Báo động khi MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_05': {'Service': '1',
#   'Data': 'Báo động thành tiếng khi HP/MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_AUDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể lựa chọn nhạc nền, bật/tắt/điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh pha trộn, bật/tắt điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh theo khu vực, bật/tắt, điều chỉnh âm lượng'},
#  'UIIT_STT_VIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn tự do'},
#  'UIIT_STT_VIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn từ nhân vật thứ ba để theo dõi bản thân từ sau lưng'},
#  'UIIT_STT_VIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn 1/4, tình trạng không thể thay đổi chất lượng màn hình cao/thấp'},
#  'UIIT_STT_INPUT_TTDESC_01': {'Service': '1',
#   'Data': 'sử dụng chuột hoặc phím tắt để thay đổi tầm nhìn.'},
#  'UIIT_STT_INPUT_TTDESC_02': {'Service': '1',
#   'Data': 'Để thay đổi tầm nhìn, sử dụng chuột phải hoặc phím tắt.'},
#  'UIIT_STT_INPUT_TTDESC_03': {'Service': '1',
#   'Data': 'Mở cửa sổ thông tin nhân vật để kiểm tra các thông tin cơ bản về nhân vật như trang bị, chỉ số sức mạnh/trí tuệ...'},
#  'UIIT_STT_INPUT_TTDESC_04': {'Service': '1',
#   'Data': 'Mở cửa sổ kỹ năng để có thể xem /học các kỹ năng, tăng/giảm chỉ số Tuyệt Kỹ.'},
#  'UIIT_STT_INPUT_TTDESC_05': {'Service': '1',
#   'Data': 'Mở cửa sổ nhóm để có thể lập nhóm, gia nhập nhóm hoặc thiết lập các điều kiện của nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_06': {'Service': '1',
#   'Data': 'Mở cửa sổ cộng đồng. Các thông tin về Hội hoặc tin nhắn, danh sách bạn bè... có thể tìm thấy ở đây.'},
#  'UIIT_STT_INPUT_TTDESC_07': {'Service': '1',
#   'Data': 'sử dụng chế độ Cuồng nộ. Bắt đầu bằng việc nhấn chuột phải lên nút năng lượng to nhất ở ô hiển thị chế độ Cuồng Nộ trên góc trái màn hình.'},
#  'UIIT_STT_INPUT_TTDESC_08': {'Service': '1',
#   'Data': 'Cửa sổ trợ giúp. Giải đáp các thắc mắc cơ bản của người chơi.'},
#  'UIIT_STT_INPUT_TTDESC_09': {'Service': '1',
#   'Data': 'sử dụng các ô nhớ nhanh hoặc bấm chuột phải vào các kỹ năng để thi triển kỹ năng.'},
#  'UIIT_STT_INPUT_TTDESC_10': {'Service': '1',
#   'Data': 'Phím tắt để nhặt đồ tự động trên mặt đất.'},
#  'UIIT_STT_INPUT_TTDESC_11': {'Service': '1',
#   'Data': 'Triệu tập hoặc thu hồi thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_12': {'Service': '1', 'Data': 'Để thú nuôi theo sau.'},
#  'UIIT_STT_INPUT_TTDESC_13': {'Service': '1',
#   'Data': 'Thiết lập chế độ nhặt của thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_14': {'Service': '1',
#   'Data': 'Bạn có thể gửi tin nhắn trực tiếp đến người đã nhắn cho bạn bằng cách nhấn vào nút tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_15': {'Service': '1',
#   'Data': 'Bạn có thể thay đổi thú nuôi bằng cách nhấn nút chuyển đổi thú nuôi khi có nhiều thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_16': {'Service': '1',
#   'Data': 'Mở cửa sổ giả kim thuật. Bạn có thể gia tăng sức mạnh của đồ vật và thêm các tính chất cho đồ vật tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_17': {'Service': '1',
#   'Data': 'Khi tắt chế độ hiển thị đồ vật, mọi thứ như các nhân vật khác, quái vật, thú nuôi... sẽ không được hiển thị ngoại trừ bản thân bạn.'},
#  'UIIT_STT_INPUT_TTDESC_18': {'Service': '1', 'Data': 'Mở hành trang'},
#  'UIIT_STT_INPUT_TTDESC_19': {'Service': '1',
#   'Data': 'Mở cửa sổ hành động. Có rất nhiều phím tắt, icon diễn tả cảm giác hay hành động khác nhau như lập gian hàng, chào hỏi...'},
#  'UIIT_STT_INPUT_TTDESC_20': {'Service': '1',
#   'Data': 'Mở cửa sổ nhiệm vụ để kiểm tra danh sách và thông tin về các nhiệm vụ đang thực hiện.'},
#  'UIIT_STT_INPUT_TTDESC_21': {'Service': '1',
#   'Data': 'Mở toàn bộ bản đồ để kiểm tra vị trí của bản thân và các thành viên trong nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_22': {'Service': '1',
#   'Data': 'Thay đổi tầm nhìn: tầm nhìn tự do --> tầm nhìn từ người thứ ba --> tầm nhìn 1/4 --> lặp lại tầm nhìn tự do'},
#  'UIIT_STT_INPUT_TTDESC_23': {'Service': '1',
#   'Data': 'Kiểm tra tên của các đồ vật dưới đất bằng cách sử dụng phím tắt tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_24': {'Service': '1',
#   'Data': 'Thiết lập chế độ đứng\\ngồi của nhân vật. Khi ngồi, tốc độ hồi phục HP/MP của nhân vật sẽ nhanh hơn.'},
#  'UIIT_STT_INPUT_TTDESC_25': {'Service': '1',
#   'Data': 'Cửa sổ kiểm tra tình trạng của thú nuôi: có thể thiết lập tên của thú nuôi, kiểm tra thông tin thú nuôi tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_26': {'Service': '1', 'Data': 'Thu hồi thú nuôi'},
#  'UIIT_STT_INPUT_TTDESC_27': {'Service': '1',
#   'Data': 'Yêu cầu thú nuôi tấn công'},
#  'UIIT_STT_INPUT_TTDESC_28': {'Service': '1',
#   'Data': 'Có thể sử dụng Hệ thống Siêu thị, tại đây, bạn có thể dùng silk để mua các đồ vật hữu dụng.'},
#  'UIIT_STT_INPUT_TTDESC_29': {'Service': '1',
#   'Data': 'Bạn có thể thiết lập chế độ tự động sử dụng giải dược và thuốc hồi phục, khi đó, việc luyện tập của bạn sẽ dễ dàng hơn.'},
#  'UIIT_STT_INPUT_TTDESC_30': {'Service': '1',
#   'Data': 'Mở cửa sổ gia nhập nhóm. Tại đây, bạn có thể tìm các nhóm đang thiếu thành viên để gia nhập.'},
#  'UIIT_STT_INPUT_TTDESC_31': {'Service': '1',
#   'Data': 'Mở cửa sổ hệ thống gian hàng. Tại đây, bạn có thể dễ dàng tìm thấy các đồ vật được bán trong hệ thống.'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị tên nhân vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị tên quái vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Hiển thị tên Hội'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_04': {'Service': '1',
#   'Data': 'Hiển thị tên các nhân vật khác'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_05': {'Service': '1',
#   'Data': 'Hiển thị tên NPC'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_06': {'Service': '1',
#   'Data': 'Hiển thị biểu tượng cấp độ thấp. Nếu lựa chọn, một dấu hiệu sẽ xuất hiện bên cạnh tên nhân vật của bạn và sẽ biến mất khi bạn lên cấp độ cao.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_01': {'Service': '1',
#   'Data': 'Trong trò chơi có rất nhiều chỉ dẫn được hiển thị dưới dạng tin nhắn ngắn trên cửa sổ trò chuyện. Bạn sẽ tìm thấy các thông tin hữu ích tại đây.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_02': {'Service': '1',
#   'Data': 'Cho phép hiển thị cửa sổ chú ý. Các chỉ dẫn chi tiết sẽ được hiển thị hoặc kiểm tra các thông tin quan trọng khi chuyển sang hệ thống mới. Sẽ rất hữu dụng khi bạn mới gia nhập trò chơi.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_03': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_04': {'Service': '1',
#   'Data': 'Ẩn hệ thống Windows một cách tự động. Nếu sử dụng chức năng này, khung của hệ thống Windows sẽ ẩn đi một cách tự động và chỉ xuất hiện trở lại khi bạn đưa con trỏ chuột lên trên.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_05': {'Service': '1',
#   'Data': 'Chuyển màn hình trò chơi sang chế độ cửa sổ. Bạn có thể sử dụng chế độ cửa sổ theo sở thích.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_06': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu mời vào nhóm. Nếu không sử dụng lựa chọn này, mọi lời mời vào nhóm gửi đến sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_07': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu giao dịch. Nếu không sử dụng chọn lựa này, mọi yêu cầu giao dịch gửi đến sẽ bị từ chối. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_08': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn cá nhân. Nếu không chọn chức năng này, mọi tin nhắn cá nhân sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_09': {'Service': '1',
#   'Data': 'Thể hiện thông tin về các trạng thái tăng cường của nhân vật trong phần thông tin nhân vật thuộc nhóm. Nếu không lựa chọn chức năng này, các thông tin sẽ không thể hiện. Không quan sát được trạng thái dị trạng của nhân vật.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_10': {'Service': '1',
#   'Data': 'Khởi động nhanh trò chơi bằng việc nạp hình ảnh bối cảnh trước khi nạp hình ảnh nhân vật. Đánh dấu vào ô này nếu bạn muốn trò chơi khởi động nhanh hơn.'},
#  'UIIT_MSG_CHATWND_HELP_WHISPER': {'Service': '1',
#   'Data': 'Thì thầm  [$tênnhânvật những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_PARTYMSG': {'Service': '1',
#   'Data': 'Tán gẫu trong nhóm [#những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_USECONTROLATSTORE': {'Service': '1',
#   'Data': 'Nếu bạn ấn phím Ctrl, bạn có thể bán hoặc mua đồ nhanh hơn'},
#  'UIIT_MSG_NOTIFY': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_MSG_CHATWND_MESSAGE_FILTER': {'Service': '1',
#   'Data': 'Một số từ ngữ hoặc cách diễn đạt bị cấm dùng'},
#  'UIIT_STT_GAMEGUIDE_START_1': {'Service': '1',
#   'Data': 'Hãy tìm hiểu những thông tin cơ bản về Con Đường Tơ Lụa và làm quen với những thông tin này trước. Thông qua cửa sổ tán gẫu bạn có thể học được thêm những chỉ dẫn vì vậy hãy luyện thói quen thật chú ý tới những hướng dẫn này. Chắc chắn bạn sẽ thu được những thông tin rất bổ ích.'},
#  'UIIT_STT_GAMEGUIDE_START_2': {'Service': '1',
#   'Data': '※ Hướng dẫn trò chơi có thể được sử dụng bất kỳ lúc nào bằng việc bấm phím  [H]'},
#  'UIIT_STT_GAMEGUIDE': {'Service': '1', 'Data': 'Trợ giúp'},
#  'UIIT_STT_EVENTGUIDE': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_QUESTGUIDE1': {'Service': '1', 'Data': 'Nhiệm vụ'},
#  'UIIT_STT_QUESTGUIDE2': {'Service': '1', 'Data': 'Từ điển nhiệm vụ'},
#  'UIIT_STT_GAMEEVENTGUIDE': {'Service': '1', 'Data': 'Hướng dẫn'},
#  'UIIT_STT_CONFIRM_BOX': {'Service': '1', 'Data': 'Cửa sổ xác nhận'},
#  'UIIT_STT_AGREEMENT_BOX': {'Service': '1', 'Data': 'Cửa sổ đồng ý'},
#  'UIIT_STT_INPUT_BOX': {'Service': '1', 'Data': 'Cửa sổ nhập vào'},
#  'UIIT_PAG_WORLDMAP': {'Service': '1', 'Data': 'Bản đồ lớn'},
#  'UIIT_PAG_LOCALMAP': {'Service': '1', 'Data': 'Bản đồ khu vực'},
#  'UIIT_STT_BACK_WORLDMAP': {'Service': '1', 'Data': 'Mở bản đồ lớn'},
#  'UIIT_STT_JANGAN': {'Service': '1', 'Data': 'Trường An'},
#  'UIIT_STT_DONHWANG': {'Service': '1', 'Data': 'Đôn Hoàng'},
#  'UIIT_STT_KHOTAN': {'Service': '1', 'Data': 'Hòa Điền'},
#  'UIIT_STT_SAMARKAND': {'Service': '1', 'Data': 'Samarkand'},
#  'UIIT_STT_CONSTANTINOPLE': {'Service': '1', 'Data': 'Constantinople'},
#  'UIIT_STT_BIJEOKDAN': {'Service': '1', 'Data': 'Bijeokdan'},
#  'UIIT_STT_HEUKMAKDAN': {'Service': '1', 'Data': 'Heukmakdan'},
#  'UIIT_STT_EVILORDER': {'Service': '1', 'Data': 'Pháo đài tà ác'},
#  'UIIT_STT_ARABIA_CITY': {'Service': '1', 'Data': 'Baghdad'},
#  'UIIT_STT_ARABIA_CITY_DUNGEON': {'Service': '1', 'Data': 'Baghdad (Phụ bản)'},
#  'UIIT_STT_MUHAN': {'Service': '1', 'Data': 'Đấu trường Vô Cực'},
#  'UIIT_MSG_CHEATMSG_GO_TOWN': {'Service': '1', 'Data': '/town'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_1': {'Service': '1',
#   'Data': 'Tìm thấy macro (chơi tự động) trong nhân vật đang chơi. Tự động thoát.'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_2': {'Service': '1',
#   'Data': 'Tên của nhân vật có macro và thời gian đã sử dụng sẽ được ghi lại trên máy chủ'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_3': {'Service': '1',
#   'Data': 'Có thể áp dụng hình phạt giới hạn về thời gian của tài khoản và khóa tài khoản'},
#  'UIIT_MSG_APPEAR_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa xuất hiện ở Hổ Huyệt Sơn'},
#  'UIIT_MSG_APPEAR_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã xuất hiện'},
#  'UIIT_MSG_APPEAR_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi xuất hiện ở Karakoram'},
#  'UIIT_MSG_APPEAR_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan xuất hiện ở Taklamakan'},
#  'UIIT_MSG_APPEAR_TAHOMET': {'Service': '1',
#   'Data': 'Sa Y Thần xuất hiện ở Lạc Khắc Sơn'},
#  'UIIT_MSG_APPEAR_UNIC': {'Service': '1', 'Data': '[%s] đã xuất hiện'},
#  'UIIT_MSG_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn đã biến mất'},
#  'UIIT_MSG_DEAD_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã biến mất'},
#  'UIIT_MSG_DEAD_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi từ Karakoram đã biến mất'},
#  'UIIT_MSG_DEAD_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan từ Taklamakan đã biến mất'},
#  'UIIT_MSG_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã biến mất'},
#  'UIIT_MSG_ANYONE_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': '[%s] đã giết Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_URRUCHI': {'Service': '1',
#   'Data': '[%s] đã giết Ô Lỗ Tề từ Tháp Lý Mộc'},
#  'UIIT_MSG_ANYONE_DEAD_IYUTARU': {'Service': '1',
#   'Data': '[%s] đã giết Băng Chúa Nhi từ Karakoram'},
#  'UIIT_MSG_ANYONE_DEAD_BONELORD': {'Service': '1',
#   'Data': '[%s] đã giết Chúa tể Yarkan từ Taklamakan'},
#  'UIIT_MSG_ANYONE_DEAD_TAHOMET': {'Service': '1',
#   'Data': '[%s] đã giết Sa Y Than từ Lạc Khắc Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã giết [%s]'},
#  'UIIT_STT_ROLL_OF_CLOTH': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILK_BUY_RESULT': {'Service': '1', 'Data': 'Bạn đã mua [%d] silk'},
#  'UIIT_STT_SILK_BUY_CANCLE': {'Service': '1',
#   'Data': 'Việc mua bán [%d] silk đã bị hủy bỏ'},
#  'UIIT_STT_SILK_BUY_RECEIVE': {'Service': '1',
#   'Data': 'Bạn nhận được quà là [%d] silk'},
#  'UIIT_STT_SILK_SEND_RESULT': {'Service': '1',
#   'Data': 'Bạn đã gửi [%d] silk đi làm quà'},
#  'UIIT_STT_SILK_POINT_BUY_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được trả tiền'},
#  'UIIT_STT_SILK_POINT_USE_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được sử dụng'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK': {'Service': '1', 'Data': 'Silk đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_MALL': {'Service': '1', 'Data': 'Cửa hàng Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_MALL': {'Service': '1',
#   'Data': 'Cửa hàng đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_TOTAL': {'Service': '1', 'Data': 'Tổng số Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_TOTAL': {'Service': '1',
#   'Data': 'Tổng số Silk đặc biệt'},
#  'UIIT_STT_SILKMALL': {'Service': '1', 'Data': 'Siêu thị'},
#  'UIIT_STT_SILKMALL_MAIN': {'Service': '1', 'Data': 'Phần chính'},
#  'UIIT_STT_SILKMALL_HOT_STORE': {'Service': '1', 'Data': 'HOT Shop'},
#  'UIIT_STT_SILKMALL_CONSUMPTION': {'Service': '1', 'Data': 'Đồ tiêu dùng'},
#  'UIIT_STT_SILKMALL_LEND_ITEM': {'Service': '1', 'Data': 'Tiền thuê đồ'},
#  'UIIT_STT_SILKMALL_AVATA': {'Service': '1', 'Data': 'Trang trí'},
#  'UIIT_STT_SILKMALL_PET': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PACKAGE': {'Service': '1', 'Data': 'Gói hàng'},
#  'UIIT_STT_SILKMALL_SHOPPING_BASKET_LIST': {'Service': '1',
#   'Data': 'Hàng đã chọn'},
#  'UIIT_STT_SILKMALL_NEW_ITEM': {'Service': '1', 'Data': 'Hàng mới'},
#  'UIIT_STT_SILKMALL_EVENT': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_SPECIAL_COAST': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_FAVORITE': {'Service': '1', 'Data': 'Hàng bán chạy'},
#  'UIIT_STT_SILKMALL_SPECIAL': {'Service': '1', 'Data': 'Đặc biệt'},
#  'UIIT_STT_SILKMALL_SCROLL': {'Service': '1', 'Data': 'Hỗ trợ'},
#  'UIIT_STT_SILKMALL_POTION': {'Service': '1', 'Data': 'Hồi phục'},
#  'UIIT_STT_SILKMALL_COMMUNITY': {'Service': '1', 'Data': 'Cộng đồng'},
#  'UIIT_STT_SILKMALL_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY': {'Service': '1', 'Data': 'Giả kim thuật'},
#  'UIIT_STT_SILKMALL_PREMIUM_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ASTRAL': {'Service': '1', 'Data': 'Tinh thạch'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': 'Bất diệt (bảo toàn 99%)'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_3': {'Service': '1', 'Data': 'Áo nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_4': {'Service': '1', 'Data': 'Quần nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_5': {'Service': '1', 'Data': 'Bao tay'},
#  'UIIT_STT_SILKMALL_ARMOR_6': {'Service': '1', 'Data': 'Giầy nặng'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_3': {'Service': '1', 'Data': 'Áo nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_4': {'Service': '1', 'Data': 'Quần nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_6': {'Service': '1', 'Data': 'Giầy nhẹ'},
#  'UIIT_STT_SILKMALL_CLOSE_1': {'Service': '1', 'Data': 'Khăn'},
#  'UIIT_STT_SILKMALL_CLOSE_2': {'Service': '1', 'Data': 'Cầu vai vải'},
#  'UIIT_STT_SILKMALL_CLOSE_3': {'Service': '1', 'Data': 'Áo vải'},
#  'UIIT_STT_SILKMALL_CLOSE_4': {'Service': '1', 'Data': 'Quần vải'},
#  'UIIT_STT_SILKMALL_CLOSE_6': {'Service': '1', 'Data': 'Giầy vải'},
#  'UIIT_STT_SILKMALL_BIG_STORE': {'Service': '1', 'Data': 'Tiệm lớn'},
#  'UIIT_STT_SILKMALL_ASSIST': {'Service': '1', 'Data': 'Chi nhánh'},
#  'UIIT_STT_SILKMALL_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_HAT': {'Service': '1', 'Data': 'Mũ'},
#  'UIIT_STT_SILKMALL_BOOTH': {'Service': '1', 'Data': 'Gian hàng'},
#  'UIIT_STT_SILKMALL_FIREWORK': {'Service': '1', 'Data': 'Kẹo'},
#  'UIIT_STT_SILKMALL_DRESS': {'Service': '1', 'Data': 'Trang phục'},
#  'UIIT_STT_SILKMALL_ATTACH': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_BALLOON': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_PET_SUMMON': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PET_CONSUME': {'Service': '1', 'Data': 'Thú nuôi hết hạn'},
#  'UIIT_STT_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1', 'Data': 'Mua hết'},
#  'UIIT_STT_SILKMALL_BOOK_MARK': {'Service': '1', 'Data': 'Sổ sách'},
#  'UIIT_STT_SILKMALL_PUT_ON': {'Service': '1', 'Data': 'sử dụng thử'},
#  'UIIT_STT_SILKMALL_BUY': {'Service': '1', 'Data': 'Mua'},
#  'UIIT_STT_SILKMALL_PRESENT': {'Service': '1', 'Data': 'Quà'},
#  'UIIT_STT_SILKMALL_DEL': {'Service': '1', 'Data': 'Xóa'},
#  'UIIT_STT_SILKMALL_BUY_LIST': {'Service': '1', 'Data': 'Hàng mua'},
#  'UIIT_STT_SILKMALL_RECEIVE_LIST': {'Service': '1', 'Data': 'Hàng nhận'},
#  'UIIT_STT_SILKMALL_SILKMALL_OUT': {'Service': '1', 'Data': 'Thoát'},
#  'UIIT_STT_SILKMALL_PUT_ON_CLOSE_BUY': {'Service': '1',
#   'Data': 'Mua đồ thời trang'},
#  'UIIT_STT_SILKMALL_ALL_CLOSE_TAKEOFF': {'Service': '1', 'Data': 'Cởi bỏ'},
#  'UIIT_STT_SILKMALL_ADD_INVENTORY': {'Service': '1', 'Data': 'Ô mở rộng'},
#  'UIIT_STT_SILKMALL_ADD_STOREHOUSE_INVENTORY': {'Service': '1',
#   'Data': 'Kho mở rộng'},
#  'UIIT_STT_SILKMALL_SILK': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILKMALL_BUY_SILK': {'Service': '1', 'Data': 'Mua Silk'},
#  'UIIT_STT_SILKMALL_SEND_SILK': {'Service': '1', 'Data': 'Tặng Silk'},
#  'UIIT_STT_SILKMALL_COUPON_EXCHANGE': {'Service': '1',
#   'Data': 'Trao đổi phiếu'},
#  'UIIT_STT_SILKMALL_BUY_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_03': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_USE_INFOMATION': {'Service': '1',
#   'Data': 'Cách sử dụng Siêu thị'},
#  'UIIT_STT_SILKMALL_ENTER': {'Service': '1', 'Data': 'Vào Siêu thị'},
#  'UIIT_STT_SILKMALL_DIRECT_ENTER': {'Service': '1',
#   'Data': 'Vào nhanh Siêu thị'},
#  'UIIT_STT_SILKMALL_NEW_CASHITEM': {'Service': '1',
#   'Data': 'Siêu thị cập nhật đồ vật mới'},
#  'UIIT_STT_SILKMALL_WARNING_1': {'Service': '1',
#   'Data': 'Bạn có thể bị quái vật'},
#  'UIIT_STT_SILKMALL_WARNING_2': {'Service': '1',
#   'Data': 'hoặc những người chơi khác tấn công trong khi vào Siêu thị'},
#  'UIIT_STT_SILKMALL_WARNING_3': {'Service': '1',
#   'Data': 'Nên sử dụng món đồ trong khu vực an toàn'},
#  'UIIT_STT_SILKMALL_MAIN_EXPLAIN': {'Service': '1',
#   'Data': '<sml2><p line_margin="12"><p line_margin="5"><font color="255,255,153,81" style="bold">Siêu Thị là gì?</font><br>Là nơi bán và cho thuê những trang bị để <br>sử dụng trên Con đường tơ lụa. Những trang bị đó phải sử dụng silk để mua.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Mua Silk</font><br>Silk có thể mua bằng cách bấm vào nút Mua silk ở góc trên bên phải màn hình.<br>Bấm vào nút Mua silk bạn sẽ được chuyển đến trang E-Cash.<br>nơi để bạn mua silk.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Tặng Silk</font><font color="255,255,117,117">(Tính năng chưa kích hoạt)</font><br>Trong quá trình mua đồ trong Siêu Thị, bạn có thể bấm vào nút Tặng Silk để gửi <br>tới người chơi khác món đồ bạn chọn.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Coupons exchanges</font><br>Phiếu giảm giá có thể được sử dụng 1 lần để mua silk hoặc sử dụng các item Mall.<br>Điền con số vào phiếu giảm giá để nhận được silk.<br>Số tiền có thể khác nhau tùy thuộc vào các loại phiếu giảm giá.<br></p></p><strong><font color="255,255,153,81">Sổ sách</font></strong><font color="255,255,117,117">(Tính năng chưa được kích hoạt)</font><br>Tất cả những đồ vật bạn mua trong Siêu Thị có thể được lưu giữ trong sổ sách của bạn <br>bằng cách bấm vào Sổ sách. Đồ vật đã lưu trong Sổ của bạn sẽ được hoàn trả <br>ngay cả khi bạn đã mua đồ vật đó.</sml2>'},
#  'UIIT_STT_SILKMALL_MY_INFO': {'Service': '1', 'Data': 'Thông tin cá nhân'},
#  'UIIT_STT_SILKMALL_POSSESSION_GOLD': {'Service': '1',
#   'Data': 'Số lượng hiện có'},
#  'UIIT_STT_SILKMALL_REMAIN_INVENTORY': {'Service': '1', 'Data': '%d ô trống'},
#  'UIIT_STT_SILKMALL_MAIN_INTRO': {'Service': '1',
#   'Data': '<sml2>Chào mừng quý khách đến với cửa hàng bán đồ chất lượng cao của Con Đường Tơ Lụa</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ORDER_SHEET': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_TOOL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_FLEAMARKET': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_ZZIM': {'Service': '1',
#   'Data': '<sml2>Đây là danh sách hàng bạn đặt mua</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_FAVORITY': {'Service': '1',
#   'Data': '<sml2>Có thể xem danh sách những mặt hàng đã mua hoặc chọn trong phần Sổ sách</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COSETC': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'MALL_CONSUME_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'MALL_CONSUME_SCROLL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'MALL_CONSUME_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'MALL_CONSUME_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'MALL_CONSUME_ETC': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'MALL_AVATAR_BOOTH': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'MALL_AVATAR_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_PET_A_GROWTH': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_SILK': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_VEHICLE': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_CART': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_STORES': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PREMIUM_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'MALL_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'MALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'UIIT_STT_SILKMALL_SHORT_KEY': {'Service': '1', 'Data': 'Siêu thị (F10)'},
#  'UIIT_STT_SILKMALL_BUY_CONFIRM': {'Service': '1', 'Data': 'Xác nhận mua'},
#  'UIIT_STT_SILKMALL_DO_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_POPUP_TITLE': {'Service': '1',
#   'Data': 'Đồ trang trí tồn kho'},
#  'UIIT_STT_SILKMALL_POPUP_ADVERTISING': {'Service': '1',
#   'Data': 'Bán có giới hạn'},
#  'UIIT_STT_SILKMALL_POPUP_DATA': {'Service': '1', 'Data': 'Ngày bán:'},
#  'UIIT_STT_SILKMALL_POPUP_REDUCTION': {'Service': '1',
#   'Data': 'Cho tới khi giảm giá'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_M': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nam)'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_W': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nữ)'},
#  'UIIT_MSG_SILKMALL_ZZIM_CONFIRM': {'Service': '1',
#   'Data': '<sml2><font color="255,255,255,255">Bạn sẽ đặt món đồ này chứ?<br>các món đồ được đặt có thể được chọn và mua một tất cả ở danh sách đặt hàng.</font></sml2>'},
#  'UIIT_MSG_SILKMALL_ZZIM_DELITE': {'Service': '1',
#   'Data': 'Xóa món đồ trong danh sách đặt hàng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1',
#   'Data': 'Bạn sẽ mua luôn số hàng đã đặt chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY_TOTAL': {'Service': '1',
#   'Data': 'Tổng cộng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_1': {'Service': '1',
#   'Data': 'Bạn có hủy số hàng đã đặt không ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_2': {'Service': '1',
#   'Data': 'Nếu bạn hủy bỏ việc sử dụng món đồ đã chọn, hiệu ứng của nó sẽ mất'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE': {'Service': '1',
#   'Data': 'Bạn sẽ dùng món đồ đã chọn chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_REVERSE_PORTAL': {'Service': '1',
#   'Data': 'sử dụng bùa dịch chuyển phản hồi. Hãy chọn điểm đến.'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_RETURN': {'Service': '1',
#   'Data': 'Dịch chuyển tới điểm về cuối'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_DEATH': {'Service': '1',
#   'Data': 'Dịch chuyển tới nơi bạn đã chết'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_INS': {'Service': '1',
#   'Data': 'sử dụng các vật phẩm này bạn sẽ không thể dịch chuyển được'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_GNGWC': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật sau khi kết thúc trận chiến'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_BUY_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không thành công do không đủ silk'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_GIFT': {'Service': '1',
#   'Data': 'Silk không đủ để tặng'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng cho loại đồ vật trang bị'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_SINCE_EQUIP_CLASS_TOO_HIGH': {'Service': '1',
#   'Data': 'Không thể thay đổi giới tính do không phù hợp với cấp độ của đồ vật'},
#  'UIIT_MSG_STRGERR_INVALID_TRANSGENDER_TARGET': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể thay đổi giới tính'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_TELEPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi cuối cùng bạn đã quay lại'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_DIEDPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi bạn đã chết'},
#  'UIIT_MSG_STRGERR_ONLY_THE_DEAD_CAN_USE_RESURRECT_SCROLL': {'Service': '1',
#   'Data': 'Chỉ sử dụng trong tình trạng đã chết'},
#  'UIIT_MSG_STRGERR_THERE_IS_NO_ITEM_TO_REPAIR': {'Service': '1',
#   'Data': 'Không có đồ vật nào cần sửa chữa'},
#  'UIIT_MSG_STRGERR_CANT_QUICKSELL_CASHITEM': {'Service': '1',
#   'Data': 'Không có chức năng mua bán nhanh với những món đồ hiếm.'},
#  'UIIT_MSG_STRGERR_TRADE_FAILURE': {'Service': '1',
#   'Data': 'Giao dịch thất bại không có lý do'},
#  'UIIT_STT_SILKMALL_FAIL_ITEMBUY_LOGOUT': {'Service': '1',
#   'Data': 'Trò chơi sẽ chấm dứt do việc mua đồ Premium thất bại'},
#  'UIIT_STT_SILKMALL_DONOT_USE_TELEPORT': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_MSG_SELL_RECONFIRM': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_PAG_CHAR_SKIN_CHANGE': {'Service': '1',
#   'Data': 'Thay đổi hình dáng bên ngoài của nhân vật'},
#  'UIIT_MSG_CHAR_SKIN_ERR_ARMOR': {'Service': '1',
#   'Data': 'Để thay đổi giới tính phải bỏ đồ bảo hộ và gỡ bỏ hết các ô mở rộng'},
#  'UIIT_MSG_CHAR_SKIN_CHANGE_SUCCESS': {'Service': '1',
#   'Data': 'Thay đổi giới tính thành công'},
#  'UIIT_STT_GUILD_INFO': {'Service': '1', 'Data': 'T.Tin Hội'},
#  'UIIT_CTL_LETTER': {'Service': '1', 'Data': 'Hộp thư kết hợp'},
#  'UIIT_CTL_FRIEND': {'Service': '1', 'Data': 'Bạn'},
#  'UIIT_STT_GUILD_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_GUILD_STAFF': {'Service': '1', 'Data': 'Hội phó'},
#  'UIIT_STT_GUILDSMAN': {'Service': '1', 'Data': 'Hội viên'},
#  'UIIT_STT_GUILDSMAN_NUM': {'Service': '1', 'Data': 'Số'},
#  'UIIT_STT_GUILD_COMMON_KNOW': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_GUILD_COMMON_KNOW_WRITE': {'Service': '1',
#   'Data': 'Viết thông báo'},
#  'UIIT_MSG_GUILD_COMMON_NOTEXIST': {'Service': '1',
#   'Data': 'Không có thông báo'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo (%d/Tối đa.%d)'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_TITLE_REMIND': {'Service': '1',
#   'Data': 'Hãy điền tiêu đề lời thông báo'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT_TITLE': {'Service': '1',
#   'Data': 'Chưa điền tiêu đề'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo'},
#  'UIIT_MSG_GUILDERR_TARGET_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Người chơi khác không có quyền'},
#  'UIIT_CTL_GUILD_WRITE_END': {'Service': '1', 'Data': 'Hoàn thành'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND_UPDATE': {'Service': '1',
#   'Data': 'Thông báo của Hội đã thay đổi'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_JOIN': {'Service': '1',
#   'Data': 'Hội chủ Hội [%s] đề nghị liên minh với bạn, bạn có chấp nhận không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_WITHDRAWA': {'Service': '1',
#   'Data': 'Bạn có muốn rời bỏ liên minh không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_BREAKUP': {'Service': '1',
#   'Data': 'Liên minh đã bị giải tán'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_NOTALLY': {'Service': '1',
# ...
#   'Data': 'Đã khỏi bệnh'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CHAOS': {'Service': '1',
#   'Data': 'Đã khỏi lẫn lộn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_PD': {'Service': '1',
#   'Data': 'Đã khỏi bị thối rữa'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_MD': {'Service': '1',
#   'Data': 'Đã được khoẻ lại'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_STR': {'Service': '1',
#   'Data': 'Đã hết bất lực'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_INT': {'Service': '1',
#   'Data': 'Đã hết bị cô lập'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_HP': {'Service': '1',
#   'Data': 'Đã hết hoảng loạn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSIE_MP': {'Service': '1',
#   'Data': 'Đã hết bị thiêu đốt'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_TIME_BOMB': {'Service': '1',
#   'Data': 'Đã hết ẩn nấp'},
#  'UIIT_MSG_BURN': {'Service': '1', 'Data': 'Thiêu đốt'},
#  'UIIT_MSG_FROSTBITE': {'Service': '1', 'Data': 'Tê cóng'},
#  'UIIT_MSG_FREEZING': {'Service': '1', 'Data': 'Đóng băng'},
#  'UIIT_MSG_SHOCK': {'Service': '1', 'Data': 'Nhiễm điện'},
#  'UIIT_MSG_ZOMBIE': {'Service': '1', 'Data': 'Yểm bùa'},
#  'UIIT_MSG_DARK': {'Service': '1', 'Data': 'Mờ mắt'},
#  'UIIT_MSG_STUN': {'Service': '1', 'Data': 'Choáng'},
#  'UIIT_MSG_PARTYERR_OUT_OF_LEVEL': {'Service': '1',
#   'Data': 'Không thể vào nhóm đó do sự chênh lệch về cấp độ.'},
#  'UIIT_MSG_FLEAMARKET_ERR_IM_BUSY': {'Service': '1',
#   'Data': 'Bạn ở trong tình trạng không được mở gian hàng mới'},
#  'UIIT_MSG_JSERR_SINCE_YOU_DIE_IN_MURDERER_SP_DEPRIVED_BY_SERVER': {'Service': '1',
#   'Data': 'Bị mất [%u] điểm kinh nghiệm'},
#  'UIIT_MSG_INTERACTION_FAIL__REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_PORTAL_SCROLL': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_SUMMON_VEHICLE': {'Service': '1',
#   'Data': 'Không thể dùng thú vận chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_INTERACTION_FAIL_MURDERER_CAN_USE_PORTAL_STRUCTURE': {'Service': '1',
#   'Data': 'Không thể qua cổng dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_FLEAMARKET_ERR_CANT_OPEN_MARKET_MURDERER': {'Service': '1',
#   'Data': 'Không thể mở gian hàng mới trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng item trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_ENABLEINPUT_FEWERTHAN_REMAIN': {'Service': '1',
#   'Data': 'Chỉ có thể nhập số đơn vị còn lại'},
#  'UIIT_MSG_STRGERR_CANNOT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy người chơi khác'},
#  'UIIT_MSG_STRGERR_SPECIFY_POSITIVE_NUMBER_ONLY': {'Service': '1',
#   'Data': 'Số không hợp lệ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi bị hủy bỏ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_BEFORE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi lần trước bị hủy bỏ vì đã thực hiện trao đổi với người chơi khác'},
#  'UIIT_MSG_STRGERR_CANNOT_WITDRAW_MORETHAN_DEPOSIT': {'Service': '1',
#   'Data': '-'},
#  'UIIT_MSG_DEAL_ASK': {'Service': '1',
#   'Data': 'Có người muốn trao đổi với bạn. Bạn chấp nhận chứ?'},
#  'UIIT_MSG_DEAL_ASKING': {'Service': '1', 'Data': 'Trao đổi với [%s]'},
#  'UIIT_MSG_STRGERR_INVALID_TARGET': {'Service': '1',
#   'Data': 'Không thấy mục tiêu'},
#  'UIIT_MSG_STRGERR_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận làm việc khác'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_OPPONENT_INV_SPACE': {'Service': '1',
#   'Data': 'Không thể đưa thêm món đồ đó vào cửa sổ trao đổi vì thùng đồ người kia đã đầy.'},
#  'UIIT_MSG_STRGERR_NON_SETUP_KEY': {'Service': '1',
#   'Data': 'Không thể đặt phím đã lựa chọn'},
#  'UIIT_MSG_STRGERR_CHATING_LIMIT': {'Service': '1',
#   'Data': 'Không thể lặp lại cùng nội dung'},
#  'UIIT_MSG_STRGERR_DEAL_FAIL_NON_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không được thực hiện do không có đồ vật giao dịch'},
#  'UIIT_STT_TARGETTING': {'Service': '1', 'Data': 'Mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTLEARN': {'Service': '1',
#   'Data': 'Kỹ năng không xác định'},
#  'UIIT_SKILL_USE_FAIL_TIMEDELAY_REUSEDELAY': {'Service': '1', 'Data': '-'},
#  'UIIT_SKILL_USE_FAIL_WRONGDISTANCE': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng với mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTENOUGHLEVEL': {'Service': '1',
#   'Data': 'Không sử dụng được vì cấp độ của bạn thấp'},
#  'UIIT_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh người chơi khác vì cấp độ của người đó cao hơn bạn'},
#  'UIIT_CHATERR_CANT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy [%s]'},
#  'UIIT_CHATERR_YOU_ARE_SQUELCHED': {'Service': '1',
#   'Data': 'Chức năng thì thầm của  [%s]đã bị tắt'},
#  'UIIT_CHATERR_NOT_A_PARTY_MEMBER': {'Service': '1',
#   'Data': 'Không ở trong nhóm nào'},
#  'UIIT_CHATERR_INVALID_COMMAND': {'Service': '1',
#   'Data': 'Lệnh chat không hợp lệ'},
#  'UIIT_CHATERR_ALLIANCE_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Không sử dụng được chức năng tán gẫu với đồng minh vì Hội được chọn không phải là đồng minh của bạn'},
#  'UIIT_CHATERR_WHISPER_TO_MESSAGE': {'Service': '1', 'Data': 'Tin đi'},
#  'UIIT_CHATERR_WHISPER_FROM_MESSAGE': {'Service': '1', 'Data': 'Tin đến'},
#  'UIIT_TOOLTIP_PK_DAY': {'Service': '1', 'Data': 'PK hàng ngày %d / %d'},
#  'UIIT_TOOLTIP_PK_TOTAL': {'Service': '1', 'Data': 'Tổng PK %d / %d'},
#  'UIIT_TOOLTIP_PK_PENALTY_TIME': {'Service': '1',
#   'Data': 'Chỉ số PK %d (Cấp độ %d)'},
#  'UIIT_TOOLTIP_PENALTY_GOLD': {'Service': '1', 'Data': 'Phạt %d vàng'},
#  'UIIT_TOOLTIP_JOB_PENALTY_TIME': {'Service': '1',
#   'Data': 'Không được hành nghề trong %d phút'},
#  'UIIT_TOOLTIP_EQUIPMENT_CLASS': {'Service': '1', 'Data': 'Cấp: Cấp %d'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_DROPPED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể bỏ đi'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_PICKED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể lấy được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_TRADED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể mang ra mua bán được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể sửa chữa được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể làm lại được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_USED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể dùng được'},
#  'UIIT_MSG_CANNOT_BE_USED_ITEM_CART': {'Service': '1',
#   'Data': 'Không thể dùng mà không có thú di chuyển/ chuyên chở'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_IN_BATTLE_STATE': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang đánh nhau'},
#  'UIIT_MSG_REMAIN_TIME': {'Service': '1', 'Data': '(còn %d giây)'},
#  'UIIT_MSG_STRGERR_ONLY_ROBBER_CAN_USE_THIS_ITEM': {'Service': '1',
#   'Data': 'Món đồ được chọn chỉ sử dụng được khi làm Đạo Tặc'},
#  'UIIT_MSG_STRGERR_CANT_OPERATE_REQUESTED_JOB_DURING_LOGOUT': {'Service': '1',
#   'Data': 'Không thể thực hiện khi đang thoát trò chơi'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED_TO_USE_THISITEM': {'Service': '1',
#   'Data': 'Không thể đung được món đồ đó vì cấp độ của nhân vật còn thấp'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_WHILE_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang dịch chuyển'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME': {'Service': '1',
#   'Data': 'Còn %d giây sẽ thoát trò chơi'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME_CANCLE': {'Service': '1',
#   'Data': 'Hủy bỏ việc thoát khỏi trò chơi'},
#  'UIIT_MSG_STRGERR_CANT_SELL_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể bán món đồ khi đang trang bị'},
#  'UIIT_MSG_STRGERR_CANT_SWAP_JOBITEM': {'Service': '1',
#   'Data': 'Phải bỏ món đồ trước ra thì mới mặc đồ mới vào được'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBCHANGE_COMPLETE': {'Service': '1',
#   'Data': 'Không thể cởi trang bị nghề nghiệp trong vòng 10 giây kể từ lúc đeo vào'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBITEM_DETACH_COMPLETE': {'Service': '1',
#   'Data': 'Không thể đeo trang bị nghề nghiệp khác trong 10 phút kể từ lúc tháo ra'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_JOBITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Bạn chỉ có thể bỏ trang bị nghề nghiệp sau 20 giây kể từ trận chiến cuối cùng.'},
#  'UIIT_MSG_STRGERR_CANT_HAVE_CART': {'Service': '1',
#   'Data': 'Không thể bỏ trang bị nghề nghiệp ra trong khi đang triệu tập thú vận chuyển'},
#  'UIIT_MSG_COSERR_COLLISION_EXIST_BETWEEN_US': {'Service': '1',
#   'Data': 'Không thực hiện được lệnh di chuyển do có chướng ngại vật'},
#  'UIIT_MSG_INTERACTION_FAIL_IM_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận việc khác'},
#  'UIIT_MSG_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh vì kỹ năng hồi sinh của bạn còn thấp'},
#  'UIIT_MSG_SKILL_USE_FAIL_NOTENOUGHHP': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng đó vì không đủ HP'},
#  'UIIT_MSG_SKILL_USE_FAIL_ITS_NOT_A_BATTLE_FIELD': {'Service': '1',
#   'Data': 'Không thể tấn công trong khu vực an toàn'},
#  'UIIT_MSG_SKILL_USE_FAIL_WAITFOR_JOB_ACTIVATE': {'Service': '1',
#   'Data': 'Không thể tấn công trong 10 giây kể từ lúc mang trang bị nghề nghiệp vào'},
#  'UIIT_MSG_STRGERR_DONT_HAVE_ANY_TRADECART_TO_PICK_SPECIALTY': {'Service': '1',
#   'Data': 'Không thể nhận được đặc sản nếu không có thú vận chuyển'},
#  'UIIT_MSG_STRGERR_CANT_BE_STORED': {'Service': '1',
#   'Data': 'Món đồ đó không thể lưu tại nơi đã chỉ định'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị đồ vật vì cấp độ hoặc cấp độ tuyệt kỹ nhân vật còn thấp'},
#  'UIIT_MSG_STRGERR_LOCKED_BY_OTHER_ONE': {'Service': '1',
#   'Data': 'Không thể lấy được món đồ đó vì nó của người chơi khác'},
#  'UIIT_MSG_STRGERR_GENDER_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác giới tính'},
#  'UIIT_MSG_STRGERR_TRADE_BAY_FULL': {'Service': '1',
#   'Data': 'Không thể thêm vào món đồ đã chọn vì cửa sổ trao đổi đã đầy'},
#  'UIIT_MSG_STRGERR_COUNTRY_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác chủng tộc'},
#  'UIIT_MSG_STRGERR_HIGHER_STRENGTH_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì thiếu sức mạnh'},
#  'UIIT_MSG_STRGERR_HIGHER_INTELLECT_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì trí tuệ thấp'},
#  'UIIT_MSG_STRGERR_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_EU_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_CANT_EQUIP_RAZED_ITEM': {'Service': '1',
#   'Data': 'Không thể trang bị món đồ đã hỏng'},
#  'UIIT_MSG_STRGERR_PREV_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển.'},
#  'UIIT_MSG_STRGERR_POSSESSION_LIMIT_EXCEEDED': {'Service': '1',
#   'Data': 'Không thể có nhiều hơn số lượng giới hạn'},
#  'UIIT_MSG_STRGERR_ROBBER_CANT_SUMMON_CART_IN_TOWN': {'Service': '1',
#   'Data': 'Không thể triệu hồi phương tiện chuyên trở khi đang ở Làng Đạo Tặc'},
#  'UIIT_MSG_INTERACTION_FAIL_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển rồi'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_TRADECART': {'Service': '1',
#   'Data': 'Không thể dịch chuyển khi đang có thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_RIDE': {'Service': '1',
#   'Data': 'Không thể sử dụng cổng dịch chuyển khi đang cưỡi thú'},
#  'UIIT_MSG_INTERACTION_FAIL_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Không thể qua đò khi đang ở xa thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không sửa chữa được'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không làm lại được'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_TEMPORARILY': {'Service': '1',
#   'Data': 'Bất khả xâm phạm - Không thể tấn công hoăc bị tấn công trong 5 giây'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_FORTRESS': {'Service': '1',
#   'Data': 'Khi tấn công pháo đài trong tình trạng bất khả xâm phạm - không thể tấn công trong 10 giây'},
#  'UIIT_MSG_COSERR_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Một nhân vật không thể cách xa quá thú vận chuyển %d m'},
#  'UIIT_MSG_RETURN_CANCLE': {'Service': '1',
#   'Data': 'Việc sử dụng bùa dịch chuyển đã bị hủy bỏ'},
#  'UIIT_MSG_QUESTEND_2': {'Service': '1',
#   'Data': 'Hãy mở cửa sổ Nhiệm vụ (Q) để kiểm tra nội dung'},
#  'UIIT_MSG_JSERR_PREVIOUS_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể vào mê cung khi sắp dịch chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_OUT_OF_REQUIRED_LEVEL_FOR_TELEPORT': {'Service': '1',
#   'Data': 'Không thể dịch chuyển vì cấp độ của bạn quá thấp'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_FREEBATTLEITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Không thể bỏ khăn ra trong khi đang đánh nhau'},
#  'UIIT_MSG_STRGERR_STORAGE_OPERATION_BLOCKED': {'Service': '1',
#   'Data': 'Hiện tại bạn không được phép di chuyển các món đồ hoặc trao đổi chúng'},
#  'UIIT_MSG_QUEST_CALLMONSTER_NOTATTACK': {'Service': '1',
#   'Data': 'Cấp độ của bạn còn quá thấp để có thể đánh nhau với quái vật'},
#  'UIIT_MSG_QUEST_GET_ITEM_FAILURE': {'Service': '1',
#   'Data': 'Không thể nhặt được món đồ'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_MONSTER': {'Service': '1',
#   'Data': 'Không thể di chuyển vì bạn đã ở cách quái vật %d m.'},
#  'UIIT_MSG_QUEST_FAIL_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Đã thất bại trong việc bắt giữ quái vật.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_CHATTING_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn đang làm nhiệm vụ nên không thể tán gẫu được.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MOVING_IN_DUNGEON': {'Service': '1',
#   'Data': 'Đã ra khỏi vị trí chỉ định nên không thể di chuyển được nữa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_DO_IT_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này vì bạn đang làm một nhiệm vụ khác có liên quan.'},
#  'UIIT_MSG_QUEST_ERR_TOO_LOW_LEVEL': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này do cấp độ của bạn còn thấp'},
#  'UIIT_MSG_QUEST_END_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ kết thúc sau %d phút'},
#  'UIIT_MSG_QUEST_START_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ bắt đầu trong %d giây (s)'},
#  'UIIT_MSG_QUEST_ERR_USE_WHANITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật này trong trạng thái Cuồng nộ'},
#  'UIIT_MSG_QUEST_ERR_CAPTUREMONSTER_ATTACK': {'Service': '1',
#   'Data': 'Không thể tấn công quái vật đã sập bẫy'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Không thể bắt quái vật thì khoảng cách quá xa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì đã đặt bẫy rồi'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_EXIST_MONSTER': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì quái vật ở quá gần'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật vì điều kiện nhiệm vụ không cho phép'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_WRONG_PLACE': {'Service': '1',
#   'Data': 'Không thể đặt bẫy trong khu vực này'},
#  'UIIT_MSG_QUEST_ERR_NO_TARGET': {'Service': '1',
#   'Data': 'Mệnh lệnh không thể thực thi do chưa chọn đối tượng'},
#  'UIIT_MSG_CANNOT_BUYBACK_ITEM_SELL': {'Service': '1',
#   'Data': 'Đồ vật không thể mua lại được. Bạn có chắc muốn bán nó đi không?'},
#  'UIIT_MSG_QUEST_INS_TIMEOUT': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ hoàn htành sau %d giây, bạn sẽ được trở lại vị trí ban đầu.'},
#  'UIIT_MSG_QUEST_INS_CONDITION': {'Service': '1',
#   'Data': 'Bạn sẽ trở lại vị trí ban đầu trong 5 giây nữa vì nhận được yêu cầu không thể ở lại khu vực hiện tại.'},
#  'UIIT_MSG_QUEST_INS_DEATH': {'Service': '1',
#   'Data': 'Không thể chuyển đến khu vực khác khi nhân vật của bạn đang bị chết'},
#  'UIIT_MSG_DROP_WARNING_1': {'Service': '1',
#   'Data': 'Nếu bạn vứt đồ vật này ra ngoài, thì bạn sẽ mất đi quyền sở hữu đồ vật này'},
#  'UIIT_MSG_DROP_WARNING_2': {'Service': '1',
#   'Data': 'Người khác có thể nhật chúng. Bạn có chắc là muốn vứt nó ra không?'},
#  ...}

# %% [markdown]
# ## TextQuest_QuestString.txt

# %%
text_quest_string = os.path.join(server_dep, 'TextQuest_QuestString.txt')
text_quest_string
# Out:
# 'server_dep\\silkroad\\textdata\\TextQuest_QuestString.txt'

# %%
text_quest_string = get_lines(text_quest_string)
text_quest_string
# Out:
# ['TextQuest_QuestString_100.txt',
#  'TextQuest_QuestString_1000.txt',
#  'TextQuest_QuestString_10000.txt',
#  'TextQuest_QuestString_10050.txt',
#  'TextQuest_QuestString_10100.txt',
#  'TextQuest_QuestString_10150.txt',
#  'TextQuest_QuestString_10200.txt',
#  'TextQuest_QuestString_10250.txt',
#  'TextQuest_QuestString_10300.txt',
#  'TextQuest_QuestString_10350.txt',
#  'TextQuest_QuestString_10400.txt',
#  'TextQuest_QuestString_10450.txt',
#  'TextQuest_QuestString_1050.txt',
#  'TextQuest_QuestString_10500.txt',
#  'TextQuest_QuestString_10550.txt',
#  'TextQuest_QuestString_10600.txt',
#  'TextQuest_QuestString_10650.txt',
#  'TextQuest_QuestString_10700.txt',
#  'TextQuest_QuestString_10750.txt',
#  'TextQuest_QuestString_10800.txt',
#  'TextQuest_QuestString_10850.txt',
#  'TextQuest_QuestString_10900.txt',
#  'TextQuest_QuestString_10950.txt',
#  'TextQuest_QuestString_1100.txt',
#  'TextQuest_QuestString_11000.txt',
#  'TextQuest_QuestString_11050.txt',
#  'TextQuest_QuestString_11100.txt',
#  'TextQuest_QuestString_11150.txt',
#  'TextQuest_QuestString_11200.txt',
#  'TextQuest_QuestString_11250.txt',
#  'TextQuest_QuestString_11300.txt',
#  'TextQuest_QuestString_11350.txt',
#  'TextQuest_QuestString_11400.txt',
#  'TextQuest_QuestString_11450.txt',
#  'TextQuest_QuestString_1150.txt',
#  'TextQuest_QuestString_11500.txt',
#  'TextQuest_QuestString_11550.txt',
#  'TextQuest_QuestString_11600.txt',
#  'TextQuest_QuestString_11650.txt',
#  'TextQuest_QuestString_11700.txt',
#  'TextQuest_QuestString_11750.txt',
#  'TextQuest_QuestString_11800.txt',
#  'TextQuest_QuestString_11850.txt',
#  'TextQuest_QuestString_11900.txt',
#  'TextQuest_QuestString_11950.txt',
#  'TextQuest_QuestString_1200.txt',
#  'TextQuest_QuestString_12000.txt',
#  'TextQuest_QuestString_12050.txt',
#  'TextQuest_QuestString_12100.txt',
#  'TextQuest_QuestString_12150.txt',
#  'TextQuest_QuestString_12200.txt',
#  'TextQuest_QuestString_12250.txt',
#  'TextQuest_QuestString_12300.txt',
#  'TextQuest_QuestString_12350.txt',
#  'TextQuest_QuestString_12400.txt',
#  'TextQuest_QuestString_12450.txt',
#  'TextQuest_QuestString_1250.txt',
#  'TextQuest_QuestString_12500.txt',
#  'TextQuest_QuestString_1300.txt',
#  'TextQuest_QuestString_1350.txt',
#  'TextQuest_QuestString_1400.txt',
#  'TextQuest_QuestString_1450.txt',
#  'TextQuest_QuestString_150.txt',
#  'TextQuest_QuestString_1500.txt',
#  'TextQuest_QuestString_1550.txt',
#  'TextQuest_QuestString_1600.txt',
#  'TextQuest_QuestString_1650.txt',
#  'TextQuest_QuestString_1700.txt',
#  'TextQuest_QuestString_1750.txt',
#  'TextQuest_QuestString_1800.txt',
#  'TextQuest_QuestString_1850.txt',
#  'TextQuest_QuestString_1900.txt',
#  'TextQuest_QuestString_1950.txt',
#  'TextQuest_QuestString_200.txt',
#  'TextQuest_QuestString_2000.txt',
#  'TextQuest_QuestString_2050.txt',
#  'TextQuest_QuestString_2100.txt',
#  'TextQuest_QuestString_2150.txt',
#  'TextQuest_QuestString_2200.txt',
#  'TextQuest_QuestString_2250.txt',
#  'TextQuest_QuestString_2300.txt',
#  'TextQuest_QuestString_2350.txt',
#  'TextQuest_QuestString_2400.txt',
#  'TextQuest_QuestString_2450.txt',
#  'TextQuest_QuestString_250.txt',
#  'TextQuest_QuestString_2500.txt',
#  'TextQuest_QuestString_2550.txt',
#  'TextQuest_QuestString_2600.txt',
#  'TextQuest_QuestString_2650.txt',
#  'TextQuest_QuestString_2700.txt',
#  'TextQuest_QuestString_2750.txt',
#  'TextQuest_QuestString_2800.txt',
#  'TextQuest_QuestString_2850.txt',
#  'TextQuest_QuestString_2900.txt',
#  'TextQuest_QuestString_2950.txt',
#  'TextQuest_QuestString_300.txt',
#  'TextQuest_QuestString_3000.txt',
#  'TextQuest_QuestString_3050.txt',
#  'TextQuest_QuestString_3100.txt',
#  'TextQuest_QuestString_3150.txt',
#  'TextQuest_QuestString_3200.txt',
#  'TextQuest_QuestString_3250.txt',
#  'TextQuest_QuestString_3300.txt',
#  'TextQuest_QuestString_3350.txt',
#  'TextQuest_QuestString_3400.txt',
#  'TextQuest_QuestString_3450.txt',
#  'TextQuest_QuestString_350.txt',
#  'TextQuest_QuestString_3500.txt',
#  'TextQuest_QuestString_3550.txt',
#  'TextQuest_QuestString_3600.txt',
#  'TextQuest_QuestString_3650.txt',
#  'TextQuest_QuestString_3700.txt',
#  'TextQuest_QuestString_3750.txt',
#  'TextQuest_QuestString_3800.txt',
#  'TextQuest_QuestString_3850.txt',
#  'TextQuest_QuestString_3900.txt',
#  'TextQuest_QuestString_3950.txt',
#  'TextQuest_QuestString_400.txt',
#  'TextQuest_QuestString_4000.txt',
#  'TextQuest_QuestString_4050.txt',
#  'TextQuest_QuestString_4100.txt',
#  'TextQuest_QuestString_4150.txt',
#  'TextQuest_QuestString_4200.txt',
#  'TextQuest_QuestString_4250.txt',
#  'TextQuest_QuestString_4300.txt',
#  'TextQuest_QuestString_4350.txt',
#  'TextQuest_QuestString_4400.txt',
#  'TextQuest_QuestString_4450.txt',
#  'TextQuest_QuestString_450.txt',
#  'TextQuest_QuestString_4500.txt',
#  'TextQuest_QuestString_4550.txt',
#  'TextQuest_QuestString_4600.txt',
#  'TextQuest_QuestString_4650.txt',
#  'TextQuest_QuestString_4700.txt',
#  'TextQuest_QuestString_4750.txt',
#  'TextQuest_QuestString_4800.txt',
#  'TextQuest_QuestString_4850.txt',
#  'TextQuest_QuestString_4900.txt',
#  'TextQuest_QuestString_4950.txt',
#  'TextQuest_QuestString_50.txt',
#  'TextQuest_QuestString_500.txt',
#  'TextQuest_QuestString_5000.txt',
#  'TextQuest_QuestString_5050.txt',
#  'TextQuest_QuestString_5100.txt',
#  'TextQuest_QuestString_5150.txt',
#  'TextQuest_QuestString_5200.txt',
#  'TextQuest_QuestString_5250.txt',
#  'TextQuest_QuestString_5300.txt',
#  'TextQuest_QuestString_5350.txt',
#  'TextQuest_QuestString_5400.txt',
#  'TextQuest_QuestString_5450.txt',
#  'TextQuest_QuestString_550.txt',
#  'TextQuest_QuestString_5500.txt',
#  'TextQuest_QuestString_5550.txt',
#  'TextQuest_QuestString_5600.txt',
#  'TextQuest_QuestString_5650.txt',
#  'TextQuest_QuestString_5700.txt',
#  'TextQuest_QuestString_5750.txt',
#  'TextQuest_QuestString_5800.txt',
#  'TextQuest_QuestString_5850.txt',
#  'TextQuest_QuestString_5900.txt',
#  'TextQuest_QuestString_5950.txt',
#  'TextQuest_QuestString_600.txt',
#  'TextQuest_QuestString_6000.txt',
#  'TextQuest_QuestString_6050.txt',
#  'TextQuest_QuestString_6100.txt',
#  'TextQuest_QuestString_6150.txt',
#  'TextQuest_QuestString_6200.txt',
#  'TextQuest_QuestString_6250.txt',
#  'TextQuest_QuestString_6300.txt',
#  'TextQuest_QuestString_6350.txt',
#  'TextQuest_QuestString_6400.txt',
#  'TextQuest_QuestString_6450.txt',
#  'TextQuest_QuestString_650.txt',
#  'TextQuest_QuestString_6500.txt',
#  'TextQuest_QuestString_6550.txt',
#  'TextQuest_QuestString_6600.txt',
#  'TextQuest_QuestString_6650.txt',
#  'TextQuest_QuestString_6700.txt',
#  'TextQuest_QuestString_6750.txt',
#  'TextQuest_QuestString_6800.txt',
#  'TextQuest_QuestString_6850.txt',
#  'TextQuest_QuestString_6900.txt',
#  'TextQuest_QuestString_6950.txt',
#  'TextQuest_QuestString_700.txt',
#  'TextQuest_QuestString_7000.txt',
#  'TextQuest_QuestString_7050.txt',
#  'TextQuest_QuestString_7100.txt',
#  'TextQuest_QuestString_7150.txt',
#  'TextQuest_QuestString_7200.txt',
#  'TextQuest_QuestString_7250.txt',
#  'TextQuest_QuestString_7300.txt',
#  'TextQuest_QuestString_7350.txt',
#  'TextQuest_QuestString_7400.txt',
#  'TextQuest_QuestString_7450.txt',
#  'TextQuest_QuestString_750.txt',
#  'TextQuest_QuestString_7500.txt',
#  'TextQuest_QuestString_7550.txt',
#  'TextQuest_QuestString_7600.txt',
#  'TextQuest_QuestString_7650.txt',
#  'TextQuest_QuestString_7700.txt',
#  'TextQuest_QuestString_7750.txt',
#  'TextQuest_QuestString_7800.txt',
#  'TextQuest_QuestString_7850.txt',
#  'TextQuest_QuestString_7900.txt',
#  'TextQuest_QuestString_7950.txt',
#  'TextQuest_QuestString_800.txt',
#  'TextQuest_QuestString_8000.txt',
#  'TextQuest_QuestString_8050.txt',
#  'TextQuest_QuestString_8100.txt',
#  'TextQuest_QuestString_8150.txt',
#  'TextQuest_QuestString_8200.txt',
#  'TextQuest_QuestString_8250.txt',
#  'TextQuest_QuestString_8300.txt',
#  'TextQuest_QuestString_8350.txt',
#  'TextQuest_QuestString_8400.txt',
#  'TextQuest_QuestString_8450.txt',
#  'TextQuest_QuestString_850.txt',
#  'TextQuest_QuestString_8500.txt',
#  'TextQuest_QuestString_8550.txt',
#  'TextQuest_QuestString_8600.txt',
#  'TextQuest_QuestString_8650.txt',
#  'TextQuest_QuestString_8700.txt',
#  'TextQuest_QuestString_8750.txt',
#  'TextQuest_QuestString_8800.txt',
#  'TextQuest_QuestString_8850.txt',
#  'TextQuest_QuestString_8900.txt',
#  'TextQuest_QuestString_8950.txt',
#  'TextQuest_QuestString_900.txt',
#  'TextQuest_QuestString_9000.txt',
#  'TextQuest_QuestString_9050.txt',
#  'TextQuest_QuestString_9100.txt',
#  'TextQuest_QuestString_9150.txt',
#  'TextQuest_QuestString_9200.txt',
#  'TextQuest_QuestString_9250.txt',
#  'TextQuest_QuestString_9300.txt',
#  'TextQuest_QuestString_9350.txt',
#  'TextQuest_QuestString_9400.txt',
#  'TextQuest_QuestString_9450.txt',
#  'TextQuest_QuestString_950.txt',
#  'TextQuest_QuestString_9500.txt',
#  'TextQuest_QuestString_9550.txt',
#  'TextQuest_QuestString_9600.txt',
#  'TextQuest_QuestString_9650.txt',
#  'TextQuest_QuestString_9700.txt',
#  'TextQuest_QuestString_9750.txt',
#  'TextQuest_QuestString_9800.txt',
#  'TextQuest_QuestString_9850.txt',
#  'TextQuest_QuestString_9900.txt',
#  'TextQuest_QuestString_9950.txt',
#  '']

# %%
for xxx in text_quest_string:
  file_name = os.path.join(server_dep, xxx)
  lines = get_lines(file_name)
  for idx, line in enumerate(lines):
    values = line.split('\t')
    if len(values) < 11:
      continue
    Service = values[0]
    name_str_id = values[2]
    Data = values[10]
    data_text[name_str_id] = {
      "Service": Service,
      "Data": Data
    }
data_text
# Out:
# {'UIC_STT_FONTNAME': {'Service': '1', 'Data': 'Tahoma'},
#  'UIIS_STT_MSG_INSTALL_START': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa"'},
#  'UIIS_STT_MSG_INSTALL_FOLDER': {'Service': '1',
#   'Data': 'Cài đặt "Con Đường Tơ Lụa" vào thư mục sau'},
#  'UIIS_STT_MSG_INSTALL_END': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt thành công'},
#  'UIIS_STT_INSTALL_FOLDER': {'Service': '1', 'Data': 'Thư mục cài đặt'},
#  'UIIS_STT_INSTALL_FILE': {'Service': '1', 'Data': 'File cài đặt'},
#  'UIIS_CTL_INSTALL': {'Service': '1', 'Data': 'Cài đặt'},
#  'UIIS_CTL_FIND_FOLDER': {'Service': '1', 'Data': 'Tìm kiếm'},
#  'UIIS_CTL_START': {'Service': '1', 'Data': 'Bắt đầu'},
#  'UIIS_CTL_CANCEL': {'Service': '1', 'Data': 'Hủy bỏ'},
#  'UIIS_CTL_CONFIRM': {'Service': '1', 'Data': 'Đồng ý'},
#  'UIIS_MSG_ALREADY_INSTALL': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đã được cài đặt'},
#  'UIIS_MSG_UNPACK_ZIP': {'Service': '1',
#   'Data': 'Không thể giải nén Con Đường Tơ Lụa. \\nFile nén bị hỏng.'},
#  'UIIS_MSG_UNPACK_CLOSE': {'Service': '1',
#   'Data': 'Không thể đóng file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_UNPACK_OPEN': {'Service': '1',
#   'Data': 'Không thể mở file nén Con Đường Tơ Lụa'},
#  'UIIS_MSG_INSTALL_SPACE': {'Service': '1',
#   'Data': 'Không thể cài đặt do thiếu dung lượng. \\nCần ít nhất %d BYTE dung lượng đĩa'},
#  'UIIS_MSG_BACKBUFFER': {'Service': '1', 'Data': 'Không thể tạo bộ nhớ đệm'},
#  'UIIS_MSG_CHANGE_FOLDER': {'Service': '1',
#   'Data': 'Thư mục cài đặt đã bị thay đổi.\\nKhông thể gỡ bỏ Con Đường Tơ Lụa'},
#  'UIIS_MSG_NOFIND': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa chưa được cài đặt. Việc gỡ bỏ không có tác dụng'},
#  'UIIS_MSG_REMOVE_COMPLETE': {'Service': '1',
#   'Data': 'Tất cả các file đã được xóa bỏ hoàn toàn'},
#  'UIIS_MSG_REMOVE_FAIL': {'Service': '1', 'Data': 'Không thể gỡ bỏ'},
#  'UIIS_STT_DELETE': {'Service': '1', 'Data': 'Xóa thư mục Con Đường Tơ Lụa'},
#  'UIIS_CTL_DELETE': {'Service': '1', 'Data': 'Gỡ bỏ'},
#  'UIIS_CTL_EXIT': {'Service': '1', 'Data': 'Thoát'},
#  'UILM_MSG_PROCESS_ALREADY_EXITS': {'Service': '1',
#   'Data': 'Con Đường Tơ Lụa đang chạy'},
#  'UILM_MSG_DETECTED_ABNORMAL_PROCESS': {'Service': '1',
#   'Data': 'Phát hiện lỗi chạy chương trình Con Đường Tơ Lụa (Lỗi hệ thống)'},
#  'UILM_MSG_FAILED_LOAD_CLIENT': {'Service': '1',
#   'Data': 'Không thể xác định đặc điểm client. Đang đóng.'},
#  'UILM_MSG_GATEWAY_NOT_IN_SERVICE_CHANNEL': {'Service': '1',
#   'Data': 'Máy chủ đang kiểm tra hoặc không làm việc. Truy cập trang %ssro.vtcgame.vn/ để biết thêm thông tin.'},
#  'UILM_MSG_DRIVER_UPDATE': {'Service': '1',
#   'Data': 'Driver đồ họa của bạn không phải là phiên bản mới nhất. Hãy cập nhật phiên bản mới nhất để xem hình ảnh game đẹp hơn.'},
#  'UILM_MSG_DRIVER_UPDATE_2': {'Service': '1',
#   'Data': 'Không bao giờ xuất hiện lại.'},
#  'UILM_MSG_FAILED_INIT_NETENGINE': {'Service': '1',
#   'Data': 'Không thể khởi chạy NetEngine (Lỗi (%d,%d))'},
#  'UILM_MSG_FAILED_LOAD_VERSION': {'Service': '1',
#   'Data': 'Không thể kiểm tra phiên bản'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_IP': {'Service': '1',
#   'Data': 'Không thể kiểm tra IP kết nối'},
#  'UILM_MSG_INVALID_CONNECT_IP': {'Service': '1',
#   'Data': 'IP kết nối không hợp lệ'},
#  'UILM_MSG_FAILED_LOAD_CONNECT_PORT': {'Service': '1',
#   'Data': 'Không thể kiểm tra cổng kết nối'},
#  'UILM_MSG_INVALID_CONNECT_PORT': {'Service': '1',
#   'Data': 'Cổng kết nối không hợp lệ'},
#  'UILM_MSG_DETECTED_ABNORMAL_DIRECTX': {'Service': '1',
#   'Data': 'DirectX 9.0 chưa được cài đặt hoặc không phải là phiên bản 9.0b. Con Đường Tơ Lụa cần DirectX9.0b hoặc phiên bản mới hơn'},
#  'UILM_MSG_DETECTED_ABNORMAL_MODULE': {'Service': '1',
#   'Data': 'Không xác định client. Kết thúc.'},
#  'UILM_MSG_DETECTED_PATCH_DIABLE': {'Service': '1',
#   'Data': 'Bạn phải cài đặt toàn bộ phiên bản. Kết nối với trang chủ để download toàn bộ phiên bản.'},
#  'UILM_MSG_DETECTED_PATCH_MANUAL': {'Service': '1',
#   'Data': 'Bạn cần cài đặt thủ công. Vui lòng truy cập trang chủ để tải bản cài thủ công về. Bạn có muốn kết nối đến trang chủ không?'},
#  'UILM_MSG_FAILED_EXECUTE_EXPLORER': {'Service': '1',
#   'Data': 'Không thể chạy Internet Explorer.'},
#  'UILM_MSG_FAILED_PATCH': {'Service': '1',
#   'Data': 'Chưa hoàn thành việc sửa lỗi. Hãy thử lại.[Lỗi số(%d)]'},
#  'UILM_MSG_FAILED_EXECUTE_CLIENT': {'Service': '1',
#   'Data': 'Xin lỗi. Không thể chạy Con Đường Tơ Lụa [Lỗi số(%d)]'},
#  'UILM_MSG_NOTEXITS_REPLACERFILE': {'Service': '1',
#   'Data': 'Không tìm thấy file replacer.exe. Chưa hoàn thành việc sửa lỗi.'},
#  'UILM_MSG_DETECTED_ABNORMAL_REPLACERFILE': {'Service': '1',
#   'Data': 'Không thể sửa lỗi vì file replacer.exe đã bị hỏng [lỗi số (%d)]'},
#  'UILM_MSG_FAILED_LOAD_GATEWAY_INFO': {'Service': '1',
#   'Data': 'Không thể đưa ra thuộc tính kết nối của GateWay [lỗi%d]'},
#  'UILM_STT_DIVISION': {'Service': '1', 'Data': 'Bộ phận'},
#  'UILM_STT_DIVISION_LIST': {'Service': '1', 'Data': 'Danh sách bộ phận'},
#  'UILM_STT_DIVISION_SELECTED': {'Service': '1', 'Data': 'Bộ phận lựa chọn'},
#  'UILM_STT_DIVISION_NAME': {'Service': '1', 'Data': 'Tên bộ phận'},
#  'UILM_STT_FARM': {'Service': '1', 'Data': 'Giải'},
#  'UILM_STT_FARM_LIST': {'Service': '1', 'Data': 'Danh sách giải'},
#  'UILM_STT_FARM_NAME': {'Service': '1', 'Data': 'Tên giải'},
#  'FARM0101': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 01 Yahoo'},
#  'FARM0102': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 01 Yahoo'},
#  'FARM0103': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 01 Yahoo'},
#  'FARM0104': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 01 Yahoo'},
#  'FARM0105': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 01 Yahoo'},
#  'FARM0201': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 02 Yahoo'},
#  'FARM0202': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 02 Yahoo'},
#  'FARM0203': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 02 Yahoo'},
#  'FARM0204': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 02 Yahoo'},
#  'FARM0205': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 02 Yahoo'},
#  'FARM0301': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 03 Yahoo'},
#  'FARM0302': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 03 Yahoo'},
#  'FARM0303': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 03 Yahoo'},
#  'FARM0304': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 03 Yahoo'},
#  'FARM0305': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 03 Yahoo'},
#  'FARM0401': {'Service': '1', 'Data': 'Giải 01 thuộc nhóm 04 Yahoo'},
#  'FARM0402': {'Service': '1', 'Data': 'Giải 02 thuộc nhóm 04 Yahoo'},
#  'FARM0403': {'Service': '1', 'Data': 'Giải 03 thuộc nhóm 04 Yahoo'},
#  'FARM0404': {'Service': '1', 'Data': 'Giải 04 thuộc nhóm 04 Yahoo'},
#  'FARM0405': {'Service': '1', 'Data': 'Giải 05 thuộc nhóm 04 Yahoo'},
#  'UILM_STT_DIVISION_PING': {'Service': '1', 'Data': 'Ping'},
#  'UILM_STT_DIVISION_CONDITION': {'Service': '1', 'Data': 'Tình trạng'},
#  'DIV01': {'Service': '1', 'Data': 'Bộ phận Yahoo 01'},
#  'DIV02': {'Service': '1', 'Data': 'Bộ phận Yahoo 02'},
#  'DIV03': {'Service': '1', 'Data': 'Bộ phận Yahoo 03'},
#  'DIV04': {'Service': '1', 'Data': 'Bộ phận Yahoo 04'},
#  'DIV05': {'Service': '1', 'Data': 'Bộ phận Yahoo 05'},
#  'DIV06': {'Service': '1', 'Data': 'Bộ phận Yahoo 06'},
#  'DIV07': {'Service': '1', 'Data': 'Bộ phận Yahoo 07'},
#  'DIV08': {'Service': '1', 'Data': 'Bộ phận Yahoo 08'},
#  'DIV09': {'Service': '1', 'Data': 'Bộ phận Yahoo 09'},
#  'DIV10': {'Service': '1', 'Data': 'Bộ phận Yahoo 10'},
#  'UILM_STT_DIVISION_RECOMMENDATION': {'Service': '1', 'Data': 'Đề nghị'},
#  'UILM_STT_DIVISION_NOT_RECOMMENDATION': {'Service': '1',
#   'Data': 'Không đề nghị'},
#  'UILM_MSG_SILKROAD_STARTING_HOME': {'Service': '1',
#   'Data': 'Trang chủ của Con đường tơ lụa đã được đặt làm trang chủ mặc định'},
#  'UILM_MSG_YAHOO_STARTING_HOME': {'Service': '1',
#   'Data': 'Đã thiết đặt xong trang chủ https://sro.vtcgame.vn/'},
#  'UILM_MSG_YAHOO_TOOLBAR': {'Service': '1',
#   'Data': 'Đã thiết đặt xong thanh công cụ yahoo'},
#  'UILM_MSG_SERVICE_CLIENT_ERROR_REINSTALL': {'Service': '1',
#   'Data': 'Client của bạn bị lỗi hoặc đã bị phá huỷ nên không thể kết nối đến máy chủ. Hãy cài lại một client mới.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ download bị ngắt. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_DOWNLOAD_CANCEL': {'Service': '1',
#   'Data': 'Kết nới với máy chủ download đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_CONNECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Xin mời hãy thử lại sau.'},
#  'UILM_MSG_SERVICE_GATEWAY_SELECT': {'Service': '1',
#   'Data': 'Kết nối với máy chủ đã kết thúc. Launcher sẽ được khởi động lại.'},
#  'UILM_TEXT_CONFIG_GRAPHIC_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UILM_TEXT_CONFIG_GRAPHIC_NORMAL': {'Service': '1', 'Data': 'Bình thường'},
#  'UILM_TEXT_CONFIG_GRAPHIC_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UILM_TEXT_CONFIG_GRAPHIC_USER_DEF': {'Service': '1', 'Data': 'Không đổi'},
#  'UIIT_STT_ETCKEY': {'Service': '1', 'Data': 'Các phím khác'},
#  'UIIT_STT_MOUSE': {'Service': '1', 'Data': 'Chuột'},
#  'UIIT_STT_MOUSE_RIGHT_BUTTON': {'Service': '1', 'Data': 'Ô Nhớ Chuột'},
#  'UIIT_STT_USE_WHEEL_TO_CHANGE_SIGHT': {'Service': '1',
#   'Data': 'Chuột lăn (đổi góc nhìn) chuột phải (dùng Ô Nhớ)'},
#  'UIIT_STT_USE_WHEEL_TO_USE_SKILL': {'Service': '1',
#   'Data': 'Chuột lăn (dùng Ô Nhớ) chuột phải (đổi góc nhìn)'},
#  'UIIT_STT_ITEM_GET': {'Service': '1', 'Data': 'Nhặt đồ'},
#  'UIIT_STT_REFLECT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng phản xạ'},
#  'UIIT_STT_WATER_DETAIL': {'Service': '1', 'Data': 'Chi tiết nước'},
#  'UIIT_STT_LIGHT_EFFECT': {'Service': '1', 'Data': 'Hiệu ứng ánh sáng'},
#  'UIIT_STT_BUMP_MAPPING': {'Service': '1', 'Data': 'ánh xạ va chạm'},
#  'UIIT_STT_ENVIRONMENT_MAPPING': {'Service': '1', 'Data': 'ánh xạ môi trường'},
#  'UIIT_STT_LENS_FLAIR': {'Service': '1', 'Data': 'Độ nhạy của thấu kính'},
#  'UIIT_STT_DYNAMIC_ANIMATION': {'Service': '1', 'Data': 'ảnh động sống động'},
#  'UIIT_STT_WATER_REFLECTION': {'Service': '1', 'Data': 'Phản xạ nước'},
#  'UIIT_STT_FILTERING': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_TEXTER_DETAIL': {'Service': '1', 'Data': 'Chi tiết lớp ảnh'},
#  'UIIT_STT_GRAPHIC_QUALITY': {'Service': '1', 'Data': 'Chất lượng đồ họa'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL': {'Service': '1',
#   'Data': 'Người dùng tự chọn'},
#  'UIIT_STT_GRAPHIC_QUALITY_USER_CONTROL': {'Service': '1', 'Data': 'Tự chọn'},
#  'UIIT_STT_METAL_DETAIL': {'Service': '1', 'Data': 'Chất liệu kim loại'},
#  'UIIT_STT_BLOOM_EFFECT': {'Service': '1', 'Data': 'Âm lượng'},
#  'UIIT_STT_GRAPHIC': {'Service': '1', 'Data': 'Đồ họa'},
#  'UIIT_STT_RESOLUTION': {'Service': '1', 'Data': 'Độ phân giải'},
#  'UIIT_STT_LUMINOSITY': {'Service': '1', 'Data': 'Độ sáng tối'},
#  'UIIT_STT_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn'},
#  'UIIT_STT_CHAR_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn nhân vật'},
#  'UIIT_STT_SCENERY_SIGHT_RANGE': {'Service': '1', 'Data': 'Tầm nhìn bối cảnh'},
#  'UIIT_STT_SHADOW_DETAIL': {'Service': '1', 'Data': 'Chi tiết bóng'},
#  'UIIT_STT_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_MIDDLE': {'Service': '1', 'Data': 'Vừa'},
#  'UIIT_STT_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_VERY_DARK': {'Service': '1', 'Data': 'Rất tối'},
#  'UIIT_STT_DARK': {'Service': '1', 'Data': 'Tối'},
#  'UIIT_STT_NORMAL': {'Service': '1', 'Data': 'Trung bình'},
#  'UIIT_STT_LIGHT': {'Service': '1', 'Data': 'Sáng'},
#  'UIIT_STT_VERY_LIGHT': {'Service': '1', 'Data': 'Rất sáng'},
#  'UIIT_STT_SIGHT_VERY_SMALL': {'Service': '1', 'Data': 'Rất hẹp'},
#  'UIIT_STT_SIGHT_SMALL': {'Service': '1', 'Data': 'Hẹp'},
#  'UIIT_STT_SIGHT_LARGE': {'Service': '1', 'Data': 'Rộng'},
#  'UIIT_STT_SIGHT_VERY_LARGE': {'Service': '1', 'Data': 'Rất rộng'},
#  'UIIT_STT_NONE': {'Service': '1', 'Data': 'Không có'},
#  'UIIT_STT_CIRCLE': {'Service': '1', 'Data': 'Vòng tròn'},
#  'UIIT_STT_DETAIL': {'Service': '1', 'Data': 'Chi tiết'},
#  'UIIT_STT_RANK': {'Service': '1', 'Data': '%d bước'},
#  'UIIT_STT_ON': {'Service': '1', 'Data': 'Bật'},
#  'UIIT_STT_OFF': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_HIGH': {'Service': '1', 'Data': 'Cao'},
#  'UIIT_STT_GRAPHIC_QUALITY_MIDDLE': {'Service': '1', 'Data': 'Bình thường'},
#  'UIIT_STT_GRAPHIC_QUALITY_LOW': {'Service': '1', 'Data': 'Thấp'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL1': {'Service': '1', 'Data': 'Đồ họa 1'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL2': {'Service': '1', 'Data': 'Đồ họa 2'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_WAR': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_GRAPHIC_QUALITY_CONTROL_USER': {'Service': '1', 'Data': 'Tắt'},
#  'UIIT_STT_VIDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể thay đổi độ phân giải của game'},
#  'UIIT_STT_VIDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể thay đổi độ sáng của game'},
#  'UIIT_STT_VIDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể thay đổi chất lượng đồ hoạ của game. Tìm đến lựa chọn Video và thiết lập các mức độ cao, trung bình hay thấp. Tốc độ tải trò chơi sẽ thay đổi tuỳ theo các mức chất lượng được thiết lập.'},
#  'UIIT_STT_VIDIO_TTDESC_04': {'Service': '1',
#   'Data': 'Có thể thay đổi mức độ chi biết bóng. Tốc độ tải game có thể bị chậm nếu chi tiết bóng được đặt ở mức cao.'},
#  'UIIT_STT_VIDIO_TTDESC_05': {'Service': '1',
#   'Data': 'Khi thiết lập khung cảnh được đặt ở mức cao, có thể nhìn thấy nhiều hình ảnh hơn, tuy nhiên, điều này cũng sẽ làm chậm tốc độ tải game. Có thể thiết lập ở mức thấp, khi đó sẽ chỉ nhìn thấy những khung cảnh ở gần.'},
#  'UIIT_STT_VIDIO_TTDESC_06': {'Service': '1',
#   'Data': 'Khi các thông tin ở nhân vật, quái vật, lâu đài... được lựa chọn hiển thị nhiều, bạn sẽ biết đầy đủ thông tin hơn nhưng như vậy có thể gây chậm tốc độ tải game.'},
#  'UIIT_STT_VIDIO_TTDESC_07': {'Service': '1',
#   'Data': 'Lựa chọn chi tiết bóng nước để hiển thị các hình ảnh được phản chiếu trên mặt nước.'},
#  'UIIT_STT_VIDIO_TTDESC_08': {'Service': '1',
#   'Data': 'Chi tiết nước được lựa chọn với các mức độ hiệu ứng mặt nước, nếu lựa chọn mức độ cao, cảnh mặt nước sẽ đẹp hơn nhưng tốc độ tải game sẽ bị chậm đi.'},
#  'UIIT_STT_VIDIO_TTDESC_09': {'Service': '1',
#   'Data': 'Chi tiết hiển thị kim loại, nếu được lựa chọn, sẽ hiển thị các hiệu ứng ánh kim trên đồ vật kim loại như giáp, vũ khí. Mức độ lựa chọn càng cao thì chất lượng đồ hoạ cũng tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_10': {'Service': '1',
#   'Data': 'Hiệu ứng ánh sáng chỉ hiệu ứng của đèn khi chiếu trên bề mặt đồ vật, khi lựa chọn mức độ hiển thị ánh sáng cao thì độ thật của đồ vật sẽ tăng lên.'},
#  'UIIT_STT_VIDIO_TTDESC_11': {'Service': '1',
#   'Data': 'Chi tiết chất liệu chỉ mức độ chi tiết của chất liệu. Chất lượng hiển thị chất liệu của đồ vật sẽ tăng lên khi chi tiết chất liệu được lựa chọn ở mức độ cao.'},
#  'UIIT_STT_VIDIO_TTDESC_12': {'Service': '1',
#   'Data': 'Chi tiết thấu kính chỉ tình trạng chiếu sáng giống như một máy quay phim đang hướng về phía mặt trời.'},
#  'UIIT_STT_VIDIO_TTDESC_13': {'Service': '1',
#   'Data': 'Hiệu ứng nở hoa chỉ tình trạng hoà trộn màu sắc giống như muôn ngàn bông hoa đang nở.'},
#  'UIIT_STT_VIDIO_TTDESC_14': {'Service': '1',
#   'Data': 'Chuyển động học chỉ kỹ thuật chuyển động của các động tác, chuyển động của tóc...'},
#  'UIIT_STT_VIDIO_TTDESC_15': {'Service': '1',
#   'Data': 'Bù đắp các phác thảo thô để các đổi tượng trong tự nhiên hơn.'},
#  'UIIT_STT_VIDIO_TTDESC_16': {'Service': '1',
#   'Data': 'Tắt hiệu ứng skill để hệ thống chạy mượt hơn'},
#  'UIIT_STT_VIDIO_TTDESC_17': {'Service': '1',
#   'Data': 'Khi được trang bị bộ đồ chiến đấu lớn, người chơi gần đó sẽ được nâng cao khả năng chiến trận'},
#  'UIIT_STT_VIDIO_TTDESC_18': {'Service': '1',
#   'Data': 'Hiển thị các hiệu ứng của tất cả các đối tượng trên màn hình chi tiết, và ánh kim loại có thể không kiểm soát được. Tùy chọn này được bất hoạt cho hình ảnh đồ họa thấp.'},
#  'UIIT_STT_GAMESET_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của thú như thú nuôi, thú thồ hàng…'},
#  'UIIT_STT_GAMESET_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị các thông tin của người chơi cùng nhóm'},
#  'UIIT_STT_GAMESET_TTDESC_03': {'Service': '1',
#   'Data': 'Báo động khi HP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_04': {'Service': '1',
#   'Data': 'Báo động khi MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_GAMESET_TTDESC_05': {'Service': '1',
#   'Data': 'Báo động thành tiếng khi HP/MP tụt đến 1 mức nào đó'},
#  'UIIT_STT_AUDIO_TTDESC_01': {'Service': '1',
#   'Data': 'Có thể lựa chọn nhạc nền, bật/tắt/điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_02': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh pha trộn, bật/tắt điều chỉnh âm lượng'},
#  'UIIT_STT_AUDIO_TTDESC_03': {'Service': '1',
#   'Data': 'Có thể lựa chọn âm thanh theo khu vực, bật/tắt, điều chỉnh âm lượng'},
#  'UIIT_STT_VIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn tự do'},
#  'UIIT_STT_VIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn từ nhân vật thứ ba để theo dõi bản thân từ sau lưng'},
#  'UIIT_STT_VIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Thay đổi sang lựa chọn tầm nhìn 1/4, tình trạng không thể thay đổi chất lượng màn hình cao/thấp'},
#  'UIIT_STT_INPUT_TTDESC_01': {'Service': '1',
#   'Data': 'sử dụng chuột hoặc phím tắt để thay đổi tầm nhìn.'},
#  'UIIT_STT_INPUT_TTDESC_02': {'Service': '1',
#   'Data': 'Để thay đổi tầm nhìn, sử dụng chuột phải hoặc phím tắt.'},
#  'UIIT_STT_INPUT_TTDESC_03': {'Service': '1',
#   'Data': 'Mở cửa sổ thông tin nhân vật để kiểm tra các thông tin cơ bản về nhân vật như trang bị, chỉ số sức mạnh/trí tuệ...'},
#  'UIIT_STT_INPUT_TTDESC_04': {'Service': '1',
#   'Data': 'Mở cửa sổ kỹ năng để có thể xem /học các kỹ năng, tăng/giảm chỉ số Tuyệt Kỹ.'},
#  'UIIT_STT_INPUT_TTDESC_05': {'Service': '1',
#   'Data': 'Mở cửa sổ nhóm để có thể lập nhóm, gia nhập nhóm hoặc thiết lập các điều kiện của nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_06': {'Service': '1',
#   'Data': 'Mở cửa sổ cộng đồng. Các thông tin về Hội hoặc tin nhắn, danh sách bạn bè... có thể tìm thấy ở đây.'},
#  'UIIT_STT_INPUT_TTDESC_07': {'Service': '1',
#   'Data': 'sử dụng chế độ Cuồng nộ. Bắt đầu bằng việc nhấn chuột phải lên nút năng lượng to nhất ở ô hiển thị chế độ Cuồng Nộ trên góc trái màn hình.'},
#  'UIIT_STT_INPUT_TTDESC_08': {'Service': '1',
#   'Data': 'Cửa sổ trợ giúp. Giải đáp các thắc mắc cơ bản của người chơi.'},
#  'UIIT_STT_INPUT_TTDESC_09': {'Service': '1',
#   'Data': 'sử dụng các ô nhớ nhanh hoặc bấm chuột phải vào các kỹ năng để thi triển kỹ năng.'},
#  'UIIT_STT_INPUT_TTDESC_10': {'Service': '1',
#   'Data': 'Phím tắt để nhặt đồ tự động trên mặt đất.'},
#  'UIIT_STT_INPUT_TTDESC_11': {'Service': '1',
#   'Data': 'Triệu tập hoặc thu hồi thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_12': {'Service': '1', 'Data': 'Để thú nuôi theo sau.'},
#  'UIIT_STT_INPUT_TTDESC_13': {'Service': '1',
#   'Data': 'Thiết lập chế độ nhặt của thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_14': {'Service': '1',
#   'Data': 'Bạn có thể gửi tin nhắn trực tiếp đến người đã nhắn cho bạn bằng cách nhấn vào nút tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_15': {'Service': '1',
#   'Data': 'Bạn có thể thay đổi thú nuôi bằng cách nhấn nút chuyển đổi thú nuôi khi có nhiều thú nuôi.'},
#  'UIIT_STT_INPUT_TTDESC_16': {'Service': '1',
#   'Data': 'Mở cửa sổ giả kim thuật. Bạn có thể gia tăng sức mạnh của đồ vật và thêm các tính chất cho đồ vật tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_17': {'Service': '1',
#   'Data': 'Khi tắt chế độ hiển thị đồ vật, mọi thứ như các nhân vật khác, quái vật, thú nuôi... sẽ không được hiển thị ngoại trừ bản thân bạn.'},
#  'UIIT_STT_INPUT_TTDESC_18': {'Service': '1', 'Data': 'Mở hành trang'},
#  'UIIT_STT_INPUT_TTDESC_19': {'Service': '1',
#   'Data': 'Mở cửa sổ hành động. Có rất nhiều phím tắt, icon diễn tả cảm giác hay hành động khác nhau như lập gian hàng, chào hỏi...'},
#  'UIIT_STT_INPUT_TTDESC_20': {'Service': '1',
#   'Data': 'Mở cửa sổ nhiệm vụ để kiểm tra danh sách và thông tin về các nhiệm vụ đang thực hiện.'},
#  'UIIT_STT_INPUT_TTDESC_21': {'Service': '1',
#   'Data': 'Mở toàn bộ bản đồ để kiểm tra vị trí của bản thân và các thành viên trong nhóm.'},
#  'UIIT_STT_INPUT_TTDESC_22': {'Service': '1',
#   'Data': 'Thay đổi tầm nhìn: tầm nhìn tự do --> tầm nhìn từ người thứ ba --> tầm nhìn 1/4 --> lặp lại tầm nhìn tự do'},
#  'UIIT_STT_INPUT_TTDESC_23': {'Service': '1',
#   'Data': 'Kiểm tra tên của các đồ vật dưới đất bằng cách sử dụng phím tắt tương ứng.'},
#  'UIIT_STT_INPUT_TTDESC_24': {'Service': '1',
#   'Data': 'Thiết lập chế độ đứng\\ngồi của nhân vật. Khi ngồi, tốc độ hồi phục HP/MP của nhân vật sẽ nhanh hơn.'},
#  'UIIT_STT_INPUT_TTDESC_25': {'Service': '1',
#   'Data': 'Cửa sổ kiểm tra tình trạng của thú nuôi: có thể thiết lập tên của thú nuôi, kiểm tra thông tin thú nuôi tại đây.'},
#  'UIIT_STT_INPUT_TTDESC_26': {'Service': '1', 'Data': 'Thu hồi thú nuôi'},
#  'UIIT_STT_INPUT_TTDESC_27': {'Service': '1',
#   'Data': 'Yêu cầu thú nuôi tấn công'},
#  'UIIT_STT_INPUT_TTDESC_28': {'Service': '1',
#   'Data': 'Có thể sử dụng Hệ thống Siêu thị, tại đây, bạn có thể dùng silk để mua các đồ vật hữu dụng.'},
#  'UIIT_STT_INPUT_TTDESC_29': {'Service': '1',
#   'Data': 'Bạn có thể thiết lập chế độ tự động sử dụng giải dược và thuốc hồi phục, khi đó, việc luyện tập của bạn sẽ dễ dàng hơn.'},
#  'UIIT_STT_INPUT_TTDESC_30': {'Service': '1',
#   'Data': 'Mở cửa sổ gia nhập nhóm. Tại đây, bạn có thể tìm các nhóm đang thiếu thành viên để gia nhập.'},
#  'UIIT_STT_INPUT_TTDESC_31': {'Service': '1',
#   'Data': 'Mở cửa sổ hệ thống gian hàng. Tại đây, bạn có thể dễ dàng tìm thấy các đồ vật được bán trong hệ thống.'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_01': {'Service': '1',
#   'Data': 'Hiển thị tên nhân vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_02': {'Service': '1',
#   'Data': 'Hiển thị tên quái vật'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_03': {'Service': '1',
#   'Data': 'Hiển thị tên Hội'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_04': {'Service': '1',
#   'Data': 'Hiển thị tên các nhân vật khác'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_05': {'Service': '1',
#   'Data': 'Hiển thị tên NPC'},
#  'UIIT_STT_GAME_NAMEVIEW_TTDESC_06': {'Service': '1',
#   'Data': 'Hiển thị biểu tượng cấp độ thấp. Nếu lựa chọn, một dấu hiệu sẽ xuất hiện bên cạnh tên nhân vật của bạn và sẽ biến mất khi bạn lên cấp độ cao.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_01': {'Service': '1',
#   'Data': 'Trong trò chơi có rất nhiều chỉ dẫn được hiển thị dưới dạng tin nhắn ngắn trên cửa sổ trò chuyện. Bạn sẽ tìm thấy các thông tin hữu ích tại đây.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_02': {'Service': '1',
#   'Data': 'Cho phép hiển thị cửa sổ chú ý. Các chỉ dẫn chi tiết sẽ được hiển thị hoặc kiểm tra các thông tin quan trọng khi chuyển sang hệ thống mới. Sẽ rất hữu dụng khi bạn mới gia nhập trò chơi.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_03': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_04': {'Service': '1',
#   'Data': 'Ẩn hệ thống Windows một cách tự động. Nếu sử dụng chức năng này, khung của hệ thống Windows sẽ ẩn đi một cách tự động và chỉ xuất hiện trở lại khi bạn đưa con trỏ chuột lên trên.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_05': {'Service': '1',
#   'Data': 'Chuyển màn hình trò chơi sang chế độ cửa sổ. Bạn có thể sử dụng chế độ cửa sổ theo sở thích.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_06': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu mời vào nhóm. Nếu không sử dụng lựa chọn này, mọi lời mời vào nhóm gửi đến sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_07': {'Service': '1',
#   'Data': 'Chế độ chấp nhận yêu cầu giao dịch. Nếu không sử dụng chọn lựa này, mọi yêu cầu giao dịch gửi đến sẽ bị từ chối. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_08': {'Service': '1',
#   'Data': 'Cho phép nhận tin nhắn cá nhân. Nếu không chọn chức năng này, mọi tin nhắn cá nhân sẽ bị chặn lại. Nên thận trọng khi điều chỉnh chức năng này.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_09': {'Service': '1',
#   'Data': 'Thể hiện thông tin về các trạng thái tăng cường của nhân vật trong phần thông tin nhân vật thuộc nhóm. Nếu không lựa chọn chức năng này, các thông tin sẽ không thể hiện. Không quan sát được trạng thái dị trạng của nhân vật.'},
#  'UIIT_STT_GAME_OPTION_TTDESC_10': {'Service': '1',
#   'Data': 'Khởi động nhanh trò chơi bằng việc nạp hình ảnh bối cảnh trước khi nạp hình ảnh nhân vật. Đánh dấu vào ô này nếu bạn muốn trò chơi khởi động nhanh hơn.'},
#  'UIIT_MSG_CHATWND_HELP_WHISPER': {'Service': '1',
#   'Data': 'Thì thầm  [$tênnhânvật những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_PARTYMSG': {'Service': '1',
#   'Data': 'Tán gẫu trong nhóm [#những gì bạn muốn nói]'},
#  'UIIT_MSG_CHATWND_HELP_USECONTROLATSTORE': {'Service': '1',
#   'Data': 'Nếu bạn ấn phím Ctrl, bạn có thể bán hoặc mua đồ nhanh hơn'},
#  'UIIT_MSG_NOTIFY': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_MSG_CHATWND_MESSAGE_FILTER': {'Service': '1',
#   'Data': 'Một số từ ngữ hoặc cách diễn đạt bị cấm dùng'},
#  'UIIT_STT_GAMEGUIDE_START_1': {'Service': '1',
#   'Data': 'Hãy tìm hiểu những thông tin cơ bản về Con Đường Tơ Lụa và làm quen với những thông tin này trước. Thông qua cửa sổ tán gẫu bạn có thể học được thêm những chỉ dẫn vì vậy hãy luyện thói quen thật chú ý tới những hướng dẫn này. Chắc chắn bạn sẽ thu được những thông tin rất bổ ích.'},
#  'UIIT_STT_GAMEGUIDE_START_2': {'Service': '1',
#   'Data': '※ Hướng dẫn trò chơi có thể được sử dụng bất kỳ lúc nào bằng việc bấm phím  [H]'},
#  'UIIT_STT_GAMEGUIDE': {'Service': '1', 'Data': 'Trợ giúp'},
#  'UIIT_STT_EVENTGUIDE': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_QUESTGUIDE1': {'Service': '1', 'Data': 'Nhiệm vụ'},
#  'UIIT_STT_QUESTGUIDE2': {'Service': '1', 'Data': 'Từ điển nhiệm vụ'},
#  'UIIT_STT_GAMEEVENTGUIDE': {'Service': '1', 'Data': 'Hướng dẫn'},
#  'UIIT_STT_CONFIRM_BOX': {'Service': '1', 'Data': 'Cửa sổ xác nhận'},
#  'UIIT_STT_AGREEMENT_BOX': {'Service': '1', 'Data': 'Cửa sổ đồng ý'},
#  'UIIT_STT_INPUT_BOX': {'Service': '1', 'Data': 'Cửa sổ nhập vào'},
#  'UIIT_PAG_WORLDMAP': {'Service': '1', 'Data': 'Bản đồ lớn'},
#  'UIIT_PAG_LOCALMAP': {'Service': '1', 'Data': 'Bản đồ khu vực'},
#  'UIIT_STT_BACK_WORLDMAP': {'Service': '1', 'Data': 'Mở bản đồ lớn'},
#  'UIIT_STT_JANGAN': {'Service': '1', 'Data': 'Trường An'},
#  'UIIT_STT_DONHWANG': {'Service': '1', 'Data': 'Đôn Hoàng'},
#  'UIIT_STT_KHOTAN': {'Service': '1', 'Data': 'Hòa Điền'},
#  'UIIT_STT_SAMARKAND': {'Service': '1', 'Data': 'Samarkand'},
#  'UIIT_STT_CONSTANTINOPLE': {'Service': '1', 'Data': 'Constantinople'},
#  'UIIT_STT_BIJEOKDAN': {'Service': '1', 'Data': 'Bijeokdan'},
#  'UIIT_STT_HEUKMAKDAN': {'Service': '1', 'Data': 'Heukmakdan'},
#  'UIIT_STT_EVILORDER': {'Service': '1', 'Data': 'Pháo đài tà ác'},
#  'UIIT_STT_ARABIA_CITY': {'Service': '1', 'Data': 'Baghdad'},
#  'UIIT_STT_ARABIA_CITY_DUNGEON': {'Service': '1', 'Data': 'Baghdad (Phụ bản)'},
#  'UIIT_STT_MUHAN': {'Service': '1', 'Data': 'Đấu trường Vô Cực'},
#  'UIIT_MSG_CHEATMSG_GO_TOWN': {'Service': '1', 'Data': '/town'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_1': {'Service': '1',
#   'Data': 'Tìm thấy macro (chơi tự động) trong nhân vật đang chơi. Tự động thoát.'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_2': {'Service': '1',
#   'Data': 'Tên của nhân vật có macro và thời gian đã sử dụng sẽ được ghi lại trên máy chủ'},
#  'UIIT_MSG_ERROR_MACRO_USE_BLOCK_3': {'Service': '1',
#   'Data': 'Có thể áp dụng hình phạt giới hạn về thời gian của tài khoản và khóa tài khoản'},
#  'UIIT_MSG_APPEAR_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa xuất hiện ở Hổ Huyệt Sơn'},
#  'UIIT_MSG_APPEAR_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã xuất hiện'},
#  'UIIT_MSG_APPEAR_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi xuất hiện ở Karakoram'},
#  'UIIT_MSG_APPEAR_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan xuất hiện ở Taklamakan'},
#  'UIIT_MSG_APPEAR_TAHOMET': {'Service': '1',
#   'Data': 'Sa Y Thần xuất hiện ở Lạc Khắc Sơn'},
#  'UIIT_MSG_APPEAR_UNIC': {'Service': '1', 'Data': '[%s] đã xuất hiện'},
#  'UIIT_MSG_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': 'Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn đã biến mất'},
#  'UIIT_MSG_DEAD_URRUCHI': {'Service': '1',
#   'Data': 'Ô Lỗ Tề từ Tháp Lý Mộc đã biến mất'},
#  'UIIT_MSG_DEAD_IYUTARU': {'Service': '1',
#   'Data': 'Băng Chúa Nhi từ Karakoram đã biến mất'},
#  'UIIT_MSG_DEAD_BONELORD': {'Service': '1',
#   'Data': 'Chúa tể Yarkan từ Taklamakan đã biến mất'},
#  'UIIT_MSG_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã biến mất'},
#  'UIIT_MSG_ANYONE_DEAD_TIGER_GIRL': {'Service': '1',
#   'Data': '[%s] đã giết Hổ Tinh Nữ Chúa từ Hổ Huyệt Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_URRUCHI': {'Service': '1',
#   'Data': '[%s] đã giết Ô Lỗ Tề từ Tháp Lý Mộc'},
#  'UIIT_MSG_ANYONE_DEAD_IYUTARU': {'Service': '1',
#   'Data': '[%s] đã giết Băng Chúa Nhi từ Karakoram'},
#  'UIIT_MSG_ANYONE_DEAD_BONELORD': {'Service': '1',
#   'Data': '[%s] đã giết Chúa tể Yarkan từ Taklamakan'},
#  'UIIT_MSG_ANYONE_DEAD_TAHOMET': {'Service': '1',
#   'Data': '[%s] đã giết Sa Y Than từ Lạc Khắc Sơn'},
#  'UIIT_MSG_ANYONE_DEAD_UNIC': {'Service': '1', 'Data': '[%s] đã giết [%s]'},
#  'UIIT_STT_ROLL_OF_CLOTH': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILK_BUY_RESULT': {'Service': '1', 'Data': 'Bạn đã mua [%d] silk'},
#  'UIIT_STT_SILK_BUY_CANCLE': {'Service': '1',
#   'Data': 'Việc mua bán [%d] silk đã bị hủy bỏ'},
#  'UIIT_STT_SILK_BUY_RECEIVE': {'Service': '1',
#   'Data': 'Bạn nhận được quà là [%d] silk'},
#  'UIIT_STT_SILK_SEND_RESULT': {'Service': '1',
#   'Data': 'Bạn đã gửi [%d] silk đi làm quà'},
#  'UIIT_STT_SILK_POINT_BUY_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được trả tiền'},
#  'UIIT_STT_SILK_POINT_USE_RECEIVE': {'Service': '1',
#   'Data': '[%d]điểm thưởng đã được sử dụng'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK': {'Service': '1', 'Data': 'Silk đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_MALL': {'Service': '1', 'Data': 'Cửa hàng Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_MALL': {'Service': '1',
#   'Data': 'Cửa hàng đặc biệt'},
#  'UIIT_STT_SILK_POINT_SILK_TOTAL': {'Service': '1', 'Data': 'Tổng số Silk'},
#  'UIIT_STT_SILK_POINT_PREMIUM_SILK_TOTAL': {'Service': '1',
#   'Data': 'Tổng số Silk đặc biệt'},
#  'UIIT_STT_SILKMALL': {'Service': '1', 'Data': 'Siêu thị'},
#  'UIIT_STT_SILKMALL_MAIN': {'Service': '1', 'Data': 'Phần chính'},
#  'UIIT_STT_SILKMALL_HOT_STORE': {'Service': '1', 'Data': 'HOT Shop'},
#  'UIIT_STT_SILKMALL_CONSUMPTION': {'Service': '1', 'Data': 'Đồ tiêu dùng'},
#  'UIIT_STT_SILKMALL_LEND_ITEM': {'Service': '1', 'Data': 'Tiền thuê đồ'},
#  'UIIT_STT_SILKMALL_AVATA': {'Service': '1', 'Data': 'Trang trí'},
#  'UIIT_STT_SILKMALL_PET': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PACKAGE': {'Service': '1', 'Data': 'Gói hàng'},
#  'UIIT_STT_SILKMALL_SHOPPING_BASKET_LIST': {'Service': '1',
#   'Data': 'Hàng đã chọn'},
#  'UIIT_STT_SILKMALL_NEW_ITEM': {'Service': '1', 'Data': 'Hàng mới'},
#  'UIIT_STT_SILKMALL_EVENT': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_SPECIAL_COAST': {'Service': '1', 'Data': 'Event'},
#  'UIIT_STT_SILKMALL_FAVORITE': {'Service': '1', 'Data': 'Hàng bán chạy'},
#  'UIIT_STT_SILKMALL_SPECIAL': {'Service': '1', 'Data': 'Đặc biệt'},
#  'UIIT_STT_SILKMALL_SCROLL': {'Service': '1', 'Data': 'Hỗ trợ'},
#  'UIIT_STT_SILKMALL_POTION': {'Service': '1', 'Data': 'Hồi phục'},
#  'UIIT_STT_SILKMALL_COMMUNITY': {'Service': '1', 'Data': 'Cộng đồng'},
#  'UIIT_STT_SILKMALL_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY': {'Service': '1', 'Data': 'Giả kim thuật'},
#  'UIIT_STT_SILKMALL_PREMIUM_PREMIUM': {'Service': '1', 'Data': 'Hảo hạng'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ASTRAL': {'Service': '1', 'Data': 'Tinh thạch'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': 'Bất diệt (bảo toàn 99%)'},
#  'UIIT_STT_SILKMALL_ARCHEMY_ETC': {'Service': '1', 'Data': 'Khác'},
#  'UIIT_STT_SILKMALL_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_3': {'Service': '1', 'Data': 'Áo nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_4': {'Service': '1', 'Data': 'Quần nặng'},
#  'UIIT_STT_SILKMALL_ARMOR_5': {'Service': '1', 'Data': 'Bao tay'},
#  'UIIT_STT_SILKMALL_ARMOR_6': {'Service': '1', 'Data': 'Giầy nặng'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_1': {'Service': '1', 'Data': 'Vương miện'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_2': {'Service': '1', 'Data': 'Cầu vai nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_3': {'Service': '1', 'Data': 'Áo nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_4': {'Service': '1', 'Data': 'Quần nhẹ'},
#  'UIIT_STT_SILKMALL_LIGHT_ARMOR_6': {'Service': '1', 'Data': 'Giầy nhẹ'},
#  'UIIT_STT_SILKMALL_CLOSE_1': {'Service': '1', 'Data': 'Khăn'},
#  'UIIT_STT_SILKMALL_CLOSE_2': {'Service': '1', 'Data': 'Cầu vai vải'},
#  'UIIT_STT_SILKMALL_CLOSE_3': {'Service': '1', 'Data': 'Áo vải'},
#  'UIIT_STT_SILKMALL_CLOSE_4': {'Service': '1', 'Data': 'Quần vải'},
#  'UIIT_STT_SILKMALL_CLOSE_6': {'Service': '1', 'Data': 'Giầy vải'},
#  'UIIT_STT_SILKMALL_BIG_STORE': {'Service': '1', 'Data': 'Tiệm lớn'},
#  'UIIT_STT_SILKMALL_ASSIST': {'Service': '1', 'Data': 'Chi nhánh'},
#  'UIIT_STT_SILKMALL_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_HAT': {'Service': '1', 'Data': 'Mũ'},
#  'UIIT_STT_SILKMALL_BOOTH': {'Service': '1', 'Data': 'Gian hàng'},
#  'UIIT_STT_SILKMALL_FIREWORK': {'Service': '1', 'Data': 'Kẹo'},
#  'UIIT_STT_SILKMALL_DRESS': {'Service': '1', 'Data': 'Trang phục'},
#  'UIIT_STT_SILKMALL_ATTACH': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_BALLOON': {'Service': '1', 'Data': 'Đi kèm'},
#  'UIIT_STT_SILKMALL_PET_SUMMON': {'Service': '1', 'Data': 'Thú nuôi'},
#  'UIIT_STT_SILKMALL_PET_CONSUME': {'Service': '1', 'Data': 'Thú nuôi hết hạn'},
#  'UIIT_STT_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1', 'Data': 'Mua hết'},
#  'UIIT_STT_SILKMALL_BOOK_MARK': {'Service': '1', 'Data': 'Sổ sách'},
#  'UIIT_STT_SILKMALL_PUT_ON': {'Service': '1', 'Data': 'sử dụng thử'},
#  'UIIT_STT_SILKMALL_BUY': {'Service': '1', 'Data': 'Mua'},
#  'UIIT_STT_SILKMALL_PRESENT': {'Service': '1', 'Data': 'Quà'},
#  'UIIT_STT_SILKMALL_DEL': {'Service': '1', 'Data': 'Xóa'},
#  'UIIT_STT_SILKMALL_BUY_LIST': {'Service': '1', 'Data': 'Hàng mua'},
#  'UIIT_STT_SILKMALL_RECEIVE_LIST': {'Service': '1', 'Data': 'Hàng nhận'},
#  'UIIT_STT_SILKMALL_SILKMALL_OUT': {'Service': '1', 'Data': 'Thoát'},
#  'UIIT_STT_SILKMALL_PUT_ON_CLOSE_BUY': {'Service': '1',
#   'Data': 'Mua đồ thời trang'},
#  'UIIT_STT_SILKMALL_ALL_CLOSE_TAKEOFF': {'Service': '1', 'Data': 'Cởi bỏ'},
#  'UIIT_STT_SILKMALL_ADD_INVENTORY': {'Service': '1', 'Data': 'Ô mở rộng'},
#  'UIIT_STT_SILKMALL_ADD_STOREHOUSE_INVENTORY': {'Service': '1',
#   'Data': 'Kho mở rộng'},
#  'UIIT_STT_SILKMALL_SILK': {'Service': '1', 'Data': 'Silk'},
#  'UIIT_STT_SILKMALL_BUY_SILK': {'Service': '1', 'Data': 'Mua Silk'},
#  'UIIT_STT_SILKMALL_SEND_SILK': {'Service': '1', 'Data': 'Tặng Silk'},
#  'UIIT_STT_SILKMALL_COUPON_EXCHANGE': {'Service': '1',
#   'Data': 'Trao đổi phiếu'},
#  'UIIT_STT_SILKMALL_BUY_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_03': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_SEND_SILK_LINK_02': {'Service': '1',
#   'Data': 'Not Translation'},
#  'UIIT_STT_SILKMALL_USE_INFOMATION': {'Service': '1',
#   'Data': 'Cách sử dụng Siêu thị'},
#  'UIIT_STT_SILKMALL_ENTER': {'Service': '1', 'Data': 'Vào Siêu thị'},
#  'UIIT_STT_SILKMALL_DIRECT_ENTER': {'Service': '1',
#   'Data': 'Vào nhanh Siêu thị'},
#  'UIIT_STT_SILKMALL_NEW_CASHITEM': {'Service': '1',
#   'Data': 'Siêu thị cập nhật đồ vật mới'},
#  'UIIT_STT_SILKMALL_WARNING_1': {'Service': '1',
#   'Data': 'Bạn có thể bị quái vật'},
#  'UIIT_STT_SILKMALL_WARNING_2': {'Service': '1',
#   'Data': 'hoặc những người chơi khác tấn công trong khi vào Siêu thị'},
#  'UIIT_STT_SILKMALL_WARNING_3': {'Service': '1',
#   'Data': 'Nên sử dụng món đồ trong khu vực an toàn'},
#  'UIIT_STT_SILKMALL_MAIN_EXPLAIN': {'Service': '1',
#   'Data': '<sml2><p line_margin="12"><p line_margin="5"><font color="255,255,153,81" style="bold">Siêu Thị là gì?</font><br>Là nơi bán và cho thuê những trang bị để <br>sử dụng trên Con đường tơ lụa. Những trang bị đó phải sử dụng silk để mua.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Mua Silk</font><br>Silk có thể mua bằng cách bấm vào nút Mua silk ở góc trên bên phải màn hình.<br>Bấm vào nút Mua silk bạn sẽ được chuyển đến trang E-Cash.<br>nơi để bạn mua silk.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Tặng Silk</font><font color="255,255,117,117">(Tính năng chưa kích hoạt)</font><br>Trong quá trình mua đồ trong Siêu Thị, bạn có thể bấm vào nút Tặng Silk để gửi <br>tới người chơi khác món đồ bạn chọn.<br></p><p line_margin="5"><font color="255,255,153,81" style="bold">Coupons exchanges</font><br>Phiếu giảm giá có thể được sử dụng 1 lần để mua silk hoặc sử dụng các item Mall.<br>Điền con số vào phiếu giảm giá để nhận được silk.<br>Số tiền có thể khác nhau tùy thuộc vào các loại phiếu giảm giá.<br></p></p><strong><font color="255,255,153,81">Sổ sách</font></strong><font color="255,255,117,117">(Tính năng chưa được kích hoạt)</font><br>Tất cả những đồ vật bạn mua trong Siêu Thị có thể được lưu giữ trong sổ sách của bạn <br>bằng cách bấm vào Sổ sách. Đồ vật đã lưu trong Sổ của bạn sẽ được hoàn trả <br>ngay cả khi bạn đã mua đồ vật đó.</sml2>'},
#  'UIIT_STT_SILKMALL_MY_INFO': {'Service': '1', 'Data': 'Thông tin cá nhân'},
#  'UIIT_STT_SILKMALL_POSSESSION_GOLD': {'Service': '1',
#   'Data': 'Số lượng hiện có'},
#  'UIIT_STT_SILKMALL_REMAIN_INVENTORY': {'Service': '1', 'Data': '%d ô trống'},
#  'UIIT_STT_SILKMALL_MAIN_INTRO': {'Service': '1',
#   'Data': '<sml2>Chào mừng quý khách đến với cửa hàng bán đồ chất lượng cao của Con Đường Tơ Lụa</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ORDER_SHEET': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_TOOL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_FLEAMARKET': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_ZZIM': {'Service': '1',
#   'Data': '<sml2>Đây là danh sách hàng bạn đặt mua</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_ZZIM_SUB_TITLE_FAVORITY': {'Service': '1',
#   'Data': '<sml2>Có thể xem danh sách những mặt hàng đã mua hoặc chọn trong phần Sổ sách</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_CONSUMPTION_SUBTITLE_COSETC': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'UIIT_STT_SILKMALL_MAIN_SUB_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'MALL_CONSUME_SPECIAL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ tiêu dùng với những chức năng đặc biệt</sml2>'},
#  'MALL_CONSUME_SCROLL': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ trong danh sách đã của cửa hàng</sml2>'},
#  'MALL_CONSUME_POTION': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ hỗ trợ với số lượng khác thường</sml2>'},
#  'MALL_CONSUME_COMMUNITY': {'Service': '1',
#   'Data': '<sml2>Có thể mua món đồ để kết nối cộng đồng</sml2>'},
#  'MALL_CONSUME_ETC': {'Service': '1',
#   'Data': '<sml2>Có thể mua những món đồ để sửa chữa trang bị</sml2>'},
#  'MALL_AVATAR_BOOTH': {'Service': '1',
#   'Data': '<sml2>Có nhiều món đồ trang trí cửa hàng nhằm thu hút khách hàng</sml2>'},
#  'MALL_AVATAR_HAT': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_DRESS': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_AVATAR_ATTACH': {'Service': '1',
#   'Data': '<sml2>Có nhiều loại mũ thời trang khiến bạn trở nên rất lôi cuốn khi sử dụng</sml2>'},
#  'MALL_PET_A_GROWTH': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_SILK': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_VEHICLE': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_CART': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PET_A_STORES': {'Service': '1',
#   'Data': '<sml2>Bạn có thể mua nhiều loại thú nuôi và các vật dụng liên quan tới thú nuôi </sml2>'},
#  'MALL_PREMIUM_PREMIUM': {'Service': '1',
#   'Data': '<sml2>Với các tính năng khác nhau, bạn sẽ có nhiều lựa chọn hơn để mua các item có chất lượng</sml2>'},
#  'MALL_ARCHEMY_ASTRAL': {'Service': '1',
#   'Data': '<sml2>Việc mua bán cần thiết để tăng sức mạnh cho các đồ vật của bạn</sml2>'},
#  'MALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Data': '<sml2>Bảo vệ đồ vật của bạn khỏi bị phân huỷ khi thực hiện giả kim thuật</sml2>'},
#  'UIIT_STT_SILKMALL_SHORT_KEY': {'Service': '1', 'Data': 'Siêu thị (F10)'},
#  'UIIT_STT_SILKMALL_BUY_CONFIRM': {'Service': '1', 'Data': 'Xác nhận mua'},
#  'UIIT_STT_SILKMALL_DO_ZZIM': {'Service': '1', 'Data': 'Đặt hàng'},
#  'UIIT_STT_SILKMALL_POPUP_TITLE': {'Service': '1',
#   'Data': 'Đồ trang trí tồn kho'},
#  'UIIT_STT_SILKMALL_POPUP_ADVERTISING': {'Service': '1',
#   'Data': 'Bán có giới hạn'},
#  'UIIT_STT_SILKMALL_POPUP_DATA': {'Service': '1', 'Data': 'Ngày bán:'},
#  'UIIT_STT_SILKMALL_POPUP_REDUCTION': {'Service': '1',
#   'Data': 'Cho tới khi giảm giá'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_M': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nam)'},
#  'UIIT_STT_SILKMALL_POPUP_ANGEL_W': {'Service': '1',
#   'Data': 'Trang phục thiên thần (Nữ)'},
#  'UIIT_MSG_SILKMALL_ZZIM_CONFIRM': {'Service': '1',
#   'Data': '<sml2><font color="255,255,255,255">Bạn sẽ đặt món đồ này chứ?<br>các món đồ được đặt có thể được chọn và mua một tất cả ở danh sách đặt hàng.</font></sml2>'},
#  'UIIT_MSG_SILKMALL_ZZIM_DELITE': {'Service': '1',
#   'Data': 'Xóa món đồ trong danh sách đặt hàng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY': {'Service': '1',
#   'Data': 'Bạn sẽ mua luôn số hàng đã đặt chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ZZIM_LUMP_BUY_TOTAL': {'Service': '1',
#   'Data': 'Tổng cộng'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_1': {'Service': '1',
#   'Data': 'Bạn có hủy số hàng đã đặt không ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_CANCLE_2': {'Service': '1',
#   'Data': 'Nếu bạn hủy bỏ việc sử dụng món đồ đã chọn, hiệu ứng của nó sẽ mất'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE': {'Service': '1',
#   'Data': 'Bạn sẽ dùng món đồ đã chọn chứ?'},
#  'UIIT_MSG_QUESTION_SILKMALL_ITEM_USE_REVERSE_PORTAL': {'Service': '1',
#   'Data': 'sử dụng bùa dịch chuyển phản hồi. Hãy chọn điểm đến.'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_RETURN': {'Service': '1',
#   'Data': 'Dịch chuyển tới điểm về cuối'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_LAST_DEATH': {'Service': '1',
#   'Data': 'Dịch chuyển tới nơi bạn đã chết'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_INS': {'Service': '1',
#   'Data': 'sử dụng các vật phẩm này bạn sẽ không thể dịch chuyển được'},
#  'UIIT_MSG_ITEM_USE_REVERSE_PORTAL_RETRUN_TO_GNGWC': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật sau khi kết thúc trận chiến'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_BUY_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không thành công do không đủ silk'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_SILK_TO_GIFT': {'Service': '1',
#   'Data': 'Silk không đủ để tặng'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng cho loại đồ vật trang bị'},
#  'UIIT_MSG_STRGERR_CANT_MUTATE_SINCE_EQUIP_CLASS_TOO_HIGH': {'Service': '1',
#   'Data': 'Không thể thay đổi giới tính do không phù hợp với cấp độ của đồ vật'},
#  'UIIT_MSG_STRGERR_INVALID_TRANSGENDER_TARGET': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể thay đổi giới tính'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_TELEPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi cuối cùng bạn đã quay lại'},
#  'UIIT_MSG_STRGERR_CANT_FIND_LAST_DIEDPOS': {'Service': '1',
#   'Data': 'Không thể tìm thấy nơi bạn đã chết'},
#  'UIIT_MSG_STRGERR_ONLY_THE_DEAD_CAN_USE_RESURRECT_SCROLL': {'Service': '1',
#   'Data': 'Chỉ sử dụng trong tình trạng đã chết'},
#  'UIIT_MSG_STRGERR_THERE_IS_NO_ITEM_TO_REPAIR': {'Service': '1',
#   'Data': 'Không có đồ vật nào cần sửa chữa'},
#  'UIIT_MSG_STRGERR_CANT_QUICKSELL_CASHITEM': {'Service': '1',
#   'Data': 'Không có chức năng mua bán nhanh với những món đồ hiếm.'},
#  'UIIT_MSG_STRGERR_TRADE_FAILURE': {'Service': '1',
#   'Data': 'Giao dịch thất bại không có lý do'},
#  'UIIT_STT_SILKMALL_FAIL_ITEMBUY_LOGOUT': {'Service': '1',
#   'Data': 'Trò chơi sẽ chấm dứt do việc mua đồ Premium thất bại'},
#  'UIIT_STT_SILKMALL_DONOT_USE_TELEPORT': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_MSG_SELL_RECONFIRM': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển khi đang giao dịch trong Siêu Thị'},
#  'UIIT_PAG_CHAR_SKIN_CHANGE': {'Service': '1',
#   'Data': 'Thay đổi hình dáng bên ngoài của nhân vật'},
#  'UIIT_MSG_CHAR_SKIN_ERR_ARMOR': {'Service': '1',
#   'Data': 'Để thay đổi giới tính phải bỏ đồ bảo hộ và gỡ bỏ hết các ô mở rộng'},
#  'UIIT_MSG_CHAR_SKIN_CHANGE_SUCCESS': {'Service': '1',
#   'Data': 'Thay đổi giới tính thành công'},
#  'UIIT_STT_GUILD_INFO': {'Service': '1', 'Data': 'T.Tin Hội'},
#  'UIIT_CTL_LETTER': {'Service': '1', 'Data': 'Hộp thư kết hợp'},
#  'UIIT_CTL_FRIEND': {'Service': '1', 'Data': 'Bạn'},
#  'UIIT_STT_GUILD_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_LEADER': {'Service': '1', 'Data': 'Hội chủ'},
#  'UIIT_STT_GUILD_STAFF': {'Service': '1', 'Data': 'Hội phó'},
#  'UIIT_STT_GUILDSMAN': {'Service': '1', 'Data': 'Hội viên'},
#  'UIIT_STT_GUILDSMAN_NUM': {'Service': '1', 'Data': 'Số'},
#  'UIIT_STT_GUILD_COMMON_KNOW': {'Service': '1', 'Data': 'Chú ý'},
#  'UIIT_STT_GUILD_COMMON_KNOW_WRITE': {'Service': '1',
#   'Data': 'Viết thông báo'},
#  'UIIT_MSG_GUILD_COMMON_NOTEXIST': {'Service': '1',
#   'Data': 'Không có thông báo'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo (%d/Tối đa.%d)'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_TITLE_REMIND': {'Service': '1',
#   'Data': 'Hãy điền tiêu đề lời thông báo'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT_TITLE': {'Service': '1',
#   'Data': 'Chưa điền tiêu đề'},
#  'UIIT_MSG_GUILDERR_INVALID_MASTER_COMMENT': {'Service': '1',
#   'Data': 'Hãy điền nội dung thông báo'},
#  'UIIT_MSG_GUILDERR_TARGET_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Người chơi khác không có quyền'},
#  'UIIT_CTL_GUILD_WRITE_END': {'Service': '1', 'Data': 'Hoàn thành'},
#  'UIIT_MSG_GUILD_COMMON_KNOW_REMIND_UPDATE': {'Service': '1',
#   'Data': 'Thông báo của Hội đã thay đổi'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_JOIN': {'Service': '1',
#   'Data': 'Hội chủ Hội [%s] đề nghị liên minh với bạn, bạn có chấp nhận không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_WITHDRAWA': {'Service': '1',
#   'Data': 'Bạn có muốn rời bỏ liên minh không?'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_BREAKUP': {'Service': '1',
#   'Data': 'Liên minh đã bị giải tán'},
#  'UIIT_MSG_QUESTION_GUILD_RESPECT_ALLY_NOTALLY': {'Service': '1',
# ...
#   'Data': 'Đã khỏi bệnh'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CHAOS': {'Service': '1',
#   'Data': 'Đã khỏi lẫn lộn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_PD': {'Service': '1',
#   'Data': 'Đã khỏi bị thối rữa'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_MD': {'Service': '1',
#   'Data': 'Đã được khoẻ lại'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_STR': {'Service': '1',
#   'Data': 'Đã hết bất lực'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_INT': {'Service': '1',
#   'Data': 'Đã hết bị cô lập'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSE_HP': {'Service': '1',
#   'Data': 'Đã hết hoảng loạn'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_CURSIE_MP': {'Service': '1',
#   'Data': 'Đã hết bị thiêu đốt'},
#  'UIIT_MSG_STATE_SKILL_CURSING_RELEASE_TIME_BOMB': {'Service': '1',
#   'Data': 'Đã hết ẩn nấp'},
#  'UIIT_MSG_BURN': {'Service': '1', 'Data': 'Thiêu đốt'},
#  'UIIT_MSG_FROSTBITE': {'Service': '1', 'Data': 'Tê cóng'},
#  'UIIT_MSG_FREEZING': {'Service': '1', 'Data': 'Đóng băng'},
#  'UIIT_MSG_SHOCK': {'Service': '1', 'Data': 'Nhiễm điện'},
#  'UIIT_MSG_ZOMBIE': {'Service': '1', 'Data': 'Yểm bùa'},
#  'UIIT_MSG_DARK': {'Service': '1', 'Data': 'Mờ mắt'},
#  'UIIT_MSG_STUN': {'Service': '1', 'Data': 'Choáng'},
#  'UIIT_MSG_PARTYERR_OUT_OF_LEVEL': {'Service': '1',
#   'Data': 'Không thể vào nhóm đó do sự chênh lệch về cấp độ.'},
#  'UIIT_MSG_FLEAMARKET_ERR_IM_BUSY': {'Service': '1',
#   'Data': 'Bạn ở trong tình trạng không được mở gian hàng mới'},
#  'UIIT_MSG_JSERR_SINCE_YOU_DIE_IN_MURDERER_SP_DEPRIVED_BY_SERVER': {'Service': '1',
#   'Data': 'Bị mất [%u] điểm kinh nghiệm'},
#  'UIIT_MSG_INTERACTION_FAIL__REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_REQUESTED_JOB_BLOCKED_BY_QUEST': {'Service': '1',
#   'Data': 'Yêu cầu không thực hiện được'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_PORTAL_SCROLL': {'Service': '1',
#   'Data': 'Không thể sử dụng bùa dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_SUMMON_VEHICLE': {'Service': '1',
#   'Data': 'Không thể dùng thú vận chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_INTERACTION_FAIL_MURDERER_CAN_USE_PORTAL_STRUCTURE': {'Service': '1',
#   'Data': 'Không thể qua cổng dịch chuyển trong tình trạng sát nhân'},
#  'UIIT_MSG_FLEAMARKET_ERR_CANT_OPEN_MARKET_MURDERER': {'Service': '1',
#   'Data': 'Không thể mở gian hàng mới trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_MURDERER_CANT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng item trong tình trạng sát nhân'},
#  'UIIT_MSG_STRGERR_ENABLEINPUT_FEWERTHAN_REMAIN': {'Service': '1',
#   'Data': 'Chỉ có thể nhập số đơn vị còn lại'},
#  'UIIT_MSG_STRGERR_CANNOT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy người chơi khác'},
#  'UIIT_MSG_STRGERR_SPECIFY_POSITIVE_NUMBER_ONLY': {'Service': '1',
#   'Data': 'Số không hợp lệ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi bị hủy bỏ'},
#  'UIIT_MSG_STRGERR_EXCHANGE_BEFORE_CANCEL': {'Service': '1',
#   'Data': 'Trao đổi lần trước bị hủy bỏ vì đã thực hiện trao đổi với người chơi khác'},
#  'UIIT_MSG_STRGERR_CANNOT_WITDRAW_MORETHAN_DEPOSIT': {'Service': '1',
#   'Data': '-'},
#  'UIIT_MSG_DEAL_ASK': {'Service': '1',
#   'Data': 'Có người muốn trao đổi với bạn. Bạn chấp nhận chứ?'},
#  'UIIT_MSG_DEAL_ASKING': {'Service': '1', 'Data': 'Trao đổi với [%s]'},
#  'UIIT_MSG_STRGERR_INVALID_TARGET': {'Service': '1',
#   'Data': 'Không thấy mục tiêu'},
#  'UIIT_MSG_STRGERR_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận làm việc khác'},
#  'UIIT_MSG_STRGERR_NOT_ENOUGH_OPPONENT_INV_SPACE': {'Service': '1',
#   'Data': 'Không thể đưa thêm món đồ đó vào cửa sổ trao đổi vì thùng đồ người kia đã đầy.'},
#  'UIIT_MSG_STRGERR_NON_SETUP_KEY': {'Service': '1',
#   'Data': 'Không thể đặt phím đã lựa chọn'},
#  'UIIT_MSG_STRGERR_CHATING_LIMIT': {'Service': '1',
#   'Data': 'Không thể lặp lại cùng nội dung'},
#  'UIIT_MSG_STRGERR_DEAL_FAIL_NON_ITEM': {'Service': '1',
#   'Data': 'Giao dịch không được thực hiện do không có đồ vật giao dịch'},
#  'UIIT_STT_TARGETTING': {'Service': '1', 'Data': 'Mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTLEARN': {'Service': '1',
#   'Data': 'Kỹ năng không xác định'},
#  'UIIT_SKILL_USE_FAIL_TIMEDELAY_REUSEDELAY': {'Service': '1', 'Data': '-'},
#  'UIIT_SKILL_USE_FAIL_WRONGDISTANCE': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng với mục tiêu'},
#  'UIIT_SKILL_USE_FAIL_NOTENOUGHLEVEL': {'Service': '1',
#   'Data': 'Không sử dụng được vì cấp độ của bạn thấp'},
#  'UIIT_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh người chơi khác vì cấp độ của người đó cao hơn bạn'},
#  'UIIT_CHATERR_CANT_FIND_TARGET': {'Service': '1',
#   'Data': 'Không tìm thấy [%s]'},
#  'UIIT_CHATERR_YOU_ARE_SQUELCHED': {'Service': '1',
#   'Data': 'Chức năng thì thầm của  [%s]đã bị tắt'},
#  'UIIT_CHATERR_NOT_A_PARTY_MEMBER': {'Service': '1',
#   'Data': 'Không ở trong nhóm nào'},
#  'UIIT_CHATERR_INVALID_COMMAND': {'Service': '1',
#   'Data': 'Lệnh chat không hợp lệ'},
#  'UIIT_CHATERR_ALLIANCE_PERMISSION_DENIED': {'Service': '1',
#   'Data': 'Không sử dụng được chức năng tán gẫu với đồng minh vì Hội được chọn không phải là đồng minh của bạn'},
#  'UIIT_CHATERR_WHISPER_TO_MESSAGE': {'Service': '1', 'Data': 'Tin đi'},
#  'UIIT_CHATERR_WHISPER_FROM_MESSAGE': {'Service': '1', 'Data': 'Tin đến'},
#  'UIIT_TOOLTIP_PK_DAY': {'Service': '1', 'Data': 'PK hàng ngày %d / %d'},
#  'UIIT_TOOLTIP_PK_TOTAL': {'Service': '1', 'Data': 'Tổng PK %d / %d'},
#  'UIIT_TOOLTIP_PK_PENALTY_TIME': {'Service': '1',
#   'Data': 'Chỉ số PK %d (Cấp độ %d)'},
#  'UIIT_TOOLTIP_PENALTY_GOLD': {'Service': '1', 'Data': 'Phạt %d vàng'},
#  'UIIT_TOOLTIP_JOB_PENALTY_TIME': {'Service': '1',
#   'Data': 'Không được hành nghề trong %d phút'},
#  'UIIT_TOOLTIP_EQUIPMENT_CLASS': {'Service': '1', 'Data': 'Cấp: Cấp %d'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_DROPPED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể bỏ đi'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_PICKED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể lấy được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_TRADED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể mang ra mua bán được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể sửa chữa được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể làm lại được'},
#  'UIIT_MSG_STRGERR_CANNOT_BE_USED': {'Service': '1',
#   'Data': 'Món đồ được chọn không thể dùng được'},
#  'UIIT_MSG_CANNOT_BE_USED_ITEM_CART': {'Service': '1',
#   'Data': 'Không thể dùng mà không có thú di chuyển/ chuyên chở'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_IN_BATTLE_STATE': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang đánh nhau'},
#  'UIIT_MSG_REMAIN_TIME': {'Service': '1', 'Data': '(còn %d giây)'},
#  'UIIT_MSG_STRGERR_ONLY_ROBBER_CAN_USE_THIS_ITEM': {'Service': '1',
#   'Data': 'Món đồ được chọn chỉ sử dụng được khi làm Đạo Tặc'},
#  'UIIT_MSG_STRGERR_CANT_OPERATE_REQUESTED_JOB_DURING_LOGOUT': {'Service': '1',
#   'Data': 'Không thể thực hiện khi đang thoát trò chơi'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED_TO_USE_THISITEM': {'Service': '1',
#   'Data': 'Không thể đung được món đồ đó vì cấp độ của nhân vật còn thấp'},
#  'UIIT_MSG_LOGOUT_ERR_CANT_LOGOUT_WHILE_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể thoát trò chơi trong khi đang dịch chuyển'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME': {'Service': '1',
#   'Data': 'Còn %d giây sẽ thoát trò chơi'},
#  'UIIT_MSG_LOGOUT_REMAIN_TIME_CANCLE': {'Service': '1',
#   'Data': 'Hủy bỏ việc thoát khỏi trò chơi'},
#  'UIIT_MSG_STRGERR_CANT_SELL_EQUIPED_ITEM': {'Service': '1',
#   'Data': 'Không thể bán món đồ khi đang trang bị'},
#  'UIIT_MSG_STRGERR_CANT_SWAP_JOBITEM': {'Service': '1',
#   'Data': 'Phải bỏ món đồ trước ra thì mới mặc đồ mới vào được'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBCHANGE_COMPLETE': {'Service': '1',
#   'Data': 'Không thể cởi trang bị nghề nghiệp trong vòng 10 giây kể từ lúc đeo vào'},
#  'UIIT_MSG_STRGERR_WAIT_FOR_JOBITEM_DETACH_COMPLETE': {'Service': '1',
#   'Data': 'Không thể đeo trang bị nghề nghiệp khác trong 10 phút kể từ lúc tháo ra'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_JOBITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Bạn chỉ có thể bỏ trang bị nghề nghiệp sau 20 giây kể từ trận chiến cuối cùng.'},
#  'UIIT_MSG_STRGERR_CANT_HAVE_CART': {'Service': '1',
#   'Data': 'Không thể bỏ trang bị nghề nghiệp ra trong khi đang triệu tập thú vận chuyển'},
#  'UIIT_MSG_COSERR_COLLISION_EXIST_BETWEEN_US': {'Service': '1',
#   'Data': 'Không thực hiện được lệnh di chuyển do có chướng ngại vật'},
#  'UIIT_MSG_INTERACTION_FAIL_IM_BUSY': {'Service': '1',
#   'Data': 'Người đó đang bận việc khác'},
#  'UIIT_MSG_SKILL_USE_FAIL_RESURRECT': {'Service': '1',
#   'Data': 'Không thể hồi sinh vì kỹ năng hồi sinh của bạn còn thấp'},
#  'UIIT_MSG_SKILL_USE_FAIL_NOTENOUGHHP': {'Service': '1',
#   'Data': 'Không thể sử dụng kỹ năng đó vì không đủ HP'},
#  'UIIT_MSG_SKILL_USE_FAIL_ITS_NOT_A_BATTLE_FIELD': {'Service': '1',
#   'Data': 'Không thể tấn công trong khu vực an toàn'},
#  'UIIT_MSG_SKILL_USE_FAIL_WAITFOR_JOB_ACTIVATE': {'Service': '1',
#   'Data': 'Không thể tấn công trong 10 giây kể từ lúc mang trang bị nghề nghiệp vào'},
#  'UIIT_MSG_STRGERR_DONT_HAVE_ANY_TRADECART_TO_PICK_SPECIALTY': {'Service': '1',
#   'Data': 'Không thể nhận được đặc sản nếu không có thú vận chuyển'},
#  'UIIT_MSG_STRGERR_CANT_BE_STORED': {'Service': '1',
#   'Data': 'Món đồ đó không thể lưu tại nơi đã chỉ định'},
#  'UIIT_MSG_STRGERR_HIGHER_LEVEL_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị đồ vật vì cấp độ hoặc cấp độ tuyệt kỹ nhân vật còn thấp'},
#  'UIIT_MSG_STRGERR_LOCKED_BY_OTHER_ONE': {'Service': '1',
#   'Data': 'Không thể lấy được món đồ đó vì nó của người chơi khác'},
#  'UIIT_MSG_STRGERR_GENDER_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác giới tính'},
#  'UIIT_MSG_STRGERR_TRADE_BAY_FULL': {'Service': '1',
#   'Data': 'Không thể thêm vào món đồ đã chọn vì cửa sổ trao đổi đã đầy'},
#  'UIIT_MSG_STRGERR_COUNTRY_MISMATCH': {'Service': '1',
#   'Data': 'Không thể trang bị vì khác chủng tộc'},
#  'UIIT_MSG_STRGERR_HIGHER_STRENGTH_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì thiếu sức mạnh'},
#  'UIIT_MSG_STRGERR_HIGHER_INTELLECT_REQUIRED': {'Service': '1',
#   'Data': 'Không thể trang bị vì trí tuệ thấp'},
#  'UIIT_MSG_STRGERR_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_EU_CANT_MIX_EXCLUSIVE_ARMOR_TYPE': {'Service': '1',
#   'Data': 'Không thể mang cả giáp nặng và giáp vải cùng lúc được'},
#  'UIIT_MSG_STRGERR_CANT_EQUIP_RAZED_ITEM': {'Service': '1',
#   'Data': 'Không thể trang bị món đồ đã hỏng'},
#  'UIIT_MSG_STRGERR_PREV_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển.'},
#  'UIIT_MSG_STRGERR_POSSESSION_LIMIT_EXCEEDED': {'Service': '1',
#   'Data': 'Không thể có nhiều hơn số lượng giới hạn'},
#  'UIIT_MSG_STRGERR_ROBBER_CANT_SUMMON_CART_IN_TOWN': {'Service': '1',
#   'Data': 'Không thể triệu hồi phương tiện chuyên trở khi đang ở Làng Đạo Tặc'},
#  'UIIT_MSG_INTERACTION_FAIL_TELESCROLL_ALREADY_WORKING': {'Service': '1',
#   'Data': 'Không thể chọn cách khác vì bạn đang dịch chuyển rồi'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_TRADECART': {'Service': '1',
#   'Data': 'Không thể dịch chuyển khi đang có thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANT_USE_TELEPORT_WITH_RIDE': {'Service': '1',
#   'Data': 'Không thể sử dụng cổng dịch chuyển khi đang cưỡi thú'},
#  'UIIT_MSG_INTERACTION_FAIL_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Không thể qua đò khi đang ở xa thú vận chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REPAIRED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không sửa chữa được'},
#  'UIIT_MSG_INTERACTION_FAIL_CANNOT_BE_REVIVED': {'Service': '1',
#   'Data': 'Món đồ đã chọn không làm lại được'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_TEMPORARILY': {'Service': '1',
#   'Data': 'Bất khả xâm phạm - Không thể tấn công hoăc bị tấn công trong 5 giây'},
#  'UIIT_MSG_SKILL_USE_FAIL_CANT_ATTACK_FORTRESS': {'Service': '1',
#   'Data': 'Khi tấn công pháo đài trong tình trạng bất khả xâm phạm - không thể tấn công trong 10 giây'},
#  'UIIT_MSG_COSERR_TOO_FAR_FROM_TRADECART': {'Service': '1',
#   'Data': 'Một nhân vật không thể cách xa quá thú vận chuyển %d m'},
#  'UIIT_MSG_RETURN_CANCLE': {'Service': '1',
#   'Data': 'Việc sử dụng bùa dịch chuyển đã bị hủy bỏ'},
#  'UIIT_MSG_QUESTEND_2': {'Service': '1',
#   'Data': 'Hãy mở cửa sổ Nhiệm vụ (Q) để kiểm tra nội dung'},
#  'UIIT_MSG_JSERR_PREVIOUS_TELEPORT_WORKING': {'Service': '1',
#   'Data': 'Không thể vào mê cung khi sắp dịch chuyển'},
#  'UIIT_MSG_INTERACTION_FAIL_OUT_OF_REQUIRED_LEVEL_FOR_TELEPORT': {'Service': '1',
#   'Data': 'Không thể dịch chuyển vì cấp độ của bạn quá thấp'},
#  'UIIT_MSG_STRGERR_CANT_DETACH_FREEBATTLEITEM_IN_BATTLESTATE': {'Service': '1',
#   'Data': 'Không thể bỏ khăn ra trong khi đang đánh nhau'},
#  'UIIT_MSG_STRGERR_STORAGE_OPERATION_BLOCKED': {'Service': '1',
#   'Data': 'Hiện tại bạn không được phép di chuyển các món đồ hoặc trao đổi chúng'},
#  'UIIT_MSG_QUEST_CALLMONSTER_NOTATTACK': {'Service': '1',
#   'Data': 'Cấp độ của bạn còn quá thấp để có thể đánh nhau với quái vật'},
#  'UIIT_MSG_QUEST_GET_ITEM_FAILURE': {'Service': '1',
#   'Data': 'Không thể nhặt được món đồ'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_MONSTER': {'Service': '1',
#   'Data': 'Không thể di chuyển vì bạn đã ở cách quái vật %d m.'},
#  'UIIT_MSG_QUEST_FAIL_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Đã thất bại trong việc bắt giữ quái vật.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_CHATTING_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn đang làm nhiệm vụ nên không thể tán gẫu được.'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MOVING_IN_DUNGEON': {'Service': '1',
#   'Data': 'Đã ra khỏi vị trí chỉ định nên không thể di chuyển được nữa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_DO_IT_ABOUTQUEST': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này vì bạn đang làm một nhiệm vụ khác có liên quan.'},
#  'UIIT_MSG_QUEST_ERR_TOO_LOW_LEVEL': {'Service': '1',
#   'Data': 'Bạn không thể nhận nhiệm vụ này do cấp độ của bạn còn thấp'},
#  'UIIT_MSG_QUEST_END_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ kết thúc sau %d phút'},
#  'UIIT_MSG_QUEST_START_TIME': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ bắt đầu trong %d giây (s)'},
#  'UIIT_MSG_QUEST_ERR_USE_WHANITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật này trong trạng thái Cuồng nộ'},
#  'UIIT_MSG_QUEST_ERR_CAPTUREMONSTER_ATTACK': {'Service': '1',
#   'Data': 'Không thể tấn công quái vật đã sập bẫy'},
#  'UIIT_MSG_QUEST_ERR_TOO_FAR_FROM_CATCH_MONSTER': {'Service': '1',
#   'Data': 'Không thể bắt quái vật thì khoảng cách quá xa'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì đã đặt bẫy rồi'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_EXIST_MONSTER': {'Service': '1',
#   'Data': 'Không thể đặt bẫy vì quái vật ở quá gần'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_USE_ITEM': {'Service': '1',
#   'Data': 'Không thể sử dụng đồ vật vì điều kiện nhiệm vụ không cho phép'},
#  'UIIT_MSG_QUEST_ERR_CANNOT_MAKE_TRAP_WRONG_PLACE': {'Service': '1',
#   'Data': 'Không thể đặt bẫy trong khu vực này'},
#  'UIIT_MSG_QUEST_ERR_NO_TARGET': {'Service': '1',
#   'Data': 'Mệnh lệnh không thể thực thi do chưa chọn đối tượng'},
#  'UIIT_MSG_CANNOT_BUYBACK_ITEM_SELL': {'Service': '1',
#   'Data': 'Đồ vật không thể mua lại được. Bạn có chắc muốn bán nó đi không?'},
#  'UIIT_MSG_QUEST_INS_TIMEOUT': {'Service': '1',
#   'Data': 'Nhiệm vụ sẽ hoàn htành sau %d giây, bạn sẽ được trở lại vị trí ban đầu.'},
#  'UIIT_MSG_QUEST_INS_CONDITION': {'Service': '1',
#   'Data': 'Bạn sẽ trở lại vị trí ban đầu trong 5 giây nữa vì nhận được yêu cầu không thể ở lại khu vực hiện tại.'},
#  'UIIT_MSG_QUEST_INS_DEATH': {'Service': '1',
#   'Data': 'Không thể chuyển đến khu vực khác khi nhân vật của bạn đang bị chết'},
#  'UIIT_MSG_DROP_WARNING_1': {'Service': '1',
#   'Data': 'Nếu bạn vứt đồ vật này ra ngoài, thì bạn sẽ mất đi quyền sở hữu đồ vật này'},
#  'UIIT_MSG_DROP_WARNING_2': {'Service': '1',
#   'Data': 'Người khác có thể nhật chúng. Bạn có chắc là muốn vứt nó ra không?'},
#  ...}

# %%
df = pd.DataFrame.from_dict(data_text, orient='index')
df.reset_index(inplace=True)
df.rename(columns={'index': 'Key'}, inplace=True)

# %%
df
# Out:
#                                Key Service  \
# 0                 UIC_STT_FONTNAME       1
# 1       UIIS_STT_MSG_INSTALL_START       1
# 2      UIIS_STT_MSG_INSTALL_FOLDER       1
# 3         UIIS_STT_MSG_INSTALL_END       1
# 4          UIIS_STT_INSTALL_FOLDER       1
# ...                            ...     ...
# 57853      SN_TALK_QNO_N_KT_082_02       1
# 57854      SN_TALK_QNO_N_KT_082_03       1
# 57855      SN_TALK_QNO_N_KT_082_04       1
# 57856      SN_TALK_QNO_N_KT_082_05       1
# 57857      SN_TALK_QNO_N_KT_082_06       1
#
#                                                     Data
# 0                                                 Tahoma
# 1                             Cài đặt "Con Đường Tơ Lụa"
# 2             Cài đặt "Con Đường Tơ Lụa" vào thư mục sau
# 3            Con Đường Tơ Lụa đã được cài đặt thành công
# 4                                        Thư mục cài đặt
# ...                                                  ...
# 57853      Giết 308 Lam Băng Binh và 330 Khôi Băng Binh.
# 57854                      Chúng quá mạnh mẽ so với bạn?
# 57855      Giết 308 Lam Băng Binh và 330 Khôi Băng Binh.
# 57856  Bạn đã làm rất tốt. Nhưng bạn không được phép ...
# 57857  Bạn đã hoàn thành nhiệm vụ tiêu diệt Lam Băng ...
#
# [57858 rows x 3 columns]

# %%
csv_file_path = 'data_text.csv'
df.to_csv(csv_file_path, index=False, encoding='utf-8')
