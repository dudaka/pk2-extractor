# %%
import os
import io
import struct
from typing import List, Tuple, Optional
from enum import Enum
import pandas as pd

from blowfish import Blowfish

# %%
class PackEntryType(Enum):
  Nop = 0
  Folder = 1
  File = 2

# %%
def generate_final_blowfish_key(password: str, salt: bytes) -> bytes:
    """
    Reproduces the 'GenerateFinalBlowfishKey' logic in C#.
    """
    # 1) Limit key length to max of 56
    plain_key_length = min(len(password), 56)

    # 2) Convert password to ASCII bytes
    a_key = password.encode("ascii")

    # 3) Create a 56-byte base key buffer
    b_key = bytearray(56)
    
    # Copy salt into b_key
    # Equivalent to `Array.ConstrainedCopy(salt, 0, bKey, 0, salt.Length)`
    b_key[:len(salt)] = salt

    # 4) Generate the final blowfish key by XOR-ing
    #    the ASCII password bytes with the corresponding part of b_key.
    bf_key = bytearray(plain_key_length)
    for x in range(plain_key_length):
        bf_key[x] = a_key[x] ^ b_key[x]

    return bytes(bf_key)

# %%
def read_string_with_length(stream, byte_count: int) -> str:
    """
    Read 'byte_count' bytes, then decode using self._encoding,
    stopping at the first 0 (null terminator) if present.
    """
    buffer = stream.read(byte_count)

    # Find null terminator offset (if any)
    terminator_offset = byte_count
    for i in range(byte_count):
        if buffer[i] == 0:
            terminator_offset = i
            break

    return buffer[:terminator_offset].decode('ascii', errors='replace')

# %%
data_pk2_path = os.path.join(os.getcwd(), 'data', 'Data.pk2')
media_pk2_path = os.path.join(os.getcwd(), 'data', 'Media.pk2')
print(data_pk2_path)
print(media_pk2_path)
# Out:
# c:\Users\htdun\Desktop\workspace\pk2-extractor\data\Data.pk2
# c:\Users\htdun\Desktop\workspace\pk2-extractor\data\Media.pk2

# %%
pk2key = '169841'
salt = [0x03, 0xF8, 0xE4, 0x44, 0x88, 0x99, 0x3F, 0x64, 0xFE, 0x35]

# %%
key = generate_final_blowfish_key(pk2key, bytes(salt))
key
# Out:
# b'2\xce\xdd|\xbc\xa8'

# %%
blowfish = Blowfish()
blowfish.Initialize(key)

# %%
_media_file_stream = open(media_pk2_path, 'rb')

# %%
signature = _media_file_stream.read(30)
version =  struct.unpack('<i', _media_file_stream.read(4))[0]
encrypted = _media_file_stream.read(1)
encryption_checksum = _media_file_stream.read(16)
payload = _media_file_stream.read(205)

# %%
Header = {
    'signature': signature,
    'version': version,
    'encrypted': encrypted,
    'encryption_checksum': encryption_checksum,
    'payload': payload
}

# %%
blowfish_checksum_decoded = "Joymax Pak File"

# %%
if blowfish and encrypted == b'\x01':
    temp_checksum = blowfish.Encode(blowfish_checksum_decoded.encode('ascii'))
    if temp_checksum is None or temp_checksum[0] != encryption_checksum[0] or temp_checksum[1] != encryption_checksum[1] or temp_checksum[2] != encryption_checksum[2]:
        raise Exception('Failed to open JoymaxPackFile: The password or salt is wrong.')

# %%
def read_block_at(position: int):
    _media_file_stream.seek(position, io.SEEK_SET)
    buffer = _media_file_stream.read(128 * 20)
    if blowfish is not None:
      entry_buffer = io.BytesIO(blowfish.Decode(buffer))
    else:
      entry_buffer = io.BytesIO(buffer)

    entries = []
    for _ in range(20):
      entry = {
        "Type": PackEntryType(entry_buffer.read(1)[0]),
        "Name": read_string_with_length(entry_buffer, 89).rstrip('\0'),
        "CreationTime": struct.unpack('<q', entry_buffer.read(8))[0],
        "ModifyTime": struct.unpack('<q', entry_buffer.read(8))[0],
        "DataPosition": struct.unpack('<q', entry_buffer.read(8))[0],
        "DataSize": struct.unpack('<i', entry_buffer.read(4))[0],
        "NextBlock": struct.unpack('<q', entry_buffer.read(8))[0],
        "Payload": entry_buffer.read(2)
      }
      entries.append(entry)
      # print(entry)

    return {
      "Position": position,
      "Entries": entries
    }


def read_blocks_at(position: int):
    result = []

    block = read_block_at(position)
    result.append(block)

    if block["Entries"][19]["NextBlock"] > 0:
        result.extend(read_blocks_at(block["Entries"][19]["NextBlock"]))

    return result

# %%
Root = read_blocks_at(256)

# %%
blocks_in_memory = {
  "": Root
}

# %%
blocks_in_memory
# Out:
# {'': [{'Position': 256,
#    'Entries': [{'Type': <PackEntryType.Folder: 1>,
#      'Name': '.',
#      'CreationTime': 133336205048819447,
#      'ModifyTime': 133336205048819447,
#      'DataPosition': 256,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'acobject',
#      'CreationTime': 133336205048829450,
#      'ModifyTime': 133336205048829450,
#      'DataPosition': 2816,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'config',
#      'CreationTime': 133336205049179438,
#      'ModifyTime': 133336205049179438,
#      'DataPosition': 35136,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Effect',
#      'CreationTime': 133336205049679437,
#      'ModifyTime': 133336205049679437,
#      'DataPosition': 41896,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Fonts',
#      'CreationTime': 133336205051829374,
#      'ModifyTime': 133336205051829374,
#      'DataPosition': 401456,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'icon',
#      'CreationTime': 133336205051849373,
#      'ModifyTime': 133336205051849373,
#      'DataPosition': 404328,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'icon64',
#      'CreationTime': 133336206109740779,
#      'ModifyTime': 133336206109740779,
#      'DataPosition': 35750058,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'interface',
#      'CreationTime': 133336206200969178,
#      'ModifyTime': 133336206200969178,
#      'DataPosition': 49794542,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Launcher',
#      'CreationTime': 133336207373584329,
#      'ModifyTime': 133336207373584329,
#      'DataPosition': 530412246,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Launcher_Europe',
#      'CreationTime': 133336207379694215,
#      'ModifyTime': 133336207379694215,
#      'DataPosition': 533020067,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'minimap',
#      'CreationTime': 133336207380240850,
#      'ModifyTime': 133336207380240850,
#      'DataPosition': 533900707,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'minimap_d',
#      'CreationTime': 133336208820638962,
#      'ModifyTime': 133336208820638962,
#      'DataPosition': 770423083,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'resinfo',
#      'CreationTime': 133336209064184553,
#      'ModifyTime': 133336209064184553,
#      'DataPosition': 868076619,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'res_ui',
#      'CreationTime': 133336209080076171,
#      'ModifyTime': 133336209080076171,
#      'DataPosition': 870428615,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'script',
#      'CreationTime': 133336209089071935,
#      'ModifyTime': 133336209089071935,
#      'DataPosition': 877210479,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'server_dep',
#      'CreationTime': 133336209091748828,
#      'ModifyTime': 133336209091748828,
#      'DataPosition': 886879815,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'silk.dat',
#      'CreationTime': 133287856801795247,
#      'ModifyTime': 127918116330156250,
#      'DataPosition': 1017317431,
#      'DataSize': 768,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'type.txt',
#      'CreationTime': 133336205046882029,
#      'ModifyTime': 133330897532736718,
#      'DataPosition': 1017318199,
#      'DataSize': 423,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'DIVISIONINFO.TXT',
#      'CreationTime': 133336210349991177,
#      'ModifyTime': 133336210349991177,
#      'DataPosition': 1017319424,
#      'DataSize': 57,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'SV.T',
#      'CreationTime': 133795825379609632,
#      'ModifyTime': 133795825379609632,
#      'DataPosition': 1017319481,
#      'DataSize': 1024,
#      'NextBlock': 1017320505,
#      'Payload': b'\x00\x00'}]},
#   {'Position': 1017320505,
#    'Entries': [{'Type': <PackEntryType.File: 2>,
#      'Name': 'GATEPORT.TXT',
#      'CreationTime': 133336210351001190,
#      'ModifyTime': 133336210351001190,
#      'DataPosition': 1017323065,
#      'DataSize': 8,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'}]}]}

# %%
server_dep = os.path.join('server_dep', 'silkroad', 'textdata')
server_dep
# Out:
# 'server_dep\\silkroad\\textdata'

# %%
ref_shop_data = dict()
ref_shop_tab_data = dict()
ref_shop_group_data = dict()
ref_mapping_shop_group_data = []
ref_mapping_shop_with_tab_data = []

# %% [markdown]
# ## RefShop.txt

# %%
ref_shop = os.path.join(server_dep, 'RefShop.txt')

# %%
def get_entry_buffer(file_path: str) -> Optional[dict]:
  parent_folder_path = os.path.dirname(file_path)
  file_name = os.path.basename(file_path)
  if parent_folder_path not in blocks_in_memory:
    paths = parent_folder_path.split(os.path.sep)
    blocks = blocks_in_memory[""]
    current_path = ""

    for sub_folder_name in paths:
        for block in blocks:
            entries = block["Entries"]
            entry = next((e for e in entries if e["Name"] == sub_folder_name and e["Type"] == PackEntryType.Folder), None)
            if entry is None:
                continue
            
            current_path = os.path.join(current_path, entry["Name"])
            if current_path in blocks_in_memory:
                blocks = blocks_in_memory[current_path]
                break
            
            blocks = read_blocks_at(entry["DataPosition"])
            blocks_in_memory[current_path] = blocks
            break
        
  root = blocks_in_memory[parent_folder_path]
  entry = None
  for entries in root:
    entry = next((x for x in entries["Entries"] if x["Name"] == file_name.lower()), None)
    if entry:
      break

  _media_file_stream.seek(entry["DataPosition"], io.SEEK_SET)
  # _media_file_stream.read(entry["DataSize"])
  buffer = io.BytesIO(_media_file_stream.read(entry["DataSize"])) 

  return buffer
   

def get_lines(file_path: str) -> List[Tuple[str, int]]:

  buffer = get_entry_buffer(file_path)

  text = buffer.read().decode('utf-16', errors="replace")
  lines = text.split('\r\n')
  return lines

# %%
lines = get_lines(ref_shop)
for idx, line in enumerate(lines):
  values = line.split('\t')
  if len(values) != 12:
    continue
  
  Service = values[0]
  Id = values[1]
  CodeName = values[2]
  

  obj = {
    "Service": Service,
    "Id": Id,
    "CodeName": CodeName,    
  }

  ref_shop_data[CodeName] = obj

# %%
ref_shop_data
# Out:
# {'4917': {'Service': '1', 'Id': '42', 'CodeName': '4917'},
#  '4904': {'Service': '1', 'Id': '42', 'CodeName': '4904'},
#  '4875': {'Service': '1', 'Id': '42', 'CodeName': '4875'},
#  '4906': {'Service': '1', 'Id': '42', 'CodeName': '4906'},
#  '4916': {'Service': '1', 'Id': '42', 'CodeName': '4916'},
#  '4981': {'Service': '1', 'Id': '42', 'CodeName': '4981'},
#  '4991': {'Service': '1', 'Id': '42', 'CodeName': '4991'},
#  '4962': {'Service': '1', 'Id': '42', 'CodeName': '4962'},
#  '4946': {'Service': '1', 'Id': '42', 'CodeName': '4946'},
#  '4930': {'Service': '1', 'Id': '42', 'CodeName': '4930'},
#  '4929': {'Service': '1', 'Id': '42', 'CodeName': '4929'},
#  '4919': {'Service': '1', 'Id': '42', 'CodeName': '4919'},
#  '4955': {'Service': '1', 'Id': '42', 'CodeName': '4955'},
#  '4940': {'Service': '1', 'Id': '42', 'CodeName': '4940'},
#  '4931': {'Service': '1', 'Id': '42', 'CodeName': '4931'},
#  '4928': {'Service': '1', 'Id': '42', 'CodeName': '4928'},
#  '4989': {'Service': '1', 'Id': '42', 'CodeName': '4989'},
#  '4932': {'Service': '1', 'Id': '42', 'CodeName': '4932'},
#  '4878': {'Service': '1', 'Id': '42', 'CodeName': '4878'},
#  '4877': {'Service': '1', 'Id': '42', 'CodeName': '4877'},
#  '4912': {'Service': '1', 'Id': '42', 'CodeName': '4912'},
#  '4949': {'Service': '1', 'Id': '42', 'CodeName': '4949'},
#  '4950': {'Service': '1', 'Id': '42', 'CodeName': '4950'},
#  '4973': {'Service': '1', 'Id': '42', 'CodeName': '4973'},
#  '4975': {'Service': '1', 'Id': '42', 'CodeName': '4975'},
#  '4977': {'Service': '1', 'Id': '42', 'CodeName': '4977'},
#  '4936': {'Service': '1', 'Id': '42', 'CodeName': '4936'},
#  '4879': {'Service': '1', 'Id': '42', 'CodeName': '4879'},
#  '4876': {'Service': '1', 'Id': '42', 'CodeName': '4876'},
#  '4985': {'Service': '1', 'Id': '42', 'CodeName': '4985'},
#  '4882': {'Service': '1', 'Id': '42', 'CodeName': '4882'},
#  '4992': {'Service': '1', 'Id': '42', 'CodeName': '4992'},
#  '4944': {'Service': '1', 'Id': '42', 'CodeName': '4944'},
#  '4942': {'Service': '1', 'Id': '42', 'CodeName': '4942'},
#  '4948': {'Service': '1', 'Id': '42', 'CodeName': '4948'},
#  '4922': {'Service': '1', 'Id': '42', 'CodeName': '4922'},
#  '4921': {'Service': '1', 'Id': '42', 'CodeName': '4921'},
#  '4915': {'Service': '1', 'Id': '42', 'CodeName': '4915'},
#  '4954': {'Service': '1', 'Id': '42', 'CodeName': '4954'},
#  '4974': {'Service': '1', 'Id': '42', 'CodeName': '4974'},
#  '4976': {'Service': '1', 'Id': '42', 'CodeName': '4976'},
#  '4978': {'Service': '1', 'Id': '42', 'CodeName': '4978'},
#  '4939': {'Service': '1', 'Id': '42', 'CodeName': '4939'},
#  '4923': {'Service': '1', 'Id': '42', 'CodeName': '4923'},
#  '4920': {'Service': '1', 'Id': '42', 'CodeName': '4920'},
#  '4986': {'Service': '1', 'Id': '42', 'CodeName': '4986'},
#  '4924': {'Service': '1', 'Id': '42', 'CodeName': '4924'},
#  '4947': {'Service': '1', 'Id': '42', 'CodeName': '4947'},
#  '4943': {'Service': '1', 'Id': '42', 'CodeName': '4943'},
#  '4941': {'Service': '1', 'Id': '42', 'CodeName': '4941'},
#  '4970': {'Service': '1', 'Id': '42', 'CodeName': '4970'},
#  '4896': {'Service': '1', 'Id': '42', 'CodeName': '4896'},
#  '4895': {'Service': '1', 'Id': '42', 'CodeName': '4895'},
#  '4914': {'Service': '1', 'Id': '42', 'CodeName': '4914'},
#  '4953': {'Service': '1', 'Id': '42', 'CodeName': '4953'},
#  '4938': {'Service': '1', 'Id': '42', 'CodeName': '4938'},
#  '4897': {'Service': '1', 'Id': '42', 'CodeName': '4897'},
#  '4894': {'Service': '1', 'Id': '42', 'CodeName': '4894'},
#  '4988': {'Service': '1', 'Id': '42', 'CodeName': '4988'},
#  '4898': {'Service': '1', 'Id': '42', 'CodeName': '4898'},
#  '4968': {'Service': '1', 'Id': '42', 'CodeName': '4968'},
#  '4969': {'Service': '1', 'Id': '42', 'CodeName': '4969'},
#  '4979': {'Service': '1', 'Id': '42', 'CodeName': '4979'},
#  '4961': {'Service': '1', 'Id': '42', 'CodeName': '4961'},
#  '4972': {'Service': '1', 'Id': '42', 'CodeName': '4972'},
#  '4958': {'Service': '1', 'Id': '42', 'CodeName': '4958'},
#  '4971': {'Service': '1', 'Id': '42', 'CodeName': '4971'},
#  '4990': {'Service': '1', 'Id': '42', 'CodeName': '4990'},
#  '4945': {'Service': '1', 'Id': '42', 'CodeName': '4945'},
#  '4980': {'Service': '1', 'Id': '42', 'CodeName': '4980'},
#  '4983': {'Service': '1', 'Id': '42', 'CodeName': '4983'},
#  '4984': {'Service': '1', 'Id': '42', 'CodeName': '4984'},
#  '4982': {'Service': '1', 'Id': '42', 'CodeName': '4982'},
#  '4888': {'Service': '1', 'Id': '42', 'CodeName': '4888'},
#  '4887': {'Service': '1', 'Id': '42', 'CodeName': '4887'},
#  '4913': {'Service': '1', 'Id': '42', 'CodeName': '4913'},
#  '4951': {'Service': '1', 'Id': '42', 'CodeName': '4951'},
#  '4952': {'Service': '1', 'Id': '42', 'CodeName': '4952'},
#  '4937': {'Service': '1', 'Id': '42', 'CodeName': '4937'},
#  '4889': {'Service': '1', 'Id': '42', 'CodeName': '4889'},
#  '4886': {'Service': '1', 'Id': '42', 'CodeName': '4886'},
#  '4987': {'Service': '1', 'Id': '42', 'CodeName': '4987'},
#  '4890': {'Service': '1', 'Id': '42', 'CodeName': '4890'}}

# %% [markdown]
# ## RefShopTab.txt

# %%
ref_shop_tab_file = os.path.join(server_dep, 'RefShopTab.txt')
ref_shop_tab_file
# Out:
# 'server_dep\\silkroad\\textdata\\RefShopTab.txt'

# %%
lines = get_lines(ref_shop_tab_file)
for idx, line in enumerate(lines):
    try:
      values = line.split('\t')

      Service = values[0]
      Country = values[1]
      Id = values[2]  
      CodeName = values[3]
      ref_tab_group_code_name = values[4]
      str_id_128_tab = values[5]

      ref_shop_tab_data[CodeName] = {
        "Service": Service,
        "Country": Country,
        "Id": Id,
        "CodeName": CodeName,
        "RefTabGroupCodeName": ref_tab_group_code_name,
        "StrId128Tab": str_id_128_tab
      }
    except Exception as e:
      continue

# %%
ref_shop_tab_data
# Out:
# {'LEVEL_CH_ARMOR1_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13563',
#   'CodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR1_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'LEVEL_CH_ARMOR1_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13564',
#   'CodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR1_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'LEVEL_CH_ARMOR1_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13565',
#   'CodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR1_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'LEVEL_CH_ARMOR1_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13566',
#   'CodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR1_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'LEVEL_CH_ARMOR1_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13567',
#   'CodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR1_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'LEVEL_CH_ARMOR1_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13568',
#   'CodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR1_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'LEVEL_CH_ARMOR2_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13583',
#   'CodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR2_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'LEVEL_CH_ARMOR2_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13584',
#   'CodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR2_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'LEVEL_CH_ARMOR2_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13585',
#   'CodeName': 'LEVEL_CH_ARMOR2_TAB3',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR2_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'LEVEL_CH_ARMOR2_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13586',
#   'CodeName': 'LEVEL_CH_ARMOR2_TAB4',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR2_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'LEVEL_CH_ARMOR2_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13587',
#   'CodeName': 'LEVEL_CH_ARMOR2_TAB5',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR2_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'LEVEL_CH_ARMOR2_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13588',
#   'CodeName': 'LEVEL_CH_ARMOR2_TAB6',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR2_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'LEVEL_CH_ARMOR3_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13603',
#   'CodeName': 'LEVEL_CH_ARMOR3_TAB1',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR3_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'LEVEL_CH_ARMOR3_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13604',
#   'CodeName': 'LEVEL_CH_ARMOR3_TAB2',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR3_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'LEVEL_CH_ARMOR3_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13605',
#   'CodeName': 'LEVEL_CH_ARMOR3_TAB3',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR3_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'LEVEL_CH_ARMOR3_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13606',
#   'CodeName': 'LEVEL_CH_ARMOR3_TAB4',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR3_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'LEVEL_CH_ARMOR3_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13607',
#   'CodeName': 'LEVEL_CH_ARMOR3_TAB5',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR3_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'LEVEL_CH_ARMOR3_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13608',
#   'CodeName': 'LEVEL_CH_ARMOR3_TAB6',
#   'RefTabGroupCodeName': 'LEVEL_CH_ARMOR3_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'LEVEL_CH_VALUABLE1_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13569',
#   'CodeName': 'LEVEL_CH_VALUABLE1_TAB1',
#   'RefTabGroupCodeName': 'LEVEL_CH_VALUABLE1_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'LEVEL_CH_VALUABLE1_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13570',
#   'CodeName': 'LEVEL_CH_VALUABLE1_TAB2',
#   'RefTabGroupCodeName': 'LEVEL_CH_VALUABLE1_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'LEVEL_CH_VALUABLE1_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13571',
#   'CodeName': 'LEVEL_CH_VALUABLE1_TAB3',
#   'RefTabGroupCodeName': 'LEVEL_CH_VALUABLE1_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY'},
#  'LEVEL_CH_VALUABLE1_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13572',
#   'CodeName': 'LEVEL_CH_VALUABLE1_TAB4',
#   'RefTabGroupCodeName': 'LEVEL_CH_VALUABLE1_GROUP1',
#   'StrId128Tab': 'SN_TAB_VALUABLES'},
#  'LEVEL_CH_VALUABLE2_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13589',
#   'CodeName': 'LEVEL_CH_VALUABLE2_TAB1',
#   'RefTabGroupCodeName': 'LEVEL_CH_VALUABLE2_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'LEVEL_CH_VALUABLE2_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13590',
#   'CodeName': 'LEVEL_CH_VALUABLE2_TAB2',
#   'RefTabGroupCodeName': 'LEVEL_CH_VALUABLE2_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'LEVEL_CH_VALUABLE2_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13591',
#   'CodeName': 'LEVEL_CH_VALUABLE2_TAB3',
#   'RefTabGroupCodeName': 'LEVEL_CH_VALUABLE2_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY'},
#  'LEVEL_CH_VALUABLE2_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13592',
#   'CodeName': 'LEVEL_CH_VALUABLE2_TAB4',
#   'RefTabGroupCodeName': 'LEVEL_CH_VALUABLE2_GROUP1',
#   'StrId128Tab': 'SN_TAB_VALUABLES'},
#  'LEVEL_CH_VALUABLE3_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13609',
#   'CodeName': 'LEVEL_CH_VALUABLE3_TAB1',
#   'RefTabGroupCodeName': 'LEVEL_CH_VALUABLE3_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'LEVEL_CH_VALUABLE3_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13610',
#   'CodeName': 'LEVEL_CH_VALUABLE3_TAB2',
#   'RefTabGroupCodeName': 'LEVEL_CH_VALUABLE3_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'LEVEL_CH_VALUABLE3_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13611',
#   'CodeName': 'LEVEL_CH_VALUABLE3_TAB3',
#   'RefTabGroupCodeName': 'LEVEL_CH_VALUABLE3_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY'},
#  'LEVEL_CH_VALUABLE3_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13612',
#   'CodeName': 'LEVEL_CH_VALUABLE3_TAB4',
#   'RefTabGroupCodeName': 'LEVEL_CH_VALUABLE3_GROUP1',
#   'StrId128Tab': 'SN_TAB_VALUABLES'},
#  'LEVEL_EU_ARMOR1_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13573',
#   'CodeName': 'LEVEL_EU_ARMOR1_TAB1',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR1_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'LEVEL_EU_ARMOR1_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13574',
#   'CodeName': 'LEVEL_EU_ARMOR1_TAB2',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR1_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'LEVEL_EU_ARMOR1_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13575',
#   'CodeName': 'LEVEL_EU_ARMOR1_TAB3',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR1_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'LEVEL_EU_ARMOR1_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13576',
#   'CodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR1_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'LEVEL_EU_ARMOR1_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13577',
#   'CodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR1_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'LEVEL_EU_ARMOR1_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13578',
#   'CodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR1_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'LEVEL_EU_ARMOR2_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13593',
#   'CodeName': 'LEVEL_EU_ARMOR2_TAB1',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR2_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'LEVEL_EU_ARMOR2_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13594',
#   'CodeName': 'LEVEL_EU_ARMOR2_TAB2',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR2_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'LEVEL_EU_ARMOR2_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13595',
#   'CodeName': 'LEVEL_EU_ARMOR2_TAB3',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR2_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'LEVEL_EU_ARMOR2_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13596',
#   'CodeName': 'LEVEL_EU_ARMOR2_TAB4',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR2_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'LEVEL_EU_ARMOR2_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13597',
#   'CodeName': 'LEVEL_EU_ARMOR2_TAB5',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR2_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'LEVEL_EU_ARMOR2_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13598',
#   'CodeName': 'LEVEL_EU_ARMOR2_TAB6',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR2_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'LEVEL_EU_ARMOR3_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13613',
#   'CodeName': 'LEVEL_EU_ARMOR3_TAB1',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR3_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'LEVEL_EU_ARMOR3_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13614',
#   'CodeName': 'LEVEL_EU_ARMOR3_TAB2',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR3_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'LEVEL_EU_ARMOR3_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13615',
#   'CodeName': 'LEVEL_EU_ARMOR3_TAB3',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR3_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'LEVEL_EU_ARMOR3_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13616',
#   'CodeName': 'LEVEL_EU_ARMOR3_TAB4',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR3_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'LEVEL_EU_ARMOR3_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13617',
#   'CodeName': 'LEVEL_EU_ARMOR3_TAB5',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR3_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'LEVEL_EU_ARMOR3_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13618',
#   'CodeName': 'LEVEL_EU_ARMOR3_TAB6',
#   'RefTabGroupCodeName': 'LEVEL_EU_ARMOR3_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'LEVEL_EU_VALUABLE1_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13579',
#   'CodeName': 'LEVEL_EU_VALUABLE1_TAB1',
#   'RefTabGroupCodeName': 'LEVEL_EU_VALUABLE1_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'LEVEL_EU_VALUABLE1_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13580',
#   'CodeName': 'LEVEL_EU_VALUABLE1_TAB2',
#   'RefTabGroupCodeName': 'LEVEL_EU_VALUABLE1_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'LEVEL_EU_VALUABLE1_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13581',
#   'CodeName': 'LEVEL_EU_VALUABLE1_TAB3',
#   'RefTabGroupCodeName': 'LEVEL_EU_VALUABLE1_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY_1'},
#  'LEVEL_EU_VALUABLE1_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13582',
#   'CodeName': 'LEVEL_EU_VALUABLE1_TAB4',
#   'RefTabGroupCodeName': 'LEVEL_EU_VALUABLE1_GROUP1',
#   'StrId128Tab': 'SN_TAB_VALUABLES'},
#  'LEVEL_EU_VALUABLE2_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13599',
#   'CodeName': 'LEVEL_EU_VALUABLE2_TAB1',
#   'RefTabGroupCodeName': 'LEVEL_EU_VALUABLE2_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'LEVEL_EU_VALUABLE2_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13600',
#   'CodeName': 'LEVEL_EU_VALUABLE2_TAB2',
#   'RefTabGroupCodeName': 'LEVEL_EU_VALUABLE2_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'LEVEL_EU_VALUABLE2_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13601',
#   'CodeName': 'LEVEL_EU_VALUABLE2_TAB3',
#   'RefTabGroupCodeName': 'LEVEL_EU_VALUABLE2_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY_1'},
#  'LEVEL_EU_VALUABLE2_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13602',
#   'CodeName': 'LEVEL_EU_VALUABLE2_TAB4',
#   'RefTabGroupCodeName': 'LEVEL_EU_VALUABLE2_GROUP1',
#   'StrId128Tab': 'SN_TAB_VALUABLES'},
#  'LEVEL_EU_VALUABLE3_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13619',
#   'CodeName': 'LEVEL_EU_VALUABLE3_TAB1',
#   'RefTabGroupCodeName': 'LEVEL_EU_VALUABLE3_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'LEVEL_EU_VALUABLE3_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13620',
#   'CodeName': 'LEVEL_EU_VALUABLE3_TAB2',
#   'RefTabGroupCodeName': 'LEVEL_EU_VALUABLE3_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'LEVEL_EU_VALUABLE3_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13621',
#   'CodeName': 'LEVEL_EU_VALUABLE3_TAB3',
#   'RefTabGroupCodeName': 'LEVEL_EU_VALUABLE3_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY_1'},
#  'LEVEL_EU_VALUABLE3_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13622',
#   'CodeName': 'LEVEL_EU_VALUABLE3_TAB4',
#   'RefTabGroupCodeName': 'LEVEL_EU_VALUABLE3_GROUP1',
#   'StrId128Tab': 'SN_TAB_VALUABLES'},
#  'LV_FELLOWS_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13623',
#   'CodeName': 'LV_FELLOWS_TAB1',
#   'RefTabGroupCodeName': 'STORE_FELLOWS_ETC_GROUP01',
#   'StrId128Tab': 'UIIT_STT_SHOP_STRING_MALL_ETC'},
#  'LV_FELLOWS_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13624',
#   'CodeName': 'LV_FELLOWS_TAB2',
#   'RefTabGroupCodeName': 'STORE_FELLOWS_ETC_GROUP02',
#   'StrId128Tab': 'UIIT_STT_SHOP_STRING_MALL_ETC'},
#  'LV_FELLOWS_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13625',
#   'CodeName': 'LV_FELLOWS_TAB3',
#   'RefTabGroupCodeName': 'STORE_FELLOWS_ETC_GROUP03',
#   'StrId128Tab': 'UIIT_STT_SHOP_STRING_MALL_ETC'},
#  'MALL_ARCHEMY_ASTRAL': {'Service': '1',
#   'Country': '42',
#   'Id': '13400',
#   'CodeName': 'MALL_ARCHEMY_ASTRAL',
#   'RefTabGroupCodeName': 'MALL_ARCHEMY_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_ARCHEMY_ASTRAL'},
#  'MALL_ARCHEMY_ATHANASIA': {'Service': '1',
#   'Country': '42',
#   'Id': '13401',
#   'CodeName': 'MALL_ARCHEMY_ATHANASIA',
#   'RefTabGroupCodeName': 'MALL_ARCHEMY_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_ARCHEMY_ATHANASIA'},
#  'MALL_ARCHEMY_ETC': {'Service': '1',
#   'Country': '42',
#   'Id': '13509',
#   'CodeName': 'MALL_ARCHEMY_ETC',
#   'RefTabGroupCodeName': 'MALL_ARCHEMY_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_ARCHEMY_ETC'},
#  'MALL_AVATAR_ATTACH': {'Service': '1',
#   'Country': '42',
#   'Id': '13484',
#   'CodeName': 'MALL_AVATAR_ATTACH',
#   'RefTabGroupCodeName': 'MALL_AVATAR_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_ATTACH'},
#  'MALL_AVATAR_BOOTH': {'Service': '1',
#   'Country': '42',
#   'Id': '13377',
#   'CodeName': 'MALL_AVATAR_BOOTH',
#   'RefTabGroupCodeName': 'MALL_AVATAR_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_BOOTH'},
#  'MALL_AVATAR_DRESS': {'Service': '1',
#   'Country': '42',
#   'Id': '13483',
#   'CodeName': 'MALL_AVATAR_DRESS',
#   'RefTabGroupCodeName': 'MALL_AVATAR_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_DRESS'},
#  'MALL_AVATAR_HAT': {'Service': '1',
#   'Country': '42',
#   'Id': '13378',
#   'CodeName': 'MALL_AVATAR_HAT',
#   'RefTabGroupCodeName': 'MALL_AVATAR_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_HAT'},
#  'MALL_CONSUME_COMMUNITY': {'Service': '1',
#   'Country': '42',
#   'Id': '13297',
#   'CodeName': 'MALL_CONSUME_COMMUNITY',
#   'RefTabGroupCodeName': 'MALL_CONSUME_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_COMMUNITY'},
#  'MALL_CONSUME_ETC': {'Service': '1',
#   'Country': '42',
#   'Id': '13298',
#   'CodeName': 'MALL_CONSUME_ETC',
#   'RefTabGroupCodeName': 'MALL_CONSUME_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_ETC'},
#  'MALL_CONSUME_POTION': {'Service': '1',
#   'Country': '42',
#   'Id': '13296',
#   'CodeName': 'MALL_CONSUME_POTION',
#   'RefTabGroupCodeName': 'MALL_CONSUME_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_POTION'},
#  'MALL_CONSUME_SCROLL': {'Service': '1',
#   'Country': '42',
#   'Id': '13295',
#   'CodeName': 'MALL_CONSUME_SCROLL',
#   'RefTabGroupCodeName': 'MALL_CONSUME_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_SCROLL'},
#  'MALL_CONSUME_SPECIAL': {'Service': '1',
#   'Country': '42',
#   'Id': '13294',
#   'CodeName': 'MALL_CONSUME_SPECIAL',
#   'RefTabGroupCodeName': 'MALL_CONSUME_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_SPECIAL'},
#  'MALL_PET_A_GROWTH': {'Service': '1',
#   'Country': '42',
#   'Id': '13468',
#   'CodeName': 'MALL_PET_A_GROWTH',
#   'RefTabGroupCodeName': 'MALL_PET_GROUP1',
#   'StrId128Tab': 'SN_TAB_PET_GROWTH'},
#  'MALL_PET_B_SILK': {'Service': '1',
#   'Country': '42',
#   'Id': '13469',
#   'CodeName': 'MALL_PET_B_SILK',
#   'RefTabGroupCodeName': 'MALL_PET_GROUP1',
#   'StrId128Tab': 'SN_TAB_PET_SILK'},
#  'MALL_PET_C_VEHICLE': {'Service': '1',
#   'Country': '42',
#   'Id': '13470',
#   'CodeName': 'MALL_PET_C_VEHICLE',
#   'RefTabGroupCodeName': 'MALL_PET_GROUP1',
#   'StrId128Tab': 'SN_TAB_VEHICLE'},
#  'MALL_PET_E_STORES': {'Service': '1',
#   'Country': '42',
#   'Id': '13472',
#   'CodeName': 'MALL_PET_E_STORES',
#   'RefTabGroupCodeName': 'MALL_PET_GROUP1',
#   'StrId128Tab': 'SN_TAB_PET_STORES'},
#  'MALL_PREMIUM_NASRUN': {'Service': '1',
#   'Country': '42',
#   'Id': '13486',
#   'CodeName': 'MALL_PREMIUM_NASRUN',
#   'RefTabGroupCodeName': 'MALL_PREMIUM_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_PREMIUM_NASRUN'},
#  'MALL_PREMIUM_NASRUN_ETC': {'Service': '1',
#   'Country': '42',
#   'Id': '13487',
#   'CodeName': 'MALL_PREMIUM_NASRUN_ETC',
#   'RefTabGroupCodeName': 'MALL_PREMIUM_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_PREMIUM_NASRUN_ETC'},
#  'MALL_PREMIUM_PREMIUM': {'Service': '1',
#   'Country': '42',
#   'Id': '13399',
#   'CodeName': 'MALL_PREMIUM_PREMIUM',
#   'RefTabGroupCodeName': 'MALL_PREMIUM_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_PREMIUM_PREMIUM'},
#  'SRORE_TRADE_COMMON_HUNTER_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13649',
#   'CodeName': 'SRORE_TRADE_COMMON_HUNTER_TAB3',
#   'RefTabGroupCodeName': 'STORE_TRADE_COMMON_HUNTER_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_WNETWORK_SUMMON'},
#  'STORE_AR_EU_SMITH_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13632',
#   'CodeName': 'STORE_AR_EU_SMITH_TAB2',
#   'RefTabGroupCodeName': 'STORE_AR_SMITH_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'STORE_AR_EU_SMITH_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13633',
#   'CodeName': 'STORE_AR_EU_SMITH_TAB3',
#   'RefTabGroupCodeName': 'STORE_AR_SMITH_EU_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_WNETWORK_BOLT'},
#  'STORE_AR_SMITH_EU_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13631',
#   'CodeName': 'STORE_AR_SMITH_EU_TAB1',
#   'RefTabGroupCodeName': 'STORE_AR_SMITH_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'STORE_AR_SMITH_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13628',
#   'CodeName': 'STORE_AR_SMITH_TAB1',
#   'RefTabGroupCodeName': 'STORE_AR_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'STORE_AR_SMITH_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13629',
#   'CodeName': 'STORE_AR_SMITH_TAB2',
#   'RefTabGroupCodeName': 'STORE_AR_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'STORE_AR_SMITH_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13630',
#   'CodeName': 'STORE_AR_SMITH_TAB3',
#   'RefTabGroupCodeName': 'STORE_AR_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_AR_SPECIALTY_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13646',
#   'CodeName': 'STORE_AR_SPECIALTY_TAB1',
#   'RefTabGroupCodeName': 'STORE_AR_SPECIALTY_GROUP1',
#   'StrId128Tab': 'SN_TAB_SPECIAL'},
#  'STORE_BATTLE_ARENA_CH_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13510',
#   'CodeName': 'STORE_BATTLE_ARENA_CH_TAB1',
#   'RefTabGroupCodeName': 'STORE_BATTLE_ARENA_CH_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY'},
#  'STORE_BATTLE_ARENA_EU_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13511',
#   'CodeName': 'STORE_BATTLE_ARENA_EU_TAB1',
#   'RefTabGroupCodeName': 'STORE_BATTLE_ARENA_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY'},
#  'STORE_BJ_BATTLEAIDE_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13465',
#   'CodeName': 'STORE_BJ_BATTLEAIDE_TAB1',
#   'RefTabGroupCodeName': 'STORE_BJ_BATTLEAIDE_GROUP1',
#   'StrId128Tab': 'SN_TAB_GUARD'},
#  'STORE_CA_ACCESSORY_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13442',
#   'CodeName': 'STORE_CA_ACCESSORY_TAB1',
#   'RefTabGroupCodeName': 'STORE_CA_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY'},
#  'STORE_CA_ACCESSORY_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13443',
#   'CodeName': 'STORE_CA_ACCESSORY_TAB2',
#   'RefTabGroupCodeName': 'STORE_CA_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_CA_ACCESSORY_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13444',
#   'CodeName': 'STORE_CA_ACCESSORY_TAB3',
#   'RefTabGroupCodeName': 'STORE_CA_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ALCHEMY'},
#  'STORE_CA_ARMOR_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13436',
#   'CodeName': 'STORE_CA_ARMOR_TAB1',
#   'RefTabGroupCodeName': 'STORE_CA_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'STORE_CA_ARMOR_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13437',
#   'CodeName': 'STORE_CA_ARMOR_TAB2',
#   'RefTabGroupCodeName': 'STORE_CA_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'STORE_CA_ARMOR_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13438',
#   'CodeName': 'STORE_CA_ARMOR_TAB3',
#   'RefTabGroupCodeName': 'STORE_CA_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'STORE_CA_ARMOR_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13439',
#   'CodeName': 'STORE_CA_ARMOR_TAB4',
#   'RefTabGroupCodeName': 'STORE_CA_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'STORE_CA_ARMOR_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13440',
#   'CodeName': 'STORE_CA_ARMOR_TAB5',
#   'RefTabGroupCodeName': 'STORE_CA_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'STORE_CA_ARMOR_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13441',
#   'CodeName': 'STORE_CA_ARMOR_TAB6',
#   'RefTabGroupCodeName': 'STORE_CA_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'STORE_CA_GUILD_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13408',
#   'CodeName': 'STORE_CA_GUILD_TAB1',
#   'RefTabGroupCodeName': 'STORE_CA_GUILD_GROUP1',
#   'StrId128Tab': 'SN_TAB_CREST'},
#  'STORE_CA_GUILD_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13410',
#   'CodeName': 'STORE_CA_GUILD_TAB3',
#   'RefTabGroupCodeName': 'STORE_CA_GUILD_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_CA_HONOR_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13481',
#   'CodeName': 'STORE_CA_HONOR_TAB1',
#   'RefTabGroupCodeName': 'STORE_CA_HONOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HONOR'},
#  'STORE_CA_HONOR_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13482',
#   'CodeName': 'STORE_CA_HONOR_TAB2',
#   'RefTabGroupCodeName': 'STORE_CA_HONOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HONOR2'},
#  'STORE_CA_POTION_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13445',
#   'CodeName': 'STORE_CA_POTION_TAB1',
#   'RefTabGroupCodeName': 'STORE_CA_POTION_GROUP1',
#   'StrId128Tab': 'SN_TAB_POTION'},
#  'STORE_CA_SMITH_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13433',
#   'CodeName': 'STORE_CA_SMITH_TAB1',
#   'RefTabGroupCodeName': 'STORE_CA_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'STORE_CA_SMITH_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13434',
#   'CodeName': 'STORE_CA_SMITH_TAB2',
#   'RefTabGroupCodeName': 'STORE_CA_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'STORE_CA_SMITH_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13435',
#   'CodeName': 'STORE_CA_SMITH_TAB3',
#   'RefTabGroupCodeName': 'STORE_CA_SMITH_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_WNETWORK_BOLT'},
#  'STORE_CA_SPECIALTY_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13644',
#   'CodeName': 'STORE_CA_SPECIALTY_TAB1',
#   'RefTabGroupCodeName': 'STORE_CA_SPECIALTY_GROUP1',
#   'StrId128Tab': 'SN_TAB_SPECIAL'},
#  'STORE_CA_STABLE_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13446',
#   'CodeName': 'STORE_CA_STABLE_TAB1',
#   'RefTabGroupCodeName': 'STORE_CA_STABLE_GROUP1',
#   'StrId128Tab': 'SN_TAB_VEHICLE'},
#  'STORE_CA_STABLE_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13449',
#   'CodeName': 'STORE_CA_STABLE_TAB4',
#   'RefTabGroupCodeName': 'STORE_CA_STABLE_GROUP1',
#   'StrId128Tab': 'SN_TAB_CURE'},
#  'STORE_CH_ACCESSORY_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13308',
#   'CodeName': 'STORE_CH_ACCESSORY_TAB1',
#   'RefTabGroupCodeName': 'STORE_CH_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY'},
#  'STORE_CH_ACCESSORY_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13309',
#   'CodeName': 'STORE_CH_ACCESSORY_TAB2',
#   'RefTabGroupCodeName': 'STORE_CH_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_CH_ACCESSORY_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13310',
#   'CodeName': 'STORE_CH_ACCESSORY_TAB3',
#   'RefTabGroupCodeName': 'STORE_CH_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ALCHEMY'},
#  'STORE_CH_ARMOR_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13302',
#   'CodeName': 'STORE_CH_ARMOR_TAB1',
#   'RefTabGroupCodeName': 'STORE_CH_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'STORE_CH_ARMOR_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13303',
#   'CodeName': 'STORE_CH_ARMOR_TAB2',
#   'RefTabGroupCodeName': 'STORE_CH_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'STORE_CH_ARMOR_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13304',
#   'CodeName': 'STORE_CH_ARMOR_TAB3',
#   'RefTabGroupCodeName': 'STORE_CH_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'STORE_CH_ARMOR_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13305',
#   'CodeName': 'STORE_CH_ARMOR_TAB4',
#   'RefTabGroupCodeName': 'STORE_CH_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'STORE_CH_ARMOR_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13306',
#   'CodeName': 'STORE_CH_ARMOR_TAB5',
#   'RefTabGroupCodeName': 'STORE_CH_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'STORE_CH_ARMOR_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13307',
#   'CodeName': 'STORE_CH_ARMOR_TAB6',
#   'RefTabGroupCodeName': 'STORE_CH_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'STORE_CH_GUILD_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13387',
#   'CodeName': 'STORE_CH_GUILD_TAB1',
#   'RefTabGroupCodeName': 'STORE_CH_GUILD_GROUP1',
#   'StrId128Tab': 'SN_TAB_CREST'},
#  'STORE_CH_GUILD_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13389',
#   'CodeName': 'STORE_CH_GUILD_TAB3',
#   'RefTabGroupCodeName': 'STORE_CH_GUILD_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_CH_HONOR_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13473',
#   'CodeName': 'STORE_CH_HONOR_TAB1',
#   'RefTabGroupCodeName': 'STORE_CH_HONOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HONOR'},
#  'STORE_CH_HONOR_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13474',
#   'CodeName': 'STORE_CH_HONOR_TAB2',
#   'RefTabGroupCodeName': 'STORE_CH_HONOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HONOR2'},
#  'STORE_CH_NEW_TRADE_HUNTER_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13534',
#   'CodeName': 'STORE_CH_NEW_TRADE_HUNTER_TAB1',
#   'RefTabGroupCodeName': 'STORE_NEW_TRADE_HUNTER_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_PARTYMATCH_AUTOMATCH_RACE_CH'},
#  'STORE_CH_NEW_TRADE_THIEF_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13536',
#   'CodeName': 'STORE_CH_NEW_TRADE_THIEF_TAB1',
#   'RefTabGroupCodeName': 'STORE_NEW_TRADE_THIEF_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_PARTYMATCH_AUTOMATCH_RACE_CH'},
#  'STORE_CH_OFFICIAL_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13455',
#   'CodeName': 'STORE_CH_OFFICIAL_TAB1',
#   'RefTabGroupCodeName': 'STORE_CH_OFFICIAL_GROUP1',
#   'StrId128Tab': 'SN_TAB_ITEM'},
#  'STORE_CH_POTION_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13311',
#   'CodeName': 'STORE_CH_POTION_TAB1',
#   'RefTabGroupCodeName': 'STORE_CH_POTION_GROUP1',
#   'StrId128Tab': 'SN_TAB_POTION'},
#  'STORE_CH_SMITH_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13299',
#   'CodeName': 'STORE_CH_SMITH_TAB1',
#   'RefTabGroupCodeName': 'STORE_CH_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'STORE_CH_SMITH_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13300',
#   'CodeName': 'STORE_CH_SMITH_TAB2',
#   'RefTabGroupCodeName': 'STORE_CH_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'STORE_CH_SMITH_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13301',
#   'CodeName': 'STORE_CH_SMITH_TAB3',
#   'RefTabGroupCodeName': 'STORE_CH_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_CH_SPECIALTY_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13640',
#   'CodeName': 'STORE_CH_SPECIALTY_TAB1',
#   'RefTabGroupCodeName': 'STORE_CH_SPECIALTY_GROUP1',
#   'StrId128Tab': 'SN_TAB_SPECIAL'},
#  'STORE_CH_STABLE_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13314',
#   'CodeName': 'STORE_CH_STABLE_TAB1',
#   'RefTabGroupCodeName': 'STORE_CH_STABLE_GROUP1',
#   'StrId128Tab': 'SN_TAB_VEHICLE'},
#  'STORE_CH_STABLE_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13317',
#   'CodeName': 'STORE_CH_STABLE_TAB4',
#   'RefTabGroupCodeName': 'STORE_CH_STABLE_GROUP1',
#   'StrId128Tab': 'SN_TAB_CURE'},
#  'STORE_COMMON_STOLEN_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13647',
#   'CodeName': 'STORE_COMMON_STOLEN_TAB1',
#   'RefTabGroupCodeName': 'STORE_COMMON_STOLEN_GROUP1',
#   'StrId128Tab': 'UIIT_STT_STOLEN_GOODS_SELL'},
#  'STORE_CT_BATTLEAIDE_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13463',
#   'CodeName': 'STORE_CT_BATTLEAIDE_TAB1',
#   'RefTabGroupCodeName': 'STORE_CT_BATTLEAIDE_GROUP1',
#   'StrId128Tab': 'SN_TAB_GUARD'},
#  'STORE_EU_ACCESSORY_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13420',
#   'CodeName': 'STORE_EU_ACCESSORY_TAB1',
#   'RefTabGroupCodeName': 'STORE_EU_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY'},
#  'STORE_EU_ACCESSORY_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13421',
#   'CodeName': 'STORE_EU_ACCESSORY_TAB2',
#   'RefTabGroupCodeName': 'STORE_EU_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_EU_ACCESSORY_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13422',
#   'CodeName': 'STORE_EU_ACCESSORY_TAB3',
#   'RefTabGroupCodeName': 'STORE_EU_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ALCHEMY'},
#  'STORE_EU_ARMOR_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13414',
#   'CodeName': 'STORE_EU_ARMOR_TAB1',
#   'RefTabGroupCodeName': 'STORE_EU_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'STORE_EU_ARMOR_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13415',
#   'CodeName': 'STORE_EU_ARMOR_TAB2',
#   'RefTabGroupCodeName': 'STORE_EU_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'STORE_EU_ARMOR_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13416',
#   'CodeName': 'STORE_EU_ARMOR_TAB3',
#   'RefTabGroupCodeName': 'STORE_EU_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'STORE_EU_ARMOR_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13417',
#   'CodeName': 'STORE_EU_ARMOR_TAB4',
#   'RefTabGroupCodeName': 'STORE_EU_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'STORE_EU_ARMOR_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13418',
#   'CodeName': 'STORE_EU_ARMOR_TAB5',
#   'RefTabGroupCodeName': 'STORE_EU_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'STORE_EU_ARMOR_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13419',
#   'CodeName': 'STORE_EU_ARMOR_TAB6',
#   'RefTabGroupCodeName': 'STORE_EU_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'STORE_EU_GUILD_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13396',
#   'CodeName': 'STORE_EU_GUILD_TAB1',
#   'RefTabGroupCodeName': 'STORE_EU_GUILD_GROUP1',
#   'StrId128Tab': 'SN_TAB_CREST'},
#  'STORE_EU_GUILD_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13398',
#   'CodeName': 'STORE_EU_GUILD_TAB3',
#   'RefTabGroupCodeName': 'STORE_EU_GUILD_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_EU_HONOR_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13479',
#   'CodeName': 'STORE_EU_HONOR_TAB1',
#   'RefTabGroupCodeName': 'STORE_EU_HONOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HONOR'},
#  'STORE_EU_HONOR_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13480',
#   'CodeName': 'STORE_EU_HONOR_TAB2',
#   'RefTabGroupCodeName': 'STORE_EU_HONOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HONOR2'},
#  'STORE_EU_NEW_TRADE_HUNTER_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13535',
#   'CodeName': 'STORE_EU_NEW_TRADE_HUNTER_TAB1',
#   'RefTabGroupCodeName': 'STORE_NEW_TRADE_HUNTER_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_PARTYMATCH_AUTOMATCH_RACE_EU'},
#  'STORE_EU_NEW_TRADE_THIEF_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13537',
#   'CodeName': 'STORE_EU_NEW_TRADE_THIEF_TAB1',
#   'RefTabGroupCodeName': 'STORE_NEW_TRADE_THIEF_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_PARTYMATCH_AUTOMATCH_RACE_EU'},
#  'STORE_EU_OFFICIAL_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13458',
#   'CodeName': 'STORE_EU_OFFICIAL_TAB1',
#   'RefTabGroupCodeName': 'STORE_EU_OFFICIAL_GROUP1',
#   'StrId128Tab': 'SN_TAB_ITEM'},
#  'STORE_EU_POTION_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13423',
#   'CodeName': 'STORE_EU_POTION_TAB1',
#   'RefTabGroupCodeName': 'STORE_EU_POTION_GROUP1',
#   'StrId128Tab': 'SN_TAB_POTION'},
#  'STORE_EU_SMITH_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13411',
#   'CodeName': 'STORE_EU_SMITH_TAB1',
#   'RefTabGroupCodeName': 'STORE_EU_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'STORE_EU_SMITH_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13412',
#   'CodeName': 'STORE_EU_SMITH_TAB2',
#   'RefTabGroupCodeName': 'STORE_EU_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'STORE_EU_SMITH_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13413',
#   'CodeName': 'STORE_EU_SMITH_TAB3',
#   'RefTabGroupCodeName': 'STORE_EU_SMITH_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_WNETWORK_BOLT'},
#  'STORE_EU_SPECIALTY_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13641',
#   'CodeName': 'STORE_EU_SPECIALTY_TAB1',
#   'RefTabGroupCodeName': 'STORE_EU_SPECIALTY_GROUP1',
#   'StrId128Tab': 'SN_TAB_SPECIAL'},
#  'STORE_EU_STABLE_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13424',
#   'CodeName': 'STORE_EU_STABLE_TAB1',
#   'RefTabGroupCodeName': 'STORE_EU_STABLE_GROUP1',
#   'StrId128Tab': 'SN_TAB_VEHICLE'},
#  'STORE_EU_STABLE_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13427',
#   'CodeName': 'STORE_EU_STABLE_TAB4',
#   'RefTabGroupCodeName': 'STORE_EU_STABLE_GROUP1',
#   'StrId128Tab': 'SN_TAB_CURE'},
#  'STORE_FELLOWS_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13540',
#   'CodeName': 'STORE_FELLOWS_TAB1',
#   'RefTabGroupCodeName': 'STORE_FELLOWS_GROUP1',
#   'StrId128Tab': 'UIIT_STT_PET2_PETTYPE_ASS'},
#  'STORE_FELLOWS_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13541',
#   'CodeName': 'STORE_FELLOWS_TAB2',
#   'RefTabGroupCodeName': 'STORE_FELLOWS_GROUP1',
#   'StrId128Tab': 'UIIT_STT_PET2_PETTYPE_PRO'},
#  'STORE_FELLOWS_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13542',
#   'CodeName': 'STORE_FELLOWS_TAB3',
#   'RefTabGroupCodeName': 'STORE_FELLOWS_GROUP1',
#   'StrId128Tab': 'UIIT_STT_PET2_PETTYPE_ENC'},
#  'STORE_FELLOWS_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13543',
#   'CodeName': 'STORE_FELLOWS_TAB4',
#   'RefTabGroupCodeName': 'STORE_FELLOWS_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SHOP_STRING_ETC'},
#  'STORE_HT_BATTLEAIDE_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13462',
#   'CodeName': 'STORE_HT_BATTLEAIDE_TAB1',
#   'RefTabGroupCodeName': 'STORE_HT_BATTLEAIDE_GROUP1',
#   'StrId128Tab': 'SN_TAB_GUARD'},
#  'STORE_JA_BATTLEAIDE_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13460',
#   'CodeName': 'STORE_JA_BATTLEAIDE_TAB1',
#   'RefTabGroupCodeName': 'STORE_JA_BATTLEAIDE_GROUP1',
#   'StrId128Tab': 'SN_TAB_GUARD'},
#  'STORE_JUPITER_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13538',
#   'CodeName': 'STORE_JUPITER_TAB1',
#   'RefTabGroupCodeName': 'STORE_JUPITER_GROUP1',
#   'StrId128Tab': 'SN_TAB_POTION'},
#  'STORE_JUPITER_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13539',
#   'CodeName': 'STORE_JUPITER_TAB2',
#   'RefTabGroupCodeName': 'STORE_JUPITER_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_WNETWORK_ARROW'},
#  'STORE_JUPITER_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13544',
#   'CodeName': 'STORE_JUPITER_TAB3',
#   'RefTabGroupCodeName': 'STORE_JUPITER_GROUP1',
#   'StrId128Tab': 'SN_TAB_ALCHEMY'},
#  'STORE_KT_ACCESSORY_EU_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13360',
#   'CodeName': 'STORE_KT_ACCESSORY_EU_TAB1',
#   'RefTabGroupCodeName': 'STORE_KT_ACCESSORY_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY'},
#  'STORE_KT_ACCESSORY_EU_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13361',
#   'CodeName': 'STORE_KT_ACCESSORY_EU_TAB2',
#   'RefTabGroupCodeName': 'STORE_KT_ACCESSORY_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_KT_ACCESSORY_EU_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13362',
#   'CodeName': 'STORE_KT_ACCESSORY_EU_TAB3',
#   'RefTabGroupCodeName': 'STORE_KT_ACCESSORY_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_ALCHEMY'},
#  'STORE_KT_ACCESSORY_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13357',
#   'CodeName': 'STORE_KT_ACCESSORY_TAB1',
#   'RefTabGroupCodeName': 'STORE_KT_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY'},
#  'STORE_KT_ACCESSORY_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13358',
#   'CodeName': 'STORE_KT_ACCESSORY_TAB2',
#   'RefTabGroupCodeName': 'STORE_KT_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_KT_ACCESSORY_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13359',
#   'CodeName': 'STORE_KT_ACCESSORY_TAB3',
#   'RefTabGroupCodeName': 'STORE_KT_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ALCHEMY'},
#  'STORE_KT_ARMOR_EU_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13402',
#   'CodeName': 'STORE_KT_ARMOR_EU_TAB1',
#   'RefTabGroupCodeName': 'STORE_KT_ARMOR_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'STORE_KT_ARMOR_EU_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13403',
#   'CodeName': 'STORE_KT_ARMOR_EU_TAB2',
#   'RefTabGroupCodeName': 'STORE_KT_ARMOR_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'STORE_KT_ARMOR_EU_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13404',
#   'CodeName': 'STORE_KT_ARMOR_EU_TAB3',
#   'RefTabGroupCodeName': 'STORE_KT_ARMOR_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'STORE_KT_ARMOR_EU_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13405',
#   'CodeName': 'STORE_KT_ARMOR_EU_TAB4',
#   'RefTabGroupCodeName': 'STORE_KT_ARMOR_EU_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'STORE_KT_ARMOR_EU_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13406',
#   'CodeName': 'STORE_KT_ARMOR_EU_TAB5',
#   'RefTabGroupCodeName': 'STORE_KT_ARMOR_EU_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'STORE_KT_ARMOR_EU_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13407',
#   'CodeName': 'STORE_KT_ARMOR_EU_TAB6',
#   'RefTabGroupCodeName': 'STORE_KT_ARMOR_EU_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'STORE_KT_ARMOR_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13351',
#   'CodeName': 'STORE_KT_ARMOR_TAB1',
#   'RefTabGroupCodeName': 'STORE_KT_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'STORE_KT_ARMOR_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13352',
#   'CodeName': 'STORE_KT_ARMOR_TAB2',
#   'RefTabGroupCodeName': 'STORE_KT_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'STORE_KT_ARMOR_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13353',
#   'CodeName': 'STORE_KT_ARMOR_TAB3',
#   'RefTabGroupCodeName': 'STORE_KT_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'STORE_KT_ARMOR_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13354',
#   'CodeName': 'STORE_KT_ARMOR_TAB4',
#   'RefTabGroupCodeName': 'STORE_KT_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'STORE_KT_ARMOR_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13355',
#   'CodeName': 'STORE_KT_ARMOR_TAB5',
#   'RefTabGroupCodeName': 'STORE_KT_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'STORE_KT_ARMOR_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13356',
#   'CodeName': 'STORE_KT_ARMOR_TAB6',
#   'RefTabGroupCodeName': 'STORE_KT_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'STORE_KT_GUILD_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13393',
#   'CodeName': 'STORE_KT_GUILD_TAB1',
#   'RefTabGroupCodeName': 'STORE_KT_GUILD_GROUP1',
#   'StrId128Tab': 'SN_TAB_CREST'},
#  'STORE_KT_GUILD_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13395',
#   'CodeName': 'STORE_KT_GUILD_TAB3',
#   'RefTabGroupCodeName': 'STORE_KT_GUILD_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_KT_HONOR_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13477',
#   'CodeName': 'STORE_KT_HONOR_TAB1',
#   'RefTabGroupCodeName': 'STORE_KT_HONOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HONOR'},
#  'STORE_KT_HONOR_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13478',
#   'CodeName': 'STORE_KT_HONOR_TAB2',
#   'RefTabGroupCodeName': 'STORE_KT_HONOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HONOR2'},
#  'STORE_KT_OFFICIAL_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13457',
#   'CodeName': 'STORE_KT_OFFICIAL_TAB1',
#   'RefTabGroupCodeName': 'STORE_KT_OFFICIAL_GROUP1',
#   'StrId128Tab': 'SN_TAB_ITEM'},
#  'STORE_KT_POTION_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13363',
#   'CodeName': 'STORE_KT_POTION_TAB1',
#   'RefTabGroupCodeName': 'STORE_KT_POTION_GROUP1',
#   'StrId128Tab': 'SN_TAB_POTION'},
#  'STORE_KT_SMITH_EU_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13348',
#   'CodeName': 'STORE_KT_SMITH_EU_TAB1',
#   'RefTabGroupCodeName': 'STORE_KT_SMITH_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'STORE_KT_SMITH_EU_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13349',
#   'CodeName': 'STORE_KT_SMITH_EU_TAB2',
#   'RefTabGroupCodeName': 'STORE_KT_SMITH_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'STORE_KT_SMITH_EU_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13350',
#   'CodeName': 'STORE_KT_SMITH_EU_TAB3',
#   'RefTabGroupCodeName': 'STORE_KT_SMITH_EU_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_WNETWORK_BOLT'},
#  'STORE_KT_SMITH_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13345',
#   'CodeName': 'STORE_KT_SMITH_TAB1',
#   'RefTabGroupCodeName': 'STORE_KT_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'STORE_KT_SMITH_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13346',
#   'CodeName': 'STORE_KT_SMITH_TAB2',
#   'RefTabGroupCodeName': 'STORE_KT_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'STORE_KT_SMITH_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13347',
#   'CodeName': 'STORE_KT_SMITH_TAB3',
#   'RefTabGroupCodeName': 'STORE_KT_SMITH_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_WNETWORK_ARROW'},
#  'STORE_KT_SPECIALTY_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13643',
#   'CodeName': 'STORE_KT_SPECIALTY_TAB1',
#   'RefTabGroupCodeName': 'STORE_KT_SPECIALTY_GROUP1',
#   'StrId128Tab': 'SN_TAB_SPECIAL'},
#  'STORE_KT_STABLE_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13364',
#   'CodeName': 'STORE_KT_STABLE_TAB1',
#   'RefTabGroupCodeName': 'STORE_KT_STABLE_GROUP1',
#   'StrId128Tab': 'SN_TAB_VEHICLE'},
#  'STORE_KT_STABLE_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13367',
#   'CodeName': 'STORE_KT_STABLE_TAB4',
#   'RefTabGroupCodeName': 'STORE_KT_STABLE_GROUP1',
#   'StrId128Tab': 'SN_TAB_CURE'},
#  'STORE_RM_WING_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13626',
#   'CodeName': 'STORE_RM_WING_TAB1',
#   'RefTabGroupCodeName': 'STORE_RM_WING_GROUP1',
#   'StrId128Tab': 'UIIT_STT_SILKMALL_ARCHEMY_ETC'},
#  'STORE_SD_ACCESSORY_EU_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13506',
#   'CodeName': 'STORE_SD_ACCESSORY_EU_TAB1',
#   'RefTabGroupCodeName': 'STORE_SD_ACCESSORY_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY'},
#  'STORE_SD_ACCESSORY_EU_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13507',
#   'CodeName': 'STORE_SD_ACCESSORY_EU_TAB2',
#   'RefTabGroupCodeName': 'STORE_SD_ACCESSORY_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_SD_ACCESSORY_EU_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13508',
#   'CodeName': 'STORE_SD_ACCESSORY_EU_TAB3',
#   'RefTabGroupCodeName': 'STORE_SD_ACCESSORY_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_ALCHEMY'},
#  'STORE_SD_ACCESSORY_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13503',
#   'CodeName': 'STORE_SD_ACCESSORY_TAB1',
#   'RefTabGroupCodeName': 'STORE_SD_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY'},
#  'STORE_SD_ACCESSORY_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13504',
#   'CodeName': 'STORE_SD_ACCESSORY_TAB2',
#   'RefTabGroupCodeName': 'STORE_SD_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_SD_ACCESSORY_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13505',
#   'CodeName': 'STORE_SD_ACCESSORY_TAB3',
#   'RefTabGroupCodeName': 'STORE_SD_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ALCHEMY'},
#  'STORE_SD_ARMOR_EU_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13557',
#   'CodeName': 'STORE_SD_ARMOR_EU_TAB1',
#   'RefTabGroupCodeName': 'STORE_SD_ARMOR_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'STORE_SD_ARMOR_EU_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13558',
#   'CodeName': 'STORE_SD_ARMOR_EU_TAB2',
#   'RefTabGroupCodeName': 'STORE_SD_ARMOR_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'STORE_SD_ARMOR_EU_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13559',
#   'CodeName': 'STORE_SD_ARMOR_EU_TAB3',
#   'RefTabGroupCodeName': 'STORE_SD_ARMOR_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'STORE_SD_ARMOR_EU_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13560',
#   'CodeName': 'STORE_SD_ARMOR_EU_TAB4',
#   'RefTabGroupCodeName': 'STORE_SD_ARMOR_EU_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR_EU'},
#  'STORE_SD_ARMOR_EU_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13561',
#   'CodeName': 'STORE_SD_ARMOR_EU_TAB5',
#   'RefTabGroupCodeName': 'STORE_SD_ARMOR_EU_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR_EU'},
#  'STORE_SD_ARMOR_EU_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13562',
#   'CodeName': 'STORE_SD_ARMOR_EU_TAB6',
#   'RefTabGroupCodeName': 'STORE_SD_ARMOR_EU_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES_EU'},
#  'STORE_SD_ARMOR_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13551',
#   'CodeName': 'STORE_SD_ARMOR_TAB1',
#   'RefTabGroupCodeName': 'STORE_SD_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'STORE_SD_ARMOR_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13552',
#   'CodeName': 'STORE_SD_ARMOR_TAB2',
#   'RefTabGroupCodeName': 'STORE_SD_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'STORE_SD_ARMOR_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13553',
#   'CodeName': 'STORE_SD_ARMOR_TAB3',
#   'RefTabGroupCodeName': 'STORE_SD_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'STORE_SD_ARMOR_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13554',
#   'CodeName': 'STORE_SD_ARMOR_TAB4',
#   'RefTabGroupCodeName': 'STORE_SD_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'STORE_SD_ARMOR_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13555',
#   'CodeName': 'STORE_SD_ARMOR_TAB5',
#   'RefTabGroupCodeName': 'STORE_SD_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'STORE_SD_ARMOR_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13556',
#   'CodeName': 'STORE_SD_ARMOR_TAB6',
#   'RefTabGroupCodeName': 'STORE_SD_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'STORE_SD_SET_ARMOR_EU_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13494',
#   'CodeName': 'STORE_SD_SET_ARMOR_EU_TAB1',
#   'RefTabGroupCodeName': 'STORE_SD_SET_ARMOR_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'STORE_SD_SET_ARMOR_EU_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13495',
#   'CodeName': 'STORE_SD_SET_ARMOR_EU_TAB2',
#   'RefTabGroupCodeName': 'STORE_SD_SET_ARMOR_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'STORE_SD_SET_ARMOR_EU_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13496',
#   'CodeName': 'STORE_SD_SET_ARMOR_EU_TAB3',
#   'RefTabGroupCodeName': 'STORE_SD_SET_ARMOR_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'STORE_SD_SET_ARMOR_EU_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13497',
#   'CodeName': 'STORE_SD_SET_ARMOR_EU_TAB4',
#   'RefTabGroupCodeName': 'STORE_SD_SET_ARMOR_EU_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'STORE_SD_SET_ARMOR_EU_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13498',
#   'CodeName': 'STORE_SD_SET_ARMOR_EU_TAB5',
#   'RefTabGroupCodeName': 'STORE_SD_SET_ARMOR_EU_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'STORE_SD_SET_ARMOR_EU_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13499',
#   'CodeName': 'STORE_SD_SET_ARMOR_EU_TAB6',
#   'RefTabGroupCodeName': 'STORE_SD_SET_ARMOR_EU_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'STORE_SD_SET_ARMOR_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13488',
#   'CodeName': 'STORE_SD_SET_ARMOR_TAB1',
#   'RefTabGroupCodeName': 'STORE_SD_SET_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'STORE_SD_SET_ARMOR_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13489',
#   'CodeName': 'STORE_SD_SET_ARMOR_TAB2',
#   'RefTabGroupCodeName': 'STORE_SD_SET_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'STORE_SD_SET_ARMOR_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13490',
#   'CodeName': 'STORE_SD_SET_ARMOR_TAB3',
#   'RefTabGroupCodeName': 'STORE_SD_SET_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'STORE_SD_SET_ARMOR_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13491',
#   'CodeName': 'STORE_SD_SET_ARMOR_TAB4',
#   'RefTabGroupCodeName': 'STORE_SD_SET_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'STORE_SD_SET_ARMOR_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13492',
#   'CodeName': 'STORE_SD_SET_ARMOR_TAB5',
#   'RefTabGroupCodeName': 'STORE_SD_SET_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'STORE_SD_SET_ARMOR_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13493',
#   'CodeName': 'STORE_SD_SET_ARMOR_TAB6',
#   'RefTabGroupCodeName': 'STORE_SD_SET_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'STORE_SD_SMITH_EU_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13548',
#   'CodeName': 'STORE_SD_SMITH_EU_TAB1',
#   'RefTabGroupCodeName': 'STORE_SD_SMITH_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'STORE_SD_SMITH_EU_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13549',
#   'CodeName': 'STORE_SD_SMITH_EU_TAB2',
#   'RefTabGroupCodeName': 'STORE_SD_SMITH_EU_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'STORE_SD_SMITH_EU_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13550',
#   'CodeName': 'STORE_SD_SMITH_EU_TAB3',
#   'RefTabGroupCodeName': 'STORE_SD_SMITH_EU_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_WNETWORK_BOLT'},
#  'STORE_SD_SMITH_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13545',
#   'CodeName': 'STORE_SD_SMITH_TAB1',
#   'RefTabGroupCodeName': 'STORE_SD_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'STORE_SD_SMITH_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13546',
#   'CodeName': 'STORE_SD_SMITH_TAB2',
#   'RefTabGroupCodeName': 'STORE_SD_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'STORE_SD_SMITH_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13547',
#   'CodeName': 'STORE_SD_SMITH_TAB3',
#   'RefTabGroupCodeName': 'STORE_SD_SMITH_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_WNETWORK_ARROW'},
#  'STORE_SD_SPECIALTY_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13645',
#   'CodeName': 'STORE_SD_SPECIALTY_TAB1',
#   'RefTabGroupCodeName': 'STORE_SD_SPECIALTY_GROUP1',
#   'StrId128Tab': 'SN_TAB_SPECIAL'},
#  'STORE_SURVIVAL_ARENA_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13627',
#   'CodeName': 'STORE_SURVIVAL_ARENA_TAB1',
#   'RefTabGroupCodeName': 'STORE_SURVIVAL_ARENA_GROUP1',
#   'StrId128Tab': 'SN_TAB_ITEM'},
#  'STORE_TRADE_COMMON_HUNTER_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13636',
#   'CodeName': 'STORE_TRADE_COMMON_HUNTER_TAB1',
#   'RefTabGroupCodeName': 'STORE_TRADE_COMMON_HUNTER_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_PARTYMATCH_AUTOMATCH_RACE_CH'},
#  'STORE_TRADE_COMMON_HUNTER_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13637',
#   'CodeName': 'STORE_TRADE_COMMON_HUNTER_TAB2',
#   'RefTabGroupCodeName': 'STORE_TRADE_COMMON_HUNTER_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_PARTYMATCH_AUTOMATCH_RACE_EU'},
#  'STORE_TRADE_COMMON_THIEF_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13638',
#   'CodeName': 'STORE_TRADE_COMMON_THIEF_TAB1',
#   'RefTabGroupCodeName': 'STORE_TRADE_COMMON_THIEF_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_PARTYMATCH_AUTOMATCH_RACE_CH'},
#  'STORE_TRADE_COMMON_THIEF_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13639',
#   'CodeName': 'STORE_TRADE_COMMON_THIEF_TAB2',
#   'RefTabGroupCodeName': 'STORE_TRADE_COMMON_THIEF_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_PARTYMATCH_AUTOMATCH_RACE_EU'},
#  'STORE_TRADE_COMMON_THIEF_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13650',
#   'CodeName': 'STORE_TRADE_COMMON_THIEF_TAB3',
#   'RefTabGroupCodeName': 'STORE_TRADE_COMMON_THIEF_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_WNETWORK_SUMMON'},
#  'STORE_TRADE_COMMON_TRADER_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13634',
#   'CodeName': 'STORE_TRADE_COMMON_TRADER_TAB1',
#   'RefTabGroupCodeName': 'STORE_TRADE_COMMON_TRADER_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_PARTYMATCH_AUTOMATCH_RACE_CH'},
#  'STORE_TRADE_COMMON_TRADER_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13635',
#   'CodeName': 'STORE_TRADE_COMMON_TRADER_TAB2',
#   'RefTabGroupCodeName': 'STORE_TRADE_COMMON_TRADER_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_PARTYMATCH_AUTOMATCH_RACE_EU'},
#  'STORE_TRADE_COMMON_TRADER_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13648',
#   'CodeName': 'STORE_TRADE_COMMON_TRADER_TAB3',
#   'RefTabGroupCodeName': 'STORE_TRADE_COMMON_TRADER_GROUP1',
#   'StrId128Tab': 'UIIT_CTL_WNETWORK_SUMMON'},
#  'STORE_WC_ACCESSORY_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13332',
#   'CodeName': 'STORE_WC_ACCESSORY_TAB1',
#   'RefTabGroupCodeName': 'STORE_WC_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ACCESSORY'},
#  'STORE_WC_ACCESSORY_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13333',
#   'CodeName': 'STORE_WC_ACCESSORY_TAB2',
#   'RefTabGroupCodeName': 'STORE_WC_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_WC_ACCESSORY_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13334',
#   'CodeName': 'STORE_WC_ACCESSORY_TAB3',
#   'RefTabGroupCodeName': 'STORE_WC_ACCESSORY_GROUP1',
#   'StrId128Tab': 'SN_TAB_ALCHEMY'},
#  'STORE_WC_ARMOR_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13326',
#   'CodeName': 'STORE_WC_ARMOR_TAB1',
#   'RefTabGroupCodeName': 'STORE_WC_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'STORE_WC_ARMOR_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13327',
#   'CodeName': 'STORE_WC_ARMOR_TAB2',
#   'RefTabGroupCodeName': 'STORE_WC_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'STORE_WC_ARMOR_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13328',
#   'CodeName': 'STORE_WC_ARMOR_TAB3',
#   'RefTabGroupCodeName': 'STORE_WC_ARMOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'STORE_WC_ARMOR_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13329',
#   'CodeName': 'STORE_WC_ARMOR_TAB4',
#   'RefTabGroupCodeName': 'STORE_WC_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_HEAVYARMOR'},
#  'STORE_WC_ARMOR_TAB5': {'Service': '1',
#   'Country': '42',
#   'Id': '13330',
#   'CodeName': 'STORE_WC_ARMOR_TAB5',
#   'RefTabGroupCodeName': 'STORE_WC_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_LIGHTARMOR'},
#  'STORE_WC_ARMOR_TAB6': {'Service': '1',
#   'Country': '42',
#   'Id': '13331',
#   'CodeName': 'STORE_WC_ARMOR_TAB6',
#   'RefTabGroupCodeName': 'STORE_WC_ARMOR_GROUP2',
#   'StrId128Tab': 'SN_TAB_CLOTHES'},
#  'STORE_WC_GUILD_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13390',
#   'CodeName': 'STORE_WC_GUILD_TAB1',
#   'RefTabGroupCodeName': 'STORE_WC_GUILD_GROUP1',
#   'StrId128Tab': 'SN_TAB_CREST'},
#  'STORE_WC_GUILD_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13392',
#   'CodeName': 'STORE_WC_GUILD_TAB3',
#   'RefTabGroupCodeName': 'STORE_WC_GUILD_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_WC_HONOR_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13475',
#   'CodeName': 'STORE_WC_HONOR_TAB1',
#   'RefTabGroupCodeName': 'STORE_WC_HONOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HONOR'},
#  'STORE_WC_HONOR_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13476',
#   'CodeName': 'STORE_WC_HONOR_TAB2',
#   'RefTabGroupCodeName': 'STORE_WC_HONOR_GROUP1',
#   'StrId128Tab': 'SN_TAB_HONOR2'},
#  'STORE_WC_POTION_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13335',
#   'CodeName': 'STORE_WC_POTION_TAB1',
#   'RefTabGroupCodeName': 'STORE_WC_POTION_GROUP1',
#   'StrId128Tab': 'SN_TAB_POTION'},
#  'STORE_WC_SMITH_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13323',
#   'CodeName': 'STORE_WC_SMITH_TAB1',
#   'RefTabGroupCodeName': 'STORE_WC_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_WEAPON'},
#  'STORE_WC_SMITH_TAB2': {'Service': '1',
#   'Country': '42',
#   'Id': '13324',
#   'CodeName': 'STORE_WC_SMITH_TAB2',
#   'RefTabGroupCodeName': 'STORE_WC_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_SHIELD'},
#  'STORE_WC_SMITH_TAB3': {'Service': '1',
#   'Country': '42',
#   'Id': '13325',
#   'CodeName': 'STORE_WC_SMITH_TAB3',
#   'RefTabGroupCodeName': 'STORE_WC_SMITH_GROUP1',
#   'StrId128Tab': 'SN_TAB_ETC'},
#  'STORE_WC_SPECIALTY_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13642',
#   'CodeName': 'STORE_WC_SPECIALTY_TAB1',
#   'RefTabGroupCodeName': 'STORE_WC_SPECIALTY_GROUP1',
#   'StrId128Tab': 'SN_TAB_SPECIAL'},
#  'STORE_WC_STABLE_TAB1': {'Service': '1',
#   'Country': '42',
#   'Id': '13336',
#   'CodeName': 'STORE_WC_STABLE_TAB1',
#   'RefTabGroupCodeName': 'STORE_WC_STABLE_GROUP1',
#   'StrId128Tab': 'SN_TAB_VEHICLE'},
#  'STORE_WC_STABLE_TAB4': {'Service': '1',
#   'Country': '42',
#   'Id': '13339',
#   'CodeName': 'STORE_WC_STABLE_TAB4',
#   'RefTabGroupCodeName': 'STORE_WC_STABLE_GROUP1',
#   'StrId128Tab': 'SN_TAB_CURE'}}

# %% [markdown]
# ## RefShopGroup.txt

# %%
ref_shop_group_file = os.path.join(server_dep, 'RefShopGroup.txt')
ref_shop_group_file
# Out:
# 'server_dep\\silkroad\\textdata\\RefShopGroup.txt'

# %%
lines = get_lines(ref_shop_group_file)
for idx, line in enumerate(lines):
    try:
      values = line.split('\t')

      Service = values[0]
      Country = values[1]
      Id = values[2]  
      CodeName = values[3]
      ref_npc_code_name = values[4]

      ref_shop_group_data[CodeName] = {
        "Service": Service,
        "Country": Country,
        "Id": Id,
        "CodeName": CodeName,
        "RefNpcCodeName": ref_npc_code_name
      }
    except Exception as e:
      continue

# %%
ref_shop_group_data
# Out:
# {'GROUP_JUPITER_STORE_POTION': {'Service': '1',
#   'Country': '42',
#   'Id': '5642',
#   'CodeName': 'GROUP_JUPITER_STORE_POTION',
#   'RefNpcCodeName': 'NPC_JUPITER_SOLDIER_03'},
#  'GROUP_MALL': {'Service': '1',
#   'Country': '42',
#   'Id': '5596',
#   'CodeName': 'GROUP_MALL',
#   'RefNpcCodeName': 'xxx'},
#  'GROUP_MALL_ARCHEMY': {'Service': '1',
#   'Country': '42',
#   'Id': '5564',
#   'CodeName': 'GROUP_MALL_ARCHEMY',
#   'RefNpcCodeName': 'xxx'},
#  'GROUP_MALL_AVATAR': {'Service': '1',
#   'Country': '42',
#   'Id': '5551',
#   'CodeName': 'GROUP_MALL_AVATAR',
#   'RefNpcCodeName': 'xxx'},
#  'GROUP_MALL_CONSUME': {'Service': '1',
#   'Country': '42',
#   'Id': '5522',
#   'CodeName': 'GROUP_MALL_CONSUME',
#   'RefNpcCodeName': 'xxx'},
#  'GROUP_MALL_PET': {'Service': '1',
#   'Country': '42',
#   'Id': '5553',
#   'CodeName': 'GROUP_MALL_PET',
#   'RefNpcCodeName': 'xxx'},
#  'GROUP_MALL_PREMIUM': {'Service': '1',
#   'Country': '42',
#   'Id': '5563',
#   'CodeName': 'GROUP_MALL_PREMIUM',
#   'RefNpcCodeName': 'xxx'},
#  'GROUP_SOTRE_CH_LEVEL2': {'Service': '1',
#   'Country': '42',
#   'Id': '5647',
#   'CodeName': 'GROUP_SOTRE_CH_LEVEL2',
#   'RefNpcCodeName': 'NPC_LEVEL_SUPPLIES_VALUABLES2_CH'},
#  'GROUP_STORE_AR_ACCESSORY': {'Service': '1',
#   'Country': '42',
#   'Id': '5655',
#   'CodeName': 'GROUP_STORE_AR_ACCESSORY',
#   'RefNpcCodeName': 'NPC_AR_ACCESSORY'},
#  'GROUP_STORE_AR_GUILD': {'Service': '1',
#   'Country': '42',
#   'Id': '5659',
#   'CodeName': 'GROUP_STORE_AR_GUILD',
#   'RefNpcCodeName': 'NPC_AR_GUILD'},
#  'GROUP_STORE_AR_NEW_TRADE_HUNTER': {'Service': '1',
#   'Country': '42',
#   'Id': '5657',
#   'CodeName': 'GROUP_STORE_AR_NEW_TRADE_HUNTER',
#   'RefNpcCodeName': 'NPC_AR_COMMERCE1'},
#  'GROUP_STORE_AR_NEW_TRADE_THIEF': {'Service': '1',
#   'Country': '42',
#   'Id': '5658',
#   'CodeName': 'GROUP_STORE_AR_NEW_TRADE_THIEF',
#   'RefNpcCodeName': 'NPC_AR_COMMERCE2'},
#  'GROUP_STORE_AR_POTION': {'Service': '1',
#   'Country': '42',
#   'Id': '5654',
#   'CodeName': 'GROUP_STORE_AR_POTION',
#   'RefNpcCodeName': 'NPC_AR_POTION'},
#  'GROUP_STORE_AR_SMITH': {'Service': '1',
#   'Country': '42',
#   'Id': '5653',
#   'CodeName': 'GROUP_STORE_AR_SMITH',
#   'RefNpcCodeName': 'NPC_AR_SMITH'},
#  'GROUP_STORE_AR_SPECIALTY': {'Service': '1',
#   'Country': '42',
#   'Id': '5669',
#   'CodeName': 'GROUP_STORE_AR_SPECIALTY',
#   'RefNpcCodeName': 'NPC_AR_TRADE_SHOP_SPECIALTY'},
#  'GROUP_STORE_AR_STABLE': {'Service': '1',
#   'Country': '42',
#   'Id': '5656',
#   'CodeName': 'GROUP_STORE_AR_STABLE',
#   'RefNpcCodeName': 'NPC_AR_HORSE'},
#  'GROUP_STORE_BATTLE_ARENA': {'Service': '1',
#   'Country': '42',
#   'Id': '5625',
#   'CodeName': 'GROUP_STORE_BATTLE_ARENA',
#   'RefNpcCodeName': 'NPC_BATTLE_ARENA_EXCHANGER'},
#  'GROUP_STORE_BJ_BATTLEAIDE': {'Service': '1',
#   'Country': '42',
#   'Id': '5593',
#   'CodeName': 'GROUP_STORE_BJ_BATTLEAIDE',
#   'RefNpcCodeName': 'NPC_CH_FORTRESS_BATTLEAIDE2'},
#  'GROUP_STORE_CA_ACCESSORY': {'Service': '1',
#   'Country': '42',
#   'Id': '5577',
#   'CodeName': 'GROUP_STORE_CA_ACCESSORY',
#   'RefNpcCodeName': 'NPC_CA_ACCESSORY'},
#  'GROUP_STORE_CA_ARMOR': {'Service': '1',
#   'Country': '42',
#   'Id': '5576',
#   'CodeName': 'GROUP_STORE_CA_ARMOR',
#   'RefNpcCodeName': 'NPC_CA_ARMOR'},
#  'GROUP_STORE_CA_GUILD': {'Service': '1',
#   'Country': '42',
#   'Id': '5566',
#   'CodeName': 'GROUP_STORE_CA_GUILD',
#   'RefNpcCodeName': 'NPC_CA_GUILD'},
#  'GROUP_STORE_CA_HONOR': {'Service': '1',
#   'Country': '42',
#   'Id': '5603',
#   'CodeName': 'GROUP_STORE_CA_HONOR',
#   'RefNpcCodeName': 'NPC_CA_WAREHOUSE'},
#  'GROUP_STORE_CA_NEW_TRADE_HUNTER': {'Service': '1',
#   'Country': '42',
#   'Id': '5635',
#   'CodeName': 'GROUP_STORE_CA_NEW_TRADE_HUNTER',
#   'RefNpcCodeName': 'NPC_CA_COMMERCE1'},
#  'GROUP_STORE_CA_NEW_TRADE_THIEF': {'Service': '1',
#   'Country': '42',
#   'Id': '5640',
#   'CodeName': 'GROUP_STORE_CA_NEW_TRADE_THIEF',
#   'RefNpcCodeName': 'NPC_CA_COMMERCE2'},
#  'GROUP_STORE_CA_POTION': {'Service': '1',
#   'Country': '42',
#   'Id': '5578',
#   'CodeName': 'GROUP_STORE_CA_POTION',
#   'RefNpcCodeName': 'NPC_CA_POTION'},
#  'GROUP_STORE_CA_SMITH': {'Service': '1',
#   'Country': '42',
#   'Id': '5575',
#   'CodeName': 'GROUP_STORE_CA_SMITH',
#   'RefNpcCodeName': 'NPC_CA_SMITH'},
#  'GROUP_STORE_CA_SPECIALTY': {'Service': '1',
#   'Country': '42',
#   'Id': '5667',
#   'CodeName': 'GROUP_STORE_CA_SPECIALTY',
#   'RefNpcCodeName': 'NPC_CA_TRADE_SHOP_SPECIALTY'},
#  'GROUP_STORE_CA_STABLE': {'Service': '1',
#   'Country': '42',
#   'Id': '5579',
#   'CodeName': 'GROUP_STORE_CA_STABLE',
#   'RefNpcCodeName': 'NPC_CA_HORSE'},
#  'GROUP_STORE_CH_ACCESSORY': {'Service': '1',
#   'Country': '42',
#   'Id': '5525',
#   'CodeName': 'GROUP_STORE_CH_ACCESSORY',
#   'RefNpcCodeName': 'NPC_CH_ACCESSORY'},
#  'GROUP_STORE_CH_ARMOR': {'Service': '1',
#   'Country': '42',
#   'Id': '5524',
#   'CodeName': 'GROUP_STORE_CH_ARMOR',
#   'RefNpcCodeName': 'NPC_CH_ARMOR'},
#  'GROUP_STORE_CH_GUILD': {'Service': '1',
#   'Country': '42',
#   'Id': '5559',
#   'CodeName': 'GROUP_STORE_CH_GUILD',
#   'RefNpcCodeName': 'NPC_CH_GENARAL_SP'},
#  'GROUP_STORE_CH_HONOR': {'Service': '1',
#   'Country': '42',
#   'Id': '5597',
#   'CodeName': 'GROUP_STORE_CH_HONOR',
#   'RefNpcCodeName': 'NPC_CH_WAREHOUSE_M'},
#  'GROUP_STORE_CH_HONOR2': {'Service': '1',
#   'Country': '42',
#   'Id': '5598',
#   'CodeName': 'GROUP_STORE_CH_HONOR2',
#   'RefNpcCodeName': 'NPC_CH_WAREHOUSE_W'},
#  'GROUP_STORE_CH_LEVEL1': {'Service': '1',
#   'Country': '42',
#   'Id': '5645',
#   'CodeName': 'GROUP_STORE_CH_LEVEL1',
#   'RefNpcCodeName': 'NPC_LEVEL_SUPPLIES_VALUABLES1_CH'},
#  'GROUP_STORE_CH_LEVEL3': {'Service': '1',
#   'Country': '42',
#   'Id': '5649',
#   'CodeName': 'GROUP_STORE_CH_LEVEL3',
#   'RefNpcCodeName': 'NPC_LEVEL_SUPPLIES_VALUABLES3_CH'},
#  'GROUP_STORE_CH_NEW_TRADE_HUNTER': {'Service': '1',
#   'Country': '42',
#   'Id': '5632',
#   'CodeName': 'GROUP_STORE_CH_NEW_TRADE_HUNTER',
#   'RefNpcCodeName': 'NPC_CH_COMMERCE1'},
#  'GROUP_STORE_CH_NEW_TRADE_THIEF': {'Service': '1',
#   'Country': '42',
#   'Id': '5637',
#   'CodeName': 'GROUP_STORE_CH_NEW_TRADE_THIEF',
#   'RefNpcCodeName': 'NPC_CH_COMMERCE2'},
#  'GROUP_STORE_CH_OFFICIAL': {'Service': '1',
#   'Country': '42',
#   'Id': '5583',
#   'CodeName': 'GROUP_STORE_CH_OFFICIAL',
#   'RefNpcCodeName': 'NPC_CH_FORTRESS_OFFICIAL'},
#  'GROUP_STORE_CH_OFFICIAL2': {'Service': '1',
#   'Country': '42',
#   'Id': '5671',
#   'CodeName': 'GROUP_STORE_CH_OFFICIAL2',
#   'RefNpcCodeName': 'NPC_CH_FORTRESS_OFFICIAL2'},
#  'GROUP_STORE_CH_POTION': {'Service': '1',
#   'Country': '42',
#   'Id': '5526',
#   'CodeName': 'GROUP_STORE_CH_POTION',
#   'RefNpcCodeName': 'NPC_CH_POTION'},
#  'GROUP_STORE_CH_SMITH': {'Service': '1',
#   'Country': '42',
#   'Id': '5523',
#   'CodeName': 'GROUP_STORE_CH_SMITH',
#   'RefNpcCodeName': 'NPC_CH_SMITH'},
#  'GROUP_STORE_CH_SPECIALTY': {'Service': '1',
#   'Country': '42',
#   'Id': '5663',
#   'CodeName': 'GROUP_STORE_CH_SPECIALTY',
#   'RefNpcCodeName': 'NPC_CH_TRADE_SHOP_SPECIALTY'},
#  'GROUP_STORE_CH_STABLE': {'Service': '1',
#   'Country': '42',
#   'Id': '5529',
#   'CodeName': 'GROUP_STORE_CH_STABLE',
#   'RefNpcCodeName': 'NPC_CH_HORSE'},
#  'GROUP_STORE_COMMON_STOLEN': {'Service': '1',
#   'Country': '42',
#   'Id': '5670',
#   'CodeName': 'GROUP_STORE_COMMON_STOLEN',
#   'RefNpcCodeName': 'NPC_TRADE_SHOP_STOLEN'},
#  'GROUP_STORE_CT_BATTLEAIDE': {'Service': '1',
#   'Country': '42',
#   'Id': '5591',
#   'CodeName': 'GROUP_STORE_CT_BATTLEAIDE',
#   'RefNpcCodeName': 'NPC_EU_FORTRESS_BATTLEAIDE'},
#  'GROUP_STORE_EU_ACCESSORY': {'Service': '1',
#   'Country': '42',
#   'Id': '5569',
#   'CodeName': 'GROUP_STORE_EU_ACCESSORY',
#   'RefNpcCodeName': 'NPC_EU_ACCESSORY'},
#  'GROUP_STORE_EU_ARMOR': {'Service': '1',
#   'Country': '42',
#   'Id': '5568',
#   'CodeName': 'GROUP_STORE_EU_ARMOR',
#   'RefNpcCodeName': 'NPC_EU_ARMOR'},
#  'GROUP_STORE_EU_GUILD': {'Service': '1',
#   'Country': '42',
#   'Id': '5562',
#   'CodeName': 'GROUP_STORE_EU_GUILD',
#   'RefNpcCodeName': 'NPC_EU_GUILD'},
#  'GROUP_STORE_EU_HONOR': {'Service': '1',
#   'Country': '42',
#   'Id': '5602',
#   'CodeName': 'GROUP_STORE_EU_HONOR',
#   'RefNpcCodeName': 'NPC_EU_WAREHOUSE'},
#  'GROUP_STORE_EU_LEVEL1': {'Service': '1',
#   'Country': '42',
#   'Id': '5646',
#   'CodeName': 'GROUP_STORE_EU_LEVEL1',
#   'RefNpcCodeName': 'NPC_LEVEL_SUPPLIES_VALUABLES1_EU'},
#  'GROUP_STORE_EU_LEVEL2': {'Service': '1',
#   'Country': '42',
#   'Id': '5648',
#   'CodeName': 'GROUP_STORE_EU_LEVEL2',
#   'RefNpcCodeName': 'NPC_LEVEL_SUPPLIES_VALUABLES2_EU'},
#  'GROUP_STORE_EU_LEVEL3': {'Service': '1',
#   'Country': '42',
#   'Id': '5650',
#   'CodeName': 'GROUP_STORE_EU_LEVEL3',
#   'RefNpcCodeName': 'NPC_LEVEL_SUPPLIES_VALUABLES3_EU'},
#  'GROUP_STORE_EU_NEW_TRADE_HUNTER': {'Service': '1',
#   'Country': '42',
#   'Id': '5634',
#   'CodeName': 'GROUP_STORE_EU_NEW_TRADE_HUNTER',
#   'RefNpcCodeName': 'NPC_EU_COMMERCE1'},
#  'GROUP_STORE_EU_NEW_TRADE_THIEF': {'Service': '1',
#   'Country': '42',
#   'Id': '5639',
#   'CodeName': 'GROUP_STORE_EU_NEW_TRADE_THIEF',
#   'RefNpcCodeName': 'NPC_EU_COMMERCE2'},
#  'GROUP_STORE_EU_OFFICIAL': {'Service': '1',
#   'Country': '42',
#   'Id': '5586',
#   'CodeName': 'GROUP_STORE_EU_OFFICIAL',
#   'RefNpcCodeName': 'NPC_EU_FORTRESS_OFFICIAL'},
#  'GROUP_STORE_EU_POTION': {'Service': '1',
#   'Country': '42',
#   'Id': '5570',
#   'CodeName': 'GROUP_STORE_EU_POTION',
#   'RefNpcCodeName': 'NPC_EU_POTION'},
#  'GROUP_STORE_EU_SMITH': {'Service': '1',
#   'Country': '42',
#   'Id': '5567',
#   'CodeName': 'GROUP_STORE_EU_SMITH',
#   'RefNpcCodeName': 'NPC_EU_SMITH'},
#  'GROUP_STORE_EU_SPECIALTY': {'Service': '1',
#   'Country': '42',
#   'Id': '5664',
#   'CodeName': 'GROUP_STORE_EU_SPECIALTY',
#   'RefNpcCodeName': 'NPC_EU_TRADE_SHOP_SPECIALTY'},
#  'GROUP_STORE_EU_STABLE': {'Service': '1',
#   'Country': '42',
#   'Id': '5571',
#   'CodeName': 'GROUP_STORE_EU_STABLE',
#   'RefNpcCodeName': 'NPC_EU_HORSE'},
#  'GROUP_STORE_HT_BATTLEAIDE': {'Service': '1',
#   'Country': '42',
#   'Id': '5590',
#   'CodeName': 'GROUP_STORE_HT_BATTLEAIDE',
#   'RefNpcCodeName': 'NPC_KT_FORTRESS_BATTLEAIDE'},
#  'GROUP_STORE_JA_BATTLEAIDE': {'Service': '1',
#   'Country': '42',
#   'Id': '5588',
#   'CodeName': 'GROUP_STORE_JA_BATTLEAIDE',
#   'RefNpcCodeName': 'NPC_CH_FORTRESS_BATTLEAIDE1'},
#  'GROUP_STORE_KT_ACCESSORY': {'Service': '1',
#   'Country': '42',
#   'Id': '5543',
#   'CodeName': 'GROUP_STORE_KT_ACCESSORY',
#   'RefNpcCodeName': 'NPC_KT_ACCESSORY'},
#  'GROUP_STORE_KT_ARMOR': {'Service': '1',
#   'Country': '42',
#   'Id': '5542',
#   'CodeName': 'GROUP_STORE_KT_ARMOR',
#   'RefNpcCodeName': 'NPC_KT_ARMOR'},
#  'GROUP_STORE_KT_GUILD': {'Service': '1',
#   'Country': '42',
#   'Id': '5561',
#   'CodeName': 'GROUP_STORE_KT_GUILD',
#   'RefNpcCodeName': 'NPC_KT_GUILD'},
#  'GROUP_STORE_KT_HONOR': {'Service': '1',
#   'Country': '42',
#   'Id': '5601',
#   'CodeName': 'GROUP_STORE_KT_HONOR',
#   'RefNpcCodeName': 'NPC_KT_WAREHOUSE'},
#  'GROUP_STORE_KT_NEW_TRADE_HUNTER': {'Service': '1',
#   'Country': '42',
#   'Id': '5636',
#   'CodeName': 'GROUP_STORE_KT_NEW_TRADE_HUNTER',
#   'RefNpcCodeName': 'NPC_KT_COMMERCE1'},
#  'GROUP_STORE_KT_NEW_TRADE_THIEF': {'Service': '1',
#   'Country': '42',
#   'Id': '5641',
#   'CodeName': 'GROUP_STORE_KT_NEW_TRADE_THIEF',
#   'RefNpcCodeName': 'NPC_KT_COMMERCE2'},
#  'GROUP_STORE_KT_OFFICIAL': {'Service': '1',
#   'Country': '42',
#   'Id': '5585',
#   'CodeName': 'GROUP_STORE_KT_OFFICIAL',
#   'RefNpcCodeName': 'NPC_KT_FORTRESS_OFFICIAL'},
#  'GROUP_STORE_KT_POTION': {'Service': '1',
#   'Country': '42',
#   'Id': '5544',
#   'CodeName': 'GROUP_STORE_KT_POTION',
#   'RefNpcCodeName': 'NPC_KT_POTION'},
#  'GROUP_STORE_KT_SMITH': {'Service': '1',
#   'Country': '42',
#   'Id': '5541',
#   'CodeName': 'GROUP_STORE_KT_SMITH',
#   'RefNpcCodeName': 'NPC_KT_SMITH'},
#  'GROUP_STORE_KT_SPECIALTY': {'Service': '1',
#   'Country': '42',
#   'Id': '5666',
#   'CodeName': 'GROUP_STORE_KT_SPECIALTY',
#   'RefNpcCodeName': 'NPC_KT_TRADE_SHOP_SPECIALTY'},
#  'GROUP_STORE_KT_STABLE': {'Service': '1',
#   'Country': '42',
#   'Id': '5545',
#   'CodeName': 'GROUP_STORE_KT_STABLE',
#   'RefNpcCodeName': 'NPC_KT_HORSE'},
#  'GROUP_STORE_RM_WING': {'Service': '1',
#   'Country': '42',
#   'Id': '5651',
#   'CodeName': 'GROUP_STORE_RM_WING',
#   'RefNpcCodeName': 'NPC_RM_WING'},
#  'GROUP_STORE_SD_HONOR': {'Service': '1',
#   'Country': '42',
#   'Id': '5623',
#   'CodeName': 'GROUP_STORE_SD_HONOR',
#   'RefNpcCodeName': 'NPC_SD_M_AREA_WAREHOUSE'},
#  'GROUP_STORE_SD_HONOR2': {'Service': '1',
#   'Country': '42',
#   'Id': '5624',
#   'CodeName': 'GROUP_STORE_SD_HONOR2',
#   'RefNpcCodeName': 'NPC_SD_T_AREA_WAREHOUSE2'},
#  'GROUP_STORE_SD_M_ACCESSORY': {'Service': '1',
#   'Country': '42',
#   'Id': '5613',
#   'CodeName': 'GROUP_STORE_SD_M_ACCESSORY',
#   'RefNpcCodeName': 'NPC_SD_M_AREA_ACCESSORY'},
#  'GROUP_STORE_SD_M_ARMOR': {'Service': '1',
#   'Country': '42',
#   'Id': '5612',
#   'CodeName': 'GROUP_STORE_SD_M_ARMOR',
#   'RefNpcCodeName': 'NPC_SD_M_AREA_ARMOR'},
#  'GROUP_STORE_SD_M_GUILD': {'Service': '1',
#   'Country': '42',
#   'Id': '5616',
#   'CodeName': 'GROUP_STORE_SD_M_GUILD',
#   'RefNpcCodeName': 'NPC_SD_M_AREA_GUILD'},
#  'GROUP_STORE_SD_M_POTION': {'Service': '1',
#   'Country': '42',
#   'Id': '5614',
#   'CodeName': 'GROUP_STORE_SD_M_POTION',
#   'RefNpcCodeName': 'NPC_SD_M_AREA_POTION'},
#  'GROUP_STORE_SD_M_SMITH': {'Service': '1',
#   'Country': '42',
#   'Id': '5611',
#   'CodeName': 'GROUP_STORE_SD_M_SMITH',
#   'RefNpcCodeName': 'NPC_SD_M_AREA_SMITH'},
#  'GROUP_STORE_SD_M_STABLE': {'Service': '1',
#   'Country': '42',
#   'Id': '5615',
#   'CodeName': 'GROUP_STORE_SD_M_STABLE',
#   'RefNpcCodeName': 'NPC_SD_M_AREA_HORSE'},
#  'GROUP_STORE_SD_MERCHANT_CHANGER': {'Service': '1',
#   'Country': '42',
#   'Id': '5604',
#   'CodeName': 'GROUP_STORE_SD_MERCHANT_CHANGER',
#   'RefNpcCodeName': 'NPC_SD_MERCHANT_CHANGER'},
#  'GROUP_STORE_SD_NEW_TRADE_HUNTER': {'Service': '1',
#   'Country': '42',
#   'Id': '5643',
#   'CodeName': 'GROUP_STORE_SD_NEW_TRADE_HUNTER',
#   'RefNpcCodeName': 'NPC_SD_COMMERCE1'},
#  'GROUP_STORE_SD_NEW_TRADE_THIEF': {'Service': '1',
#   'Country': '42',
#   'Id': '5644',
#   'CodeName': 'GROUP_STORE_SD_NEW_TRADE_THIEF',
#   'RefNpcCodeName': 'NPC_SD_COMMERCE2'},
#  'GROUP_STORE_SD_SPECIALTY': {'Service': '1',
#   'Country': '42',
#   'Id': '5668',
#   'CodeName': 'GROUP_STORE_SD_SPECIALTY',
#   'RefNpcCodeName': 'NPC_SD_TRADE_SHOP_SPECIALTY'},
#  'GROUP_STORE_SD_T_ACCESSORY': {'Service': '1',
#   'Country': '42',
#   'Id': '5620',
#   'CodeName': 'GROUP_STORE_SD_T_ACCESSORY',
#   'RefNpcCodeName': 'NPC_SD_T_AREA_ACCESSORY'},
#  'GROUP_STORE_SD_T_ARMOR': {'Service': '1',
#   'Country': '42',
#   'Id': '5619',
#   'CodeName': 'GROUP_STORE_SD_T_ARMOR',
#   'RefNpcCodeName': 'NPC_SD_T_AREA_ARMOR'},
#  'GROUP_STORE_SD_T_GUILD': {'Service': '1',
#   'Country': '42',
#   'Id': '5622',
#   'CodeName': 'GROUP_STORE_SD_T_GUILD',
#   'RefNpcCodeName': 'NPC_SD_T_AREA_GUILD2'},
#  'GROUP_STORE_SD_T_POTION': {'Service': '1',
#   'Country': '42',
#   'Id': '5621',
#   'CodeName': 'GROUP_STORE_SD_T_POTION',
#   'RefNpcCodeName': 'NPC_SD_T_AREA_POTION'},
#  'GROUP_STORE_SD_T_SMITH': {'Service': '1',
#   'Country': '42',
#   'Id': '5618',
#   'CodeName': 'GROUP_STORE_SD_T_SMITH',
#   'RefNpcCodeName': 'NPC_SD_T_AREA_SMITH'},
#  'GROUP_STORE_SD_THIEF_AGENT_CHANGER': {'Service': '1',
#   'Country': '42',
#   'Id': '5605',
#   'CodeName': 'GROUP_STORE_SD_THIEF_AGENT_CHANGER',
#   'RefNpcCodeName': 'NPC_SD_THIEF_AGENT_CHANGER'},
#  'GROUP_STORE_SURVIVAL_ARENA': {'Service': '1',
#   'Country': '42',
#   'Id': '5652',
#   'CodeName': 'GROUP_STORE_SURVIVAL_ARENA',
#   'RefNpcCodeName': 'NPC_SURVIVAL_ARENA_MANAGER'},
#  'GROUP_STORE_TRADE_COMMON_HUNTER': {'Service': '1',
#   'Country': '42',
#   'Id': '5661',
#   'CodeName': 'GROUP_STORE_TRADE_COMMON_HUNTER',
#   'RefNpcCodeName': 'NPC_TRADE_COMMON_HUNTER'},
#  'GROUP_STORE_TRADE_COMMON_THIEF': {'Service': '1',
#   'Country': '42',
#   'Id': '5662',
#   'CodeName': 'GROUP_STORE_TRADE_COMMON_THIEF',
#   'RefNpcCodeName': 'NPC_TRADE_COMMON_ROBBER'},
#  'GROUP_STORE_TRADE_COMMON_TRADER': {'Service': '1',
#   'Country': '42',
#   'Id': '5660',
#   'CodeName': 'GROUP_STORE_TRADE_COMMON_TRADER',
#   'RefNpcCodeName': 'NPC_TRADE_COMMON_TRADER'},
#  'GROUP_STORE_WC_ACCESSORY': {'Service': '1',
#   'Country': '42',
#   'Id': '5535',
#   'CodeName': 'GROUP_STORE_WC_ACCESSORY',
#   'RefNpcCodeName': 'NPC_WC_ACCESSORY'},
#  'GROUP_STORE_WC_ARMOR': {'Service': '1',
#   'Country': '42',
#   'Id': '5534',
#   'CodeName': 'GROUP_STORE_WC_ARMOR',
#   'RefNpcCodeName': 'NPC_WC_ARMOR'},
#  'GROUP_STORE_WC_GUILD': {'Service': '1',
#   'Country': '42',
#   'Id': '5560',
#   'CodeName': 'GROUP_STORE_WC_GUILD',
#   'RefNpcCodeName': 'NPC_WC_GUILD'},
#  'GROUP_STORE_WC_HONOR': {'Service': '1',
#   'Country': '42',
#   'Id': '5599',
#   'CodeName': 'GROUP_STORE_WC_HONOR',
#   'RefNpcCodeName': 'NPC_WC_WAREHOUSE_M'},
#  'GROUP_STORE_WC_HONOR2': {'Service': '1',
#   'Country': '42',
#   'Id': '5600',
#   'CodeName': 'GROUP_STORE_WC_HONOR2',
#   'RefNpcCodeName': 'NPC_WC_WAREHOUSE_W'},
#  'GROUP_STORE_WC_NEW_TRADE_HUNTER': {'Service': '1',
#   'Country': '42',
#   'Id': '5633',
#   'CodeName': 'GROUP_STORE_WC_NEW_TRADE_HUNTER',
#   'RefNpcCodeName': 'NPC_WC_COMMERCE1'},
#  'GROUP_STORE_WC_NEW_TRADE_THIEF': {'Service': '1',
#   'Country': '42',
#   'Id': '5638',
#   'CodeName': 'GROUP_STORE_WC_NEW_TRADE_THIEF',
#   'RefNpcCodeName': 'NPC_WC_COMMERCE2'},
#  'GROUP_STORE_WC_POTION': {'Service': '1',
#   'Country': '42',
#   'Id': '5536',
#   'CodeName': 'GROUP_STORE_WC_POTION',
#   'RefNpcCodeName': 'NPC_WC_POTION'},
#  'GROUP_STORE_WC_SMITH': {'Service': '1',
#   'Country': '42',
#   'Id': '5533',
#   'CodeName': 'GROUP_STORE_WC_SMITH',
#   'RefNpcCodeName': 'NPC_WC_SMITH'},
#  'GROUP_STORE_WC_SPECIALTY': {'Service': '1',
#   'Country': '42',
#   'Id': '5665',
#   'CodeName': 'GROUP_STORE_WC_SPECIALTY',
#   'RefNpcCodeName': 'NPC_WC_TRADE_SHOP_SPECIALTY'},
#  'GROUP_STORE_WC_STABLE': {'Service': '1',
#   'Country': '42',
#   'Id': '5537',
#   'CodeName': 'GROUP_STORE_WC_STABLE',
#   'RefNpcCodeName': 'NPC_WC_HORSE'}}

# %% [markdown]
# ## RefMappingShopGroup.txt

# %%
ref_mapping_shop_group_file = os.path.join(server_dep, 'RefMappingShopGroup.txt')
ref_mapping_shop_group_file
# Out:
# 'server_dep\\silkroad\\textdata\\RefMappingShopGroup.txt'

# %%
lines = get_lines(ref_mapping_shop_group_file)
for idx, line in enumerate(lines):
    try:
      values = line.split('\t')

      Service = values[0]
      Country = values[1]
      Group = values[2]  
      Shop = values[3]

      obj = {
        "Service": Service,
        "Country": Country,
        "Group": Group,
        "Shop": Shop
      }

      ref_mapping_shop_group_data.append(obj)
    except Exception as e:
      continue

# %%
ref_mapping_shop_group_data
# Out:
# [{'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_JUPITER_STORE_POTION',
#   'Shop': 'STORE_JUPITER'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_MALL',
#   'Shop': 'MALL_ARCHEMY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_MALL',
#   'Shop': 'MALL_AVATAR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_MALL',
#   'Shop': 'MALL_CONSUME'},
#  {'Service': '1', 'Country': '42', 'Group': 'GROUP_MALL', 'Shop': 'MALL_PET'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_MALL',
#   'Shop': 'MALL_PREMIUM'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_SOTRE_CH_LEVEL2',
#   'Shop': 'STORE_CH_LEVEL2'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_AR_ACCESSORY',
#   'Shop': 'STORE_SD_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_AR_GUILD',
#   'Shop': 'STORE_KT_GUILD'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_AR_NEW_TRADE_HUNTER',
#   'Shop': 'STORE_NEW_TRADE_HUNTER'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_AR_NEW_TRADE_THIEF',
#   'Shop': 'STORE_NEW_TRADE_THIEF'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_AR_POTION',
#   'Shop': 'STORE_KT_POTION'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_AR_SMITH',
#   'Shop': 'STORE_AR_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_AR_SPECIALTY',
#   'Shop': 'STORE_AR_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_AR_STABLE',
#   'Shop': 'STORE_KT_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_BATTLE_ARENA',
#   'Shop': 'STORE_BATTLE_ARENA'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_BJ_BATTLEAIDE',
#   'Shop': 'STORE_BJ_BATTLEAIDE'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CA_ACCESSORY',
#   'Shop': 'STORE_CA_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CA_ARMOR',
#   'Shop': 'STORE_CA_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CA_GUILD',
#   'Shop': 'STORE_CA_GUILD'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CA_HONOR',
#   'Shop': 'STORE_CA_HONOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CA_NEW_TRADE_HUNTER',
#   'Shop': 'STORE_NEW_TRADE_HUNTER'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CA_NEW_TRADE_THIEF',
#   'Shop': 'STORE_NEW_TRADE_THIEF'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CA_POTION',
#   'Shop': 'STORE_CA_POTION'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CA_SMITH',
#   'Shop': 'STORE_CA_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CA_SPECIALTY',
#   'Shop': 'STORE_SD_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CA_STABLE',
#   'Shop': 'STORE_CA_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_ACCESSORY',
#   'Shop': 'STORE_CH_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_ARMOR',
#   'Shop': 'STORE_CH_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_GUILD',
#   'Shop': 'STORE_CH_GUILD'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_HONOR',
#   'Shop': 'STORE_CH_HONOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_HONOR2',
#   'Shop': 'STORE_CH_HONOR2'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_LEVEL1',
#   'Shop': 'STORE_CH_LEVEL1'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_LEVEL3',
#   'Shop': 'STORE_CH_LEVEL3'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_NEW_TRADE_HUNTER',
#   'Shop': 'STORE_NEW_TRADE_HUNTER'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_NEW_TRADE_THIEF',
#   'Shop': 'STORE_NEW_TRADE_THIEF'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_OFFICIAL',
#   'Shop': 'STORE_CH_OFFICIAL'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_OFFICIAL2',
#   'Shop': 'STORE_CH_OFFICIAL'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_POTION',
#   'Shop': 'STORE_CH_POTION'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_SMITH',
#   'Shop': 'STORE_CH_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_SPECIALTY',
#   'Shop': 'STORE_CH_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CH_STABLE',
#   'Shop': 'STORE_CH_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_COMMON_STOLEN',
#   'Shop': 'STORE_COMMON_STOLEN'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_CT_BATTLEAIDE',
#   'Shop': 'STORE_CT_BATTLEAIDE'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_ACCESSORY',
#   'Shop': 'STORE_EU_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_ARMOR',
#   'Shop': 'STORE_EU_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_GUILD',
#   'Shop': 'STORE_EU_GUILD'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_HONOR',
#   'Shop': 'STORE_EU_HONOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_LEVEL1',
#   'Shop': 'STORE_EU_LEVEL1'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_LEVEL2',
#   'Shop': 'STORE_EU_LEVEL2'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_LEVEL3',
#   'Shop': 'STORE_EU_LEVEL3'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_NEW_TRADE_HUNTER',
#   'Shop': 'STORE_NEW_TRADE_HUNTER'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_NEW_TRADE_THIEF',
#   'Shop': 'STORE_NEW_TRADE_THIEF'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_OFFICIAL',
#   'Shop': 'STORE_EU_OFFICIAL'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_POTION',
#   'Shop': 'STORE_EU_POTION'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_SMITH',
#   'Shop': 'STORE_EU_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_SPECIALTY',
#   'Shop': 'STORE_EU_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_EU_STABLE',
#   'Shop': 'STORE_EU_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_HT_BATTLEAIDE',
#   'Shop': 'STORE_HT_BATTLEAIDE'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_JA_BATTLEAIDE',
#   'Shop': 'STORE_JA_BATTLEAIDE'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_KT_ACCESSORY',
#   'Shop': 'STORE_KT_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_KT_ARMOR',
#   'Shop': 'STORE_KT_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_KT_GUILD',
#   'Shop': 'STORE_KT_GUILD'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_KT_HONOR',
#   'Shop': 'STORE_KT_HONOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_KT_NEW_TRADE_HUNTER',
#   'Shop': 'STORE_NEW_TRADE_HUNTER'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_KT_NEW_TRADE_THIEF',
#   'Shop': 'STORE_NEW_TRADE_THIEF'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_KT_OFFICIAL',
#   'Shop': 'STORE_KT_OFFICIAL'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_KT_POTION',
#   'Shop': 'STORE_KT_POTION'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_KT_SMITH',
#   'Shop': 'STORE_KT_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_KT_SPECIALTY',
#   'Shop': 'STORE_KT_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_KT_STABLE',
#   'Shop': 'STORE_KT_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_RM_WING',
#   'Shop': 'STORE_RM_WING'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_HONOR',
#   'Shop': 'STORE_KT_HONOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_HONOR2',
#   'Shop': 'STORE_KT_HONOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_M_ACCESSORY',
#   'Shop': 'STORE_SD_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_M_ARMOR',
#   'Shop': 'STORE_SD_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_M_GUILD',
#   'Shop': 'STORE_KT_GUILD'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_M_POTION',
#   'Shop': 'STORE_KT_POTION'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_M_SMITH',
#   'Shop': 'STORE_SD_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_M_STABLE',
#   'Shop': 'STORE_KT_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_MERCHANT_CHANGER',
#   'Shop': 'STORE_SD_SET'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_NEW_TRADE_HUNTER',
#   'Shop': 'STORE_NEW_TRADE_HUNTER'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_NEW_TRADE_THIEF',
#   'Shop': 'STORE_NEW_TRADE_THIEF'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_SPECIALTY',
#   'Shop': 'STORE_SD_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_T_ACCESSORY',
#   'Shop': 'STORE_SD_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_T_ARMOR',
#   'Shop': 'STORE_SD_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_T_GUILD',
#   'Shop': 'STORE_KT_GUILD'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_T_POTION',
#   'Shop': 'STORE_KT_POTION'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_T_SMITH',
#   'Shop': 'STORE_SD_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SD_THIEF_AGENT_CHANGER',
#   'Shop': 'STORE_SD_SET'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_SURVIVAL_ARENA',
#   'Shop': 'STORE_SURVIVAL_ARENA'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_TRADE_COMMON_HUNTER',
#   'Shop': 'STORE_TRADE_COMMON_HUNTER'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_TRADE_COMMON_THIEF',
#   'Shop': 'STORE_TRADE_COMMON_THIEF'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_TRADE_COMMON_TRADER',
#   'Shop': 'STORE_TRADE_COMMON_TRADER'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_WC_ACCESSORY',
#   'Shop': 'STORE_WC_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_WC_ARMOR',
#   'Shop': 'STORE_WC_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_WC_GUILD',
#   'Shop': 'STORE_WC_GUILD'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_WC_HONOR',
#   'Shop': 'STORE_WC_HONOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_WC_HONOR2',
#   'Shop': 'STORE_WC_HONOR2'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_WC_NEW_TRADE_HUNTER',
#   'Shop': 'STORE_NEW_TRADE_HUNTER'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_WC_NEW_TRADE_THIEF',
#   'Shop': 'STORE_NEW_TRADE_THIEF'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_WC_POTION',
#   'Shop': 'STORE_WC_POTION'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_WC_SMITH',
#   'Shop': 'STORE_WC_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_WC_SPECIALTY',
#   'Shop': 'STORE_WC_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Group': 'GROUP_STORE_WC_STABLE',
#   'Shop': 'STORE_WC_STABLE'}]

# %% [markdown]
# ## RefMappingShopWithTab.txt

# %%
ref_mapping_shop_with_tab_file = os.path.join(server_dep, 'RefMappingShopWithTab.txt')
ref_mapping_shop_with_tab_file
# Out:
# 'server_dep\\silkroad\\textdata\\RefMappingShopWithTab.txt'

# %%
lines = get_lines(ref_mapping_shop_with_tab_file)
for idx, line in enumerate(lines):
    try:
      values = line.split('\t')

      Service = values[0]
      Country = values[1]
      Shop = values[2]  
      Tab = values[3]

      obj = {
        "Service": Service,
        "Country": Country,
        "Tab": Tab,
        "Shop": Shop
      }

      ref_mapping_shop_with_tab_data.append(obj)
    except Exception as e:
      continue

# %%
ref_mapping_shop_with_tab_data
# Out:
# [{'Service': '1',
#   'Country': '42',
#   'Tab': 'MALL_ARCHEMY_GROUP1',
#   'Shop': 'MALL_ARCHEMY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'MALL_AVATAR_GROUP1',
#   'Shop': 'MALL_AVATAR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'MALL_CONSUME_GROUP1',
#   'Shop': 'MALL_CONSUME'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'MALL_PET_GROUP1',
#   'Shop': 'MALL_PET'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'MALL_PREMIUM_GROUP1',
#   'Shop': 'MALL_PREMIUM'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_AR_SMITH_EU_GROUP1',
#   'Shop': 'STORE_AR_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_AR_SMITH_GROUP1',
#   'Shop': 'STORE_AR_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_AR_SPECIALTY_GROUP1',
#   'Shop': 'STORE_AR_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_BATTLE_ARENA_CH_GROUP1',
#   'Shop': 'STORE_BATTLE_ARENA'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_BATTLE_ARENA_EU_GROUP1',
#   'Shop': 'STORE_BATTLE_ARENA'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_BJ_BATTLEAIDE_GROUP1',
#   'Shop': 'STORE_BJ_BATTLEAIDE'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CA_ACCESSORY_GROUP1',
#   'Shop': 'STORE_CA_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CA_ARMOR_GROUP1',
#   'Shop': 'STORE_CA_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CA_ARMOR_GROUP2',
#   'Shop': 'STORE_CA_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CA_GUILD_GROUP1',
#   'Shop': 'STORE_CA_GUILD'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CA_HONOR_GROUP1',
#   'Shop': 'STORE_CA_HONOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CA_POTION_GROUP1',
#   'Shop': 'STORE_CA_POTION'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CA_SMITH_GROUP1',
#   'Shop': 'STORE_CA_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CA_SPECIALTY_GROUP1',
#   'Shop': 'STORE_CA_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CA_STABLE_GROUP1',
#   'Shop': 'STORE_CA_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_FELLOWS_GROUP1',
#   'Shop': 'STORE_CA_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CH_ACCESSORY_GROUP1',
#   'Shop': 'STORE_CH_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CH_ARMOR_GROUP1',
#   'Shop': 'STORE_CH_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CH_ARMOR_GROUP2',
#   'Shop': 'STORE_CH_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CH_GUILD_GROUP1',
#   'Shop': 'STORE_CH_GUILD'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CH_HONOR_GROUP1',
#   'Shop': 'STORE_CH_HONOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CH_HONOR_GROUP1',
#   'Shop': 'STORE_CH_HONOR2'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_CH_ARMOR1_GROUP1',
#   'Shop': 'STORE_CH_LEVEL1'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_CH_ARMOR1_GROUP2',
#   'Shop': 'STORE_CH_LEVEL1'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_CH_VALUABLE1_GROUP1',
#   'Shop': 'STORE_CH_LEVEL1'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_FELLOWS_ETC_GROUP01',
#   'Shop': 'STORE_CH_LEVEL1'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_CH_ARMOR2_GROUP1',
#   'Shop': 'STORE_CH_LEVEL2'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_CH_ARMOR2_GROUP2',
#   'Shop': 'STORE_CH_LEVEL2'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_CH_VALUABLE2_GROUP1',
#   'Shop': 'STORE_CH_LEVEL2'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_FELLOWS_ETC_GROUP02',
#   'Shop': 'STORE_CH_LEVEL2'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_CH_ARMOR3_GROUP1',
#   'Shop': 'STORE_CH_LEVEL3'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_CH_ARMOR3_GROUP2',
#   'Shop': 'STORE_CH_LEVEL3'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_CH_VALUABLE3_GROUP1',
#   'Shop': 'STORE_CH_LEVEL3'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_FELLOWS_ETC_GROUP03',
#   'Shop': 'STORE_CH_LEVEL3'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CH_OFFICIAL_GROUP1',
#   'Shop': 'STORE_CH_OFFICIAL'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CH_POTION_GROUP1',
#   'Shop': 'STORE_CH_POTION'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CH_SMITH_GROUP1',
#   'Shop': 'STORE_CH_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CH_SPECIALTY_GROUP1',
#   'Shop': 'STORE_CH_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CH_STABLE_GROUP1',
#   'Shop': 'STORE_CH_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_FELLOWS_GROUP1',
#   'Shop': 'STORE_CH_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_COMMON_STOLEN_GROUP1',
#   'Shop': 'STORE_COMMON_STOLEN'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_CT_BATTLEAIDE_GROUP1',
#   'Shop': 'STORE_CT_BATTLEAIDE'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_EU_ACCESSORY_GROUP1',
#   'Shop': 'STORE_EU_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_EU_ARMOR_GROUP1',
#   'Shop': 'STORE_EU_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_EU_ARMOR_GROUP2',
#   'Shop': 'STORE_EU_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_EU_GUILD_GROUP1',
#   'Shop': 'STORE_EU_GUILD'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_EU_HONOR_GROUP1',
#   'Shop': 'STORE_EU_HONOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_EU_ARMOR1_GROUP1',
#   'Shop': 'STORE_EU_LEVEL1'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_EU_ARMOR1_GROUP2',
#   'Shop': 'STORE_EU_LEVEL1'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_EU_VALUABLE1_GROUP1',
#   'Shop': 'STORE_EU_LEVEL1'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_FELLOWS_ETC_GROUP01',
#   'Shop': 'STORE_EU_LEVEL1'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_EU_ARMOR2_GROUP1',
#   'Shop': 'STORE_EU_LEVEL2'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_EU_ARMOR2_GROUP2',
#   'Shop': 'STORE_EU_LEVEL2'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_EU_VALUABLE2_GROUP1',
#   'Shop': 'STORE_EU_LEVEL2'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_FELLOWS_ETC_GROUP02',
#   'Shop': 'STORE_EU_LEVEL2'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_EU_ARMOR3_GROUP1',
#   'Shop': 'STORE_EU_LEVEL3'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_EU_ARMOR3_GROUP2',
#   'Shop': 'STORE_EU_LEVEL3'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'LEVEL_EU_VALUABLE3_GROUP1',
#   'Shop': 'STORE_EU_LEVEL3'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_FELLOWS_ETC_GROUP03',
#   'Shop': 'STORE_EU_LEVEL3'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_EU_OFFICIAL_GROUP1',
#   'Shop': 'STORE_EU_OFFICIAL'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_EU_POTION_GROUP1',
#   'Shop': 'STORE_EU_POTION'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_EU_SMITH_GROUP1',
#   'Shop': 'STORE_EU_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_EU_SPECIALTY_GROUP1',
#   'Shop': 'STORE_EU_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_EU_STABLE_GROUP1',
#   'Shop': 'STORE_EU_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_FELLOWS_GROUP1',
#   'Shop': 'STORE_EU_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_HT_BATTLEAIDE_GROUP1',
#   'Shop': 'STORE_HT_BATTLEAIDE'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_JA_BATTLEAIDE_GROUP1',
#   'Shop': 'STORE_JA_BATTLEAIDE'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_JUPITER_GROUP1',
#   'Shop': 'STORE_JUPITER'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_ACCESSORY_EU_GROUP1',
#   'Shop': 'STORE_KT_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_ACCESSORY_GROUP1',
#   'Shop': 'STORE_KT_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_ARMOR_EU_GROUP1',
#   'Shop': 'STORE_KT_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_ARMOR_EU_GROUP2',
#   'Shop': 'STORE_KT_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_ARMOR_GROUP1',
#   'Shop': 'STORE_KT_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_ARMOR_GROUP2',
#   'Shop': 'STORE_KT_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_GUILD_GROUP1',
#   'Shop': 'STORE_KT_GUILD'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_HONOR_GROUP1',
#   'Shop': 'STORE_KT_HONOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_OFFICIAL_GROUP1',
#   'Shop': 'STORE_KT_OFFICIAL'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_POTION_GROUP1',
#   'Shop': 'STORE_KT_POTION'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_SMITH_EU_GROUP1',
#   'Shop': 'STORE_KT_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_SMITH_GROUP1',
#   'Shop': 'STORE_KT_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_SPECIALTY_GROUP1',
#   'Shop': 'STORE_KT_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_FELLOWS_GROUP1',
#   'Shop': 'STORE_KT_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_KT_STABLE_GROUP1',
#   'Shop': 'STORE_KT_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_NEW_TRADE_HUNTER_GROUP1',
#   'Shop': 'STORE_NEW_TRADE_HUNTER'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_NEW_TRADE_THIEF_GROUP1',
#   'Shop': 'STORE_NEW_TRADE_THIEF'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_RM_WING_GROUP1',
#   'Shop': 'STORE_RM_WING'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SD_ACCESSORY_EU_GROUP1',
#   'Shop': 'STORE_SD_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SD_ACCESSORY_GROUP1',
#   'Shop': 'STORE_SD_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SD_ARMOR_EU_GROUP1',
#   'Shop': 'STORE_SD_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SD_ARMOR_EU_GROUP2',
#   'Shop': 'STORE_SD_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SD_ARMOR_GROUP1',
#   'Shop': 'STORE_SD_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SD_ARMOR_GROUP2',
#   'Shop': 'STORE_SD_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SD_SET_ARMOR_EU_GROUP1',
#   'Shop': 'STORE_SD_SET'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SD_SET_ARMOR_EU_GROUP2',
#   'Shop': 'STORE_SD_SET'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SD_SET_ARMOR_GROUP1',
#   'Shop': 'STORE_SD_SET'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SD_SET_ARMOR_GROUP2',
#   'Shop': 'STORE_SD_SET'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SD_SMITH_EU_GROUP1',
#   'Shop': 'STORE_SD_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SD_SMITH_GROUP1',
#   'Shop': 'STORE_SD_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SD_SPECIALTY_GROUP1',
#   'Shop': 'STORE_SD_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_SURVIVAL_ARENA_GROUP1',
#   'Shop': 'STORE_SURVIVAL_ARENA'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_TRADE_COMMON_HUNTER_GROUP1',
#   'Shop': 'STORE_TRADE_COMMON_HUNTER'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_TRADE_COMMON_THIEF_GROUP1',
#   'Shop': 'STORE_TRADE_COMMON_THIEF'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_TRADE_COMMON_TRADER_GROUP1',
#   'Shop': 'STORE_TRADE_COMMON_TRADER'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_WC_ACCESSORY_GROUP1',
#   'Shop': 'STORE_WC_ACCESSORY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_WC_ARMOR_GROUP1',
#   'Shop': 'STORE_WC_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_WC_ARMOR_GROUP2',
#   'Shop': 'STORE_WC_ARMOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_WC_GUILD_GROUP1',
#   'Shop': 'STORE_WC_GUILD'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_WC_HONOR_GROUP1',
#   'Shop': 'STORE_WC_HONOR'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_WC_HONOR_GROUP1',
#   'Shop': 'STORE_WC_HONOR2'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_WC_POTION_GROUP1',
#   'Shop': 'STORE_WC_POTION'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_WC_SMITH_GROUP1',
#   'Shop': 'STORE_WC_SMITH'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_WC_SPECIALTY_GROUP1',
#   'Shop': 'STORE_WC_SPECIALTY'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_FELLOWS_GROUP1',
#   'Shop': 'STORE_WC_STABLE'},
#  {'Service': '1',
#   'Country': '42',
#   'Tab': 'STORE_WC_STABLE_GROUP1',
#   'Shop': 'STORE_WC_STABLE'}]

# %% [markdown]
# ## RefScrapOfPackageItem.txt

# %%
package_item_scrap_data = dict()

# %%
ref_scrap_of_package_item = os.path.join(server_dep, 'RefScrapOfPackageItem.txt')
ref_scrap_of_package_item
# Out:
# 'server_dep\\silkroad\\textdata\\RefScrapOfPackageItem.txt'

# %%
ref_scrap_of_package_item_files = get_lines(ref_scrap_of_package_item)
ref_scrap_of_package_item_files
# Out:
# ['refscrapofpackageitem_500.txt',
#  'refscrapofpackageitem_1000.txt',
#  'refscrapofpackageitem_1500.txt',
#  'refscrapofpackageitem_2000.txt',
#  'refscrapofpackageitem_2500.txt',
#  'refscrapofpackageitem_3000.txt',
#  'refscrapofpackageitem_3500.txt',
#  'refscrapofpackageitem_4000.txt',
#  'refscrapofpackageitem_4500.txt',
#  'refscrapofpackageitem_5500.txt',
#  '']

# %%
for xxx in ref_scrap_of_package_item_files:
  file_name = os.path.join(server_dep, xxx)
  lines = get_lines(file_name)
  for idx, line in enumerate(lines):
    values = line.split('\t')
    if len(values) != 29:
      continue
    Service = values[0]
    Country = values[1]
    RefPackageItemCodeName = values[2]
    RefItemCodeName = values[3]
    OptLevel = values[4]
    Variance = values[5]
    Data = values[6]

    package_item_scrap_data[RefPackageItemCodeName] = {
      "Service": Service,
      "Country": Country,
      "RefPackageItemCodeName": RefPackageItemCodeName,
      "RefItemCodeName": RefItemCodeName,
      "OptLevel": OptLevel,
      "Variance": Variance,
      "Data": Data
    }

# %%
package_item_scrap_data
# Out:
# {'PACKAGE_ITEM_CART_COS_T_BEHEMOTH': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_BEHEMOTH',
#   'RefItemCodeName': 'ITEM_CART_COS_T_BEHEMOTH',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_CAMEL1': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_CAMEL1',
#   'RefItemCodeName': 'ITEM_CART_COS_T_CAMEL1',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_CAMEL2': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_CAMEL2',
#   'RefItemCodeName': 'ITEM_CART_COS_T_CAMEL2',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_CAMEL3': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_CAMEL3',
#   'RefItemCodeName': 'ITEM_CART_COS_T_CAMEL3',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_COW1': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_COW1',
#   'RefItemCodeName': 'ITEM_CART_COS_T_COW1',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_COW2': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_COW2',
#   'RefItemCodeName': 'ITEM_CART_COS_T_COW2',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_COW3': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_COW3',
#   'RefItemCodeName': 'ITEM_CART_COS_T_COW3',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_DHORSE1': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_DHORSE1',
#   'RefItemCodeName': 'ITEM_CART_COS_T_DHORSE1',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_DHORSE2': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_DHORSE2',
#   'RefItemCodeName': 'ITEM_CART_COS_T_DHORSE2',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_DHORSE3': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_DHORSE3',
#   'RefItemCodeName': 'ITEM_CART_COS_T_DHORSE3',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_DONKEY': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_DONKEY',
#   'RefItemCodeName': 'ITEM_CART_COS_T_DONKEY',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_HORSE1': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_HORSE1',
#   'RefItemCodeName': 'ITEM_CART_COS_T_HORSE1',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_HORSE2': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_HORSE2',
#   'RefItemCodeName': 'ITEM_CART_COS_T_HORSE2',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_HORSE3': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_HORSE3',
#   'RefItemCodeName': 'ITEM_CART_COS_T_HORSE3',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CART_COS_T_LIZARD': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CART_COS_T_LIZARD',
#   'RefItemCodeName': 'ITEM_CART_COS_T_LIZARD',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CH_BLADE_01_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_01_A',
#   'RefItemCodeName': 'ITEM_CH_BLADE_01_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '69'},
#  'PACKAGE_ITEM_CH_BLADE_02_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_02_A',
#   'RefItemCodeName': 'ITEM_CH_BLADE_02_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '74'},
#  'PACKAGE_ITEM_CH_BLADE_03_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_03_A',
#   'RefItemCodeName': 'ITEM_CH_BLADE_03_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_BLADE_04_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_04_A',
#   'RefItemCodeName': 'ITEM_CH_BLADE_04_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '84'},
#  'PACKAGE_ITEM_CH_BLADE_05_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_05_A',
#   'RefItemCodeName': 'ITEM_CH_BLADE_05_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '90'},
#  'PACKAGE_ITEM_CH_BLADE_06_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_06_A',
#   'RefItemCodeName': 'ITEM_CH_BLADE_06_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '97'},
#  'PACKAGE_ITEM_CH_BLADE_07_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_07_A',
#   'RefItemCodeName': 'ITEM_CH_BLADE_07_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '103'},
#  'PACKAGE_ITEM_CH_BLADE_08_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_08_A',
#   'RefItemCodeName': 'ITEM_CH_BLADE_08_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '112'},
#  'PACKAGE_ITEM_CH_BLADE_08_A_RARE_HONOR': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_08_A_RARE_HONOR',
#   'RefItemCodeName': 'ITEM_CH_BLADE_08_A_RARE_HONOR',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '115'},
#  'PACKAGE_ITEM_CH_BLADE_08_B_RARE_HONOR': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_08_B_RARE_HONOR',
#   'RefItemCodeName': 'ITEM_CH_BLADE_08_B_RARE_HONOR',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '118'},
#  'PACKAGE_ITEM_CH_BLADE_08_C_RARE_HONOR': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_08_C_RARE_HONOR',
#   'RefItemCodeName': 'ITEM_CH_BLADE_08_C_RARE_HONOR',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '122'},
#  'PACKAGE_ITEM_CH_BLADE_09_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_09_A',
#   'RefItemCodeName': 'ITEM_CH_BLADE_09_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '120'},
#  'PACKAGE_ITEM_CH_BLADE_09_A_RARE_HONOR': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_09_A_RARE_HONOR',
#   'RefItemCodeName': 'ITEM_CH_BLADE_09_A_RARE_HONOR',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '123'},
#  'PACKAGE_ITEM_CH_BLADE_09_B_RARE_HONOR': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_09_B_RARE_HONOR',
#   'RefItemCodeName': 'ITEM_CH_BLADE_09_B_RARE_HONOR',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '127'},
#  'PACKAGE_ITEM_CH_BLADE_09_C_RARE_HONOR': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_09_C_RARE_HONOR',
#   'RefItemCodeName': 'ITEM_CH_BLADE_09_C_RARE_HONOR',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '130'},
#  'PACKAGE_ITEM_CH_BLADE_10_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_10_A',
#   'RefItemCodeName': 'ITEM_CH_BLADE_10_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '129'},
#  'PACKAGE_ITEM_CH_BLADE_10_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_10_B',
#   'RefItemCodeName': 'ITEM_CH_BLADE_10_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '132'},
#  'PACKAGE_ITEM_CH_BLADE_10_C': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_10_C',
#   'RefItemCodeName': 'ITEM_CH_BLADE_10_C',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '135'},
#  'PACKAGE_ITEM_CH_BLADE_11_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BLADE_11_A',
#   'RefItemCodeName': 'ITEM_CH_BLADE_11_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '137'},
#  'PACKAGE_ITEM_CH_BOW_01_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_01_A',
#   'RefItemCodeName': 'ITEM_CH_BOW_01_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '47'},
#  'PACKAGE_ITEM_CH_BOW_02_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_02_A',
#   'RefItemCodeName': 'ITEM_CH_BOW_02_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '50'},
#  'PACKAGE_ITEM_CH_BOW_03_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_03_A',
#   'RefItemCodeName': 'ITEM_CH_BOW_03_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '54'},
#  'PACKAGE_ITEM_CH_BOW_04_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_04_A',
#   'RefItemCodeName': 'ITEM_CH_BOW_04_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '58'},
#  'PACKAGE_ITEM_CH_BOW_05_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_05_A',
#   'RefItemCodeName': 'ITEM_CH_BOW_05_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '62'},
#  'PACKAGE_ITEM_CH_BOW_06_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_06_A',
#   'RefItemCodeName': 'ITEM_CH_BOW_06_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '66'},
#  'PACKAGE_ITEM_CH_BOW_07_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_07_A',
#   'RefItemCodeName': 'ITEM_CH_BOW_07_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '71'},
#  'PACKAGE_ITEM_CH_BOW_08_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_08_A',
#   'RefItemCodeName': 'ITEM_CH_BOW_08_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '77'},
#  'PACKAGE_ITEM_CH_BOW_08_A_RARE_HONOR': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_08_A_RARE_HONOR',
#   'RefItemCodeName': 'ITEM_CH_BOW_08_A_RARE_HONOR',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_BOW_08_B_RARE_HONOR': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_08_B_RARE_HONOR',
#   'RefItemCodeName': 'ITEM_CH_BOW_08_B_RARE_HONOR',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '81'},
#  'PACKAGE_ITEM_CH_BOW_08_C_RARE_HONOR': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_08_C_RARE_HONOR',
#   'RefItemCodeName': 'ITEM_CH_BOW_08_C_RARE_HONOR',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '84'},
#  'PACKAGE_ITEM_CH_BOW_09_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_09_A',
#   'RefItemCodeName': 'ITEM_CH_BOW_09_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '82'},
#  'PACKAGE_ITEM_CH_BOW_09_A_RARE_HONOR': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_09_A_RARE_HONOR',
#   'RefItemCodeName': 'ITEM_CH_BOW_09_A_RARE_HONOR',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '84'},
#  'PACKAGE_ITEM_CH_BOW_09_B_RARE_HONOR': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_09_B_RARE_HONOR',
#   'RefItemCodeName': 'ITEM_CH_BOW_09_B_RARE_HONOR',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '87'},
#  'PACKAGE_ITEM_CH_BOW_09_C_RARE_HONOR': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_09_C_RARE_HONOR',
#   'RefItemCodeName': 'ITEM_CH_BOW_09_C_RARE_HONOR',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '89'},
#  'PACKAGE_ITEM_CH_BOW_10_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_10_A',
#   'RefItemCodeName': 'ITEM_CH_BOW_10_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '89'},
#  'PACKAGE_ITEM_CH_BOW_10_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_10_B',
#   'RefItemCodeName': 'ITEM_CH_BOW_10_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '91'},
#  'PACKAGE_ITEM_CH_BOW_10_C': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_10_C',
#   'RefItemCodeName': 'ITEM_CH_BOW_10_C',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '92'},
#  'PACKAGE_ITEM_CH_BOW_11_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_BOW_11_A',
#   'RefItemCodeName': 'ITEM_CH_BOW_11_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '94'},
#  'PACKAGE_ITEM_CH_EARRING_01_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_01_A',
#   'RefItemCodeName': 'ITEM_CH_EARRING_01_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_02_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_02_A',
#   'RefItemCodeName': 'ITEM_CH_EARRING_02_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_03_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_03_A',
#   'RefItemCodeName': 'ITEM_CH_EARRING_03_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_04_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_04_A',
#   'RefItemCodeName': 'ITEM_CH_EARRING_04_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_05_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_05_A',
#   'RefItemCodeName': 'ITEM_CH_EARRING_05_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_06_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_06_A',
#   'RefItemCodeName': 'ITEM_CH_EARRING_06_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_07_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_07_A',
#   'RefItemCodeName': 'ITEM_CH_EARRING_07_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_08_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_08_A',
#   'RefItemCodeName': 'ITEM_CH_EARRING_08_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_09_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_09_A',
#   'RefItemCodeName': 'ITEM_CH_EARRING_09_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_09_A_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_09_A_RARE',
#   'RefItemCodeName': 'ITEM_CH_EARRING_09_A_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_09_B_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_09_B_RARE',
#   'RefItemCodeName': 'ITEM_CH_EARRING_09_B_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_09_C_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_09_C_RARE',
#   'RefItemCodeName': 'ITEM_CH_EARRING_09_C_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_10_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_10_A',
#   'RefItemCodeName': 'ITEM_CH_EARRING_10_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_10_A_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_10_A_RARE',
#   'RefItemCodeName': 'ITEM_CH_EARRING_10_A_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_10_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_10_B',
#   'RefItemCodeName': 'ITEM_CH_EARRING_10_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_10_B_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_10_B_RARE',
#   'RefItemCodeName': 'ITEM_CH_EARRING_10_B_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_10_C': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_10_C',
#   'RefItemCodeName': 'ITEM_CH_EARRING_10_C',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_10_C_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_10_C_RARE',
#   'RefItemCodeName': 'ITEM_CH_EARRING_10_C_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_11_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_11_A',
#   'RefItemCodeName': 'ITEM_CH_EARRING_11_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_11_SET_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_11_SET_A',
#   'RefItemCodeName': 'ITEM_CH_EARRING_11_SET_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_11_SET_A_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_11_SET_A_RARE',
#   'RefItemCodeName': 'ITEM_CH_EARRING_11_SET_A_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_11_SET_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_11_SET_B',
#   'RefItemCodeName': 'ITEM_CH_EARRING_11_SET_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_EARRING_11_SET_B_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_EARRING_11_SET_B_RARE',
#   'RefItemCodeName': 'ITEM_CH_EARRING_11_SET_B_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '1'},
#  'PACKAGE_ITEM_CH_F_FRPVP_VOUCHER_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_F_FRPVP_VOUCHER_A',
#   'RefItemCodeName': 'ITEM_CH_F_FRPVP_VOUCHER_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CH_F_FRPVP_VOUCHER_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_F_FRPVP_VOUCHER_B',
#   'RefItemCodeName': 'ITEM_CH_F_FRPVP_VOUCHER_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CH_F_FRPVP_VOUCHER_C': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_F_FRPVP_VOUCHER_C',
#   'RefItemCodeName': 'ITEM_CH_F_FRPVP_VOUCHER_C',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CH_F_FRPVP_VOUCHER_D': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_F_FRPVP_VOUCHER_D',
#   'RefItemCodeName': 'ITEM_CH_F_FRPVP_VOUCHER_D',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CH_F_FRPVP_VOUCHER_E': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_F_FRPVP_VOUCHER_E',
#   'RefItemCodeName': 'ITEM_CH_F_FRPVP_VOUCHER_E',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_01_AA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_01_AA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_01_AA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '39'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_01_BA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_01_BA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_01_BA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '39'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_01_CA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_01_CA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_01_CA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '39'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_01_FA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_01_FA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_01_FA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '39'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_01_LA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_01_LA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_01_LA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '39'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_01_SA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_01_SA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_01_SA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '39'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_02_AA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_02_AA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_02_AA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '42'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_02_BA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_02_BA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_02_BA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '44'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_02_CA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_02_CA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_02_CA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '43'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_02_FA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_02_FA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_02_FA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '43'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_02_LA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_02_LA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_02_LA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '44'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_02_SA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_02_SA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_02_SA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '42'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_03_AA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_03_AA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_03_AA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '45'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_03_BA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_03_BA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_03_BA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '47'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_03_CA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_03_CA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_03_CA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '46'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_03_FA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_03_FA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_03_FA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '46'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_03_LA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_03_LA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_03_LA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '47'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_03_SA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_03_SA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_03_SA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '46'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_04_AA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_04_AA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_04_AA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '48'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_04_BA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_04_BA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_04_BA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '50'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_04_CA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_04_CA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_04_CA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '49'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_04_FA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_04_FA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_04_FA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '49'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_04_LA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_04_LA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_04_LA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '50'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_04_SA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_04_SA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_04_SA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '49'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_05_AA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_05_AA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_05_AA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '51'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_05_BA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_05_BA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_05_BA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '53'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_05_CA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_05_CA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_05_CA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '53'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_05_FA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_05_FA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_05_FA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '52'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_05_LA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_05_LA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_05_LA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '53'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_05_SA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_05_SA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_05_SA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '52'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_06_AA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_06_AA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_06_AA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '55'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_06_BA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_06_BA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_06_BA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '57'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_06_CA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_06_CA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_06_CA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '56'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_06_FA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_06_FA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_06_FA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '56'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_06_LA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_06_LA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_06_LA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '57'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_06_SA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_06_SA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_06_SA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '56'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_07_AA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_07_AA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_07_AA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '59'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_07_BA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_07_BA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_07_BA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '61'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_07_CA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_07_CA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_07_CA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '60'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_07_FA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_07_FA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_07_FA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '60'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_07_LA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_07_LA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_07_LA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '61'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_07_SA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_07_SA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_07_SA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '60'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_08_AA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_08_AA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_08_AA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '64'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_08_BA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_08_BA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_08_BA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '66'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_08_CA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_08_CA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_08_CA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '65'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_08_FA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_08_FA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_08_FA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '65'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_08_LA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_08_LA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_08_LA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '65'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_08_SA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_08_SA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_08_SA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '64'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_09_AA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_09_AA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_09_AA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '68'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_09_BA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_09_BA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_09_BA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '70'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_09_CA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_09_CA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_09_CA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '70'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_09_FA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_09_FA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_09_FA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '69'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_09_LA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_09_LA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_09_LA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '70'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_09_SA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_09_SA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_09_SA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '69'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_AA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_AA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_AA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '74'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_AA_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_AA_B',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_AA_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '75'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_AA_C': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_AA_C',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_AA_C',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '77'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_BA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_BA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_BA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '75'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_BA_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_BA_B',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_BA_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '76'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_BA_C': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_BA_C',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_BA_C',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '78'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_CA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_CA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_CA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '74'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_CA_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_CA_B',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_CA_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '76'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_CA_C': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_CA_C',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_CA_C',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '77'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_FA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_FA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_FA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '74'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_FA_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_FA_B',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_FA_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '76'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_FA_C': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_FA_C',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_FA_C',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '77'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_HA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_HA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_HA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '74'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_HA_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_HA_B',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_HA_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '76'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_HA_C': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_HA_C',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_HA_C',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '77'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_LA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_LA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_LA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '75'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_LA_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_LA_B',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_LA_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '76'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_LA_C': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_LA_C',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_LA_C',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '78'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_SA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_SA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_SA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '74'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_SA_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_SA_B',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_SA_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '75'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_10_SA_C': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_10_SA_C',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_10_SA_C',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '77'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_AA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_AA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_AA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '78'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_AA_SET_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_AA_SET_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_AA_SET_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '78'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_AA_SET_A_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_AA_SET_A_RARE',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_AA_SET_A_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '80'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_AA_SET_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_AA_SET_B',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_AA_SET_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '78'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_AA_SET_B_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_AA_SET_B_RARE',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_AA_SET_B_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '80'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_BA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_BA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_BA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_BA_SET_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_BA_SET_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_BA_SET_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_BA_SET_A_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_BA_SET_A_RARE',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_BA_SET_A_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '81'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_BA_SET_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_BA_SET_B',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_BA_SET_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_BA_SET_B_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_BA_SET_B_RARE',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_BA_SET_B_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '81'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_FA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_FA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_FA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_FA_SET_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_FA_SET_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_FA_SET_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_FA_SET_A_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_FA_SET_A_RARE',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_FA_SET_A_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '81'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_FA_SET_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_FA_SET_B',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_FA_SET_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_FA_SET_B_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_FA_SET_B_RARE',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_FA_SET_B_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '81'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_HA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_HA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_HA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_HA_SET_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_HA_SET_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_HA_SET_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_HA_SET_A_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_HA_SET_A_RARE',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_HA_SET_A_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '81'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_HA_SET_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_HA_SET_B',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_HA_SET_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_HA_SET_B_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_HA_SET_B_RARE',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_HA_SET_B_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '81'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_LA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_LA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_LA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_LA_SET_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_LA_SET_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_LA_SET_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_LA_SET_A_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_LA_SET_A_RARE',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_LA_SET_A_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '81'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_LA_SET_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_LA_SET_B',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_LA_SET_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '79'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_LA_SET_B_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_LA_SET_B_RARE',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_LA_SET_B_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '81'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_SA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_SA_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_SA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '78'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_SA_SET_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_SA_SET_A',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_SA_SET_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '78'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_SA_SET_A_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_SA_SET_A_RARE',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_SA_SET_A_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '80'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_SA_SET_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_SA_SET_B',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_SA_SET_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '78'},
#  'PACKAGE_ITEM_CH_M_CLOTHES_11_SA_SET_B_RARE': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_CLOTHES_11_SA_SET_B_RARE',
#   'RefItemCodeName': 'ITEM_CH_M_CLOTHES_11_SA_SET_B_RARE',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '80'},
#  'PACKAGE_ITEM_CH_M_FRPVP_VOUCHER_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_FRPVP_VOUCHER_A',
#   'RefItemCodeName': 'ITEM_CH_M_FRPVP_VOUCHER_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CH_M_FRPVP_VOUCHER_B': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_FRPVP_VOUCHER_B',
#   'RefItemCodeName': 'ITEM_CH_M_FRPVP_VOUCHER_B',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CH_M_FRPVP_VOUCHER_C': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_FRPVP_VOUCHER_C',
#   'RefItemCodeName': 'ITEM_CH_M_FRPVP_VOUCHER_C',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CH_M_FRPVP_VOUCHER_D': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_FRPVP_VOUCHER_D',
#   'RefItemCodeName': 'ITEM_CH_M_FRPVP_VOUCHER_D',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CH_M_FRPVP_VOUCHER_E': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_FRPVP_VOUCHER_E',
#   'RefItemCodeName': 'ITEM_CH_M_FRPVP_VOUCHER_E',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_CH_M_HEAVY_01_AA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_HEAVY_01_AA_A',
#   'RefItemCodeName': 'ITEM_CH_M_HEAVY_01_AA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '48'},
#  'PACKAGE_ITEM_CH_M_HEAVY_01_BA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_HEAVY_01_BA_A',
#   'RefItemCodeName': 'ITEM_CH_M_HEAVY_01_BA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '48'},
#  'PACKAGE_ITEM_CH_M_HEAVY_01_CA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_HEAVY_01_CA_A',
#   'RefItemCodeName': 'ITEM_CH_M_HEAVY_01_CA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '48'},
#  'PACKAGE_ITEM_CH_M_HEAVY_01_FA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_HEAVY_01_FA_A',
#   'RefItemCodeName': 'ITEM_CH_M_HEAVY_01_FA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '48'},
#  'PACKAGE_ITEM_CH_M_HEAVY_01_LA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_HEAVY_01_LA_A',
#   'RefItemCodeName': 'ITEM_CH_M_HEAVY_01_LA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '48'},
#  'PACKAGE_ITEM_CH_M_HEAVY_01_SA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_HEAVY_01_SA_A',
#   'RefItemCodeName': 'ITEM_CH_M_HEAVY_01_SA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '48'},
#  'PACKAGE_ITEM_CH_M_HEAVY_02_AA_A': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_CH_M_HEAVY_02_AA_A',
#   'RefItemCodeName': 'ITEM_CH_M_HEAVY_02_AA_A',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '51'},
#  'PACKAGE_ITEM_CH_M_HEAVY_02_BA_A': {'Service': '1',
#   'Country': '42',
# ...
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_05_02',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_05',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_05_03': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_05_03',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_05',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_11': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_11',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_11',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_11_02': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_11_02',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_11',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_11_03': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_11_03',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_POTION_SPEED_11',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_01': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_01',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_01',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_02': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_02',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_02',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_03': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_03',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_03',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_04': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_04',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_04',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '10'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_05': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_05',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_05',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '10'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_06': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_06',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_06',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '30'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_07': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_07',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_REINFORCE_PROB_UP_A_07',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '30'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_RONDO_01': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_RONDO_01',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_RONDO_01',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '50'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_RONDO_03': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_RONDO_03',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_RONDO_01',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '150'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_RONDO_05': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_RONDO_05',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_RONDO_01',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '350'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_RONDO_06': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_RONDO_06',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_RONDO_02',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '20'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_RONDO_04': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_RONDO_04',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_RONDO_02',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '10'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_RONDO_02': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_LEVEL_RONDO_02',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_LEVEL_RONDO_02',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '3'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_01': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_01',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_01',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_02': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_02',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_02',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_03': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_03',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_03',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_04': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_04',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_04',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_05': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_05',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_05',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_06': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_06',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_06',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_07': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_07',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_07',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_08': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_08',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_08',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_09': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_09',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_09',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_10': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_10',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_10',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_11': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_11',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ASTRAL_11',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_01': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_01',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_01',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_02': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_02',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_02',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_03': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_03',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_03',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_04': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_04',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_04',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_05': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_05',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_05',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_06': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_06',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_06',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_07': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_07',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_07',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_08': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_08',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_08',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_09': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_09',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_09',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_10': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_10',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_10',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_11': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_11',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_ATHANASIA_11',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_REPAIR_08': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_REPAIR_08',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_REPAIR_08',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_REPAIR_09': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_MAGICSTONE_REPAIR_09',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_MAGICSTONE_REPAIR_09',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_POTION_SPEED_05': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_POTION_SPEED_05',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_POTION_SPEED_05',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_POTION_SPEED_11': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_POTION_SPEED_11',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_POTION_SPEED_11',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_01': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_01',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_01',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_02': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_02',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_02',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_03': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_03',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_03',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_04': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_04',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_04',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_05': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_05',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_05',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_06': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_06',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_06',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_07': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_07',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_07',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_08': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_08',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_08',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_09': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_09',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_09',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_10': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_10',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_10',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_11': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_11',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_REINFORCE_PROB_UP_A_11',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_RONDO_01': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_RONDO_01',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_RONDO_01',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  'PACKAGE_ITEM_ETC_ARCHEMY_RONDO_02': {'Service': '1',
#   'Country': '42',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_ETC_ARCHEMY_RONDO_02',
#   'RefItemCodeName': 'ITEM_ETC_ARCHEMY_RONDO_02',
#   'OptLevel': '0',
#   'Variance': '0',
#   'Data': '0'},
#  ...}

# %% [markdown]
# ## RefShopGoods.txt

# %%
ref_shop_goods_data = []

# %%
ref_shop_goods = os.path.join(server_dep, 'RefShopGoods.txt')
ref_shop_goods
# Out:
# 'server_dep\\silkroad\\textdata\\RefShopGoods.txt'

# %%
ref_shop_goods_files = get_lines(ref_shop_goods)
ref_shop_goods_files
# Out:
# ['refshopgoods_50.txt',
#  'refshopgoods_100.txt',
#  'refshopgoods_150.txt',
#  'refshopgoods_200.txt',
#  'refshopgoods_250.txt',
#  'refshopgoods_300.txt',
#  'refshopgoods_350.txt',
#  '']

# %%
for xxx in ref_shop_goods_files:
  file_name = os.path.join(server_dep, xxx)
  lines = get_lines(file_name)
  for idx, line in enumerate(lines):
    values = line.split('\t')
    if len(values) != 13:
      continue
    Service = values[0]
    Country = values[1]
    RefTabCodeName = values[2]
    RefPackageItemCodeName = values[3]
    SlotIndex = values[4]

    obj = {
      "Service": Service,
      "Country": Country,
      "RefTabCodeName": RefTabCodeName,
      "RefPackageItemCodeName": RefPackageItemCodeName,
      "SlotIndex": SlotIndex
    }

    ref_shop_goods_data.append(obj)

# %%
ref_shop_goods_data
# Out:
# [{'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_01_AA_B_RARE',
#   'SlotIndex': '4'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_01_AA_C_RARE',
#   'SlotIndex': '22'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_01_BA_B_RARE',
#   'SlotIndex': '2'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_01_BA_C_RARE',
#   'SlotIndex': '20'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_01_FA_B_RARE',
#   'SlotIndex': '5'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_01_FA_C_RARE',
#   'SlotIndex': '23'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_01_HA_B_RARE',
#   'SlotIndex': '0'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_01_HA_C_RARE',
#   'SlotIndex': '18'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_01_LA_B_RARE',
#   'SlotIndex': '3'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_01_LA_C_RARE',
#   'SlotIndex': '21'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_01_SA_B_RARE',
#   'SlotIndex': '1'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_01_SA_C_RARE',
#   'SlotIndex': '19'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_02_AA_B_RARE',
#   'SlotIndex': '10'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_02_AA_C_RARE',
#   'SlotIndex': '28'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_02_BA_B_RARE',
#   'SlotIndex': '8'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_02_BA_C_RARE',
#   'SlotIndex': '26'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_02_FA_B_RARE',
#   'SlotIndex': '11'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_02_FA_C_RARE',
#   'SlotIndex': '29'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_02_HA_B_RARE',
#   'SlotIndex': '6'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_02_HA_C_RARE',
#   'SlotIndex': '24'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_02_LA_B_RARE',
#   'SlotIndex': '9'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_02_LA_C_RARE',
#   'SlotIndex': '27'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_02_SA_B_RARE',
#   'SlotIndex': '7'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_02_SA_C_RARE',
#   'SlotIndex': '25'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_03_AA_B_RARE',
#   'SlotIndex': '16'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_03_AA_C_RARE',
#   'SlotIndex': '34'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_03_BA_B_RARE',
#   'SlotIndex': '14'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_03_BA_C_RARE',
#   'SlotIndex': '32'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_03_FA_B_RARE',
#   'SlotIndex': '17'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_03_FA_C_RARE',
#   'SlotIndex': '35'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_03_HA_B_RARE',
#   'SlotIndex': '12'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_03_HA_C_RARE',
#   'SlotIndex': '30'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_03_LA_B_RARE',
#   'SlotIndex': '15'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_03_LA_C_RARE',
#   'SlotIndex': '33'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_03_SA_B_RARE',
#   'SlotIndex': '13'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_03_SA_C_RARE',
#   'SlotIndex': '31'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_01_AA_B_RARE',
#   'SlotIndex': '4'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_01_AA_C_RARE',
#   'SlotIndex': '22'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_01_BA_B_RARE',
#   'SlotIndex': '2'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_01_BA_C_RARE',
#   'SlotIndex': '20'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_01_FA_B_RARE',
#   'SlotIndex': '5'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_01_FA_C_RARE',
#   'SlotIndex': '23'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_01_HA_B_RARE',
#   'SlotIndex': '0'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_01_HA_C_RARE',
#   'SlotIndex': '18'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_01_LA_B_RARE',
#   'SlotIndex': '3'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_01_LA_C_RARE',
#   'SlotIndex': '21'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_01_SA_B_RARE',
#   'SlotIndex': '1'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_01_SA_C_RARE',
#   'SlotIndex': '19'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_02_AA_B_RARE',
#   'SlotIndex': '10'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_02_AA_C_RARE',
#   'SlotIndex': '28'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_02_BA_B_RARE',
#   'SlotIndex': '8'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_02_BA_C_RARE',
#   'SlotIndex': '26'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_02_FA_B_RARE',
#   'SlotIndex': '11'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_02_FA_C_RARE',
#   'SlotIndex': '29'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_02_HA_B_RARE',
#   'SlotIndex': '6'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_02_HA_C_RARE',
#   'SlotIndex': '24'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_02_LA_B_RARE',
#   'SlotIndex': '9'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_02_LA_C_RARE',
#   'SlotIndex': '27'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_02_SA_B_RARE',
#   'SlotIndex': '7'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_02_SA_C_RARE',
#   'SlotIndex': '25'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_03_AA_B_RARE',
#   'SlotIndex': '16'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_03_AA_C_RARE',
#   'SlotIndex': '34'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_03_BA_B_RARE',
#   'SlotIndex': '14'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_03_BA_C_RARE',
#   'SlotIndex': '32'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_03_FA_B_RARE',
#   'SlotIndex': '17'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_03_FA_C_RARE',
#   'SlotIndex': '35'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_03_HA_B_RARE',
#   'SlotIndex': '12'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_03_HA_C_RARE',
#   'SlotIndex': '30'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_03_LA_B_RARE',
#   'SlotIndex': '15'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_03_LA_C_RARE',
#   'SlotIndex': '33'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_03_SA_B_RARE',
#   'SlotIndex': '13'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_03_SA_C_RARE',
#   'SlotIndex': '31'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_01_AA_B_RARE',
#   'SlotIndex': '4'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_01_AA_C_RARE',
#   'SlotIndex': '22'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_01_BA_B_RARE',
#   'SlotIndex': '2'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_01_BA_C_RARE',
#   'SlotIndex': '20'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_01_FA_B_RARE',
#   'SlotIndex': '5'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_01_FA_C_RARE',
#   'SlotIndex': '23'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_01_HA_B_RARE',
#   'SlotIndex': '0'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_01_HA_C_RARE',
#   'SlotIndex': '18'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_01_LA_B_RARE',
#   'SlotIndex': '3'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_01_LA_C_RARE',
#   'SlotIndex': '21'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_01_SA_B_RARE',
#   'SlotIndex': '1'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_01_SA_C_RARE',
#   'SlotIndex': '19'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_02_AA_B_RARE',
#   'SlotIndex': '10'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_02_AA_C_RARE',
#   'SlotIndex': '28'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_02_BA_B_RARE',
#   'SlotIndex': '8'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_02_BA_C_RARE',
#   'SlotIndex': '26'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_02_FA_B_RARE',
#   'SlotIndex': '11'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_02_FA_C_RARE',
#   'SlotIndex': '29'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_02_HA_B_RARE',
#   'SlotIndex': '6'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_02_HA_C_RARE',
#   'SlotIndex': '24'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_02_LA_B_RARE',
#   'SlotIndex': '9'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_02_LA_C_RARE',
#   'SlotIndex': '27'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_02_SA_B_RARE',
#   'SlotIndex': '7'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_02_SA_C_RARE',
#   'SlotIndex': '25'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_03_AA_B_RARE',
#   'SlotIndex': '16'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_03_AA_C_RARE',
#   'SlotIndex': '34'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_03_BA_B_RARE',
#   'SlotIndex': '14'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_03_BA_C_RARE',
#   'SlotIndex': '32'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_03_FA_B_RARE',
#   'SlotIndex': '17'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_03_FA_C_RARE',
#   'SlotIndex': '35'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_03_HA_B_RARE',
#   'SlotIndex': '12'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_03_HA_C_RARE',
#   'SlotIndex': '30'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_03_LA_B_RARE',
#   'SlotIndex': '15'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_03_LA_C_RARE',
#   'SlotIndex': '33'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_03_SA_B_RARE',
#   'SlotIndex': '13'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_03_SA_C_RARE',
#   'SlotIndex': '31'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_01_AA_B_RARE',
#   'SlotIndex': '4'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_01_AA_C_RARE',
#   'SlotIndex': '22'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_01_BA_B_RARE',
#   'SlotIndex': '2'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_01_BA_C_RARE',
#   'SlotIndex': '20'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_01_FA_B_RARE',
#   'SlotIndex': '5'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_01_FA_C_RARE',
#   'SlotIndex': '23'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_01_HA_B_RARE',
#   'SlotIndex': '0'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_01_HA_C_RARE',
#   'SlotIndex': '18'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_01_LA_B_RARE',
#   'SlotIndex': '3'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_01_LA_C_RARE',
#   'SlotIndex': '21'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_01_SA_B_RARE',
#   'SlotIndex': '1'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_01_SA_C_RARE',
#   'SlotIndex': '19'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_02_AA_B_RARE',
#   'SlotIndex': '10'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_02_AA_C_RARE',
#   'SlotIndex': '28'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_02_BA_B_RARE',
#   'SlotIndex': '8'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_02_BA_C_RARE',
#   'SlotIndex': '26'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_02_FA_B_RARE',
#   'SlotIndex': '11'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_02_FA_C_RARE',
#   'SlotIndex': '29'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_02_HA_B_RARE',
#   'SlotIndex': '6'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_02_HA_C_RARE',
#   'SlotIndex': '24'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_02_LA_B_RARE',
#   'SlotIndex': '9'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_02_LA_C_RARE',
#   'SlotIndex': '27'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_02_SA_B_RARE',
#   'SlotIndex': '7'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_02_SA_C_RARE',
#   'SlotIndex': '25'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_03_AA_B_RARE',
#   'SlotIndex': '16'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_03_AA_C_RARE',
#   'SlotIndex': '34'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_03_BA_B_RARE',
#   'SlotIndex': '14'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_03_BA_C_RARE',
#   'SlotIndex': '32'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_03_FA_B_RARE',
#   'SlotIndex': '17'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_03_FA_C_RARE',
#   'SlotIndex': '35'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_03_HA_B_RARE',
#   'SlotIndex': '12'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_03_HA_C_RARE',
#   'SlotIndex': '30'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_03_LA_B_RARE',
#   'SlotIndex': '15'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_03_LA_C_RARE',
#   'SlotIndex': '33'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_03_SA_B_RARE',
#   'SlotIndex': '13'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_HEAVY_03_SA_C_RARE',
#   'SlotIndex': '31'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_01_AA_B_RARE',
#   'SlotIndex': '4'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_01_AA_C_RARE',
#   'SlotIndex': '22'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_01_BA_B_RARE',
#   'SlotIndex': '2'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_01_BA_C_RARE',
#   'SlotIndex': '20'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_01_FA_B_RARE',
#   'SlotIndex': '5'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_01_FA_C_RARE',
#   'SlotIndex': '23'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_01_HA_B_RARE',
#   'SlotIndex': '0'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_01_HA_C_RARE',
#   'SlotIndex': '18'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_01_LA_B_RARE',
#   'SlotIndex': '3'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_01_LA_C_RARE',
#   'SlotIndex': '21'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_01_SA_B_RARE',
#   'SlotIndex': '1'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_01_SA_C_RARE',
#   'SlotIndex': '19'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_02_AA_B_RARE',
#   'SlotIndex': '10'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_02_AA_C_RARE',
#   'SlotIndex': '28'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_02_BA_B_RARE',
#   'SlotIndex': '8'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_02_BA_C_RARE',
#   'SlotIndex': '26'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_02_FA_B_RARE',
#   'SlotIndex': '11'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_02_FA_C_RARE',
#   'SlotIndex': '29'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_02_HA_B_RARE',
#   'SlotIndex': '6'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_02_HA_C_RARE',
#   'SlotIndex': '24'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_02_LA_B_RARE',
#   'SlotIndex': '9'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_02_LA_C_RARE',
#   'SlotIndex': '27'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_02_SA_B_RARE',
#   'SlotIndex': '7'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_02_SA_C_RARE',
#   'SlotIndex': '25'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_03_AA_B_RARE',
#   'SlotIndex': '16'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_03_AA_C_RARE',
#   'SlotIndex': '34'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_03_BA_B_RARE',
#   'SlotIndex': '14'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_03_BA_C_RARE',
#   'SlotIndex': '32'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_03_FA_B_RARE',
#   'SlotIndex': '17'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_03_FA_C_RARE',
#   'SlotIndex': '35'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_03_HA_B_RARE',
#   'SlotIndex': '12'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_03_HA_C_RARE',
#   'SlotIndex': '30'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_03_LA_B_RARE',
#   'SlotIndex': '15'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_03_LA_C_RARE',
#   'SlotIndex': '33'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_03_SA_B_RARE',
#   'SlotIndex': '13'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_LIGHT_03_SA_C_RARE',
#   'SlotIndex': '31'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_01_AA_B_RARE',
#   'SlotIndex': '4'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_01_AA_C_RARE',
#   'SlotIndex': '22'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_01_BA_B_RARE',
#   'SlotIndex': '2'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_01_BA_C_RARE',
#   'SlotIndex': '20'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_01_FA_B_RARE',
#   'SlotIndex': '5'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_01_FA_C_RARE',
#   'SlotIndex': '23'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_01_HA_B_RARE',
#   'SlotIndex': '0'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_01_HA_C_RARE',
#   'SlotIndex': '18'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_01_LA_B_RARE',
#   'SlotIndex': '3'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_01_LA_C_RARE',
#   'SlotIndex': '21'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_01_SA_B_RARE',
#   'SlotIndex': '1'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_01_SA_C_RARE',
#   'SlotIndex': '19'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_02_AA_B_RARE',
#   'SlotIndex': '10'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_02_AA_C_RARE',
#   'SlotIndex': '28'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_02_BA_B_RARE',
#   'SlotIndex': '8'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_02_BA_C_RARE',
#   'SlotIndex': '26'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_02_FA_B_RARE',
#   'SlotIndex': '11'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_02_FA_C_RARE',
#   'SlotIndex': '29'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_02_HA_B_RARE',
#   'SlotIndex': '6'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_02_HA_C_RARE',
#   'SlotIndex': '24'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_02_LA_B_RARE',
#   'SlotIndex': '9'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_02_LA_C_RARE',
#   'SlotIndex': '27'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_02_SA_B_RARE',
#   'SlotIndex': '7'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_02_SA_C_RARE',
#   'SlotIndex': '25'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_03_AA_B_RARE',
#   'SlotIndex': '16'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_03_AA_C_RARE',
#   'SlotIndex': '34'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_03_BA_B_RARE',
#   'SlotIndex': '14'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_03_BA_C_RARE',
#   'SlotIndex': '32'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_03_FA_B_RARE',
#   'SlotIndex': '17'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_03_FA_C_RARE',
#   'SlotIndex': '35'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_03_HA_B_RARE',
#   'SlotIndex': '12'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_03_HA_C_RARE',
#   'SlotIndex': '30'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_03_LA_B_RARE',
#   'SlotIndex': '15'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_03_LA_C_RARE',
#   'SlotIndex': '33'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_03_SA_B_RARE',
#   'SlotIndex': '13'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_W_CLOTHES_03_SA_C_RARE',
#   'SlotIndex': '31'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_04_AA_B_RARE',
#   'SlotIndex': '4'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_04_AA_C_RARE',
#   'SlotIndex': '16'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_04_BA_B_RARE',
#   'SlotIndex': '2'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_04_BA_C_RARE',
#   'SlotIndex': '14'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_04_FA_B_RARE',
#   'SlotIndex': '5'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_04_FA_C_RARE',
#   'SlotIndex': '17'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_04_HA_B_RARE',
#   'SlotIndex': '0'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_04_HA_C_RARE',
#   'SlotIndex': '12'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_04_LA_B_RARE',
#   'SlotIndex': '3'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_04_LA_C_RARE',
#   'SlotIndex': '15'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_04_SA_B_RARE',
#   'SlotIndex': '1'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_04_SA_C_RARE',
#   'SlotIndex': '13'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_05_AA_B_RARE',
#   'SlotIndex': '10'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_05_AA_C_RARE',
#   'SlotIndex': '22'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_05_BA_B_RARE',
#   'SlotIndex': '8'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_05_BA_C_RARE',
#   'SlotIndex': '20'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_05_FA_B_RARE',
#   'SlotIndex': '11'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_05_FA_C_RARE',
#   'SlotIndex': '23'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_05_HA_B_RARE',
#   'SlotIndex': '6'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_05_HA_C_RARE',
#   'SlotIndex': '18'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_05_LA_B_RARE',
#   'SlotIndex': '9'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_05_LA_C_RARE',
#   'SlotIndex': '21'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_05_SA_B_RARE',
#   'SlotIndex': '7'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_HEAVY_05_SA_C_RARE',
#   'SlotIndex': '19'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_04_AA_B_RARE',
#   'SlotIndex': '4'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_04_AA_C_RARE',
#   'SlotIndex': '16'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_04_BA_B_RARE',
#   'SlotIndex': '2'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_04_BA_C_RARE',
#   'SlotIndex': '14'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_04_FA_B_RARE',
#   'SlotIndex': '5'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_04_FA_C_RARE',
#   'SlotIndex': '17'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_04_HA_B_RARE',
#   'SlotIndex': '0'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_04_HA_C_RARE',
#   'SlotIndex': '12'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_04_LA_B_RARE',
#   'SlotIndex': '3'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_04_LA_C_RARE',
#   'SlotIndex': '15'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_04_SA_B_RARE',
#   'SlotIndex': '1'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_04_SA_C_RARE',
#   'SlotIndex': '13'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_05_AA_B_RARE',
#   'SlotIndex': '10'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_05_AA_C_RARE',
#   'SlotIndex': '22'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_05_BA_B_RARE',
#   'SlotIndex': '8'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_05_BA_C_RARE',
#   'SlotIndex': '20'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_05_FA_B_RARE',
#   'SlotIndex': '11'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_05_FA_C_RARE',
#   'SlotIndex': '23'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_05_HA_B_RARE',
#   'SlotIndex': '6'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_05_HA_C_RARE',
#   'SlotIndex': '18'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_05_LA_B_RARE',
#   'SlotIndex': '9'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_05_LA_C_RARE',
#   'SlotIndex': '21'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_05_SA_B_RARE',
#   'SlotIndex': '7'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB2',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_LIGHT_05_SA_C_RARE',
#   'SlotIndex': '19'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_04_AA_B_RARE',
#   'SlotIndex': '4'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_04_AA_C_RARE',
#   'SlotIndex': '16'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_04_BA_B_RARE',
#   'SlotIndex': '2'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_04_BA_C_RARE',
#   'SlotIndex': '14'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_04_FA_B_RARE',
#   'SlotIndex': '5'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB3',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_CH_M_CLOTHES_04_FA_C_RARE',
#   'SlotIndex': '17'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_CH_ARMOR2_TAB3',
# ...
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_02_LA_C_RARE',
#   'SlotIndex': '27'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_02_SA_B_RARE',
#   'SlotIndex': '7'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_02_SA_C_RARE',
#   'SlotIndex': '25'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_03_AA_B_RARE',
#   'SlotIndex': '16'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_03_AA_C_RARE',
#   'SlotIndex': '34'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_03_BA_B_RARE',
#   'SlotIndex': '14'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_03_BA_C_RARE',
#   'SlotIndex': '32'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_03_FA_B_RARE',
#   'SlotIndex': '17'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_03_FA_C_RARE',
#   'SlotIndex': '35'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_03_HA_B_RARE',
#   'SlotIndex': '12'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_03_HA_C_RARE',
#   'SlotIndex': '30'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_03_LA_B_RARE',
#   'SlotIndex': '15'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_03_LA_C_RARE',
#   'SlotIndex': '33'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_03_SA_B_RARE',
#   'SlotIndex': '13'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB4',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_HEAVY_03_SA_C_RARE',
#   'SlotIndex': '31'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_01_AA_B_RARE',
#   'SlotIndex': '4'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_01_AA_C_RARE',
#   'SlotIndex': '22'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_01_BA_B_RARE',
#   'SlotIndex': '2'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_01_BA_C_RARE',
#   'SlotIndex': '20'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_01_FA_B_RARE',
#   'SlotIndex': '5'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_01_FA_C_RARE',
#   'SlotIndex': '23'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_01_HA_B_RARE',
#   'SlotIndex': '0'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_01_HA_C_RARE',
#   'SlotIndex': '18'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_01_LA_B_RARE',
#   'SlotIndex': '3'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_01_LA_C_RARE',
#   'SlotIndex': '21'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_01_SA_B_RARE',
#   'SlotIndex': '1'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_01_SA_C_RARE',
#   'SlotIndex': '19'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_02_AA_B_RARE',
#   'SlotIndex': '10'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_02_AA_C_RARE',
#   'SlotIndex': '28'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_02_BA_B_RARE',
#   'SlotIndex': '8'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_02_BA_C_RARE',
#   'SlotIndex': '26'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_02_FA_B_RARE',
#   'SlotIndex': '11'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_02_FA_C_RARE',
#   'SlotIndex': '29'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_02_HA_B_RARE',
#   'SlotIndex': '6'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_02_HA_C_RARE',
#   'SlotIndex': '24'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_02_LA_B_RARE',
#   'SlotIndex': '9'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_02_LA_C_RARE',
#   'SlotIndex': '27'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_02_SA_B_RARE',
#   'SlotIndex': '7'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_02_SA_C_RARE',
#   'SlotIndex': '25'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_03_AA_B_RARE',
#   'SlotIndex': '16'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_03_AA_C_RARE',
#   'SlotIndex': '34'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_03_BA_B_RARE',
#   'SlotIndex': '14'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_03_BA_C_RARE',
#   'SlotIndex': '32'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_03_FA_B_RARE',
#   'SlotIndex': '17'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_03_FA_C_RARE',
#   'SlotIndex': '35'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_03_HA_B_RARE',
#   'SlotIndex': '12'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_03_HA_C_RARE',
#   'SlotIndex': '30'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_03_LA_B_RARE',
#   'SlotIndex': '15'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_03_LA_C_RARE',
#   'SlotIndex': '33'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_03_SA_B_RARE',
#   'SlotIndex': '13'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB5',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_LIGHT_03_SA_C_RARE',
#   'SlotIndex': '31'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_01_AA_B_RARE',
#   'SlotIndex': '4'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_01_AA_C_RARE',
#   'SlotIndex': '22'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_01_BA_B_RARE',
#   'SlotIndex': '2'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_01_BA_C_RARE',
#   'SlotIndex': '20'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_01_FA_B_RARE',
#   'SlotIndex': '5'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_01_FA_C_RARE',
#   'SlotIndex': '23'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_01_HA_B_RARE',
#   'SlotIndex': '0'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_01_HA_C_RARE',
#   'SlotIndex': '18'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_01_LA_B_RARE',
#   'SlotIndex': '3'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_01_LA_C_RARE',
#   'SlotIndex': '21'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_01_SA_B_RARE',
#   'SlotIndex': '1'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_01_SA_C_RARE',
#   'SlotIndex': '19'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_02_AA_B_RARE',
#   'SlotIndex': '10'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_02_AA_C_RARE',
#   'SlotIndex': '28'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_02_BA_B_RARE',
#   'SlotIndex': '8'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_02_BA_C_RARE',
#   'SlotIndex': '26'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_02_FA_B_RARE',
#   'SlotIndex': '11'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_02_FA_C_RARE',
#   'SlotIndex': '29'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_02_HA_B_RARE',
#   'SlotIndex': '6'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_02_HA_C_RARE',
#   'SlotIndex': '24'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_02_LA_B_RARE',
#   'SlotIndex': '9'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_02_LA_C_RARE',
#   'SlotIndex': '27'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_02_SA_B_RARE',
#   'SlotIndex': '7'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_02_SA_C_RARE',
#   'SlotIndex': '25'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_03_AA_B_RARE',
#   'SlotIndex': '16'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_03_AA_C_RARE',
#   'SlotIndex': '34'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_03_BA_B_RARE',
#   'SlotIndex': '14'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_03_BA_C_RARE',
#   'SlotIndex': '32'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_03_FA_B_RARE',
#   'SlotIndex': '17'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_03_FA_C_RARE',
#   'SlotIndex': '35'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_03_HA_B_RARE',
#   'SlotIndex': '12'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_03_HA_C_RARE',
#   'SlotIndex': '30'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_03_LA_B_RARE',
#   'SlotIndex': '15'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_03_LA_C_RARE',
#   'SlotIndex': '33'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_03_SA_B_RARE',
#   'SlotIndex': '13'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR1_TAB6',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_W_CLOTHES_03_SA_C_RARE',
#   'SlotIndex': '31'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_M_HEAVY_04_AA_B_RARE',
#   'SlotIndex': '4'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_M_HEAVY_04_AA_C_RARE',
#   'SlotIndex': '16'},
#  {'Service': '1',
#   'Country': '42',
#   'RefTabCodeName': 'LEVEL_EU_ARMOR2_TAB1',
#   'RefPackageItemCodeName': 'PACKAGE_ITEM_EVENT_EU_M_HEAVY_04_BA_B_RARE',
#   'SlotIndex': '2'},
#  ...]
