# %%
import os
import io
import struct
from typing import List, Tuple, Optional
from enum import Enum

from blowfish import Blowfish

# %%
class PackEntryType(Enum):
  Nop = 0
  Folder = 1
  File = 2

# %%
def generate_final_blowfish_key(password: str, salt: bytes) -> bytes:
    """
    Reproduces the 'GenerateFinalBlowfishKey' logic in C#.
    """
    # 1) Limit key length to max of 56
    plain_key_length = min(len(password), 56)

    # 2) Convert password to ASCII bytes
    a_key = password.encode("ascii")

    # 3) Create a 56-byte base key buffer
    b_key = bytearray(56)
    
    # Copy salt into b_key
    # Equivalent to `Array.ConstrainedCopy(salt, 0, bKey, 0, salt.Length)`
    b_key[:len(salt)] = salt

    # 4) Generate the final blowfish key by XOR-ing
    #    the ASCII password bytes with the corresponding part of b_key.
    bf_key = bytearray(plain_key_length)
    for x in range(plain_key_length):
        bf_key[x] = a_key[x] ^ b_key[x]

    return bytes(bf_key)

# %%
def read_string_with_length(stream, byte_count: int) -> str:
    """
    Read 'byte_count' bytes, then decode using self._encoding,
    stopping at the first 0 (null terminator) if present.
    """
    buffer = stream.read(byte_count)

    # Find null terminator offset (if any)
    terminator_offset = byte_count
    for i in range(byte_count):
        if buffer[i] == 0:
            terminator_offset = i
            break

    return buffer[:terminator_offset].decode('ascii', errors='replace')

# %%
data_pk2_path = os.path.join(os.getcwd(), 'data', 'Data.pk2')
media_pk2_path = os.path.join(os.getcwd(), 'data', 'Media.pk2')
print(data_pk2_path)
print(media_pk2_path)
# Out:
# c:\Users\htdun\Desktop\workspace\pk2-extractor\data\Data.pk2
# c:\Users\htdun\Desktop\workspace\pk2-extractor\data\Media.pk2

# %%
pk2key = '169841'
salt = [0x03, 0xF8, 0xE4, 0x44, 0x88, 0x99, 0x3F, 0x64, 0xFE, 0x35]

# %%
key = generate_final_blowfish_key(pk2key, bytes(salt))
key
# Out:
# b'2\xce\xdd|\xbc\xa8'

# %%
blowfish = Blowfish()
blowfish.Initialize(key)

# %%
_media_file_stream = open(media_pk2_path, 'rb')

# %%
signature = _media_file_stream.read(30)
version =  struct.unpack('<i', _media_file_stream.read(4))[0]
encrypted = _media_file_stream.read(1)
encryption_checksum = _media_file_stream.read(16)
payload = _media_file_stream.read(205)

# %%
Header = {
    'signature': signature,
    'version': version,
    'encrypted': encrypted,
    'encryption_checksum': encryption_checksum,
    'payload': payload
}

# %%
blowfish_checksum_decoded = "Joymax Pak File"

# %%
if blowfish and encrypted == b'\x01':
    temp_checksum = blowfish.Encode(blowfish_checksum_decoded.encode('ascii'))
    if temp_checksum is None or temp_checksum[0] != encryption_checksum[0] or temp_checksum[1] != encryption_checksum[1] or temp_checksum[2] != encryption_checksum[2]:
        raise Exception('Failed to open JoymaxPackFile: The password or salt is wrong.')

# %%
def read_block_at(position: int):
    _media_file_stream.seek(position, io.SEEK_SET)
    buffer = _media_file_stream.read(128 * 20)
    if blowfish is not None:
      entry_buffer = io.BytesIO(blowfish.Decode(buffer))
    else:
      entry_buffer = io.BytesIO(buffer)

    entries = []
    for _ in range(20):
      entry = {
        "Type": PackEntryType(entry_buffer.read(1)[0]),
        "Name": read_string_with_length(entry_buffer, 89).rstrip('\0'),
        "CreationTime": struct.unpack('<q', entry_buffer.read(8))[0],
        "ModifyTime": struct.unpack('<q', entry_buffer.read(8))[0],
        "DataPosition": struct.unpack('<q', entry_buffer.read(8))[0],
        "DataSize": struct.unpack('<i', entry_buffer.read(4))[0],
        "NextBlock": struct.unpack('<q', entry_buffer.read(8))[0],
        "Payload": entry_buffer.read(2)
      }
      entries.append(entry)
      # print(entry)

    return {
      "Position": position,
      "Entries": entries
    }


def read_blocks_at(position: int):
    result = []

    block = read_block_at(position)
    result.append(block)

    if block["Entries"][19]["NextBlock"] > 0:
        result.extend(read_blocks_at(block["Entries"][19]["NextBlock"]))

    return result

# %%
Root = read_blocks_at(256)

# %%
blocks_in_memory = {
  "": Root
}

# %%
blocks_in_memory
# Out:
# {'': [{'Position': 256,
#    'Entries': [{'Type': <PackEntryType.Folder: 1>,
#      'Name': '.',
#      'CreationTime': 133336205048819447,
#      'ModifyTime': 133336205048819447,
#      'DataPosition': 256,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'acobject',
#      'CreationTime': 133336205048829450,
#      'ModifyTime': 133336205048829450,
#      'DataPosition': 2816,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'config',
#      'CreationTime': 133336205049179438,
#      'ModifyTime': 133336205049179438,
#      'DataPosition': 35136,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Effect',
#      'CreationTime': 133336205049679437,
#      'ModifyTime': 133336205049679437,
#      'DataPosition': 41896,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Fonts',
#      'CreationTime': 133336205051829374,
#      'ModifyTime': 133336205051829374,
#      'DataPosition': 401456,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'icon',
#      'CreationTime': 133336205051849373,
#      'ModifyTime': 133336205051849373,
#      'DataPosition': 404328,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'icon64',
#      'CreationTime': 133336206109740779,
#      'ModifyTime': 133336206109740779,
#      'DataPosition': 35750058,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'interface',
#      'CreationTime': 133336206200969178,
#      'ModifyTime': 133336206200969178,
#      'DataPosition': 49794542,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Launcher',
#      'CreationTime': 133336207373584329,
#      'ModifyTime': 133336207373584329,
#      'DataPosition': 530412246,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Launcher_Europe',
#      'CreationTime': 133336207379694215,
#      'ModifyTime': 133336207379694215,
#      'DataPosition': 533020067,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'minimap',
#      'CreationTime': 133336207380240850,
#      'ModifyTime': 133336207380240850,
#      'DataPosition': 533900707,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'minimap_d',
#      'CreationTime': 133336208820638962,
#      'ModifyTime': 133336208820638962,
#      'DataPosition': 770423083,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'resinfo',
#      'CreationTime': 133336209064184553,
#      'ModifyTime': 133336209064184553,
#      'DataPosition': 868076619,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'res_ui',
#      'CreationTime': 133336209080076171,
#      'ModifyTime': 133336209080076171,
#      'DataPosition': 870428615,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'script',
#      'CreationTime': 133336209089071935,
#      'ModifyTime': 133336209089071935,
#      'DataPosition': 877210479,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'server_dep',
#      'CreationTime': 133336209091748828,
#      'ModifyTime': 133336209091748828,
#      'DataPosition': 886879815,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'silk.dat',
#      'CreationTime': 133287856801795247,
#      'ModifyTime': 127918116330156250,
#      'DataPosition': 1017317431,
#      'DataSize': 768,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'type.txt',
#      'CreationTime': 133336205046882029,
#      'ModifyTime': 133330897532736718,
#      'DataPosition': 1017318199,
#      'DataSize': 423,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'DIVISIONINFO.TXT',
#      'CreationTime': 133336210349991177,
#      'ModifyTime': 133336210349991177,
#      'DataPosition': 1017319424,
#      'DataSize': 57,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'SV.T',
#      'CreationTime': 133795825379609632,
#      'ModifyTime': 133795825379609632,
#      'DataPosition': 1017319481,
#      'DataSize': 1024,
#      'NextBlock': 1017320505,
#      'Payload': b'\x00\x00'}]},
#   {'Position': 1017320505,
#    'Entries': [{'Type': <PackEntryType.File: 2>,
#      'Name': 'GATEPORT.TXT',
#      'CreationTime': 133336210351001190,
#      'ModifyTime': 133336210351001190,
#      'DataPosition': 1017323065,
#      'DataSize': 8,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'}]}]}

# %%
server_dep = os.path.join('server_dep', 'silkroad', 'textdata')
server_dep
# Out:
# 'server_dep\\silkroad\\textdata'

# %%
character_text_data = dict()

# %% [markdown]
# ## TextUISystem.txt

# %%
character_data = os.path.join(server_dep, 'CharacterData.txt')
character_data
# Out:
# 'server_dep\\silkroad\\textdata\\CharacterData.txt'

# %%
def get_entry_buffer(file_path: str) -> Optional[dict]:
  parent_folder_path = os.path.dirname(file_path)
  file_name = os.path.basename(file_path)
  if parent_folder_path not in blocks_in_memory:
    paths = parent_folder_path.split(os.path.sep)
    blocks = blocks_in_memory[""]
    current_path = ""

    for sub_folder_name in paths:
        for block in blocks:
            entries = block["Entries"]
            entry = next((e for e in entries if e["Name"] == sub_folder_name and e["Type"] == PackEntryType.Folder), None)
            if entry is None:
                continue
            
            current_path = os.path.join(current_path, entry["Name"])
            if current_path in blocks_in_memory:
                blocks = blocks_in_memory[current_path]
                break
            
            blocks = read_blocks_at(entry["DataPosition"])
            blocks_in_memory[current_path] = blocks
            break
        
  root = blocks_in_memory[parent_folder_path]
  entry = None
  for entries in root:
    entry = next((x for x in entries["Entries"] if x["Name"] == file_name.lower()), None)
    if entry:
      break

  _media_file_stream.seek(entry["DataPosition"], io.SEEK_SET)
  # _media_file_stream.read(entry["DataSize"])
  buffer = io.BytesIO(_media_file_stream.read(entry["DataSize"])) 

  return buffer
   

def get_lines(file_path: str) -> List[Tuple[str, int]]:

  buffer = get_entry_buffer(file_path)

  text = buffer.read().decode('utf-16', errors="replace")
  lines = text.split('\r\n')
  return lines

# %%
character_data_files = get_lines(character_data)
character_data_files
# Out:
# ['CharacterData_10000.txt',
#  'CharacterData_10100.txt',
#  'CharacterData_10200.txt',
#  'CharacterData_10300.txt',
#  'CharacterData_14800.txt',
#  'CharacterData_14900.txt',
#  'CharacterData_15000.txt',
#  'CharacterData_15100.txt',
#  'CharacterData_15200.txt',
#  'CharacterData_15300.txt',
#  'CharacterData_15400.txt',
#  'CharacterData_15500.txt',
#  'CharacterData_15600.txt',
#  'CharacterData_15700.txt',
#  'CharacterData_15800.txt',
#  'CharacterData_15900.txt',
#  'CharacterData_16000.txt',
#  'CharacterData_16100.txt',
#  'CharacterData_16200.txt',
#  'CharacterData_16300.txt',
#  'CharacterData_16400.txt',
#  'CharacterData_16500.txt',
#  'CharacterData_16600.txt',
#  'CharacterData_16700.txt',
#  'CharacterData_16800.txt',
#  'CharacterData_16900.txt',
#  'CharacterData_17000.txt',
#  'CharacterData_17100.txt',
#  'CharacterData_17200.txt',
#  'CharacterData_17300.txt',
#  'CharacterData_17400.txt',
#  'CharacterData_17500.txt',
#  'CharacterData_17600.txt',
#  'CharacterData_17700.txt',
#  'CharacterData_17800.txt',
#  'CharacterData_17900.txt',
#  'CharacterData_18000.txt',
#  'CharacterData_18100.txt',
#  'CharacterData_18200.txt',
#  'CharacterData_18300.txt',
#  'CharacterData_18400.txt',
#  'CharacterData_18500.txt',
#  'CharacterData_18600.txt',
#  'CharacterData_18700.txt',
#  'CharacterData_18800.txt',
#  'CharacterData_18900.txt',
#  'CharacterData_19000.txt',
#  'CharacterData_19100.txt',
#  'CharacterData_19300.txt',
#  'CharacterData_19400.txt',
#  'CharacterData_19500.txt',
#  'CharacterData_19600.txt',
#  'CharacterData_19700.txt',
#  'CharacterData_19800.txt',
#  'CharacterData_19900.txt',
#  'CharacterData_2000.txt',
#  'CharacterData_20000.txt',
#  'CharacterData_20100.txt',
#  'CharacterData_20200.txt',
#  'CharacterData_20300.txt',
#  'CharacterData_20400.txt',
#  'CharacterData_20500.txt',
#  'CharacterData_20600.txt',
#  'CharacterData_20700.txt',
#  'CharacterData_20800.txt',
#  'CharacterData_20900.txt',
#  'CharacterData_2100.txt',
#  'CharacterData_21000.txt',
#  'CharacterData_21100.txt',
#  'CharacterData_21200.txt',
#  'CharacterData_21300.txt',
#  'CharacterData_21400.txt',
#  'CharacterData_21500.txt',
#  'CharacterData_21600.txt',
#  'CharacterData_21700.txt',
#  'CharacterData_21800.txt',
#  'CharacterData_21900.txt',
#  'CharacterData_2200.txt',
#  'CharacterData_22000.txt',
#  'CharacterData_22100.txt',
#  'CharacterData_22200.txt',
#  'CharacterData_22300.txt',
#  'CharacterData_22400.txt',
#  'CharacterData_22500.txt',
#  'CharacterData_22600.txt',
#  'CharacterData_22700.txt',
#  'CharacterData_22800.txt',
#  'CharacterData_22900.txt',
#  'CharacterData_2300.txt',
#  'CharacterData_23000.txt',
#  'CharacterData_23100.txt',
#  'CharacterData_23200.txt',
#  'CharacterData_23300.txt',
#  'CharacterData_23500.txt',
#  'CharacterData_23600.txt',
#  'CharacterData_23700.txt',
#  'CharacterData_23800.txt',
#  'CharacterData_23900.txt',
#  'CharacterData_2400.txt',
#  'CharacterData_24000.txt',
#  'CharacterData_24100.txt',
#  'CharacterData_24200.txt',
#  'CharacterData_24300.txt',
#  'CharacterData_24400.txt',
#  'CharacterData_24700.txt',
#  'CharacterData_2500.txt',
#  'CharacterData_2600.txt',
#  'CharacterData_26700.txt',
#  'CharacterData_26800.txt',
#  'CharacterData_26900.txt',
#  'CharacterData_2700.txt',
#  'CharacterData_27600.txt',
#  'CharacterData_27700.txt',
#  'CharacterData_2800.txt',
#  'CharacterData_28200.txt',
#  'CharacterData_28400.txt',
#  'CharacterData_28500.txt',
#  'CharacterData_2900.txt',
#  'CharacterData_3000.txt',
#  'CharacterData_3100.txt',
#  'CharacterData_3200.txt',
#  'CharacterData_32800.txt',
#  'CharacterData_32900.txt',
#  'CharacterData_3300.txt',
#  'CharacterData_33000.txt',
#  'CharacterData_33400.txt',
#  'CharacterData_33500.txt',
#  'CharacterData_33600.txt',
#  'CharacterData_33700.txt',
#  'CharacterData_33800.txt',
#  'CharacterData_3400.txt',
#  'CharacterData_3500.txt',
#  'CharacterData_35200.txt',
#  'CharacterData_35800.txt',
#  'CharacterData_3600.txt',
#  'CharacterData_36200.txt',
#  'CharacterData_36300.txt',
#  'CharacterData_3700.txt',
#  'CharacterData_3800.txt',
#  'CharacterData_38600.txt',
#  'CharacterData_38700.txt',
#  'CharacterData_38800.txt',
#  'CharacterData_3900.txt',
#  'CharacterData_39000.txt',
#  'CharacterData_39700.txt',
#  'CharacterData_39800.txt',
#  'CharacterData_4000.txt',
#  'CharacterData_40400.txt',
#  'CharacterData_40500.txt',
#  'CharacterData_40600.txt',
#  'CharacterData_40700.txt',
#  'CharacterData_40800.txt',
#  'CharacterData_41000.txt',
#  'CharacterData_41100.txt',
#  'CharacterData_41200.txt',
#  'CharacterData_41300.txt',
#  'CharacterData_41400.txt',
#  'CharacterData_42100.txt',
#  'CharacterData_42400.txt',
#  'CharacterData_42500.txt',
#  'CharacterData_42900.txt',
#  'CharacterData_43000.txt',
#  'CharacterData_43700.txt',
#  'CharacterData_43800.txt',
#  'CharacterData_43900.txt',
#  'CharacterData_44100.txt',
#  'CharacterData_44200.txt',
#  'CharacterData_5900.txt',
#  'CharacterData_6000.txt',
#  'CharacterData_6200.txt',
#  'CharacterData_6300.txt',
#  'CharacterData_7100.txt',
#  'CharacterData_7500.txt',
#  'CharacterData_7600.txt',
#  'CharacterData_7700.txt',
#  'CharacterData_7800.txt',
#  'CharacterData_7900.txt',
#  'CharacterData_8000.txt',
#  'CharacterData_8100.txt',
#  'CharacterData_8200.txt',
#  'CharacterData_8300.txt',
#  'CharacterData_8400.txt',
#  'CharacterData_8500.txt',
#  'CharacterData_8600.txt',
#  'CharacterData_8700.txt',
#  'CharacterData_8800.txt',
#  'CharacterData_8900.txt',
#  'CharacterData_9000.txt',
#  'CharacterData_9300.txt',
#  'CharacterData_9400.txt',
#  'CharacterData_9500.txt',
#  'CharacterData_9600.txt',
#  'CharacterData_9700.txt',
#  'CharacterData_9800.txt',
#  'CharacterData_9900.txt',
#  '']

# %%
for xxx in character_data_files:
  file_name = os.path.join(server_dep, xxx)
  lines = get_lines(file_name)
  for idx, line in enumerate(lines):
    values = line.split('\t')
    if len(values) < 11:
      continue
    Service = values[0]
    ID = values[1]
    CodeName = values[2]
    ObjName = values[3]
    NameStrId = values[5]
    CashItem = values[7]
    Bionic = values[8]
    TypeId1 = values[9]
    TypeId2 = values[10]
    TypeId3 = values[11]
    TypeId4 = values[12]
    Country = values[14]
    Rarity = values[15]
    CanDrop = values[20]
    CanUSe = values[24]
    RequestLevelType1 = values[32]
    RequestLevel1 = values[33]
    RequestLevelType2 = values[34]
    RequestLevel2 = values[35]
    RequestLevelType3 = values[36]
    RequestLevel3 = values[37]
    RequestLevelType4 = values[38]
    RequestLevel4 = values[39]
    Speed1 = values[46]
    Speed2 = values[47]
    AssicFileIcon = values[54]

    Level = values[57]
    CharGender = values[58]
    MaxHealth = values[59]
    MaxMP = values[60]
    InventorySize = values[61]
    CanStore_TID1 = values[62]
    CanStore_TID2 = values[63]
    CanStore_TID3 = values[64]
    CanStore_TID4 = values[65]
    CanBeVehicle = values[66]
    CanControl = values[67]
    DamagePortion = values[68]
    MaxPassenger = values[69]

    IsDimensionPillar = NameStrId == "SN_MOB_GOD_PILLAR"
    IsSummonFlower = CodeName.startswith("STRUCTURE_SUMMON_FLOWER_")
    IsEventMob = CodeName.startswith("MOB_EV")
    IsPandora = TypeId2 == 2 and TypeId3 == 1 and TypeId4 == 5

    character_text_data[ID] = {
      "Service": Service,
      "ID": ID,
      "CodeName": CodeName,
      "ObjName": ObjName,
      "NameStrId": NameStrId,
      "CashItem": CashItem,
      "Bionic": Bionic,
      "TypeId1": TypeId1,
      "TypeId2": TypeId2,
      "TypeId3": TypeId3,
      "TypeId4": TypeId4,
      "Country": Country,
      "Rarity": Rarity,
      "CanDrop": CanDrop,
      "CanUSe": CanUSe,
      "RequestLevelType1": RequestLevelType1,
      "RequestLevel1": RequestLevel1,
      "RequestLevelType2": RequestLevelType2,
      "RequestLevel2": RequestLevel2,
      "RequestLevelType3": RequestLevelType3,
      "RequestLevel3": RequestLevel3,
      "RequestLevelType4": RequestLevelType4,
      "RequestLevel4": RequestLevel4,
      "Speed1": Speed1,
      "Speed2": Speed2,
      "AssicFileIcon": AssicFileIcon,
      "Level": Level,
      "CharGender": CharGender,
      "MaxHealth": MaxHealth,
      "MaxMP": MaxMP,
      "InventorySize": InventorySize,
      "CanStore_TID1": CanStore_TID1,
      "CanStore_TID2": CanStore_TID2,
      "CanStore_TID3": CanStore_TID3,
      "CanStore_TID4": CanStore_TID4,
      "CanBeVehicle": CanBeVehicle,
      "CanControl": CanControl,
      "DamagePortion": DamagePortion,
      "MaxPassenger": MaxPassenger,
      "IsDimensionPillar": IsDimensionPillar,
      "IsSummonFlower": IsSummonFlower,
      "IsEventMob": IsEventMob,
      "IsPandora": IsPandora
    }

# %%
character_text_data
# Out:
# {'9900': {'Service': '1',
#   'ID': '9900',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_059',
#   'ObjName': '???? lv 59',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '59',
#   'CharGender': '0',
#   'MaxHealth': '13245',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9901': {'Service': '1',
#   'ID': '9901',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_060',
#   'ObjName': '???? lv 60',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '60',
#   'CharGender': '0',
#   'MaxHealth': '13725',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9902': {'Service': '1',
#   'ID': '9902',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_061',
#   'ObjName': '???? lv 61',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '61',
#   'CharGender': '0',
#   'MaxHealth': '14218',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9903': {'Service': '1',
#   'ID': '9903',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_062',
#   'ObjName': '???? lv 62',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '62',
#   'CharGender': '0',
#   'MaxHealth': '14725',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9904': {'Service': '1',
#   'ID': '9904',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_063',
#   'ObjName': '???? lv 63',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '63',
#   'CharGender': '0',
#   'MaxHealth': '15247',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9905': {'Service': '1',
#   'ID': '9905',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_064',
#   'ObjName': '???? lv 64',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '64',
#   'CharGender': '0',
#   'MaxHealth': '15784',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9906': {'Service': '1',
#   'ID': '9906',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_065',
#   'ObjName': '???? lv 65',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '65',
#   'CharGender': '0',
#   'MaxHealth': '16337',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9907': {'Service': '1',
#   'ID': '9907',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_066',
#   'ObjName': '???? lv 66',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '66',
#   'CharGender': '0',
#   'MaxHealth': '16905',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9908': {'Service': '1',
#   'ID': '9908',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_067',
#   'ObjName': '???? lv 67',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '67',
#   'CharGender': '0',
#   'MaxHealth': '17490',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9909': {'Service': '1',
#   'ID': '9909',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_068',
#   'ObjName': '???? lv 68',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '68',
#   'CharGender': '0',
#   'MaxHealth': '18091',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9910': {'Service': '1',
#   'ID': '9910',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_069',
#   'ObjName': '???? lv 69',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '69',
#   'CharGender': '0',
#   'MaxHealth': '18709',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9911': {'Service': '1',
#   'ID': '9911',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_070',
#   'ObjName': '???? lv 70',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '70',
#   'CharGender': '0',
#   'MaxHealth': '19344',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9912': {'Service': '1',
#   'ID': '9912',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_071',
#   'ObjName': '???? lv 71',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '71',
#   'CharGender': '0',
#   'MaxHealth': '19998',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9913': {'Service': '1',
#   'ID': '9913',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_072',
#   'ObjName': '???? lv 72',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '72',
#   'CharGender': '0',
#   'MaxHealth': '20670',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9914': {'Service': '1',
#   'ID': '9914',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_073',
#   'ObjName': '???? lv 73',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '73',
#   'CharGender': '0',
#   'MaxHealth': '21361',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9915': {'Service': '1',
#   'ID': '9915',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_074',
#   'ObjName': '???? lv 74',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '74',
#   'CharGender': '0',
#   'MaxHealth': '22071',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9916': {'Service': '1',
#   'ID': '9916',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_075',
#   'ObjName': '???? lv 75',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '75',
#   'CharGender': '0',
#   'MaxHealth': '22801',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9917': {'Service': '1',
#   'ID': '9917',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_076',
#   'ObjName': '???? lv 76',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '76',
#   'CharGender': '0',
#   'MaxHealth': '23551',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9918': {'Service': '1',
#   'ID': '9918',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_077',
#   'ObjName': '???? lv 77',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '77',
#   'CharGender': '0',
#   'MaxHealth': '24322',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9919': {'Service': '1',
#   'ID': '9919',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_078',
#   'ObjName': '???? lv 78',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '78',
#   'CharGender': '0',
#   'MaxHealth': '25115',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9920': {'Service': '1',
#   'ID': '9920',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_079',
#   'ObjName': '???? lv 79',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '79',
#   'CharGender': '0',
#   'MaxHealth': '25930',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9921': {'Service': '1',
#   'ID': '9921',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_080',
#   'ObjName': '???? lv 80',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '80',
#   'CharGender': '0',
#   'MaxHealth': '26767',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9922': {'Service': '1',
#   'ID': '9922',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_081',
#   'ObjName': '???? lv 81',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '81',
#   'CharGender': '0',
#   'MaxHealth': '27627',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9923': {'Service': '1',
#   'ID': '9923',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_082',
#   'ObjName': '???? lv 82',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '82',
#   'CharGender': '0',
#   'MaxHealth': '28512',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9924': {'Service': '1',
#   'ID': '9924',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_083',
#   'ObjName': '???? lv 83',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '83',
#   'CharGender': '0',
#   'MaxHealth': '29420',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9925': {'Service': '1',
#   'ID': '9925',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_084',
#   'ObjName': '???? lv 84',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '84',
#   'CharGender': '0',
#   'MaxHealth': '30353',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9926': {'Service': '1',
#   'ID': '9926',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_085',
#   'ObjName': '???? lv 85',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '85',
#   'CharGender': '0',
#   'MaxHealth': '31312',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9927': {'Service': '1',
#   'ID': '9927',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_086',
#   'ObjName': '???? lv 86',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '86',
#   'CharGender': '0',
#   'MaxHealth': '32297',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9928': {'Service': '1',
#   'ID': '9928',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_087',
#   'ObjName': '???? lv 87',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '87',
#   'CharGender': '0',
#   'MaxHealth': '33309',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9929': {'Service': '1',
#   'ID': '9929',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_088',
#   'ObjName': '???? lv 88',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '88',
#   'CharGender': '0',
#   'MaxHealth': '34349',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9930': {'Service': '1',
#   'ID': '9930',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_089',
#   'ObjName': '???? lv 89',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '89',
#   'CharGender': '0',
#   'MaxHealth': '35417',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9931': {'Service': '1',
#   'ID': '9931',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_090',
#   'ObjName': '???? lv 90',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '90',
#   'CharGender': '0',
#   'MaxHealth': '36513',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9932': {'Service': '1',
#   'ID': '9932',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_091',
#   'ObjName': '???? lv 91',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '91',
#   'CharGender': '0',
#   'MaxHealth': '37640',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9933': {'Service': '1',
#   'ID': '9933',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_092',
#   'ObjName': '???? lv 92',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '92',
#   'CharGender': '0',
#   'MaxHealth': '38797',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9934': {'Service': '1',
#   'ID': '9934',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_093',
#   'ObjName': '???? lv 93',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '93',
#   'CharGender': '0',
#   'MaxHealth': '39985',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9935': {'Service': '1',
#   'ID': '9935',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_094',
#   'ObjName': '???? lv 94',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '94',
#   'CharGender': '0',
#   'MaxHealth': '41205',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9936': {'Service': '1',
#   'ID': '9936',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_095',
#   'ObjName': '???? lv 95',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '95',
#   'CharGender': '0',
#   'MaxHealth': '42458',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9937': {'Service': '1',
#   'ID': '9937',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_096',
#   'ObjName': '???? lv 96',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '96',
#   'CharGender': '0',
#   'MaxHealth': '43745',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9938': {'Service': '1',
#   'ID': '9938',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_097',
#   'ObjName': '???? lv 97',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '97',
#   'CharGender': '0',
#   'MaxHealth': '45066',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9939': {'Service': '1',
#   'ID': '9939',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_098',
#   'ObjName': '???? lv 98',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '98',
#   'CharGender': '0',
#   'MaxHealth': '46422',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9940': {'Service': '1',
#   'ID': '9940',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_099',
#   'ObjName': '???? lv 99',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '99',
#   'CharGender': '0',
#   'MaxHealth': '47815',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9941': {'Service': '1',
#   'ID': '9941',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_100',
#   'ObjName': '???? lv 100',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '100',
#   'CharGender': '0',
#   'MaxHealth': '49245',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9942': {'Service': '1',
#   'ID': '9942',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_101',
#   'ObjName': '???? lv 101',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '101',
#   'CharGender': '0',
#   'MaxHealth': '50713',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9943': {'Service': '1',
#   'ID': '9943',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_102',
#   'ObjName': '???? lv 102',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '102',
#   'CharGender': '0',
#   'MaxHealth': '52219',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9944': {'Service': '1',
#   'ID': '9944',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_103',
#   'ObjName': '???? lv 103',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '103',
#   'CharGender': '0',
#   'MaxHealth': '53766',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9945': {'Service': '1',
#   'ID': '9945',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_104',
#   'ObjName': '???? lv 104',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '104',
#   'CharGender': '0',
#   'MaxHealth': '55354',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '9946': {'Service': '1',
#   'ID': '9946',
#   'CodeName': 'COS_GUILD_CH_SOLDIER5_105',
#   'ObjName': '???? lv 105',
#   'NameStrId': 'SN_COS_GUILD_CH_SOLDIER5',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '3',
#   'TypeId4': '5',
#   'Country': '0',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '50',
#   'AssicFileIcon': 'cos\\guild_ch_soldier5_scroll.ddj',
#   'Level': '105',
# ...
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15352': {'Service': '1',
#   'ID': '15352',
#   'CodeName': 'MOB_EU_THIEF_NPC_0485',
#   'ObjName': '0485 ?? ????(??)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '58',
#   'AssicFileIcon': 'xxx',
#   'Level': '49',
#   'CharGender': '0',
#   'MaxHealth': '3557',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15353': {'Service': '1',
#   'ID': '15353',
#   'CodeName': 'MOB_EU_THIEF_NPC_0486',
#   'ObjName': '0486 ?? ????(??)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '62',
#   'AssicFileIcon': 'xxx',
#   'Level': '49',
#   'CharGender': '0',
#   'MaxHealth': '3557',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15354': {'Service': '1',
#   'ID': '15354',
#   'CodeName': 'MOB_EU_THIEF_NPC_0487',
#   'ObjName': '0487 ?? ????(???)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '62',
#   'AssicFileIcon': 'xxx',
#   'Level': '49',
#   'CharGender': '0',
#   'MaxHealth': '3557',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15355': {'Service': '1',
#   'ID': '15355',
#   'CodeName': 'MOB_EU_THIEF_NPC_0488',
#   'ObjName': '0488 ?? ????(???)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '62',
#   'AssicFileIcon': 'xxx',
#   'Level': '49',
#   'CharGender': '0',
#   'MaxHealth': '3557',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15356': {'Service': '1',
#   'ID': '15356',
#   'CodeName': 'MOB_EU_THIEF_NPC_0489',
#   'ObjName': '0489 ?? ????(????)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '62',
#   'AssicFileIcon': 'xxx',
#   'Level': '49',
#   'CharGender': '0',
#   'MaxHealth': '3557',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15357': {'Service': '1',
#   'ID': '15357',
#   'CodeName': 'MOB_EU_THIEF_NPC_0490',
#   'ObjName': '0490 ?? ????(??)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '62',
#   'AssicFileIcon': 'xxx',
#   'Level': '49',
#   'CharGender': '0',
#   'MaxHealth': '3557',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15358': {'Service': '1',
#   'ID': '15358',
#   'CodeName': 'MOB_EU_THIEF_NPC_0491',
#   'ObjName': '0491 ?? ????(???)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '67',
#   'AssicFileIcon': 'xxx',
#   'Level': '50',
#   'CharGender': '0',
#   'MaxHealth': '4237',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15359': {'Service': '1',
#   'ID': '15359',
#   'CodeName': 'MOB_EU_THIEF_NPC_0492',
#   'ObjName': '0492 ?? ????(???)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '67',
#   'AssicFileIcon': 'xxx',
#   'Level': '50',
#   'CharGender': '0',
#   'MaxHealth': '4237',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15360': {'Service': '1',
#   'ID': '15360',
#   'CodeName': 'MOB_EU_THIEF_NPC_0493',
#   'ObjName': '0493 ?? ????(????)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '67',
#   'AssicFileIcon': 'xxx',
#   'Level': '50',
#   'CharGender': '0',
#   'MaxHealth': '4237',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15361': {'Service': '1',
#   'ID': '15361',
#   'CodeName': 'MOB_EU_THIEF_NPC_0494',
#   'ObjName': '0494 ?? ????(??)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '75',
#   'AssicFileIcon': 'xxx',
#   'Level': '50',
#   'CharGender': '0',
#   'MaxHealth': '4237',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15362': {'Service': '1',
#   'ID': '15362',
#   'CodeName': 'MOB_EU_THIEF_NPC_0495',
#   'ObjName': '0495 ?? ????(??)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '58',
#   'AssicFileIcon': 'xxx',
#   'Level': '50',
#   'CharGender': '0',
#   'MaxHealth': '3701',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15363': {'Service': '1',
#   'ID': '15363',
#   'CodeName': 'MOB_EU_THIEF_NPC_0496',
#   'ObjName': '0496 ?? ????(??)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '63',
#   'AssicFileIcon': 'xxx',
#   'Level': '50',
#   'CharGender': '0',
#   'MaxHealth': '3701',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15364': {'Service': '1',
#   'ID': '15364',
#   'CodeName': 'MOB_EU_THIEF_NPC_0497',
#   'ObjName': '0497 ?? ????(???)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '63',
#   'AssicFileIcon': 'xxx',
#   'Level': '50',
#   'CharGender': '0',
#   'MaxHealth': '3701',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15365': {'Service': '1',
#   'ID': '15365',
#   'CodeName': 'MOB_EU_THIEF_NPC_0498',
#   'ObjName': '0498 ?? ????(???)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '63',
#   'AssicFileIcon': 'xxx',
#   'Level': '50',
#   'CharGender': '0',
#   'MaxHealth': '3701',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15366': {'Service': '1',
#   'ID': '15366',
#   'CodeName': 'MOB_EU_THIEF_NPC_0499',
#   'ObjName': '0499 ?? ????(????)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '63',
#   'AssicFileIcon': 'xxx',
#   'Level': '50',
#   'CharGender': '0',
#   'MaxHealth': '3701',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  '15367': {'Service': '1',
#   'ID': '15367',
#   'CodeName': 'MOB_EU_THIEF_NPC_0500',
#   'ObjName': '0500 ?? ????(??)',
#   'NameStrId': 'SN_MOB_THIEF_NPC',
#   'CashItem': '0',
#   'Bionic': '1',
#   'TypeId1': '1',
#   'TypeId2': '2',
#   'TypeId3': '1',
#   'TypeId4': '2',
#   'Country': '3',
#   'Rarity': '0',
#   'CanDrop': '0',
#   'CanUSe': '0',
#   'RequestLevelType1': '-1',
#   'RequestLevel1': '0',
#   'RequestLevelType2': '-1',
#   'RequestLevel2': '0',
#   'RequestLevelType3': '-1',
#   'RequestLevel3': '0',
#   'RequestLevelType4': '-1',
#   'RequestLevel4': '0',
#   'Speed1': '20',
#   'Speed2': '63',
#   'AssicFileIcon': 'xxx',
#   'Level': '50',
#   'CharGender': '0',
#   'MaxHealth': '3701',
#   'MaxMP': '0',
#   'InventorySize': '0',
#   'CanStore_TID1': '0',
#   'CanStore_TID2': '0',
#   'CanStore_TID3': '0',
#   'CanStore_TID4': '0',
#   'CanBeVehicle': '0',
#   'CanControl': '0',
#   'DamagePortion': '0',
#   'MaxPassenger': '0',
#   'IsDimensionPillar': False,
#   'IsSummonFlower': False,
#   'IsEventMob': False,
#   'IsPandora': False},
#  ...}
