# %%
import os
import io
import struct
from typing import List, Tuple, Optional
from enum import Enum
import pandas as pd

from blowfish import Blowfish

# %%
class PackEntryType(Enum):
  Nop = 0
  Folder = 1
  File = 2

# %%
def generate_final_blowfish_key(password: str, salt: bytes) -> bytes:
    """
    Reproduces the 'GenerateFinalBlowfishKey' logic in C#.
    """
    # 1) Limit key length to max of 56
    plain_key_length = min(len(password), 56)

    # 2) Convert password to ASCII bytes
    a_key = password.encode("ascii")

    # 3) Create a 56-byte base key buffer
    b_key = bytearray(56)
    
    # Copy salt into b_key
    # Equivalent to `Array.ConstrainedCopy(salt, 0, bKey, 0, salt.Length)`
    b_key[:len(salt)] = salt

    # 4) Generate the final blowfish key by XOR-ing
    #    the ASCII password bytes with the corresponding part of b_key.
    bf_key = bytearray(plain_key_length)
    for x in range(plain_key_length):
        bf_key[x] = a_key[x] ^ b_key[x]

    return bytes(bf_key)

# %%
def read_string_with_length(stream, byte_count: int) -> str:
    """
    Read 'byte_count' bytes, then decode using self._encoding,
    stopping at the first 0 (null terminator) if present.
    """
    buffer = stream.read(byte_count)

    # Find null terminator offset (if any)
    terminator_offset = byte_count
    for i in range(byte_count):
        if buffer[i] == 0:
            terminator_offset = i
            break

    return buffer[:terminator_offset].decode('ascii', errors='replace')

# %%
# data_pk2_path = os.path.join(os.getcwd(), 'data', 'Data.pk2')
media_pk2_path = os.path.join(os.getcwd(), 'data', 'Media.pk2')
# print(data_pk2_path)
print(media_pk2_path)
# Out:
# /Users/hodung/Desktop/Workspace/silkroad/pk2-extractor/LoadSkillData/data/Media.pk2

# %%
pk2key = '169841'
salt = [0x03, 0xF8, 0xE4, 0x44, 0x88, 0x99, 0x3F, 0x64, 0xFE, 0x35]

# %%
key = generate_final_blowfish_key(pk2key, bytes(salt))
key
# Out:
# b'2\xce\xdd|\xbc\xa8'

# %%
blowfish = Blowfish()
blowfish.Initialize(key)

# %%
_media_file_stream = open(media_pk2_path, 'rb')

# %%
signature = _media_file_stream.read(30)
version =  struct.unpack('<i', _media_file_stream.read(4))[0]
encrypted = _media_file_stream.read(1)
encryption_checksum = _media_file_stream.read(16)
payload = _media_file_stream.read(205)

# %%
Header = {
    'signature': signature,
    'version': version,
    'encrypted': encrypted,
    'encryption_checksum': encryption_checksum,
    'payload': payload
}

# %%
blowfish_checksum_decoded = "Joymax Pak File"

# %%
if blowfish and encrypted == b'\x01':
    temp_checksum = blowfish.Encode(blowfish_checksum_decoded.encode('ascii'))
    if temp_checksum is None or temp_checksum[0] != encryption_checksum[0] or temp_checksum[1] != encryption_checksum[1] or temp_checksum[2] != encryption_checksum[2]:
        raise Exception('Failed to open JoymaxPackFile: The password or salt is wrong.')

# %%
def read_block_at(position: int):
    _media_file_stream.seek(position, io.SEEK_SET)
    buffer = _media_file_stream.read(128 * 20)
    if blowfish is not None:
      entry_buffer = io.BytesIO(blowfish.Decode(buffer))
    else:
      entry_buffer = io.BytesIO(buffer)

    entries = []
    for _ in range(20):
      entry = {
        "Type": PackEntryType(entry_buffer.read(1)[0]),
        "Name": read_string_with_length(entry_buffer, 89).rstrip('\0'),
        "CreationTime": struct.unpack('<q', entry_buffer.read(8))[0],
        "ModifyTime": struct.unpack('<q', entry_buffer.read(8))[0],
        "DataPosition": struct.unpack('<q', entry_buffer.read(8))[0],
        "DataSize": struct.unpack('<i', entry_buffer.read(4))[0],
        "NextBlock": struct.unpack('<q', entry_buffer.read(8))[0],
        "Payload": entry_buffer.read(2)
      }
      entries.append(entry)
      # print(entry)

    return {
      "Position": position,
      "Entries": entries
    }


def read_blocks_at(position: int):
    result = []

    block = read_block_at(position)
    result.append(block)

    if block["Entries"][19]["NextBlock"] > 0:
        result.extend(read_blocks_at(block["Entries"][19]["NextBlock"]))

    return result

# %%
Root = read_blocks_at(256)

# %%
blocks_in_memory = {
  "": Root
}

# %%
blocks_in_memory
# Out:
# {'': [{'Position': 256,
#    'Entries': [{'Type': <PackEntryType.Folder: 1>,
#      'Name': '.',
#      'CreationTime': 133336205048819447,
#      'ModifyTime': 133336205048819447,
#      'DataPosition': 256,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'acobject',
#      'CreationTime': 133336205048829450,
#      'ModifyTime': 133336205048829450,
#      'DataPosition': 2816,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'config',
#      'CreationTime': 133336205049179438,
#      'ModifyTime': 133336205049179438,
#      'DataPosition': 35136,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Effect',
#      'CreationTime': 133336205049679437,
#      'ModifyTime': 133336205049679437,
#      'DataPosition': 41896,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Fonts',
#      'CreationTime': 133336205051829374,
#      'ModifyTime': 133336205051829374,
#      'DataPosition': 401456,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'icon',
#      'CreationTime': 133336205051849373,
#      'ModifyTime': 133336205051849373,
#      'DataPosition': 404328,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'icon64',
#      'CreationTime': 133336206109740779,
#      'ModifyTime': 133336206109740779,
#      'DataPosition': 35750058,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'interface',
#      'CreationTime': 133336206200969178,
#      'ModifyTime': 133336206200969178,
#      'DataPosition': 49794542,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Launcher',
#      'CreationTime': 133336207373584329,
#      'ModifyTime': 133336207373584329,
#      'DataPosition': 530412246,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'Launcher_Europe',
#      'CreationTime': 133336207379694215,
#      'ModifyTime': 133336207379694215,
#      'DataPosition': 533020067,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'minimap',
#      'CreationTime': 133336207380240850,
#      'ModifyTime': 133336207380240850,
#      'DataPosition': 533900707,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'minimap_d',
#      'CreationTime': 133336208820638962,
#      'ModifyTime': 133336208820638962,
#      'DataPosition': 770423083,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'resinfo',
#      'CreationTime': 133336209064184553,
#      'ModifyTime': 133336209064184553,
#      'DataPosition': 868076619,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'res_ui',
#      'CreationTime': 133336209080076171,
#      'ModifyTime': 133336209080076171,
#      'DataPosition': 870428615,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'script',
#      'CreationTime': 133336209089071935,
#      'ModifyTime': 133336209089071935,
#      'DataPosition': 877210479,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Folder: 1>,
#      'Name': 'server_dep',
#      'CreationTime': 133336209091748828,
#      'ModifyTime': 133336209091748828,
#      'DataPosition': 886879815,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'silk.dat',
#      'CreationTime': 133287856801795247,
#      'ModifyTime': 127918116330156250,
#      'DataPosition': 1017317431,
#      'DataSize': 768,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'type.txt',
#      'CreationTime': 133336205046882029,
#      'ModifyTime': 133330897532736718,
#      'DataPosition': 1017318199,
#      'DataSize': 423,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'DIVISIONINFO.TXT',
#      'CreationTime': 133336210349991177,
#      'ModifyTime': 133336210349991177,
#      'DataPosition': 1017319424,
#      'DataSize': 57,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.File: 2>,
#      'Name': 'SV.T',
#      'CreationTime': 133795823380867913,
#      'ModifyTime': 133795823380867913,
#      'DataPosition': 1017319481,
#      'DataSize': 1024,
#      'NextBlock': 1017320505,
#      'Payload': b'\x00\x00'}]},
#   {'Position': 1017320505,
#    'Entries': [{'Type': <PackEntryType.File: 2>,
#      'Name': 'GATEPORT.TXT',
#      'CreationTime': 133336210351001190,
#      'ModifyTime': 133336210351001190,
#      'DataPosition': 1017323065,
#      'DataSize': 8,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'},
#     {'Type': <PackEntryType.Nop: 0>,
#      'Name': '',
#      'CreationTime': 0,
#      'ModifyTime': 0,
#      'DataPosition': 0,
#      'DataSize': 0,
#      'NextBlock': 0,
#      'Payload': b'\x00\x00'}]}]}

# %%
def get_entry_buffer(file_path: str) -> Optional[dict]:
  parent_folder_path = os.path.dirname(file_path)
  file_name = os.path.basename(file_path)
  if parent_folder_path not in blocks_in_memory:
    paths = parent_folder_path.split(os.path.sep)
    blocks = blocks_in_memory[""]
    current_path = ""

    for sub_folder_name in paths:
        for block in blocks:
            entries = block["Entries"]
            entry = next((e for e in entries if e["Name"] == sub_folder_name and e["Type"] == PackEntryType.Folder), None)
            if entry is None:
                continue
            
            current_path = os.path.join(current_path, entry["Name"])
            if current_path in blocks_in_memory:
                blocks = blocks_in_memory[current_path]
                break
            
            blocks = read_blocks_at(entry["DataPosition"])
            blocks_in_memory[current_path] = blocks
            break
        
  root = blocks_in_memory[parent_folder_path]
  entry = None
  for entries in root:
    entry = next((x for x in entries["Entries"] if x["Name"] == file_name.lower()), None)
    if entry:
      break

  _media_file_stream.seek(entry["DataPosition"], io.SEEK_SET)
  # _media_file_stream.read(entry["DataSize"])
  buffer = io.BytesIO(_media_file_stream.read(entry["DataSize"])) 

  return buffer
   

def get_lines(file_path: str) -> List[Tuple[str, int]]:

  buffer = get_entry_buffer(file_path)

  text = buffer.read().decode('utf-16', errors="replace")
  lines = text.split('\r\n')
  return lines  

def convert_string(value):
    try:
        # First, try to convert to an integer
        return int(value)
    except ValueError:
        try:
            # If it fails, try to convert to a float
            return float(value)
        except ValueError:
            # If both conversions fail, return the original string
            return value

# %%
text_data_directory = os.path.join('server_dep', 'silkroad', 'textdata')
text_data_directory
# Out:
# 'server_dep/silkroad/textdata'

# %% [markdown]
# ## Load Text Data

# %% [markdown]
# ### SkillMasteryData.txt

# %%
skill_mastery_data_file = os.path.join(text_data_directory, 'SkillMasteryData.txt')
skill_mastery_data_file
# Out:
# 'server_dep/silkroad/textdata/SkillMasteryData.txt'

# %%
df_mastery_data= pd.DataFrame(columns=range(14))

lines = get_lines(skill_mastery_data_file)
for idx, line in enumerate(lines):
  values = line.split('\t')
  if len(values) < 14:
    continue
  df_mastery_data.loc[len(df_mastery_data)] = values

# %%
df_mastery_data
# Out:
#       0   1        2                            3   4   \
# 0      1  -1      캐릭터                          xxx   0
# 1      2  -1   상인마스터리                          xxx   0
# 2      3  -1   도적마스터리                          xxx   0
# 3      4  -1   헌터마스터리                          xxx   0
# 4    257  -1  비천검법101          UIIT_STT_MASTERY_VI  10
# 5    258  -1  흑살창법102        UIIT_STT_MASTERY_HEUK   9
# 6    259  -1  파천신궁103          UIIT_STT_MASTERY_PA  10
# 7    277   0  한빙면공111         UIIT_CTL_FORCE_SKILL   8
# 8    277   1  풍뢰비공112         UIIT_CTL_FORCE_SKILL   7
# 9    277   2  화령신공113         UIIT_CTL_FORCE_SKILL   8
# 10   276  -1  기혈대법114          UIIT_STT_MASTERY_GI  12
# 11   513  -1   워리어201             UIIT_STT_WARRIOR  12
# 12   515  -1    로그203                 UIIT_STT_ROG  13
# 13   514  -1   위저드202              UIIT_STT_WIZARD  10
# 14   516  -1    워락204             UIIT_STT_WARLOCK  13
# 15   517  -1    바드205                UIIT_STT_BARD  10
# 16   518  -1   클레릭206              UIIT_STT_CLERIC  14
# 17  1000  -1     직업스킬  UIIT_STT_CONFLICT_JOB_SKILL   4
#
#                                    5                              6    7  8   \
# 0                                 xxx                            xxx  255  2
# 1                                 xxx                            xxx  255  2
# 2                                 xxx                            xxx  255  2
# 3                                 xxx                            xxx  255  2
# 4     UIIT_STT_MASTERY_VI_EXPLANATION          UIIT_CTL_WEAPON_SKILL    0  0
# 5   UIIT_STT_MASTERY_HEUK_EXPLANATION          UIIT_CTL_WEAPON_SKILL    0  0
# 6     UIIT_STT_MASTERY_PA_EXPLANATION          UIIT_CTL_WEAPON_SKILL    0  0
# 7    UIIT_STT_MASTERY_HAN_EXPLANATION           UIIT_CTL_FORCE_SKILL    1  1
# 8   UIIT_STT_MASTERY_PUNG_EXPLANATION           UIIT_CTL_FORCE_SKILL    1  1
# 9    UIIT_STT_MASTERY_HWA_EXPLANATION           UIIT_CTL_FORCE_SKILL    1  1
# 10    UIIT_STT_MASTERY_GI_EXPLANATION            UIIT_CTL_CURE_SKILL    2  2
# 11           UIIT_STT_WARRIOR_TT_DESC  UIIT_CTL_EU_SKILLWND_PHYSICAL    0  3
# 12               UIIT_STT_ROG_TT_DESC  UIIT_CTL_EU_SKILLWND_PHYSICAL    0  3
# 13            UIIT_STT_WIZARD_TT_DESC   UIIT_CTL_EU_SKILLWND_MASICAL    1  3
# 14           UIIT_STT_WARLOCK_TT_DESC   UIIT_CTL_EU_SKILLWND_MASICAL    1  3
# 15              UIIT_STT_BARD_TT_DESC    UIIT_CTL_EU_SKILLWND_ASSIST    2  3
# 16            UIIT_STT_CLERIC_TT_DESC    UIIT_CTL_EU_SKILLWND_ASSIST    2  3
# 17   UIIT_STT_CONFLICT_JOB_SKILL_DESC          UIIT_STT_CONFLICT_JOB    0  3
#
#     9   10 11                                          12  \
# 0    0   0  0                                         xxx
# 1    0   0  0                                         xxx
# 2    0   0  0                                         xxx
# 3    0   0  0                                         xxx
# 4    2   3  0   icon\skillmastery\china\mastery_sword.ddj
# 5    4   5  0   icon\skillmastery\china\mastery_spear.ddj
# 6    6   0  0     icon\skillmastery\china\mastery_bow.ddj
# 7    0   0  0  icon\skillmastery\china\mastery_gigong.ddj
# 8    0   0  0  icon\skillmastery\china\mastery_gigong.ddj
# 9    0   0  0  icon\skillmastery\china\mastery_gigong.ddj
# 10   0   0  0   icon\skillmastery\china\mastery_water.ddj
# 11   7   8  9     icon\skillmastery\europe\eu_warrior.ddj
# 12  11  12  0         icon\skillmastery\europe\eu_rog.ddj
# 13  11   0  0      icon\skillmastery\europe\eu_wizard.ddj
# 14  10   0  0     icon\skillmastery\europe\eu_warlock.ddj
# 15  14   0  0        icon\skillmastery\europe\eu_bard.ddj
# 16  10   0  0      icon\skillmastery\europe\eu_cleric.ddj
# 17   0   0  0      icon\skillmastery\europe\eu_wizard.ddj
#
#                                                   13
# 0                                                xxx
# 1                                                xxx
# 2                                                xxx
# 3                                                xxx
# 4    icon\skillmastery\china\mastery_sword_focus.ddj
# 5    icon\skillmastery\china\mastery_spear_focus.ddj
# 6      icon\skillmastery\china\mastery_bow_focus.ddj
# 7   icon\skillmastery\china\mastery_gigong_focus.ddj
# 8   icon\skillmastery\china\mastery_gigong_focus.ddj
# 9   icon\skillmastery\china\mastery_gigong_focus.ddj
# 10   icon\skillmastery\china\mastery_water_focus.ddj
# 11     icon\skillmastery\europe\eu_warrior_focus.ddj
# 12         icon\skillmastery\europe\eu_rog_focus.ddj
# 13      icon\skillmastery\europe\eu_wizard_focus.ddj
# 14     icon\skillmastery\europe\eu_warlock_focus.ddj
# 15        icon\skillmastery\europe\eu_bard_focus.ddj
# 16      icon\skillmastery\europe\eu_cleric_focus.ddj
# 17      icon\skillmastery\europe\eu_wizard_focus.ddj
